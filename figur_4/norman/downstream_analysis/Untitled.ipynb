# %%
import pandas as pd

# %%
df = pd.read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/norman_2/results/allocation/norman_results_all.csv")

# %%
df = df[df["subgroup"]=="double_seen_2"]

# %%
df.shape
# Out:
# (474, 23)

# %%
df[df["model"]=="cellflow"]
# Out:
#      Unnamed: 0       subgroup       condition  encoded_ood_r_squared  \
# 321        1723  double_seen_2      CEBPE+CNN1               0.513077
# 322        1724  double_seen_2      CNN1+MAPK1              -0.222226
# 323        1725  double_seen_2      ETS2+CEBPE               0.947064
# 324        1726  double_seen_2       ETS2+CNN1              -1.483088
# 325        1727  double_seen_2      ETS2+MAPK1               0.833988
# ...         ...            ...             ...                    ...
# 2186       2175  double_seen_2      MAPK1+PRTG               0.465566
# 2187       2176  double_seen_2    POU3F2+FOXL2               0.904246
# 2188       2177  double_seen_2    UBASH3B+OSR2               0.750369
# 2189       2178  double_seen_2  ZC3HAV1+HOXC13              -0.048162
# 2190       2179  double_seen_2    ZNF318+FOXL2               0.616148
#
#       encoded_ood_sinkhorn_div_1  encoded_ood_sinkhorn_div_10  \
# 321                    12.411013                     5.862267
# 322                    14.838248                     8.552464
# 323                    12.201508                     6.080887
# 324                    10.655437                     5.470594
# 325                    14.258225                     8.659798
# ...                          ...                          ...
# 2186                    7.953072                     2.619587
# 2187                   12.767378                     5.825722
# 2188                    7.470798                     2.955349
# 2189                   11.149944                     5.786953
# 2190                   10.349024                     4.103716
#
#       encoded_ood_sinkhorn_div_100  encoded_ood_e_distance  encoded_ood_mmd  \
# 321                       2.407028                4.199890         0.012603
# 322                       5.276764               10.073715         0.022171
# 323                       2.525063                3.104020         0.012278
# 324                       2.530704                4.463629         0.011202
# 325                       5.246227                9.834080         0.024127
# ...                            ...                     ...              ...
# 2186                      0.736546                1.252300         0.005320
# 2187                      1.817406                2.869626         0.009492
# 2188                      0.967777                1.633347         0.006199
# 2189                      2.365784                3.623307         0.011512
# 2190                      1.035351                1.404807         0.007613
#
#       decoded_ood_r_squared  ...  deg_ood_sinkhorn_div_1  \
# 321                0.991670  ...               10.333342
# 322                0.989285  ...               13.842778
# 323                0.992701  ...               14.149956
# 324                0.991645  ...               12.727690
# 325                0.987806  ...               17.719292
# ...                     ...  ...                     ...
# 2186               0.996349  ...                9.556091
# 2187               0.991037  ...               16.662399
# 2188               0.995663  ...                9.006811
# 2189               0.991090  ...               15.003050
# 2190               0.995321  ...                4.838305
#
#       deg_ood_sinkhorn_div_10  deg_ood_sinkhorn_div_100  deg_ood_e_distance  \
# 321                  3.616978                  2.765791            5.434803
# 322                  4.395050                  3.279337            6.454282
# 323                  3.677299                  2.011751            3.747948
# 324                  3.119314                  2.273312            4.448897
# 325                  6.543118                  4.706961            9.122637
# ...                       ...                       ...                 ...
# 2186                 1.287092                  0.836338            1.616965
# 2187                 4.683765                  2.184792            4.120574
# 2188                 2.673918                  2.281513            4.514956
# 2189                 5.050005                  3.761751            7.365075
# 2190                 1.147689                  0.858913            1.682811
#
#       deg_ood_mmd  seed     model  decoded_ood_sinkhorn_div_1  \
# 321      0.049359   1.0  cellflow                         NaN
# 322      0.060098   1.0  cellflow                         NaN
# 323      0.033925   1.0  cellflow                         NaN
# 324      0.046523   1.0  cellflow                         NaN
# 325      0.080103   1.0  cellflow                         NaN
# ...           ...   ...       ...                         ...
# 2186     0.047969   5.0  cellflow                         NaN
# 2187     0.043931   5.0  cellflow                         NaN
# 2188     0.083487   5.0  cellflow                         NaN
# 2189     0.055470   5.0  cellflow                         NaN
# 2190     0.034626   5.0  cellflow                         NaN
#
#       decoded_ood_sinkhorn_div_10 decoded_ood_sinkhorn_div_100
# 321                           NaN                          NaN
# 322                           NaN                          NaN
# 323                           NaN                          NaN
# 324                           NaN                          NaN
# 325                           NaN                          NaN
# ...                           ...                          ...
# 2186                          NaN                          NaN
# 2187                          NaN                          NaN
# 2188                          NaN                          NaN
# 2189                          NaN                          NaN
# 2190                          NaN                          NaN
#
# [64 rows x 23 columns]

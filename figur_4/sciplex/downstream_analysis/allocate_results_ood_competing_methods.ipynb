# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
chemcpa_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/chemcpa"
biolord_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/biolord"
id_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/identity"
condot_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/condot"
cl_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/closest_embedding"
otfm_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/otfm/pca_mean_pooling"

# %%
model_dirs = {"id": id_dir, "biolord": biolord_dir, "otfm": otfm_dir, "condot": condot_dir, "chemCPA": chemcpa_dir, "cl": cl_dir}

# %%
splits = [5]

# %%
df_id = pd.read_csv(os.path.join(id_dir, "ood_metrics_encoded_5.csv"), index_col=0)
df_cl = pd.read_csv(os.path.join(cl_dir, "ood_metrics_encoded_5.csv"), index_col=0)

# %%
df_id
# Out:
#                   A549_Alvespimycin_(17-DMAG)_HCl_10.0  \
# r_squared                                     0.991957
# sinkhorn_div_1                                2.307025
# sinkhorn_div_10                               0.227769
# sinkhorn_div_100                              0.168244
# e_distance                                    0.327692
# mmd                                           0.006430
#
#                   A549_Alvespimycin_(17-DMAG)_HCl_100.0  \
# r_squared                                      0.927052
# sinkhorn_div_1                                 4.128780
# sinkhorn_div_10                                1.803228
# sinkhorn_div_100                               1.707416
# e_distance                                     3.400646
# mmd                                            0.031141
#
#                   A549_Belinostat_(PXD101)_10.0  \
# r_squared                              0.989759
# sinkhorn_div_1                         2.716664
# sinkhorn_div_10                        0.303897
# sinkhorn_div_100                       0.220857
# e_distance                             0.430965
# mmd                                    0.007781
#
#                   A549_Belinostat_(PXD101)_100.0  \
# r_squared                               0.981975
# sinkhorn_div_1                          2.714895
# sinkhorn_div_10                         0.463155
# sinkhorn_div_100                        0.375640
# e_distance                              0.738167
# mmd                                     0.009462
#
#                   A549_Belinostat_(PXD101)_1000.0  \
# r_squared                                0.866370
# sinkhorn_div_1                           5.193576
# sinkhorn_div_10                          3.033432
# sinkhorn_div_100                         2.922339
# e_distance                               5.823819
# mmd                                      0.046849
#
#                   A549_Dacinostat_(LAQ824)_10.0  \
# r_squared                              0.869501
# sinkhorn_div_1                         5.085152
# sinkhorn_div_10                        2.769406
# sinkhorn_div_100                       2.631795
# e_distance                             5.238036
# mmd                                    0.041040
#
#                   A549_Dacinostat_(LAQ824)_100.0  \
# r_squared                               0.427423
# sinkhorn_div_1                         11.299255
# sinkhorn_div_10                         8.616455
# sinkhorn_div_100                        8.283750
# e_distance                             16.503496
# mmd                                     0.101762
#
#                   A549_Dacinostat_(LAQ824)_1000.0  A549_Flavopiridol_HCl_10.0  \
# r_squared                               -0.603800                    0.977870
# sinkhorn_div_1                          27.051903                    2.573650
# sinkhorn_div_10                         24.241169                    0.543386
# sinkhorn_div_100                        23.847782                    0.473164
# e_distance                              47.621104                    0.935901
# mmd                                      0.229107                    0.011590
#
#                   A549_Flavopiridol_HCl_100.0  ...  \
# r_squared                            0.728241  ...
# sinkhorn_div_1                       6.816446  ...
# sinkhorn_div_10                      4.491053  ...
# sinkhorn_div_100                     4.287161  ...
# e_distance                           8.531695  ...
# mmd                                  0.056519  ...
#
#                   MCF7_Quisinostat_(JNJ-26481585)_2HCl_100.0  \
# r_squared                                          -0.016266
# sinkhorn_div_1                                     23.613262
# sinkhorn_div_10                                    21.203529
# sinkhorn_div_100                                   20.873260
# e_distance                                         41.676289
# mmd                                                 0.213791
#
#                   MCF7_Quisinostat_(JNJ-26481585)_2HCl_1000.0  \
# r_squared                                           -0.048846
# sinkhorn_div_1                                      31.708105
# sinkhorn_div_10                                     29.338650
# sinkhorn_div_100                                    28.999487
# e_distance                                          57.928829
# mmd                                                  0.263644
#
#                   MCF7_Quisinostat_(JNJ-26481585)_2HCl_10000.0  \
# r_squared                                            -0.072117
# sinkhorn_div_1                                       33.317558
# sinkhorn_div_10                                      30.801771
# sinkhorn_div_100                                     30.398010
# e_distance                                           60.710620
# mmd                                                   0.268079
#
#                   MCF7_TAK-901_10.0  MCF7_TAK-901_100.0  MCF7_TAK-901_1000.0  \
# r_squared                  0.958611            0.953261             0.912535
# sinkhorn_div_1             1.860462            1.795921             2.333364
# sinkhorn_div_10            0.298410            0.319118             0.582773
# sinkhorn_div_100           0.252384            0.282484             0.510885
# e_distance                 0.498419            0.560711             1.012994
# mmd                        0.007557            0.008315             0.013167
#
#                   MCF7_Tanespimycin_(17-AAG)_10.0  \
# r_squared                                0.972290
# sinkhorn_div_1                           1.623790
# sinkhorn_div_10                          0.199063
# sinkhorn_div_100                         0.165966
# e_distance                               0.327969
# mmd                                      0.005725
#
#                   MCF7_Tanespimycin_(17-AAG)_100.0  \
# r_squared                                 0.779775
# sinkhorn_div_1                            3.031616
# sinkhorn_div_10                           1.414109
# sinkhorn_div_100                          1.329693
# e_distance                                2.644340
# mmd                                       0.029571
#
#                   MCF7_Tanespimycin_(17-AAG)_1000.0  \
# r_squared                                  0.690923
# sinkhorn_div_1                             3.635315
# sinkhorn_div_10                            1.917632
# sinkhorn_div_100                           1.816133
# e_distance                                 3.614822
# mmd                                        0.038917
#
#                   MCF7_Tanespimycin_(17-AAG)_10000.0
# r_squared                                   0.662353
# sinkhorn_div_1                              3.704210
# sinkhorn_div_10                             2.069400
# sinkhorn_div_100                            1.980951
# e_distance                                  3.945865
# mmd                                         0.043850
#
# [6 rows x 83 columns]

# %%
df_cl
# Out:
#             A549_Alvespimycin_(17-DMAG)_HCl_10.0  \
# r_squared                              -0.081489
# e_distance                             44.060265
# mmd                                     0.142243
#
#             A549_Alvespimycin_(17-DMAG)_HCl_100.0  \
# r_squared                               -0.078285
# e_distance                              50.267020
# mmd                                      0.161163
#
#             A549_Belinostat_(PXD101)_10.0  A549_Belinostat_(PXD101)_100.0  \
# r_squared                       -0.087396                       -0.089256
# e_distance                      45.758003                       44.606530
# mmd                              0.136622                        0.137607
#
#             A549_Belinostat_(PXD101)_1000.0  A549_Dacinostat_(LAQ824)_10.0  \
# r_squared                         -0.069852                      -0.072992
# e_distance                        46.625748                      43.068375
# mmd                                0.157021                       0.147192
#
#             A549_Dacinostat_(LAQ824)_100.0  A549_Dacinostat_(LAQ824)_1000.0  \
# r_squared                        -0.013817                         0.056684
# e_distance                       29.221443                        28.009567
# mmd                               0.130940                         0.160808
#
#             A549_Flavopiridol_HCl_10.0  A549_Flavopiridol_HCl_100.0  ...  \
# r_squared                    -0.078547                    -0.058458  ...
# e_distance                   45.612810                    33.229560  ...
# mmd                           0.147837                     0.131581  ...
#
#             MCF7_Quisinostat_(JNJ-26481585)_2HCl_100.0  \
# r_squared                                     0.137595
# e_distance                                   35.366570
# mmd                                           0.155750
#
#             MCF7_Quisinostat_(JNJ-26481585)_2HCl_1000.0  \
# r_squared                                      0.108522
# e_distance                                    49.237236
# mmd                                            0.192898
#
#             MCF7_Quisinostat_(JNJ-26481585)_2HCl_10000.0  MCF7_TAK-901_10.0  \
# r_squared                                       0.098885           0.223588
# e_distance                                     51.027320           9.349739
# mmd                                             0.195410           0.039076
#
#             MCF7_TAK-901_100.0  MCF7_TAK-901_1000.0  \
# r_squared             0.231106             0.236402
# e_distance            9.224094             8.843742
# mmd                   0.040463             0.041804
#
#             MCF7_Tanespimycin_(17-AAG)_10.0  MCF7_Tanespimycin_(17-AAG)_100.0  \
# r_squared                          0.235740                          0.234715
# e_distance                         9.045578                          9.189110
# mmd                                0.039931                          0.053745
#
#             MCF7_Tanespimycin_(17-AAG)_1000.0  \
# r_squared                            0.230739
# e_distance                           8.996941
# mmd                                  0.056998
#
#             MCF7_Tanespimycin_(17-AAG)_10000.0
# r_squared                             0.223331
# e_distance                            9.076450
# mmd                                   0.062735
#
# [3 rows x 83 columns]

# %% [markdown]
# # Decoded

# %%
all_dfs = []
for split in splits:
    dfs = {}
    for model, model_dir in model_dirs.items():
        if model == "otfm":
            metrics_file = f"ood_metrics_decoded_{split+5}.csv" # because we take 100-dim PCA space for CellFlow
        else:
            metrics_file = f"ood_metrics_decoded_{split}.csv"
        dfs[model] = pd.read_csv(os.path.join(model_dir, metrics_file), index_col=0)
        #dfs[model].loc["sinkhorn_div"] = dfs[model].loc[["sinkhorn_div_1", "sinkhorn_div_10", "sinkhorn_div_100"]].mean(axis=0)
        if "sinkhorn_div_1" in dfs[model].index:
            dfs[model] = dfs[model].drop(["sinkhorn_div_1", "sinkhorn_div_10", "sinkhorn_div_100"])
        if "mmd_distance" in dfs[model].index:
            dfs[model] = dfs[model].drop(["mmd_distance"])
        if "mmd" in dfs[model].index:
            dfs[model] = dfs[model].drop(["mmd"])
        if "e_distance" in dfs[model].index:
            dfs[model] = dfs[model].drop(["e_distance"])
        dfs[model]["model"] = model
    result_df = pd.concat(dfs.values(), ignore_index=False)
    result_df["metric"] = result_df.index
    metrics = result_df["metric"].unique()
    df2 = pd.melt(result_df, id_vars=["model", "metric"])
    df2["split"] = split
    all_dfs.append(df2)

# %%
df_ood_metrics_decoded = pd.concat(all_dfs)

# %%
df_ood_metrics_decoded.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/allocation/ood_metrics_decoded.csv")

# %%
all_dfs = []
for split in splits:
    dfs = {}
    for model, model_dir in model_dirs.items():
        if model == "otfm": 
            metrics_file = f"ood_metrics_encoded_{split+5}.csv" # because we take 100-dim PCA space for CellFlow
        else:
            metrics_file = f"ood_metrics_encoded_{split}.csv"
        
        dfs[model] = pd.read_csv(os.path.join(model_dir, metrics_file), index_col=0)
        if "sinkhorn_div_1" in dfs[model].index:
            dfs[model] = dfs[model].drop(["sinkhorn_div_1", "sinkhorn_div_10", "sinkhorn_div_100"])
        dfs[model]["model"] = model
    result_df = pd.concat(dfs.values(), ignore_index=False)
    result_df["metric"] = result_df.index
    metrics = result_df["metric"].unique()
    df2 = pd.melt(result_df, id_vars=["model", "metric"])
    df2["split"] = split
    all_dfs.append(df2)

# %%
df_ood_metrics_encoded = pd.concat(all_dfs)

# %%
df_ood_metrics_encoded["metric"].value_counts()
# Out:
# metric
# r_squared     498
# e_distance    498
# mmd           498
# Name: count, dtype: int64

# %%
df_ood_metrics_encoded.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/allocation/ood_metrics_encoded.csv")

# %%
all_dfs = []
for split in splits:
    dfs = {}
    for model, model_dir in model_dirs.items():
        if model == "otfm": 
            metrics_file = f"ood_metrics_encoded_{split+5}.csv" # because we take 100-dim PCA space for CellFlow
        else:
            metrics_file = f"ood_metrics_encoded_{split}.csv"
        dfs[model] = pd.read_csv(os.path.join(model_dir, metrics_file), index_col=0)
        if "sinkhorn_div_1" in dfs[model].index:
            dfs[model] = dfs[model].drop(["sinkhorn_div_1", "sinkhorn_div_10", "sinkhorn_div_100"])
        dfs[model]["model"] = model
    result_df = pd.concat(dfs.values(), ignore_index=False)
    result_df["metric"] = result_df.index
    metrics = result_df["metric"].unique()
    df2 = pd.melt(result_df, id_vars=["model", "metric"])
    df2["split"] = split
    all_dfs.append(df2)

# %%
df_ood_metrics_deg = pd.concat(all_dfs)

# %%
df_ood_metrics_deg.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/allocation/ood_metrics_deg.csv")

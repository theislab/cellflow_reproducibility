# %%
library(tidyverse)
library(glue)
library(dplyr)

install.packages("showtext")
install.packages("extrafont")
library(extrafont)
font_import()


theme_rangeframe <- function(size = 0.3) {
    theme(
        axis.line = element_line(colour = "black", lineend = "round", size = size),
        axis.ticks = element_line(linewidth = size),
        panel.border = element_blank()
    )
}

scale_axis_rangeframe <- function() {
    guides(x = "axis_truncated", y = "axis_truncated")
}

rotate_x_text <- function(angle=45) {
    theme(
        axis.text.x = element_text(angle = angle, hjust = 1)
    )
}

article_text <- function() {
    theme(
        text = element_text(size = 5, family = "Helvetica"),
        title = element_text(size = 6),
        axis.text.x = element_text(size = 5),
        axis.text.y = element_text(size = 5)
    )
}

no_legend <- function() {
    theme(
        legend.position = "none"
    )
}

no_margin <- function() {
    theme(
        plot.margin = margin(0, 0, 0, 0, unit = "lines")
    )
}

no_label <- function() {
    theme(
        axis.title = element_blank()
    )
}

no_text <- function() {
    theme(
        axis.title = element_blank(),
        axis.text = element_blank(),
        axis.ticks = element_blank()
    )
}

no_x_text <- function() {
    theme(
        axis.text.x = element_blank(),
        axis.ticks.x = element_blank()
    )
}

no_y_text <- function() {
    theme(
        axis.text.y = element_blank(),
        axis.ticks.y = element_blank()
    )
}


custom_theme <- function(size = 0.3){
    theme_minimal() +
    theme(
        text = element_text(family='Helvetica'),
        axis.line = element_line(colour = "black", lineend = "round", size = size),
        axis.ticks = element_line(linewidth = size),
        panel.border = element_blank()
    )

}
theme_set(custom_theme())

article_text <- function() {
    theme(
        text = element_text(size = 5, family = "Helvetica"),
        title = element_text(size = 6),
        axis.text.x = element_text(size = 5),
        axis.text.y = element_text(size = 5)
    )
}
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.2.3”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# also installing the dependencies ‘sysfonts’, ‘showtextdb’
#
#
# Warning message in install.packages("showtext"):
# “installation of package ‘sysfonts’ had non-zero exit status”
# Warning message in install.packages("showtext"):
# “installation of package ‘showtextdb’ had non-zero exit status”
# Warning message in install.packages("showtext"):
# “installation of package ‘showtext’ had non-zero exit status”
# Registering fonts with R
# Importing fonts may take a few minutes, depending on the number of fonts and the speed of the system.
# Continue? [y/n]  y
# Scanning ttf files in /usr/share/fonts/ ...
#
# Extracting .afm files from .ttf files...
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSans-Bold.ttf
#  : DejaVuSans-Bold already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSans-BoldOblique.ttf
#  : DejaVuSans-BoldOblique already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSans-ExtraLight.ttf
#  : DejaVuSans-ExtraLight already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSans-Oblique.ttf
#  : DejaVuSans-Oblique already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSans.ttf
#  : DejaVuSans already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSansCondensed-Bold.ttf
#  : DejaVuSansCondensed-Bold already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSansCondensed-BoldOblique.ttf
#  : DejaVuSansCondensed-BoldOblique already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSansCondensed-Oblique.ttf
#  : DejaVuSansCondensed-Oblique already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-fonts/DejaVuSansCondensed.ttf
#  : DejaVuSansCondensed already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-mono-fonts/DejaVuSansMono-Bold.ttf
#  : DejaVuSansMono-Bold already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-mono-fonts/DejaVuSansMono-BoldOblique.ttf
#  : DejaVuSansMono-BoldOblique already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-mono-fonts/DejaVuSansMono-Oblique.ttf
#  : DejaVuSansMono-Oblique already registered in fonts database. Skipping.
#
# /usr/share/fonts/dejavu-sans-mono-fonts/DejaVuSansMono.ttf
#  : DejaVuSansMono already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidKufi-Bold.ttf
#  : DroidArabicKufi-Bold already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidKufi-Regular.ttf
#  : DroidArabicKufi already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSans-Bold.ttf
#  : DroidSans-Bold already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSans.ttf
#  : DroidSans already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansArmenian.ttf
#  : DroidSansArmenian already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansDevanagari-Regular.ttf
#  : DroidSansDevanagari already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansEthiopic-Bold.ttf
#  : DroidSansEthiopic-Bold already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansEthiopic-Regular.ttf
#  : DroidSansEthiopic already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansFallbackFull.ttf
#  : DroidSansFallback already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansGeorgian.ttf
#  : DroidSansGeorgian already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansHebrew-Bold.ttf
#  : DroidSansHebrew-Bold already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansHebrew-Regular.ttf
#  : DroidSansHebrew already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansJapanese.ttf
# Warning message in system2(enc2native(ttf2pt1), c(args, shQuote(ttfiles[i]), shQuote(tmpfiles[i])), :
# “running command ''/ictstr01/home/icb/dominik.klein/mambaforge/envs/gene-regulatory-networks-atac/lib/R/library/Rttf2pt1/exec//ttf2pt1' -a -GfAe '/usr/share/fonts/google-droid-sans-fonts/DroidSansJapanese.ttf' '/tmp/RtmpsxtgMk/fonts/DroidSansJapanese' 2>&1' had status 1”
#  : No FontName. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansTamil-Bold.ttf
#  : DroidSansTamil-Bold already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansTamil-Regular.ttf
#  : DroidSansTamil already registered in fonts database. Skipping.
#
# /usr/share/fonts/google-droid-sans-fonts/DroidSansThai.ttf
#  : DroidSansThai already registered in fonts database. Skipping.
#
# Found FontName for 0 fonts.
#
# Scanning afm files in /ictstr01/home/icb/dominik.klein/mambaforge/envs/gene-regulatory-networks-atac/lib/R/library/extrafontdb/metrics
#
# Warning message:
# “The `size` argument of `element_line()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”

# %%
output_dir <- "/lustre/groups/ml01/workspace/ot_perturbation/figures/zebrafish/cell_type_proportion_changes"

# %%
data_dir <- "/lustre/groups/ml01/workspace/cell_flow_zebrafish/results/single_condition/cell_type_proportion_downstream"

# %%
df1
# Out:
#     ...1 index                                                 ratio_oligo
# 1    0   periderm                                              0.9998768
# 2    1   mature fast muscle                                    0.9252921
# 3    2   basal cell                                            1.2345588
# 4    3   connective tissue-meninges-dermal FB                  1.3118586
# 5    4   neurons (gabaergic, glutamatergic)                    0.9000647
# 6    5   neurons (differentiating, contains peripheral)        1.0586808
# 7    6   fin fold                                              1.4390701
# 8    7   retinal neuron                                        0.6464881
# 9    8   neurons (gabaergic, glutamatergic; contains Purkinje) 0.8624285
# 10   9   hatching gland                                        1.2708031
# 11  10   neural tube-like connective tissue (+ taste bud)      1.6801624
# 12  11   head mesenchyme (maybe ventral, hand2+)               1.0085823
# 13  12   pharyngeal arch (early)                               0.8340581
# 14  13   notochord                                             1.1814050
# 15  14   pharyngeal arch (contains muscle, early cartilage)    0.9831214
# 16  15   mature slow muscle                                    0.8334360
# 17  16   endothelium (dorsal aorta)                            0.9583518
# 18  17   neural progenitor (diencephalon/telencephalon)        0.8623780
# 19  18   support cells/otic vesicle                            1.3979555
# 20  19   head mesenchyme                                       0.7927164
# 21  20   endothelium (vein + early artery)                     1.1411661
# 22  21   anterior migratory muscle                             0.7699135
# 23  22   retinal pigmented epithelium (early)                  1.1714404
# 24  23   cranial muscle (non-somitic, fast-twitch)             1.1917441
# 25  24   intestine                                             0.7578945
# 26  25   ionocyte/goblet cell                                  1.0508438
# 27  26   cranial muscle (early)                                1.0205324
# 28  27   neuron (cranial ganglion, enteric)                    1.0284867
# 29  28   glia                                                  1.3631699
# 30  29   eye, optic cup                                        0.6536819
# ⋮   ⋮    ⋮                                                     ⋮
# 716 715  71                                                    NA
# 717 716  72                                                    NA
# 718 717  73                                                    NA
# 719 718  74                                                    NA
# 720 719  75                                                    NA
# 721 720  76                                                    NA
# 722 721  77                                                    NA
# 723 722  78                                                    NA
# 724 723  79                                                    NA
# 725 724  80                                                    NA
# 726 725  81                                                    NA
# 727 726  82                                                    NA
# 728 727  83                                                    NA
# 729 728  84                                                    NA
# 730 729  85                                                    NA
# 731 730  86                                                    NA
# 732 731  87                                                    NA
# 733 732  88                                                    NA
# 734 733  89                                                    NA
# 735 734  90                                                    NA
# 736 735  91                                                    NA
# 737 736  92                                                    NA
# 738 737  93                                                    NA
# 739 738  94                                                    NA
# 740 739  95                                                    NA
# 741 740  96                                                    NA
# 742 741  97                                                    NA
# 743 742  98                                                    NA
# 744 743  99                                                    NA
# 745 744  100                                                   NA
#     ratio_true  logratio_true logratio_pred Oligo              timepoint
# 1   0.9252300   -0.112116010  -0.0001777195 48h_met-mut_P10_B1 48
# 2   0.9657993   -0.050204720  -0.1120192036 48h_met-mut_P10_B1 48
# 3   1.2382991    0.308359790   0.3039955604 48h_met-mut_P10_B1 48
# 4   1.1404693    0.189627615   0.3916122231 48h_met-mut_P10_B1 48
# 5   0.9635730   -0.053534166  -0.1518993728 48h_met-mut_P10_B1 48
# 6   1.0331295    0.047021099   0.0822677196 48h_met-mut_P10_B1 48
# 7   1.2522606    0.324534791   0.5251368776 48h_met-mut_P10_B1 48
# 8   0.7576667   -0.400364803  -0.6293042290 48h_met-mut_P10_B1 48
# 9   0.9313952   -0.102534637  -0.2135232669 48h_met-mut_P10_B1 48
# 10  0.9963118   -0.005330788   0.3457405185 48h_met-mut_P10_B1 48
# 11  1.3317753    0.413350704   0.7486007104 48h_met-mut_P10_B1 48
# 12  0.9565039   -0.064157182   0.0123288564 48h_met-mut_P10_B1 48
# 13  1.2066804    0.271043573  -0.2617802451 48h_met-mut_P10_B1 48
# 14  1.2460548    0.317367488   0.2405035883 48h_met-mut_P10_B1 48
# 15  1.0304935    0.043335343  -0.0245584708 48h_met-mut_P10_B1 48
# 16  0.9384527   -0.091644054  -0.2628567621 48h_met-mut_P10_B1 48
# 17  0.9131643   -0.131053650  -0.0613727898 48h_met-mut_P10_B1 48
# 18  1.0194549    0.027797959  -0.2136077159 48h_met-mut_P10_B1 48
# 19  1.3100511    0.389623114   0.4833184422 48h_met-mut_P10_B1 48
# 20  0.7787940   -0.360686416  -0.3351233562 48h_met-mut_P10_B1 48
# 21  1.1327291    0.179802892   0.1905088558 48h_met-mut_P10_B1 48
# 22  0.8745760   -0.193344417  -0.3772318036 48h_met-mut_P10_B1 48
# 23  1.1752503    0.232968100   0.2282835290 48h_met-mut_P10_B1 48
# 24  1.1514660    0.203471798   0.2530745422 48h_met-mut_P10_B1 48
# 25  0.9885549   -0.016607043  -0.3999310847 48h_met-mut_P10_B1 48
# 26  0.9600456   -0.058825222   0.0715482215 48h_met-mut_P10_B1 48
# 27  1.0199137    0.028447078   0.0293220319 48h_met-mut_P10_B1 48
# 28  1.0325998    0.046281275   0.0405231366 48h_met-mut_P10_B1 48
# 29  1.1363325    0.184385055   0.4469653544 48h_met-mut_P10_B1 48
# 30  0.8484885   -0.237032956  -0.6133393394 48h_met-mut_P10_B1 48
# ⋮   ⋮           ⋮             ⋮             ⋮                  ⋮
# 716  1.15207234  0.2042313    -0.30939755   NA                 48
# 717  0.58811435 -0.7658314     0.47661415   NA                 48
# 718  1.13947155  0.1883649     0.76784545   NA                 48
# 719  0.65538233 -0.6095913    -0.09722497   NA                 48
# 720  0.42797054 -1.2244166    -0.79693917   NA                 48
# 721  1.17774837  0.2360313    -0.65841930   NA                 48
# 722  0.09207851 -3.4409917     0.18288295   NA                 48
# 723  1.17150489  0.2283630    -0.14776236   NA                 48
# 724  0.55247106 -0.8560292     0.63034193   NA                 48
# 725  1.70457533  0.7694124    -0.26777846   NA                 48
# 726  0.40514544 -1.3034882     1.18288295   NA                 48
# 727  0.75964770 -0.3965976    -0.49518896   NA                 48
# 728  1.51929540  0.6034024    -0.08015146   NA                 48
# 729  0.28938960 -1.7889150     0.37552803   NA                 48
# 730          NA         NA     0.59792045   NA                 48
# 731  0.70121326 -0.5120748     0.06740573   NA                 48
# 732          NA         NA     2.35280795   NA                 48
# 733  0.81029088 -0.3034882    -0.13904515   NA                 48
# 734          NA         NA     0.76784545   NA                 48
# 735          NA         NA     0.59792045   NA                 48
# 736          NA         NA     0.76784545   NA                 48
# 737 12.15436321  3.6034024     1.76784545   NA                 48
# 738          NA         NA     0.44591736   NA                 48
# 739  3.03859080  1.6034024     0.76784545   NA                 48
# 740          NA         NA           -Inf   NA                 48
# 741          NA         NA           -Inf   NA                 48
# 742          NA         NA           -Inf   NA                 48
# 743          NA         NA           -Inf   NA                 48
# 744          NA         NA             NA   NA                 48
# 745          NA         NA           -Inf   NA                 48
#     condition      gene_target
# 1   met_control_48 met_control
# 2   met_control_48 met_control
# 3   met_control_48 met_control
# 4   met_control_48 met_control
# 5   met_control_48 met_control
# 6   met_control_48 met_control
# 7   met_control_48 met_control
# 8   met_control_48 met_control
# 9   met_control_48 met_control
# 10  met_control_48 met_control
# 11  met_control_48 met_control
# 12  met_control_48 met_control
# 13  met_control_48 met_control
# 14  met_control_48 met_control
# 15  met_control_48 met_control
# 16  met_control_48 met_control
# 17  met_control_48 met_control
# 18  met_control_48 met_control
# 19  met_control_48 met_control
# 20  met_control_48 met_control
# 21  met_control_48 met_control
# 22  met_control_48 met_control
# 23  met_control_48 met_control
# 24  met_control_48 met_control
# 25  met_control_48 met_control
# 26  met_control_48 met_control
# 27  met_control_48 met_control
# 28  met_control_48 met_control
# 29  met_control_48 met_control
# 30  met_control_48 met_control
# ⋮   ⋮              ⋮
# 716 met_control_48 met_control
# 717 met_control_48 met_control
# 718 met_control_48 met_control
# 719 met_control_48 met_control
# 720 met_control_48 met_control
# 721 met_control_48 met_control
# 722 met_control_48 met_control
# 723 met_control_48 met_control
# 724 met_control_48 met_control
# 725 met_control_48 met_control
# 726 met_control_48 met_control
# 727 met_control_48 met_control
# 728 met_control_48 met_control
# 729 met_control_48 met_control
# 730 met_control_48 met_control
# 731 met_control_48 met_control
# 732 met_control_48 met_control
# 733 met_control_48 met_control
# 734 met_control_48 met_control
# 735 met_control_48 met_control
# 736 met_control_48 met_control
# 737 met_control_48 met_control
# 738 met_control_48 met_control
# 739 met_control_48 met_control
# 740 met_control_48 met_control
# 741 met_control_48 met_control
# 742 met_control_48 met_control
# 743 met_control_48 met_control
# 744 met_control_48 met_control
# 745 met_control_48 met_control
#     cell_type_broad_transfer                              mode
# 1   periderm                                              single_oligo
# 2   mature fast muscle                                    single_oligo
# 3   basal cell                                            single_oligo
# 4   connective tissue-meninges-dermal FB                  single_oligo
# 5   neurons (gabaergic, glutamatergic)                    single_oligo
# 6   neurons (differentiating, contains peripheral)        single_oligo
# 7   fin fold                                              single_oligo
# 8   retinal neuron                                        single_oligo
# 9   neurons (gabaergic, glutamatergic; contains Purkinje) single_oligo
# 10  hatching gland                                        single_oligo
# 11  neural tube-like connective tissue (+ taste bud)      single_oligo
# 12  head mesenchyme (maybe ventral, hand2+)               single_oligo
# 13  pharyngeal arch (early)                               single_oligo
# 14  notochord                                             single_oligo
# 15  pharyngeal arch (contains muscle, early cartilage)    single_oligo
# 16  mature slow muscle                                    single_oligo
# 17  endothelium (dorsal aorta)                            single_oligo
# 18  neural progenitor (diencephalon/telencephalon)        single_oligo
# 19  support cells/otic vesicle                            single_oligo
# 20  head mesenchyme                                       single_oligo
# 21  endothelium (vein + early artery)                     single_oligo
# 22  anterior migratory muscle                             single_oligo
# 23  retinal pigmented epithelium (early)                  single_oligo
# 24  cranial muscle (non-somitic, fast-twitch)             single_oligo
# 25  intestine                                             single_oligo
# 26  ionocyte/goblet cell                                  single_oligo
# 27  cranial muscle (early)                                single_oligo
# 28  neuron (cranial ganglion, enteric)                    single_oligo
# 29  glia                                                  single_oligo
# 30  eye, optic cup                                        single_oligo
# ⋮   ⋮                                                     ⋮
# 716 hypophysis/locus coeruleus                            CellFlow
# 717 pronephric duct                                       CellFlow
# 718 thyroid follicle cell                                 CellFlow
# 719 red blood cell                                        CellFlow
# 720 osteoblast                                            CellFlow
# 721 pronephric podocyte                                   CellFlow
# 722 neural progenitor (hindbrain)                         CellFlow
# 723 primordial germ cell                                  CellFlow
# 724 adrenal gland                                         CellFlow
# 725 hypochord                                             CellFlow
# 726 vascular smooth muscle                                CellFlow
# 727 retinal pigmented epithelium (late)                   CellFlow
# 728 neuron (dopaminergic)                                 CellFlow
# 729 satellite cells                                       CellFlow
# 730 pharyngeal arch (NC-derived)                          CellFlow
# 731 pharynx                                               CellFlow
# 732 contains head vasculature?                            CellFlow
# 733 cranial muscle (progenitor)                           CellFlow
# 734 fast-committed myocyte (fusing)                       CellFlow
# 735 neural crest + pigment cell progenitor                CellFlow
# 736 swim bladder primordium                               CellFlow
# 737 unknown (k+ channel, ciliated)                        CellFlow
# 738 odontoblast                                           CellFlow
# 739 fin mesenchyme                                        CellFlow
# 740 fast-committed myocyte (pre-fusion)                   CellFlow
# 741 slow-committed myocyte                                CellFlow
# 742 myoblast                                              CellFlow
# 743 mesodermal progenitor cells (contains PSM)            CellFlow
# 744 enveloping layer (EVL)                                CellFlow
# 745 mineralized tissue, bone                              CellFlow
#     ratio_pred n_cells
# 1   NA         8.906664
# 2   NA         7.991592
# 3   NA         7.635304
# 4   NA         7.488294
# 5   NA         7.315218
# 6   NA         7.089243
# 7   NA         6.967909
# 8   NA         7.126087
# 9   NA         6.854355
# 10  NA         6.434547
# 11  NA         6.413459
# 12  NA         6.388561
# 13  NA         6.783325
# 14  NA         6.467699
# 15  NA         6.405228
# 16  NA         6.285998
# 17  NA         5.926926
# 18  NA         6.142037
# 19  NA         5.888878
# 20  NA         5.891644
# 21  NA         5.755742
# 22  NA         5.863631
# 23  NA         5.739793
# 24  NA         5.459586
# 25  NA         5.723585
# 26  NA         5.332719
# 27  NA         5.384495
# 28  NA         5.389072
# 29  NA         5.204007
# 30  NA         5.605802
# ⋮   ⋮          ⋮
# 716 0.8069787  3.7135721
# 717 1.3914742  2.3025851
# 718 1.7027250  2.5649494
# 719 0.9348294  2.4849066
# 720 0.5755690  2.3978953
# 721 0.6335721  3.2580965
# 722 1.1351500  0.6931472
# 723 0.9026494  2.8332133
# 724 1.5479318  1.6094379
# 725 0.8305976  3.1780538
# 726 2.2703000  0.6931472
# 727 0.7094687  1.9459101
# 728 0.9459583  2.3025851
# 729 1.2973143  0.6931472
# 730 1.5135333  0.0000000
# 731 1.0478308  1.3862944
# 732 5.1081750  0.0000000
# 733 0.9081200  1.0986123
# 734 1.7027250  0.0000000
# 735 1.5135333  0.0000000
# 736 1.7027250  0.0000000
# 737 3.4054500  1.6094379
# 738 1.3621800  0.0000000
# 739 1.7027250  1.0986123
# 740 0.0000000  0.0000000
# 741 0.0000000  0.0000000
# 742 0.0000000  0.0000000
# 743 0.0000000  0.0000000
# 744        NA  0.0000000
# 745 0.0000000  0.0000000

# %%
library(ggplot2)
library(readr)
library(glue)

df1 <- read_csv(file.path(data_dir, glue("logfoldchanges_met_control_48.csv")))

# Remove NA and infinite values before computing range
valid_x <- df1$logratio_true[is.finite(df1$logratio_true)]
valid_y <- df1$logratio_pred[is.finite(df1$logratio_pred)]

# Compute axis limits ignoring NA and Inf values
x_limits <- range(valid_x, na.rm = TRUE)
y_limits <- range(valid_y, na.rm = TRUE)

p <- ggplot(df1, aes(x = logratio_true, y = logratio_pred, color = mode)) +
  scale_color_manual(values = c("CellFlow" = "#B12F8C", "single_oligo"="#D6D6D6")) +
  geom_point(size = 0.1, alpha = 0.9) +  # Adjusting point size and adding transparency
  geom_abline(slope = 1, intercept = 0, color="black", size=0.3) +
  coord_cartesian(xlim = x_limits, ylim = y_limits) +  # Apply computed limits
  custom_theme() +
  article_text() +
  no_legend() +
  theme(
    panel.grid.major = element_blank(), 
    panel.grid.minor = element_blank(),
    axis.title.x = element_blank(),
    axis.title.y = element_blank()
  )

# Uncomment to save the plot
ggsave(file.path(output_dir, glue("met_control_48_scatter.pdf")), plot = p, device = "pdf", width = 2.3, height = 2.3, unit="cm")

print(p)
# Out:
# New names:
# • `` -> `...1`
# Rows: 745 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (6): index, Oligo, condition, gene_target, cell_type_broad_transfer, mode
# dbl (8): ...1, ratio_oligo, ratio_true, logratio_true, logratio_pred, timepo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 12 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
library(ggplot2)
library(readr)
library(glue)

df1 <- read_csv(file.path(data_dir, glue("logfoldchanges_tbx16_msgn1_18.csv")))

# Remove NA and infinite values before computing range
valid_x <- df1$logratio_true[is.finite(df1$logratio_true)]
valid_y <- df1$logratio_pred[is.finite(df1$logratio_pred)]

# Compute axis limits ignoring NA and Inf values
x_limits <- range(valid_x, na.rm = TRUE)
y_limits <- range(valid_y, na.rm = TRUE)

p <- ggplot(df1, aes(x = logratio_true, y = logratio_pred, color = mode)) +
  scale_color_manual(values = c("CellFlow" = "#B12F8C", "single_oligo"="#D6D6D6")) +
  geom_point(size = 0.1, alpha = 0.9) +  # Adjusting point size and adding transparency
  geom_abline(slope = 1, intercept = 0, color="black", size=0.3) +
  coord_cartesian(xlim = x_limits, ylim = y_limits) +  # Apply computed limits
  custom_theme() +
  article_text() +
  no_legend() +
  theme(
    panel.grid.major = element_blank(), 
    panel.grid.minor = element_blank(),
    axis.title.x = element_blank(),
    axis.title.y = element_blank()
  )

# Uncomment to save the plot
ggsave(file.path(output_dir, glue("tbx16_msgn1_18_scatter.pdf")), plot = p, device = "pdf", width = 2.3, height = 2.3, unit="cm")

print(p)
# Out:
# New names:
# • `` -> `...1`
# Rows: 699 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (6): index, Oligo, condition, gene_target, cell_type_broad_transfer, mode
# dbl (8): ...1, ratio_oligo, ratio_true, logratio_true, logratio_pred, timepo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “Removed 16 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 16 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
library(ggplot2)
library(readr)
library(glue)

df1 <- read_csv(file.path(data_dir, glue("logfoldchanges_mature_fast_muscle.csv")))

# Remove NA and infinite values before computing range
valid_x <- df1$logratio_true[is.finite(df1$logratio_true)]
valid_y <- df1$logratio_pred[is.finite(df1$logratio_pred)]

# Compute axis limits ignoring NA and Inf values
x_limits <- range(valid_x, na.rm = TRUE)
y_limits <- range(valid_y, na.rm = TRUE)

p <- ggplot(df1, aes(x = logratio_true, y = logratio_pred, color = mode)) +
  scale_color_manual(values = c("CellFlow" = "#B12F8C", "single_oligo"="#D6D6D6")) +
  geom_point(size = 0.1, alpha = 0.9) +  # Adjusting point size and adding transparency
  geom_abline(slope = 1, intercept = 0, color="black", size=0.3) +
  coord_cartesian(xlim = x_limits, ylim = y_limits) +  # Apply computed limits
  custom_theme() +
  article_text() +
  no_legend() +
  theme(
    panel.grid.major = element_blank(), 
    panel.grid.minor = element_blank(),
    axis.title.x = element_blank(),
    axis.title.y = element_blank()
  )

# Uncomment to save the plot
ggsave(file.path(output_dir, glue("mature_fast_muscle_scatter.pdf")), plot = p, device = "pdf", width = 2.3, height = 2.3, unit="cm")

print(p)
# Out:
# New names:
# • `` -> `...1`
# Rows: 881 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (6): ...1, Oligo, condition, gene_target, cell_type_broad_transfer, mode
# dbl (6): ratio_oligo, ratio_true, logratio_true, logratio_pred, timepoint, r...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
library(ggplot2)
library(readr)
library(glue)

df1 <- read_csv(file.path(data_dir, glue("logfoldchanges_mature_slow_muscle.csv")))

# Remove NA and infinite values before computing range
valid_x <- df1$logratio_true[is.finite(df1$logratio_true)]
valid_y <- df1$logratio_pred[is.finite(df1$logratio_pred)]

# Compute axis limits ignoring NA and Inf values
x_limits <- range(valid_x, na.rm = TRUE)
y_limits <- range(valid_y, na.rm = TRUE)

p <- ggplot(df1, aes(x = logratio_true, y = logratio_pred, color = mode)) +
  scale_color_manual(values = c("CellFlow" = "#B12F8C", "single_oligo"="#D6D6D6")) +
  geom_point(size = 0.1, alpha = 0.9) +  # Adjusting point size and adding transparency
  geom_abline(slope = 1, intercept = 0, color="black", size=0.3) +
  coord_cartesian(xlim = x_limits, ylim = y_limits) +  # Apply computed limits
  custom_theme() +
  article_text() +
  no_legend() +
  theme(
    panel.grid.major = element_blank(), 
    panel.grid.minor = element_blank(),
    axis.title.x = element_blank(),
    axis.title.y = element_blank()
  )

# Uncomment to save the plot
ggsave(file.path(output_dir, glue("mature_fast_muscle_scatter.pdf")), plot = p, device = "pdf", width = 2.3, height = 2.3, unit="cm")

print(p)
# Out:
# [1]     -Inf 4.693249

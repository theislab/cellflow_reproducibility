# %%
import os
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# %%
adata = sc.read_h5ad("/lustre/groups/ml01/workspace/ot_perturbation/data/zebrafish_new/zebrafish_processed.h5ad")
cts_meso = adata[adata.obs["germ_layer"].isin(["mesoderm", 'mesoderm/neural crest', 'mesoderm/ectoderm'])].obs["cell_type_broad"].unique()

# %%
len(cts_meso)
# Out:
# 42

# %%
data_dir = "/lustre/groups/ml01/workspace/cell_flow_zebrafish/results/single_condition/interpolate_time"

# %%
gene_target = "tbx16_control"

# %%
df_pert = pd.read_csv(os.path.join(data_dir, f"interpolated_tbx16_control_obs.csv"))

# %%
df_pert = df_pert[df_pert["cell_type_broad"].isin(cts_meso)]

# %%
df_pert.shape
# Out:
# (366653, 5)

# %%
df_pert["logtime"] = df_pert.apply(lambda x: float(x["condition"].split("_")[-1][:4]), axis=1)

# %%
df_pert.head(-5)
# Out:
#         Unnamed: 0                         condition  \
# 4                4  tbx16_control_2.8903717578961645
# 21              21  tbx16_control_2.8903717578961645
# 23              23  tbx16_control_2.8903717578961645
# 26              26  tbx16_control_2.8903717578961645
# 30              30  tbx16_control_2.8903717578961645
# ...            ...                               ...
# 999972      999972  tbx16_control_3.1780538303479453
# 999973      999973  tbx16_control_3.1780538303479453
# 999976      999976  tbx16_control_3.1780538303479453
# 999978      999978  tbx16_control_3.1780538303479453
# 999979      999979  tbx16_control_3.1780538303479453
#
#                           cell_type_broad_transfer  \
# 4                       contains head vasculature?
# 21      mesodermal progenitor cells (contains PSM)
# 23                    head mesenchyme/PA cartilage
# 26                              mature fast muscle
# 30                                  red blood cell
# ...                                            ...
# 999972                   endothelium (f8+, clic2+)
# 999973  mesodermal progenitor cells (contains PSM)
# 999976        connective tissue-meninges-dermal FB
# 999978                              fin mesenchyme
# 999979                          mature fast muscle
#
#         cell_type_broad_transfer_score  \
# 4                                  1.0
# 21                                 1.0
# 23                                 1.0
# 26                                 1.0
# 30                                 1.0
# ...                                ...
# 999972                             1.0
# 999973                             1.0
# 999976                             1.0
# 999978                             1.0
# 999979                             1.0
#
#                                    cell_type_broad  logtime
# 4                       contains head vasculature?     2.89
# 21      mesodermal progenitor cells (contains PSM)     2.89
# 23                    head mesenchyme/PA cartilage     2.89
# 26                              mature fast muscle     2.89
# 30                                  red blood cell     2.89
# ...                                            ...      ...
# 999972                   endothelium (f8+, clic2+)     3.17
# 999973  mesodermal progenitor cells (contains PSM)     3.17
# 999976        connective tissue-meninges-dermal FB     3.17
# 999978                              fin mesenchyme     3.17
# 999979                          mature fast muscle     3.17
#
# [366648 rows x 6 columns]

# %%
ct_dists = {}
for lt in df_pert["logtime"].unique():
    df_tmp = df_pert[df_pert["logtime"]==lt]
    ct_tmp = df_tmp["cell_type_broad"].value_counts().to_frame()
    ct_tmp["counts_normalized"] = ct_tmp["count"]/ct_tmp["count"].sum()
    ct_tmp["log_counts_normalized"] = ct_tmp["counts_normalized"]# np.log2(ct_tmp["counts_normalized"]+1+1e-6)
    ct_tmp["norm"] = ct_tmp["log_counts_normalized"]/ct_tmp["log_counts_normalized"].sum()
    ct_tmp["cell_type_broad"] = ct_tmp.index
    ct_dists[lt] = ct_tmp

# %%
ct_18_pred = ct_dists[2.89]

# %%
n_segments = len(ct_18_pred)
fractions = ct_18_pred["norm"].values
categories = ct_18_pred["cell_type_broad"].values


colors = plt.get_cmap('tab20').colors  # Start with tab20
colors += plt.get_cmap('tab20b').colors  # Add tab20b
colors += plt.get_cmap('tab20c').colors  # Add tab20c

color_palette = colors[:n_segments]

# Plot horizontal bar
fig, ax = plt.subplots(figsize=(12, 2))
cumulative = [0] + list(np.cumsum(fractions)[:-1])  # Cumulative fractions

for i, (frac, color, cat) in enumerate(zip(fractions, color_palette, categories)):
    ax.barh(0, width=frac, left=cumulative[i], color=color, edgecolor='black', label=cat)

# Aesthetics
ax.set_xlim(0, 1)
ax.get_yaxis().set_visible(False)
ax.set_xlabel("Fractions")
# Out:
# Text(0.5, 0, 'Fractions')

# %%
n_segments = len(ct_18_pred)
fractions = ct_18_pred["norm"].values
categories = ct_18_pred["cell_type_broad"].values


# Combine multiple categorical colormaps to get 41 distinguishable colors
colors = plt.get_cmap('tab20').colors  # Start with tab20
colors += plt.get_cmap('tab20b').colors  # Add tab20b
colors += plt.get_cmap('tab20c').colors  # Add tab20c

# Ensure exactly 41 colors
color_palette = colors[:n_segments]

# Plot horizontal bar
fig, ax = plt.subplots(figsize=(12, 2))
cumulative = [0] + list(np.cumsum(fractions)[:-1])  # Cumulative fractions

for i, (frac, color, cat) in enumerate(zip(fractions, color_palette, categories)):
    ax.barh(0, width=frac, left=cumulative[i], color=color, edgecolor='black', label=cat)

# Aesthetics
ax.set_xlim(0, 1)
ax.get_yaxis().set_visible(False)
ax.set_xlabel("Fractions")

# Create a discrete colorbar
norm = mcolors.BoundaryNorm(range(n_segments + 1), n_segments)
cmap = mcolors.ListedColormap(color_palette)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', ticks=np.arange(0.5, n_segments, 1))
cbar.ax.set_xticklabels([f"{i+1}" for i in range(n_segments)], rotation=90)

# Add legend
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title="Categories", ncol=2, fontsize=8)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example dictionary for demonstration purposes
# Replace with your actual `ct_dists` dictionary

# Total number of plots
n_plots = len(ct_dists)

# Initialize the figure with multiple subplots, one column
fig, axes = plt.subplots(n_plots, 1, figsize=(12, 2 * n_plots), constrained_layout=True)

# Ensure axes is iterable even if there is one subplot
if n_plots == 1:
    axes = [axes]

# Prepare color palettes
colors = list(plt.get_cmap('tab20').colors) + \
         list(plt.get_cmap('tab20b').colors) + \
         list(plt.get_cmap('tab20c').colors)

# Loop through the dictionary and make individual plots
for ax, (name, ct_pred) in zip(axes, ct_dists.items()):
    n_segments = len(ct_pred)
    fractions = ct_pred["norm"].values  # Fraction values
    categories = ct_pred["cell_type_broad"].values  # Categories
    
    # Select colors for this plot
    color_palette = colors[:n_segments]
    
    # Cumulative fractions for positioning
    cumulative = [0] + list(np.cumsum(fractions)[:-1])
    
    # Plot horizontal bar for each fraction
    for i, (frac, color, cat) in enumerate(zip(fractions, color_palette, categories)):
        ax.barh(0, width=frac, left=cumulative[i], color=color, edgecolor='black', label=cat)
    
    # Aesthetics
    ax.set_xlim(0, 1)
    ax.get_yaxis().set_visible(False)
    ax.set_xlabel("Fractions")
    ax.set_title(f"Plot for {name}")  # Title with dictionary key

# Show the figure
plt.show()

# %%
ct_dists_true = {}
for t in [18, 24, 36]:
    df_tmp = adata.obs[(adata.obs["timepoint"]==t) & (adata.obs["gene_target"]==gene_target)]
    df_tmp = df_tmp[df_tmp["cell_type_broad"].isin(cts_meso)]
    ct_tmp = df_tmp["cell_type_broad"].value_counts().to_frame()
    ct_tmp["counts_normalized"] = ct_tmp["count"]/ct_tmp["count"].sum()
    ct_tmp["log_counts_normalized"] = ct_tmp["counts_normalized"]# np.log2(ct_tmp["counts_normalized"]+1+1e-6)
    ct_tmp["norm"] = ct_tmp["log_counts_normalized"]/ct_tmp["log_counts_normalized"].sum()
    ct_tmp["cell_type_broad"] = ct_tmp.index
    ct_dists_true[np.log(t).round(2)] = ct_tmp

# %%
import matplotlib.pyplot as plt
import numpy as np


# Total number of plots
n_plots = len(ct_dists_true)

# Initialize the figure with multiple subplots, one column
fig, axes = plt.subplots(n_plots, 1, figsize=(12, 2 * n_plots), constrained_layout=True)

# Ensure axes is iterable even if there is one subplot
if n_plots == 1:
    axes = [axes]

# Prepare color palettes
colors = list(plt.get_cmap('tab20').colors) + \
         list(plt.get_cmap('tab20b').colors) + \
         list(plt.get_cmap('tab20c').colors)

# Loop through the dictionary and make individual plots
for ax, (name, ct_pred) in zip(axes, ct_dists_true.items()):
    n_segments = len(ct_pred)
    fractions = ct_pred["norm"].values  # Fraction values
    categories = ct_pred["cell_type_broad"].values  # Categories
    
    # Select colors for this plot
    color_palette = colors[:n_segments]
    
    # Cumulative fractions for positioning
    cumulative = [0] + list(np.cumsum(fractions)[:-1])
    
    # Plot horizontal bar for each fraction
    for i, (frac, color, cat) in enumerate(zip(fractions, color_palette, categories)):
        ax.barh(0, width=frac, left=cumulative[i], color=color, edgecolor='black', label=cat)
    
    # Aesthetics
    ax.set_xlim(0, 1)
    ax.get_yaxis().set_visible(False)
    ax.set_xlabel("Fractions")
    ax.set_title(f"Plot for {name}")  # Title with dictionary key

# Show the figure
plt.show()

# %%
df_18_true
# Out:
#                                                     count  counts_normalized  \
# cell_type_broad
# mesodermal progenitor cells (contains PSM)           3583           0.194348
# connective tissue-meninges-dermal FB                 2634           0.142873
# mature fast muscle                                   1746           0.094706
# fin mesenchyme                                       1694           0.091885
# head mesenchyme (maybe ventral, hand2+)              1000           0.054242
# mature slow muscle                                    909           0.049306
# pectoral fin bud (osteoblast+)                        883           0.047895
# endothelium (vein + early artery)                     603           0.032708
# head mesenchyme/PA cartilage                          597           0.032382
# anterior migratory muscle                             561           0.030430
# cranial muscle (progenitor)                           513           0.027826
# head mesenchyme                                       512           0.027772
# pharyngeal arch (early)                               501           0.027175
# contains head vasculature?                            411           0.022293
# fast-committed myocyte (fusing)                       309           0.016761
# pronephros proximal tubule                            233           0.012638
# myoblast                                              231           0.012530
# pronephros distal tubule                              188           0.010197
# myeloid cell                                          188           0.010197
# endothelium (dorsal aorta)                            163           0.008841
# slow-committed myocyte                                150           0.008136
# cranial muscle (non-somitic, fast-twitch)             143           0.007757
# fast-committed myocyte (pre-fusion)                   139           0.007540
# cardiomyocyte                                         131           0.007106
# pharyngeal arch (contains muscle, early cartilage)     78           0.004231
# cranial muscle (early)                                 67           0.003634
# hypochord                                              58           0.003146
# endothelium (f8+, clic2+)                              54           0.002929
# satellite cells                                        49           0.002658
# red blood cell                                         39           0.002115
# fin fold                                               19           0.001031
# cranial muscle (mid)                                   18           0.000976
# pronephric podocyte                                    14           0.000759
# fin bud mesoderm (pectoral)                             8           0.000434
# periocular mesenchyme                                   7           0.000380
# jaw chondrocyte                                         3           0.000163
#
#                                                     log_counts_normalized  \
# cell_type_broad
# mesodermal progenitor cells (contains PSM)                       0.194348
# connective tissue-meninges-dermal FB                             0.142873
# mature fast muscle                                               0.094706
# fin mesenchyme                                                   0.091885
# head mesenchyme (maybe ventral, hand2+)                          0.054242
# mature slow muscle                                               0.049306
# pectoral fin bud (osteoblast+)                                   0.047895
# endothelium (vein + early artery)                                0.032708
# head mesenchyme/PA cartilage                                     0.032382
# anterior migratory muscle                                        0.030430
# cranial muscle (progenitor)                                      0.027826
# head mesenchyme                                                  0.027772
# pharyngeal arch (early)                                          0.027175
# contains head vasculature?                                       0.022293
# fast-committed myocyte (fusing)                                  0.016761
# pronephros proximal tubule                                       0.012638
# myoblast                                                         0.012530
# pronephros distal tubule                                         0.010197
# myeloid cell                                                     0.010197
# endothelium (dorsal aorta)                                       0.008841
# slow-committed myocyte                                           0.008136
# cranial muscle (non-somitic, fast-twitch)                        0.007757
# fast-committed myocyte (pre-fusion)                              0.007540
# cardiomyocyte                                                    0.007106
# pharyngeal arch (contains muscle, early cartilage)               0.004231
# cranial muscle (early)                                           0.003634
# hypochord                                                        0.003146
# endothelium (f8+, clic2+)                                        0.002929
# satellite cells                                                  0.002658
# red blood cell                                                   0.002115
# fin fold                                                         0.001031
# cranial muscle (mid)                                             0.000976
# pronephric podocyte                                              0.000759
# fin bud mesoderm (pectoral)                                      0.000434
# periocular mesenchyme                                            0.000380
# jaw chondrocyte                                                  0.000163
#
#                                                         norm  \
# cell_type_broad
# mesodermal progenitor cells (contains PSM)          0.194348
# connective tissue-meninges-dermal FB                0.142873
# mature fast muscle                                  0.094706
# fin mesenchyme                                      0.091885
# head mesenchyme (maybe ventral, hand2+)             0.054242
# mature slow muscle                                  0.049306
# pectoral fin bud (osteoblast+)                      0.047895
# endothelium (vein + early artery)                   0.032708
# head mesenchyme/PA cartilage                        0.032382
# anterior migratory muscle                           0.030430
# cranial muscle (progenitor)                         0.027826
# head mesenchyme                                     0.027772
# pharyngeal arch (early)                             0.027175
# contains head vasculature?                          0.022293
# fast-committed myocyte (fusing)                     0.016761
# pronephros proximal tubule                          0.012638
# myoblast                                            0.012530
# pronephros distal tubule                            0.010197
# myeloid cell                                        0.010197
# endothelium (dorsal aorta)                          0.008841
# slow-committed myocyte                              0.008136
# cranial muscle (non-somitic, fast-twitch)           0.007757
# fast-committed myocyte (pre-fusion)                 0.007540
# cardiomyocyte                                       0.007106
# pharyngeal arch (contains muscle, early cartilage)  0.004231
# cranial muscle (early)                              0.003634
# hypochord                                           0.003146
# endothelium (f8+, clic2+)                           0.002929
# satellite cells                                     0.002658
# red blood cell                                      0.002115
# fin fold                                            0.001031
# cranial muscle (mid)                                0.000976
# pronephric podocyte                                 0.000759
# fin bud mesoderm (pectoral)                         0.000434
# periocular mesenchyme                               0.000380
# jaw chondrocyte                                     0.000163
#
#                                                                                       cell_type_broad
# cell_type_broad
# mesodermal progenitor cells (contains PSM)                 mesodermal progenitor cells (contains PSM)
# connective tissue-meninges-dermal FB                             connective tissue-meninges-dermal FB
# mature fast muscle                                                                 mature fast muscle
# fin mesenchyme                                                                         fin mesenchyme
# head mesenchyme (maybe ventral, hand2+)                       head mesenchyme (maybe ventral, hand2+)
# mature slow muscle                                                                 mature slow muscle
# pectoral fin bud (osteoblast+)                                         pectoral fin bud (osteoblast+)
# endothelium (vein + early artery)                                   endothelium (vein + early artery)
# head mesenchyme/PA cartilage                                             head mesenchyme/PA cartilage
# anterior migratory muscle                                                   anterior migratory muscle
# cranial muscle (progenitor)                                               cranial muscle (progenitor)
# head mesenchyme                                                                       head mesenchyme
# pharyngeal arch (early)                                                       pharyngeal arch (early)
# contains head vasculature?                                                 contains head vasculature?
# fast-committed myocyte (fusing)                                       fast-committed myocyte (fusing)
# pronephros proximal tubule                                                 pronephros proximal tubule
# myoblast                                                                                     myoblast
# pronephros distal tubule                                                     pronephros distal tubule
# myeloid cell                                                                             myeloid cell
# endothelium (dorsal aorta)                                                 endothelium (dorsal aorta)
# slow-committed myocyte                                                         slow-committed myocyte
# cranial muscle (non-somitic, fast-twitch)                   cranial muscle (non-somitic, fast-twitch)
# fast-committed myocyte (pre-fusion)                               fast-committed myocyte (pre-fusion)
# cardiomyocyte                                                                           cardiomyocyte
# pharyngeal arch (contains muscle, early cartilage)  pharyngeal arch (contains muscle, early cartil...
# cranial muscle (early)                                                         cranial muscle (early)
# hypochord                                                                                   hypochord
# endothelium (f8+, clic2+)                                                   endothelium (f8+, clic2+)
# satellite cells                                                                       satellite cells
# red blood cell                                                                         red blood cell
# fin fold                                                                                     fin fold
# cranial muscle (mid)                                                             cranial muscle (mid)
# pronephric podocyte                                                               pronephric podocyte
# fin bud mesoderm (pectoral)                                               fin bud mesoderm (pectoral)
# periocular mesenchyme                                                           periocular mesenchyme
# jaw chondrocyte                                                                       jaw chondrocyte

# %%
ct_dists[3.17]["count"] - df_18_true["count"]
# Out:
# cell_type_broad
# mesodermal progenitor cells (contains PSM)            0
# connective tissue-meninges-dermal FB                  0
# mature fast muscle                                    0
# fin mesenchyme                                        0
# head mesenchyme (maybe ventral, hand2+)               0
# mature slow muscle                                    0
# pectoral fin bud (osteoblast+)                        0
# endothelium (vein + early artery)                     0
# head mesenchyme/PA cartilage                          0
# anterior migratory muscle                             0
# cranial muscle (progenitor)                           0
# head mesenchyme                                       0
# pharyngeal arch (early)                               0
# contains head vasculature?                            0
# fast-committed myocyte (fusing)                       0
# pronephros proximal tubule                            0
# myoblast                                              0
# pronephros distal tubule                              0
# myeloid cell                                          0
# endothelium (dorsal aorta)                            0
# slow-committed myocyte                                0
# cranial muscle (non-somitic, fast-twitch)             0
# fast-committed myocyte (pre-fusion)                   0
# cardiomyocyte                                         0
# pharyngeal arch (contains muscle, early cartilage)    0
# cranial muscle (early)                                0
# hypochord                                             0
# endothelium (f8+, clic2+)                             0
# satellite cells                                       0
# red blood cell                                        0
# fin fold                                              0
# cranial muscle (mid)                                  0
# pronephric podocyte                                   0
# fin bud mesoderm (pectoral)                           0
# periocular mesenchyme                                 0
# jaw chondrocyte                                       0
# Name: count, dtype: int64

# %%
mat_f_m = {}
for k,v in ct_dists.items():
    mat_f_m[k] = v.loc["mesodermal progenitor cells (contains PSM)"]["norm"]

# %%
mat_f_m
# Out:
# {2.89: 0.19817156621229542,
#  2.9: 0.19917943107221006,
#  2.92: 0.199704304019275,
#  2.93: 0.19982485906627995,
#  2.95: 0.1998905309250137,
#  2.96: 0.20004374931641689,
#  2.98: 0.2004590665646519,
#  2.99: 0.20067729954118418,
#  3.01: 0.2007751514820678,
#  3.02: 0.2006659752169878,
#  3.04: 0.20069846120266288,
#  3.05: 0.20038167938931298,
#  3.07: 0.20017444395987788,
#  3.08: 0.19989097846824747,
#  3.1: 0.19893205470495287,
#  3.11: 0.19840060929169842,
#  3.13: 0.19730332191594624,
#  3.14: 0.19663500678426055,
#  3.16: 0.19588691735851108,
#  3.17: 0.1943480147537427}

# %%
v.loc["mature slow muscle"]
# Out:
# count                                   909
# counts_normalized                  0.049306
# log_counts_normalized              0.049306
# norm                               0.049306
# cell_type_broad          mature slow muscle
# Name: mature slow muscle, dtype: object

# %%
adata.o

# %%
np.log(18).round(2)
# Out:
# 2.89

# %%
ct_dists_true[2.89]
# Out:
#                                             count  counts_normalized  \
# cell_type_broad
# mesodermal progenitor cells (contains PSM)  12707           0.131419
# connective tissue-meninges-dermal FB        11373           0.117622
# fin mesenchyme                               8754           0.090536
# head mesenchyme (maybe ventral, hand2+)      6493           0.067152
# fast-committed myocyte (fusing)              5637           0.058299
# ...                                           ...                ...
# adrenal gland                                   0           0.000000
# motor neuron (hindbrain, spinal cord)           0           0.000000
# mineralized tissue, bone                        0           0.000000
# melanophore                                     0           0.000000
# xanthophore                                     0           0.000000
#
#                                             log_counts_normalized      norm  \
# cell_type_broad
# mesodermal progenitor cells (contains PSM)               0.131419  0.131419
# connective tissue-meninges-dermal FB                     0.117622  0.117622
# fin mesenchyme                                           0.090536  0.090536
# head mesenchyme (maybe ventral, hand2+)                  0.067152  0.067152
# fast-committed myocyte (fusing)                          0.058299  0.058299
# ...                                                           ...       ...
# adrenal gland                                            0.000000  0.000000
# motor neuron (hindbrain, spinal cord)                    0.000000  0.000000
# mineralized tissue, bone                                 0.000000  0.000000
# melanophore                                              0.000000  0.000000
# xanthophore                                              0.000000  0.000000
#
#                                                                        cell_type_broad
# cell_type_broad
# mesodermal progenitor cells (contains PSM)  mesodermal progenitor cells (contains PSM)
# connective tissue-meninges-dermal FB              connective tissue-meninges-dermal FB
# fin mesenchyme                                                          fin mesenchyme
# head mesenchyme (maybe ventral, hand2+)        head mesenchyme (maybe ventral, hand2+)
# fast-committed myocyte (fusing)                        fast-committed myocyte (fusing)
# ...                                                                                ...
# adrenal gland                                                            adrenal gland
# motor neuron (hindbrain, spinal cord)            motor neuron (hindbrain, spinal cord)
# mineralized tissue, bone                                      mineralized tissue, bone
# melanophore                                                                melanophore
# xanthophore                                                                xanthophore
#
# [101 rows x 5 columns]

# %%
mat_f_m_true = {}
for k,v in ct_dists_true.items():
    mat_f_m_true[k] = v.loc["mesodermal progenitor cells (contains PSM)"]["norm"]

# %%
mat_f_m_true
# Out:
# {2.89: 0.13141864289334065,
#  3.18: 0.051114155619132046,
#  3.58: 0.0003914828606893918}

# %%
mat_f_m
# Out:
# {2.89: 0.03569277932884437,
#  2.9: 0.0362691466083151,
#  2.92: 0.036797722045778115,
#  2.93: 0.03705325379015928,
#  2.95: 0.037547892720306515,
#  2.96: 0.03839002515585693,
#  2.98: 0.03902065799540934,
#  2.99: 0.03921782827179375,
#  3.01: 0.03957639609148971,
#  3.02: 0.04006768928434958,
#  3.04: 0.040543490123322055,
#  3.05: 0.041112322791712105,
#  3.07: 0.04164849542084605,
#  3.08: 0.04246388661760698,
#  3.1: 0.04331716885522803,
#  3.11: 0.04450005440104451,
#  3.13: 0.045723916707443045,
#  3.14: 0.046784260515603804,
#  3.16: 0.04785935210809052,
#  3.17: 0.049305706226947285}

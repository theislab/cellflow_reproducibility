# %%
library(dplyr)
library(ggplot2)
install.packages("jsonlite")
library(jsonlite)
library(glue)
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Error in value[[3L]](cond): Package ‘jsonlite’ version 1.8.9 cannot be unloaded:
#  Error in unloadNamespace(package) : namespace ‘jsonlite’ is imported by ‘IRkernel’, ‘repr’ so cannot be unloaded
#
# Traceback:
#
# 1. tryCatch(unloadNamespace(package), error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste("Error in", deparse(cc)[1L], ": ")
#  .     else "Error : "
#  .     stop(gettextf("Package %s version %s cannot be unloaded:\n %s",
#  .         sQuote(package), oldversion, paste0(P, conditionMessage(e),
#  .             "\n")), domain = NA)
#  . })
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. value[[3L]](cond)
# 5. stop(gettextf("Package %s version %s cannot be unloaded:\n %s",
#  .     sQuote(package), oldversion, paste0(P, conditionMessage(e),
#  .         "\n")), domain = NA)
# 6. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "Package ‘jsonlite’ version 1.8.9 cannot be unloaded:\n Error in unloadNamespace(package) : namespace ‘jsonlite’ is imported by ‘IRkernel’, ‘repr’ so cannot be unloaded\n",
#  .     base::quote(value[[3L]](cond)))

# %%
output_dir <- glue("/lustre/groups/ml01/workspace/ot_perturbation/figures/zebrafish/benchmark/single_condition/large_heatmaps")
# Out:
# Error in glue("/lustre/groups/ml01/workspace/ot_perturbation/figures/zebrafish/benchmark/single_condition/large_heatmaps"): could not find function "glue"
# Traceback:

# %%
cts_ordered <- read.csv("/lustre/groups/ml01/workspace/ot_perturbation/data/zebrafish_new/cell_types_ordered.csv")
gts_ordered <- read.csv("/lustre/groups/ml01/workspace/ot_perturbation/data/zebrafish_new/gene_targets_ordered2.csv")
df_merged <- read.csv("/lustre/groups/ml01/workspace/ot_perturbation/data/zebrafish_new/results/allocation/same_tp_cf_diff_e_distance.csv")

# %%
df_merged$condition <- factor(df_merged$condition, levels = rev(gts_ordered$condition))
df_merged$cell_type <- factor(df_merged$cell_type, levels = cts_ordered$CTs)

# %%
options(repr.plot.width = 20, repr.plot.height = 16)

color_dict = c(
    "True"= "#B12F8C",
    "False"= "#566573")
# Ensure the color scale is centered at 0

# Create ggplot
p <- ggplot(df_merged, aes(
  x = cell_type,
  y = condition,
  size = log_perturbation_effect,
  color = larger_zero
)) +
  geom_point(alpha = 0.8) +
  scale_color_manual(
    values = color_dict,
  ) +
  scale_size(range = c(1, 10), name = "Perturbation Effect") +
  theme_minimal() +
  theme(
    axis.text.x = element_text(angle = 90, hjust = 1, size = 8),
    axis.text.y = element_text(size = 8),
    legend.position = "right"
  ) +
  labs(
    title = "Improvement of CellFlow over additive model",
    x = "Cell Type",
    y = "Condition"
  )

# %%
ggsave(file.path(output_dir, "e_distance_improvement_large.pdf"), plot = p, device = "pdf", width = 20.0, height = 16.0)
# Out:
# Error in file.path(output_dir, "e_distance_improvement_large.pdf"): object 'output_dir' not found
# Traceback:
#
# 1. check_path(path, filename, create.dir)
# 2. file.path(output_dir, "e_distance_improvement_large.pdf")
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "object 'output_dir' not found", base::quote(file.path(output_dir,
#  .     "e_distance_improvement_large.pdf")))

# %%
p
# Out:
# Warning message:
# “Removed 2556 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
import pandas as pd
import os
import seaborn as sns

# %%
id_dir = "/lustre/groups/ml01/workspace/ot_perturbation/models/identity/zebrafish/single_condition_identity_from_same_timepoint"
cf_dir = "/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/zebrafish/full_gene_final"

# %%
ood_conditions = ['zc4h2_control_24','met_control_36','tfap2a_control_72','hgfa_control_48','tfap2a_foxd3_72','noto_control_18','cdx4_cdx1a_36','epha4a_control_48','mafba_control_36','tbx16_msgn1_24','noto_control_24','smo_control_18','hand2_control_24','noto_control_36','egr2b_control_36','cdx4_control_18','tfap2a_control_36','foxi1_control_72','egr2b_control_24','cdx4_control_36','zc4h2_control_36','hoxb1a_control_48','tfap2a_foxd3_36','tbx16_tbx16l_24','smo_control_36','mafba_control_18','hgfa_control_72','tbx16_control_18','mafba_control_24','tbx1_control_36','zc4h2_control_48','wnt3a_wnt8_36','foxi1_control_48','smo_control_24','noto_control_48','mafba_control_48','tfap2a_control_48','hand2_control_48','egr2b_control_48','phox2a_control_48','tbx1_control_48','tbx16_msgn1_36','foxd3_control_72','wnt3a_wnt8_24','egr2b_control_18','wnt3a_wnt8_18','met_control_72','phox2a_control_36','epha4a_control_24','foxd3_control_36','tfap2a_foxd3_48','hand2_control_36','cdx4_cdx1a_24','hgfa_control_36','tbx16_tbx16l_18','tbxta_control_36','cdx4_control_24','foxd3_control_48','met_control_48','tbx1_control_24','epha4a_control_36','cdx4_cdx1a_18','tbx16_control_36','tbx16_tbx16l_36','tbx16_control_24','tbxta_control_24','tbx16_msgn1_18','epha4a_control_18','tbxta_control_18','hoxb1a_control_36','hoxb1a_control_24']

# %%
dfs = []
for ood_cond in ood_conditions:
    csv_file = [el for el in os.listdir(cf_dir) if ((ood_cond in el) and ("csv" in el))]
    assert len(csv_file) == 1
    df = pd.read_csv(os.path.join(cf_dir, csv_file[0])).set_index("Unnamed: 0").T
    df["condition"] = f"{ood_cond}"
    dfs.append(df)

# %%
df_cf = pd.concat(dfs)

# %%
dfs = []
for ood_cond in ood_conditions:
    csv_file = [el for el in os.listdir(id_dir) if ((ood_cond in el) and ("csv" in el))]
    assert len(csv_file) == 1
    df = pd.read_csv(os.path.join(id_dir, csv_file[0])).set_index("Unnamed: 0").T
    df["condition"] = f"{ood_cond}"
    dfs.append(df)

# %%
df_id = pd.concat(dfs)

# %%
df_id["model"]="id"
df_cf["model"]="cf"
# Out:
# /tmp/ipykernel_3023112/3922286274.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_id["model"]="id"
# /tmp/ipykernel_3023112/3922286274.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_cf["model"]="cf"

# %%
df_all = pd.concat((df_id, df_cf))

# %%
sns.boxplot(df_all, x="model", y="ood_mmd")
# Out:
# <Axes: xlabel='model', ylabel='ood_mmd'>

# %%
sns.boxplot(df_all, x="model", y="ood_e_distance")
# Out:
# <Axes: xlabel='model', ylabel='ood_e_distance'>

# %%
sns.boxplot(df_all, x="model", y="ood_sdiv_100")
# Out:
# <Axes: xlabel='model', ylabel='ood_sdiv_100'>

# %%
sns.boxplot(df_all, x="model", y="cell_type_fraction_error")
# Out:
# <Axes: xlabel='model', ylabel='cell_type_fraction_error'>

# %%
sns.boxplot(df_all, x="model", y="fraction_cell_types_covered")
# Out:
# <Axes: xlabel='model', ylabel='fraction_cell_types_covered'>

# %%
sns.boxplot(df_all, x="model", y="mean_e_distance_per_cell_type")
# Out:
# <Axes: xlabel='model', ylabel='mean_e_distance_per_cell_type'>

# %%
sns.boxplot(df_all, x="model", y="mean_mmd_per_cell_type")
# Out:
# <Axes: xlabel='model', ylabel='mean_mmd_per_cell_type'>

# %%
df_all["cell_type_fraction_error"].min()
# Out:
# 0.1144

# %%
df_all.head()
# Out:
# Unnamed: 0         fraction_cell_types_covered  cell_type_fraction_error  \
# zc4h2_control_24                           1.0                  0.198075
# met_control_36                             1.0                  0.290707
# tfap2a_control_72                          1.0                  0.321600
# hgfa_control_48                            1.0                  0.348580
# tfap2a_foxd3_72                            1.0                  0.229467
#
# Unnamed: 0         mean_r_sq_per_cell_type  mean_e_distance_per_cell_type  \
# zc4h2_control_24                  0.997143                      17.884346
# met_control_36                    0.996653                      21.373934
# tfap2a_control_72                 0.979980                     127.018322
# hgfa_control_48                   0.990385                      55.715163
# tfap2a_foxd3_72                   0.988895                      92.352286
#
# Unnamed: 0         mean_mmd_per_cell_type  mean_sdiv_10_per_cell_type  \
# zc4h2_control_24                 0.007304                  176.589351
# met_control_36                   0.007520                  196.086758
# tfap2a_control_72                0.009210                  338.764505
# hgfa_control_48                  0.012429                  239.495950
# tfap2a_foxd3_72                  0.009099                  292.229661
#
# Unnamed: 0         mean_sdiv_100_per_cell_type  median_r_sq_per_cell_type  \
# zc4h2_control_24                     50.130940                   0.998086
# met_control_36                       64.315720                   0.997639
# tfap2a_control_72                   212.046395                   0.996153
# hgfa_control_48                      99.938459                   0.993441
# tfap2a_foxd3_72                     157.077969                   0.994277
#
# Unnamed: 0         median_e_distance_per_cell_type  median_mmd_per_cell_type  \
# zc4h2_control_24                         10.724632                  0.006735
# met_control_36                           15.631581                  0.006816
# tfap2a_control_72                        24.456763                  0.007337
# hgfa_control_48                          34.930590                  0.011155
# tfap2a_foxd3_72                          32.852069                  0.007775
#
# Unnamed: 0         ...  e_distance_hypochord  mmd_hypochord  div_10_hypochord  \
# zc4h2_control_24   ...                   NaN            NaN               NaN
# met_control_36     ...                   NaN            NaN               NaN
# tfap2a_control_72  ...                   NaN            NaN               NaN
# hgfa_control_48    ...                   NaN            NaN               NaN
# tfap2a_foxd3_72    ...                   NaN            NaN               NaN
#
# Unnamed: 0         div_100_hypochord  r_squared_hypophysis/locus coeruleus  \
# zc4h2_control_24                 NaN                                   NaN
# met_control_36                   NaN                                   NaN
# tfap2a_control_72                NaN                                   NaN
# hgfa_control_48                  NaN                                   NaN
# tfap2a_foxd3_72                  NaN                                   NaN
#
# Unnamed: 0         e_distance_hypophysis/locus coeruleus  \
# zc4h2_control_24                                     NaN
# met_control_36                                       NaN
# tfap2a_control_72                                    NaN
# hgfa_control_48                                      NaN
# tfap2a_foxd3_72                                      NaN
#
# Unnamed: 0         mmd_hypophysis/locus coeruleus  \
# zc4h2_control_24                              NaN
# met_control_36                                NaN
# tfap2a_control_72                             NaN
# hgfa_control_48                               NaN
# tfap2a_foxd3_72                               NaN
#
# Unnamed: 0         div_10_hypophysis/locus coeruleus  \
# zc4h2_control_24                                 NaN
# met_control_36                                   NaN
# tfap2a_control_72                                NaN
# hgfa_control_48                                  NaN
# tfap2a_foxd3_72                                  NaN
#
# Unnamed: 0         div_100_hypophysis/locus coeruleus  model
# zc4h2_control_24                                  NaN     id
# met_control_36                                    NaN     id
# tfap2a_control_72                                 NaN     id
# hgfa_control_48                                   NaN     id
# tfap2a_foxd3_72                                   NaN     id
#
# [5 rows x 484 columns]

# %%
df_all[df_all.index.str.contains("cdx4_cdx1a")]
# Out:
# Unnamed: 0     fraction_cell_types_covered  cell_type_fraction_error  \
# cdx4_cdx1a_36                          1.0                  0.514259
# cdx4_cdx1a_24                          1.0                  0.449182
# cdx4_cdx1a_18                          1.0                  0.385988
# cdx4_cdx1a_36                          1.0                  0.315233
# cdx4_cdx1a_24                          1.0                  0.391152
# cdx4_cdx1a_18                          1.0                  0.325747
#
# Unnamed: 0     mean_r_sq_per_cell_type  mean_e_distance_per_cell_type  \
# cdx4_cdx1a_36                 0.987338                      86.167833
# cdx4_cdx1a_24                 0.992851                      41.010255
# cdx4_cdx1a_18                 0.991030                      51.255747
# cdx4_cdx1a_36                 0.994201                      44.181866
# cdx4_cdx1a_24                 0.995017                      28.983099
# cdx4_cdx1a_18                 0.997334                      15.006083
#
# Unnamed: 0     mean_mmd_per_cell_type  mean_sdiv_10_per_cell_type  \
# cdx4_cdx1a_36                0.011618                  248.039455
# cdx4_cdx1a_24                0.012503                  192.468700
# cdx4_cdx1a_18                0.013787                  197.283905
# cdx4_cdx1a_36                0.007115                  205.637023
# cdx4_cdx1a_24                0.008842                  170.975533
# cdx4_cdx1a_18                0.007397                  154.616967
#
# Unnamed: 0     mean_sdiv_100_per_cell_type  median_r_sq_per_cell_type  \
# cdx4_cdx1a_36                   112.634547                   0.994051
# cdx4_cdx1a_24                    69.471328                   0.995123
# cdx4_cdx1a_18                    64.728762                   0.993750
# cdx4_cdx1a_36                    74.997577                   0.997645
# cdx4_cdx1a_24                    53.614085                   0.996594
# cdx4_cdx1a_18                    32.534254                   0.997873
#
# Unnamed: 0     median_e_distance_per_cell_type  median_mmd_per_cell_type  ...  \
# cdx4_cdx1a_36                        32.589680                  0.009991  ...
# cdx4_cdx1a_24                        27.638649                  0.011033  ...
# cdx4_cdx1a_18                        32.987601                  0.012781  ...
# cdx4_cdx1a_36                        13.284815                  0.006534  ...
# cdx4_cdx1a_24                        19.158058                  0.008899  ...
# cdx4_cdx1a_18                        11.029293                  0.007044  ...
#
# Unnamed: 0     e_distance_hypochord  mmd_hypochord  div_10_hypochord  \
# cdx4_cdx1a_36                   NaN            NaN               NaN
# cdx4_cdx1a_24                   NaN            NaN               NaN
# cdx4_cdx1a_18                   NaN            NaN               NaN
# cdx4_cdx1a_36                   NaN            NaN               NaN
# cdx4_cdx1a_24                   NaN            NaN               NaN
# cdx4_cdx1a_18                   NaN            NaN               NaN
#
# Unnamed: 0     div_100_hypochord  r_squared_hypophysis/locus coeruleus  \
# cdx4_cdx1a_36                NaN                                   NaN
# cdx4_cdx1a_24                NaN                                   NaN
# cdx4_cdx1a_18                NaN                                   NaN
# cdx4_cdx1a_36                NaN                                   NaN
# cdx4_cdx1a_24                NaN                                   NaN
# cdx4_cdx1a_18                NaN                                   NaN
#
# Unnamed: 0     e_distance_hypophysis/locus coeruleus  \
# cdx4_cdx1a_36                                    NaN
# cdx4_cdx1a_24                                    NaN
# cdx4_cdx1a_18                                    NaN
# cdx4_cdx1a_36                                    NaN
# cdx4_cdx1a_24                                    NaN
# cdx4_cdx1a_18                                    NaN
#
# Unnamed: 0     mmd_hypophysis/locus coeruleus  \
# cdx4_cdx1a_36                             NaN
# cdx4_cdx1a_24                             NaN
# cdx4_cdx1a_18                             NaN
# cdx4_cdx1a_36                             NaN
# cdx4_cdx1a_24                             NaN
# cdx4_cdx1a_18                             NaN
#
# Unnamed: 0     div_10_hypophysis/locus coeruleus  \
# cdx4_cdx1a_36                                NaN
# cdx4_cdx1a_24                                NaN
# cdx4_cdx1a_18                                NaN
# cdx4_cdx1a_36                                NaN
# cdx4_cdx1a_24                                NaN
# cdx4_cdx1a_18                                NaN
#
# Unnamed: 0     div_100_hypophysis/locus coeruleus  model
# cdx4_cdx1a_36                                 NaN     id
# cdx4_cdx1a_24                                 NaN     id
# cdx4_cdx1a_18                                 NaN     id
# cdx4_cdx1a_36                                 NaN     cf
# cdx4_cdx1a_24                                 NaN     cf
# cdx4_cdx1a_18                                 NaN     cf
#
# [6 rows x 484 columns]

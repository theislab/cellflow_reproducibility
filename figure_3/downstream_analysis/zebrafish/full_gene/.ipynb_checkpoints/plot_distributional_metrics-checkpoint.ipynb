# %%
library(tidyverse)
library(glue)
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.2.3”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ...

# %%
color_dict = c(
    "CellFlow"= "#B12F8C",
    "Mean model 1"= "#d8dfa5",
    "Mean model 2"= "#88afd7",
    "Identity"="#E1C8AC",
    "min"="#475a69")

# %%
output_dir <- glue("/lustre/groups/ml01/workspace/ot_perturbation/figures/zebrafish/benchmark/single_condition")
dir.create(output_dir)
# Out:
# Warning message in dir.create(output_dir):
# “'/lustre/groups/ml01/workspace/ot_perturbation/figures/zebrafish/benchmark/single_condition' already exists”

# %%
results <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/zebrafish_new/results/allocation/all_models_metrics.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 257 Columns: 485
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr   (3): ...1, condition, model
# dbl (482): fraction_cell_types_covered, cell_type_fraction_error, mean_r_sq_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
results$model <- factor(results$model, 
                                levels = c("id", "same_timepoint", "same_perturbation", "cf"),
                                labels = c("Identity", "Mean model 1", "Mean model 2", "CellFlow"))  # Correct factorization

# %%
p <- ggplot(results, aes(x=model, y=ood_mmd, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="MMD") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "mmd.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
p <- ggplot(results, aes(x=model, y=ood_sdiv_100, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Sinkhorn divergence") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "sink_div.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
p <- ggplot(results, aes(x=model, y=ood_e_distance, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Energy distance") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "e_distance.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
p <- ggplot(results, aes(x=model, y=mean_e_distance_per_cell_type, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Mean energy distance per cell type") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "mean_e_distance_per_cell_type.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
p <- ggplot(results, aes(x=model, y=mean_mmd_per_cell_type, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Mean MMD per cell type") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "mean_mmd_per_cell_type.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
p <- ggplot(results, aes(x=model, y=mean_sdiv_100_per_cell_type, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Mean Sinkhorn divergence per cell type") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "mean_sdiv_per_cell_type.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
p <- ggplot(results, aes(x=model, y=cell_type_fraction_error, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Cell type fraction error") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "cell_type_fraction_error.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
p <- ggplot(results, aes(x=model, y=fraction_cell_types_covered, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Fraction of cell types covered") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "fraction_cell_types_covered.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
results_ct <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/zebrafish_new/results/allocation/cell_type_fraction_error_all.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 328 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): ...1, condition, model
# dbl (1): cell_type_fraction_error
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
results_ct$model <- factor(results_ct$model, 
                                levels = c("id", "same_timepoint", "same_perturbation", "cf", "min"),
                                labels = c("Identity", "Mean model 1", "Mean model 2", "CellFlow", "min"))  # Correct factorization

# %%
p <- ggplot(results_ct, aes(x=model, y=cell_type_fraction_error, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Cell type fraction error") +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "cell_type_fraction_error_with_baseline.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/metrics_new_cytokine.csv", index_col=0)
# Out:
# /tmp/ipykernel_4041240/44285347.py:1: DtypeWarning: Columns (1,128,129,171) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/metrics_new_cytokine.csv", index_col=0)

# %%
df_scaling = pd.DataFrame(df.groupby(["method", "num_donors_in_train"])["ood_e_distance"].mean())
df_scaling = df_scaling.reset_index()

# %%
df_scaling = df_scaling[df_scaling["num_donors_in_train"]>0.0]

# %%
df_scaling.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/scaling_law_wrt_num_donors.csv")

# %%
df_cf = df_scaling[df_scaling["method"]=="cf"]
df_cf["num_cytokines_in_train"] = df_cf.index

x = df_cf["num_donors_in_train"].values.reshape(-1, 1)
y = df_cf["ood_e_distance"].values
# Out:
# /tmp/ipykernel_4041240/1860972066.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cf["num_cytokines_in_train"] = df_cf.index

# %%
from sklearn.linear_model import LinearRegression

# Reshape x for sklearn
x = x.reshape(-1, 1)

# Create and fit model
model = LinearRegression()
model.fit(x, y)

# Get parameters
m_sklearn = model.coef_[0]
b_sklearn = model.intercept_

# Predict
y_fit = model.predict(x)

# Plot
plt.scatter(x, y, label="Data")
plt.plot(x, y_fit, color='red', label=f"Fit: y = {m_sklearn:.2f}x + {b_sklearn:.2f}")
plt.legend()
plt.show()

# %%
df_cf = df_scaling[df_scaling["method"]=="m1"]
df_cf["num_cytokines_in_train"] = df_cf.index

x = df_cf["num_donors_in_train"].values.reshape(-1, 1)
y = df_cf["ood_e_distance"].values
# Out:
# /tmp/ipykernel_4041240/2993347522.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cf["num_cytokines_in_train"] = df_cf.index

# %%
from sklearn.linear_model import LinearRegression

# Reshape x for sklearn
x = x.reshape(-1, 1)

# Create and fit model
model = LinearRegression()
model.fit(x, y)

# Get parameters
m_sklearn = model.coef_[0]
b_sklearn = model.intercept_

# Predict
y_fit = model.predict(x)

# Plot
plt.scatter(x, y, label="Data")
plt.plot(x, y_fit, color='red', label=f"Fit: y = {m_sklearn:.2f}x + {b_sklearn:.2f}")
plt.legend()
plt.show()

# %%
df_cf = df_scaling[df_scaling["method"]=="m2"]
df_cf["num_cytokines_in_train"] = df_cf.index

x = df_cf["num_donors_in_train"].values.reshape(-1, 1)
y = df_cf["ood_e_distance"].values
# Out:
# /tmp/ipykernel_4041240/3001226835.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cf["num_cytokines_in_train"] = df_cf.index

# %%
from sklearn.linear_model import LinearRegression

# Reshape x for sklearn
x = x.reshape(-1, 1)

# Create and fit model
model = LinearRegression()
model.fit(x, y)

# Get parameters
m_sklearn = model.coef_[0]
b_sklearn = model.intercept_

# Predict
y_fit = model.predict(x)

# Plot
plt.scatter(x, y, label="Data")
plt.plot(x, y_fit, color='red', label=f"Fit: y = {m_sklearn:.2f}x + {b_sklearn:.2f}")
plt.legend()
plt.show()

# %%
df_cf = df_scaling[df_scaling["method"]=="id"]
df_cf["num_cytokines_in_train"] = df_cf.index

x = df_cf["num_donors_in_train"].values.reshape(-1, 1)
y = df_cf["ood_e_distance"].values
# Out:
# /tmp/ipykernel_4041240/3633475258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cf["num_cytokines_in_train"] = df_cf.index

# %%
from sklearn.linear_model import LinearRegression

# Reshape x for sklearn
x = x.reshape(-1, 1)

# Create and fit model
model = LinearRegression()
model.fit(x, y)

# Get parameters
m_sklearn = model.coef_[0]
b_sklearn = model.intercept_

# Predict
y_fit = model.predict(x)

# Plot
plt.scatter(x, y, label="Data")
plt.plot(x, y_fit, color='red', label=f"Fit: y = {m_sklearn:.2f}x + {b_sklearn:.2f}")
plt.legend()
plt.show()

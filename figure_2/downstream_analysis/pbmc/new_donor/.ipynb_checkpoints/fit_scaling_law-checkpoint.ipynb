# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/metrics_new_donor.csv", index_col=0)
df = df[df["method"]=="cf"]
# Out:
# /tmp/ipykernel_1615765/3248026366.py:1: DtypeWarning: Columns (1,148,149,150,154,175) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/metrics_new_donor.csv", index_col=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df is your DataFrame
unique_donors = df["donor"].unique()
num_cytokines = len(unique_donors)

# Set up the subplots with 2 columns
fig, axes = plt.subplots(nrows=(num_cytokines + 1) // 2, ncols=2, figsize=(15, num_cytokines * 3 // 2))

# Flatten the axes array for easier iteration
axes = axes.flatten()

for i, cyto in enumerate(unique_donors):
    ax = axes[i]
    df_tmp = df[df["donor"] == cyto]
    sns.boxplot(data=df_tmp, x="num_cytokines_in_train", y="ood_e_distance", ax=ax)
    ax.set_title(f'donor: {cyto}')
    ax.set_xlabel("Number of cytokines")
    ax.set_ylabel("E distance")

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df_donor9 = df[df["donor"]=="Donor9"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df is your DataFrame
unique_donors = df["donor"].unique()
num_cytokines = len(unique_donors)

# Set up the subplots with 2 columns
fig, axes = plt.subplots(nrows=(num_cytokines + 1) // 2, ncols=2, figsize=(15, num_cytokines * 3 // 2))

# Flatten the axes array for easier iteration
axes = axes.flatten()

for i, cyto in enumerate(unique_donors):
    ax = axes[i]
    df_tmp = df[df["donor"] == cyto]
    sns.boxplot(data=df_tmp, x="num_cytokines_in_train", y="ood_e_distance", ax=ax)
    ax.set_title(f'donor: {cyto}')
    ax.set_xlabel("Number of cytokines")
    ax.set_ylabel("E distance")

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
#              Unnamed: 0  mean_decoded_r_sq_per_cell_type  \
# 13     Donor9_IFN-gamma                         0.883380
# 26        Donor9_IL-1Ra                         0.919727
# 31    Donor9_IL-32-beta                         0.889882
# 33          Donor9_ADSF                         0.928119
# 34          Donor9_FasL                         0.916267
# ...                 ...                              ...
# 2718       Donor9_OX40L                         0.927472
# 2727      Donor9_IL-1Ra                         0.930039
# 2735   Donor9_IFN-gamma                         0.919960
# 2741        Donor9_BAFF                         0.929648
# 2750   Donor9_IFN-gamma                         0.911994
#
#       mean_e_distance_per_cell_type  mean_mmd_per_cell_type  \
# 13                        64.206102                0.028197
# 26                        23.673812                0.011794
# 31                        51.780234                0.022677
# 33                        18.180637                0.011853
# 34                        22.499174                0.012146
# ...                             ...                     ...
# 2718                      18.792339                0.011176
# 2727                      16.400185                0.009505
# 2735                      33.500485                0.016385
# 2741                      16.867408                0.010355
# 2750                      36.638948                0.020234
#
#       mean_sdiv_10_per_cell_type  mean_sdiv_100_per_cell_type  \
# 13                    131.215644                    44.839279
# 26                     96.400147                    18.440009
# 31                    121.191304                    37.224622
# 33                     98.634405                    17.748582
# 34                    100.136501                    19.428511
# ...                          ...                          ...
# 2718                   95.613458                    16.881913
# 2727                   88.497762                    14.240104
# 2735                  112.291215                    26.819284
# 2741                   95.559401                    15.446462
# 2750                  112.127569                    27.871438
#
#       mean_deg_r_sq_per_cell_type  mean_deg_e_distance_per_cell_type  \
# 13                       0.624802                          58.623045
# 26                       0.789430                          31.581178
# 31                       0.698306                          54.455558
# 33                       0.845950                          22.882000
# 34                       0.766156                          34.883202
# ...                           ...                                ...
# 2718                     0.807840                          25.687050
# 2727                     0.842848                          23.952267
# 2735                     0.753025                          41.013722
# 2741                     0.859589                          22.983388
# 2750                     0.741798                          40.714795
#
#       mean_deg_mmd_per_cell_type  mean_deg_sdiv_10_per_cell_type  ...  \
# 13                      0.052275                      165.536657  ...
# 26                      0.048543                      141.392472  ...
# 31                      0.058217                      158.041794  ...
# 33                      0.050055                      134.852172  ...
# 34                      0.063973                      135.110949  ...
# ...                          ...                             ...  ...
# 2718                    0.056223                      131.743475  ...
# 2727                    0.051102                      135.609626  ...
# 2735                    0.045013                      156.967255  ...
# 2741                    0.044058                      139.008565  ...
# 2750                    0.049347                      155.586080  ...
#
#       e_distance_pDC  mmd_pDC  div_10_pDC  div_100_pDC  \
# 13               NaN      NaN         NaN          NaN
# 26               NaN      NaN         NaN          NaN
# 31               NaN      NaN         NaN          NaN
# 33               NaN      NaN         NaN          NaN
# 34               NaN      NaN         NaN          NaN
# ...              ...      ...         ...          ...
# 2718             NaN      NaN         NaN          NaN
# 2727             NaN      NaN         NaN          NaN
# 2735             NaN      NaN         NaN          NaN
# 2741             NaN      NaN         NaN          NaN
# 2750             NaN      NaN         NaN          NaN
#
#       deg_decoded_r_squared_pDC  deg_e_distance_pDC  deg_mmd_pDC  \
# 13                          NaN                 NaN          NaN
# 26                          NaN                 NaN          NaN
# 31                          NaN                 NaN          NaN
# 33                          NaN                 NaN          NaN
# 34                          NaN                 NaN          NaN
# ...                         ...                 ...          ...
# 2718                        NaN                 NaN          NaN
# 2727                        NaN                 NaN          NaN
# 2735                        NaN                 NaN          NaN
# 2741                        NaN                 NaN          NaN
# 2750                        NaN                 NaN          NaN
#
#       deg_div_10_pDC  deg_div_100_pDC  new_run
# 13               NaN              NaN     True
# 26               NaN              NaN     True
# 31               NaN              NaN     True
# 33               NaN              NaN     True
# 34               NaN              NaN     True
# ...              ...              ...      ...
# 2718             NaN              NaN      NaN
# 2727             NaN              NaN      NaN
# 2735             NaN              NaN      NaN
# 2741             NaN              NaN      NaN
# 2750             NaN              NaN      NaN
#
# [230 rows x 175 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame
unique_cytokines = df["cytokine"].unique()
num_cytokines = len(unique_cytokines)

# Set up the subplots with 2 columns
fig, axes = plt.subplots(nrows=(num_cytokines + 1) // 2, ncols=2, figsize=(15, num_cytokines * 2.5))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Seaborn style
sns.set_theme(style="whitegrid")

for i, cyto in enumerate(unique_cytokines):
    ax = axes[i]
    df_tmp = df[df["cytokine"] == cyto]
    sns.boxplot(
        data=df_tmp,
        x="num_cytokines_in_train",
        y="ood_e_distance",
        ax=ax,
        linewidth=0.8,   # Subtle edge definition
    )
    ax.set_title(f'Cytokine: {cyto}', fontsize=14, weight='bold')
    ax.set_xlabel("Number of Cytokines", fontsize=12)
    ax.set_ylabel("e distance", fontsize=12)
    #ax.set_ylim(0.9, 1.0)
    ax.xaxis.grid(False)
    ax.yaxis.grid(True, linestyle='--', alpha=0.7)

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout to prevent overlapping
plt.tight_layout()
plt.show()

# %%
df_tmp =

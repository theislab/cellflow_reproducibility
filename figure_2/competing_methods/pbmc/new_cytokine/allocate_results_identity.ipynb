# %%
import pandas as pd
import os

# %%
data_dir = "/lustre/groups/ml01/workspace/ot_perturbation/models/identity/pbmc_new_cytokine"

# %%
dfs = []
for el in os.listdir(data_dir):
    if el.endswith(".csv"):
        df_tmp = pd.read_csv(os.path.join(data_dir, el), index_col=0)
        if 'decoded_ood_r_squared' not in df_tmp.index:
            continue
        dfs.append(df_tmp)

# %%
len(dfs)
# Out:
# 144

# %%
df = pd.concat([el.T for el in dfs])

# %%
df.head()
# Out:
#                     mean_decoded_r_sq_per_cell_type  \
# Donor11_4-1BBL                             0.952231
# Donor6_OSM                                 0.971253
# Donor5_OSM                                 0.963199
# Donor11_IL-15                              0.708561
# Donor9_IFN-epsilon                         0.958272
#
#                     mean_e_distance_per_cell_type  mean_mmd_per_cell_type  \
# Donor11_4-1BBL                          16.956072                0.010637
# Donor6_OSM                              12.543774                0.009362
# Donor5_OSM                              16.772043                0.013827
# Donor11_IL-15                          223.197493                0.062335
# Donor9_IFN-epsilon                      17.262488                0.010379
#
#                     mean_sdiv_10_per_cell_type  mean_sdiv_100_per_cell_type  \
# Donor11_4-1BBL                       99.556975                    15.163120
# Donor6_OSM                           95.318699                    12.748448
# Donor5_OSM                          100.421643                    18.415279
# Donor11_IL-15                       206.096110                   121.117554
# Donor9_IFN-epsilon                   95.222219                    16.849409
#
#                     mean_deg_r_sq_per_cell_type  \
# Donor11_4-1BBL                         0.840879
# Donor6_OSM                             0.906224
# Donor5_OSM                             0.881481
# Donor11_IL-15                         -0.575223
# Donor9_IFN-epsilon                     0.834105
#
#                     mean_deg_e_distance_per_cell_type  \
# Donor11_4-1BBL                              20.551774
# Donor6_OSM                                  14.238600
# Donor5_OSM                                  16.945014
# Donor11_IL-15                              253.205242
# Donor9_IFN-epsilon                          27.442682
#
#                     mean_deg_mmd_per_cell_type  \
# Donor11_4-1BBL                        0.009822
# Donor6_OSM                            0.009931
# Donor5_OSM                            0.014184
# Donor11_IL-15                         0.044979
# Donor9_IFN-epsilon                    0.013281
#
#                     mean_deg_sdiv_10_per_cell_type  \
# Donor11_4-1BBL                          200.891204
# Donor6_OSM                              170.430477
# Donor5_OSM                              182.197518
# Donor11_IL-15                           334.972606
# Donor9_IFN-epsilon                      169.696548
#
#                     mean_deg_sdiv_100_per_cell_type  ...  \
# Donor11_4-1BBL                            22.730617  ...
# Donor6_OSM                                13.971736  ...
# Donor5_OSM                                19.460894  ...
# Donor11_IL-15                            143.973776  ...
# Donor9_IFN-epsilon                        20.873341  ...
#
#                     decoded_r_squared_pDC  e_distance_pDC  mmd_pDC  \
# Donor11_4-1BBL                        NaN             NaN      NaN
# Donor6_OSM                            NaN             NaN      NaN
# Donor5_OSM                            NaN             NaN      NaN
# Donor11_IL-15                         NaN             NaN      NaN
# Donor9_IFN-epsilon                    NaN             NaN      NaN
#
#                     div_10_pDC  div_100_pDC  deg_decoded_r_squared_pDC  \
# Donor11_4-1BBL             NaN          NaN                        NaN
# Donor6_OSM                 NaN          NaN                        NaN
# Donor5_OSM                 NaN          NaN                        NaN
# Donor11_IL-15              NaN          NaN                        NaN
# Donor9_IFN-epsilon         NaN          NaN                        NaN
#
#                     deg_e_distance_pDC  deg_mmd_pDC  deg_div_10_pDC  \
# Donor11_4-1BBL                     NaN          NaN             NaN
# Donor6_OSM                         NaN          NaN             NaN
# Donor5_OSM                         NaN          NaN             NaN
# Donor11_IL-15                      NaN          NaN             NaN
# Donor9_IFN-epsilon                 NaN          NaN             NaN
#
#                     deg_div_100_pDC
# Donor11_4-1BBL                  NaN
# Donor6_OSM                      NaN
# Donor5_OSM                      NaN
# Donor11_IL-15                   NaN
# Donor9_IFN-epsilon              NaN
#
# [5 rows x 165 columns]

# %%
df["donor_cytokine_split-idx"] = df.index
df["donor"] = df.apply(lambda x: x["donor_cytokine_split-idx"].split("_")[0], axis=1)
df["cytokine"] = df.apply(lambda x: x["donor_cytokine_split-idx"].split("_")[1], axis=1)

# %%
df.to_csv(os.path.join(data_dir, "metrics_new_cytokine.csv"))

# %%
df["donor"].value_counts()
# Out:
# donor
# Donor11    12
# Donor6     12
# Donor5     12
# Donor9     12
# Donor10    12
# Donor1     12
# Donor2     12
# Donor12    12
# Donor8     12
# Donor3     12
# Donor7     12
# Donor4     12
# Name: count, dtype: int64

# %%
df["cytokine"].value_counts()
# Out:
# cytokine
# 4-1BBL         12
# OSM            12
# IL-15          12
# IFN-epsilon    12
# APRIL          12
# OX40L          12
# Noggin         12
# C5a            12
# IFN-beta       12
# IL-13          12
# ADSF           12
# BAFF           12
# Name: count, dtype: int64

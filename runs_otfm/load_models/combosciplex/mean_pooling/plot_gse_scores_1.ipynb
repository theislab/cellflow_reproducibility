# %%
import pandas as pd
import seaborn as sns
import scanpy as sc

# %%
split = 1
path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_ood_{split}.h5ad"
adata_ood = sc.read(path)
ood_conditions = adata_ood.obs["condition"].cat.categories

# %%
df = pd.read_csv(f"gse_score_{split}.csv")
df.drop(columns=["Unnamed: 0"])
# Out:
#    Alvespimycin+Pirarubicin  Cediranib+PCI-34051  Dacinostat+Danusertib  \
# 0                 -0.743823              0.53755               -0.92813
#
#    Dacinostat+Dasatinib  Dacinostat+PCI-34051  Givinostat+Carmofur  \
# 0             -0.888834              -0.89906            -0.902173
#
#    Givinostat+Cediranib  Givinostat+Crizotinib  Givinostat+Curcumin  \
# 0             -0.905792              -0.846437            -0.800292
#
#    Givinostat+Dasatinib  ...  SRT2104+Alvespimycin  SRT3025+Cediranib  \
# 0             -0.873432  ...             -0.553309           0.362456
#
#    SRT3025+Cediranib_pred  control+Alvespimycin  control+Dacinostat  \
# 0               -0.793472             -0.652629           -0.925477
#
#    control+Dasatinib  control+Dasatinib_pred  control+Givinostat  \
# 0          -0.898273               -0.691992           -0.878298
#
#    control+Panobinostat  control+SRT2104
# 0             -0.854523        -0.261799
#
# [1 rows x 38 columns]

# %%
df = pd.read_csv(f"gse_score_{split}.csv")
df = df.drop(columns=["Unnamed: 0"])
df = df.T
df["score"] = df[0]
df["condition"] = df.index

# %%
def get_mode(x):
    if "pred" in x["condition"]:
        return "ood_pred"
    if x["condition"] in ood_conditions:
        return "ood_true"
    return "seen"

# %%
df["mode"] = df.apply(get_mode, axis=1)

# %%
import matplotlib.pyplot as plt
sns.barplot(df, y="condition", x="score", hue="mode")
plt.xticks(rotation=0)
plt.show()

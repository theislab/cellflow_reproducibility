# %%
import pandas as pd
import seaborn as sns
import scanpy as sc

# %%
split = 2
path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_ood_{split}.h5ad"
adata_ood = sc.read(path)
ood_conditions = adata_ood.obs["condition"].cat.categories

# %%
df = pd.read_csv(f"gse_score_{split}.csv")
df.drop(columns=["Unnamed: 0"])
# Out:
#    Alvespimycin+Pirarubicin  Cediranib+PCI-34051  Dacinostat+Danusertib  \
# 0                 -0.748955             -0.29316              -0.921418
#
#    Dacinostat+Dasatinib  Dacinostat+Dasatinib_pred  Dacinostat+PCI-34051  \
# 0             -0.911627                  -0.933606             -0.903615
#
#    Dacinostat+PCI-34051_pred  Givinostat+Carmofur  Givinostat+Cediranib  \
# 0                  -0.930872            -0.951434             -0.934287
#
#    Givinostat+Cediranib_pred  ...  Panobinostat+Sorafenib  \
# 0                  -0.846441  ...               -0.828509
#
#    SRT2104+Alvespimycin  SRT3025+Cediranib  control+Alvespimycin  \
# 0             -0.501889          -0.435519             -0.682521
#
#    control+Dacinostat  control+Dasatinib  control+Givinostat  \
# 0           -0.930562           -0.90259           -0.934179
#
#    control+Panobinostat  control+Panobinostat_pred  control+SRT2104
# 0             -0.856993                  -0.879664        -0.535814
#
# [1 rows x 38 columns]

# %%
df = pd.read_csv(f"gse_score_{split}.csv")
df = df.drop(columns=["Unnamed: 0"])
df = df.T
df["score"] = df[0]
df["condition"] = df.index

# %%
def get_mode(x):
    if "pred" in x["condition"]:
        return "ood_pred"
    if x["condition"] in ood_conditions:
        return "ood_true"
    return "seen"

# %%
df["mode"] = df.apply(get_mode, axis=1)

# %%
import matplotlib.pyplot as plt
sns.barplot(df, y="condition", x="score", hue="mode")
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt
sns.barplot(df, y="condition", x="score", hue="mode")
plt.xticks(rotation=0)
plt.show()

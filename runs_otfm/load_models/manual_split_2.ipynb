# %%
1
# Out:
# 1

# %%
import functools
import os
import sys
import traceback
from typing import Dict, Literal, Optional, Tuple

import cfp
import scanpy as sc
import numpy as np
import functools
from ott.solvers import utils as solver_utils
import optax
from omegaconf import OmegaConf
from typing import NamedTuple, Any
import hydra
import wandb

# %%
import yaml

with open("/home/icb/dominik.klein/git_repos/ot_pert_new/runs_otfm/conf/model/combosciplex.yaml") as stream:

    model_config = yaml.safe_load(stream)

with open("/home/icb/dominik.klein/git_repos/ot_pert_new/runs_otfm/conf/dataset/combosciplex.yaml") as stream:

    dataset_config = yaml.safe_load(stream)

with open("/home/icb/dominik.klein/git_repos/ot_pert_new/runs_otfm/conf/training/combosciplex.yaml") as stream:

    training_config = yaml.safe_load(stream)

# %%
config_dict = {}
config_dict["model"] = model_config
config_dict["dataset"] = dataset_config
config_dict["training"] = training_config

# %%
def prepare_data(adata_train, adata_test, adata_ood):
    
    adata_tmp =  adata_train[adata_train.obs["Drug1"].drop_duplicates().index]
    ecfp_dict = {drug: adata_tmp[adata_tmp.obs["Drug1"]==drug].obsm["ecfp_drug_1"] for drug in adata_tmp.obs["Drug1"]}

    adata_tmp =  adata_train[adata_train.obs["Drug2"].drop_duplicates().index]
    ecfp_dict.update({drug: adata_tmp[adata_tmp.obs["Drug2"]==drug].obsm["ecfp_drug_2"] for drug in adata_tmp.obs["Drug2"]})

    adata_tmp =  adata_ood[adata_ood.obs["Drug1"].drop_duplicates().index]
    ecfp_dict.update({drug: adata_tmp[adata_tmp.obs["Drug1"]==drug].obsm["ecfp_drug_1"] for drug in adata_tmp.obs["Drug1"]})

    adata_tmp =  adata_ood[adata_ood.obs["Drug2"].drop_duplicates().index]
    ecfp_dict.update({drug: adata_tmp[adata_tmp.obs["Drug2"]==drug].obsm["ecfp_drug_2"] for drug in adata_tmp.obs["Drug2"]})

        
    adata_train.uns['ecfp_rep'] = ecfp_dict
    adata_test.uns['ecfp_rep'] = ecfp_dict
    adata_ood.uns['ecfp_rep'] = ecfp_dict
    return adata_train, adata_test, adata_ood

# %%
def run(config):
    config_dict  = config#OmegaConf.to_container(config, resolve=True)
    #split = config_dict["dataset"]["split"]
    split = 2
    adata_train_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_train_{split}.h5ad"
    adata_test_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_test_{split}.h5ad"
    adata_ood_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_ood_{split}.h5ad"
    adata_train = sc.read_h5ad(adata_train_path)
    adata_test = sc.read_h5ad(adata_test_path)
    adata_ood = sc.read_h5ad(adata_ood_path)
    adata_train, adata_test, adata_ood = prepare_data(adata_train, adata_test, adata_ood)

    
    cf = cfp.model.CellFlow(adata_train, solver="otfm")

    # Prepare the training data and perturbation conditions
    perturbation_covariates = {k: tuple(v) for k, v in config_dict["dataset"]["perturbation_covariates"].items()}
    cf.prepare_data(
        sample_rep="X_pca",
        control_key="control",
        perturbation_covariates=perturbation_covariates,
        perturbation_covariate_reps=dict(config_dict["dataset"]["perturbation_covariate_reps"]),
    )

    match_fn = functools.partial(
        solver_utils.match_linear,
        epsilon=config_dict["model"]["epsilon"],
        scale_cost="mean",
        tau_a=config_dict["model"]["tau_a"],
        tau_b=config_dict["model"]["tau_b"]
    )
    optimizer = optax.MultiSteps(optax.adam(config_dict["model"]["learning_rate"]), config_dict["model"]["multi_steps"])
    flow = {config_dict["model"]["flow_type"]: config_dict["model"]["flow_noise"]}

    layers_before_pool = config_dict["model"]["layers_before_pool"]
    layers_after_pool = config_dict["model"]["layers_after_pool"]


    # Prepare the model
    cf.prepare_model(
        encode_conditions=True,
        condition_embedding_dim=config_dict["model"]["condition_embedding_dim"],
        time_encoder_dims=config_dict["model"]["time_encoder_dims"],
        time_encoder_dropout=config_dict["model"]["time_encoder_dropout"],
        hidden_dims=config_dict["model"]["hidden_dims"],
        hidden_dropout=config_dict["model"]["hidden_dropout"],
        decoder_dims=config_dict["model"]["decoder_dims"],
        decoder_dropout=config_dict["model"]["decoder_dropout"],
        pooling=config_dict["model"]["pooling"],
        layers_before_pool=layers_before_pool,
        layers_after_pool=layers_after_pool,
        cond_output_dropout=config_dict["model"]["cond_output_dropout"],
        time_freqs=config_dict["model"]["time_freqs"],
        match_fn=match_fn,
        optimizer=optimizer,
        flow=flow,
    )

    cf.prepare_validation_data(
        adata_test,
        name="test",
        n_conditions_on_log_iteration=config_dict["training"]["test_n_conditions_on_log_iteration"],
        n_conditions_on_train_end=config_dict["training"]["test_n_conditions_on_log_iteration"],
    )

    cf.prepare_validation_data(
        adata_ood,
        name="ood",
        n_conditions_on_log_iteration=config_dict["training"]["ood_n_conditions_on_log_iteration"],
        n_conditions_on_train_end=config_dict["training"]["ood_n_conditions_on_log_iteration"],
    )

    metrics_callback = cfp.training.Metrics(metrics=["r_squared", "mmd", "e_distance"])
    decoded_metrics_callback = cfp.training.PCADecodedMetrics(ref_adata=adata_train, metrics=["r_squared", "mmd", "e_distance"])
    wandb_callback = cfp.training.WandbLogger(project="cfp_combosciplex_otfm", out_dir="/home/icb/dominik.klein/tmp", config=config_dict)

    callbacks = [metrics_callback, decoded_metrics_callback, wandb_callback]

    cf.train(
        num_iterations=240_000,#num_iterations=config_dict["training"]["num_iterations"],
        batch_size=config_dict["training"]["batch_size"],
        callbacks=callbacks,
        valid_freq=config_dict["training"]["valid_freq"],
    )

    if config_dict["training"]["save_model"]:
        cf.save(config_dict["training"]["out_dir"], file_prefix=wandb.run.name)

# %%
run(config_dict)
# Out:
# /ictstr01/home/icb/dominik.klein/git_repos/cell_flow_perturbation/src/cfp/data/_datamanager.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _covariate_data["cell_index"] = _covariate_data.index
# 100%|████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 48.10it/s]
# /ictstr01/home/icb/dominik.klein/git_repos/cell_flow_perturbation/src/cfp/data/_datamanager.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _covariate_data["cell_index"] = _covariate_data.index
# 100%|███████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 222.90it/s]
# /ictstr01/home/icb/dominik.klein/git_repos/cell_flow_perturbation/src/cfp/data/_datamanager.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _covariate_data["cell_index"] = _covariate_data.index
# 100%|███████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 225.47it/s]
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: mucdk (modality_translation). Use `wandb login --relogin` to force relogin
# wandb version 0.17.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.6
# Run data is saved locally in <code>/home/icb/dominik.klein/tmp/wandb/run-20240911_155938-cmce2nhf</code>
# Syncing run <strong><a href='https://wandb.ai/modality_translation/cfp_combosciplex_otfm/runs/cmce2nhf' target="_blank">swept-bush-84</a></strong> to <a href='https://wandb.ai/modality_translation/cfp_combosciplex_otfm' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/modality_translation/cfp_combosciplex_otfm' target="_blank">https://wandb.ai/modality_translation/cfp_combosciplex_otfm</a>
#  View run at <a href='https://wandb.ai/modality_translation/cfp_combosciplex_otfm/runs/cmce2nhf' target="_blank">https://wandb.ai/modality_translation/cfp_combosciplex_otfm/runs/cmce2nhf</a>
#  33%|████████████████████████▉                                                  | 79999/240000 [35:10<1:09:39, 38.28it/s]/home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
#  67%|█████████████████████████████████████████▎                    | 160001/240000 [1:16:13<32:54, 40.51it/s, loss=0.326]/home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
#  67%|█████████████████████████████████████████▎                    | 160001/240000 [1:16:24<32:54, 40.51it/s, loss=0.326]/home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████| 240000/240000 [1:56:52<00:00, 34.22it/s, loss=0.275]
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(
# /home/icb/dominik.klein/mambaforge/envs/cfp/lib/python3.11/site-packages/jax/_src/core.py:691: FutureWarning: unhashable type: <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>. Attempting to hash a tracer will lead to an error in a future JAX release.
#   warnings.warn(

# %%
model_name = wandb.run.name

# %%
model_name = 'swept-bush-84'

# %%
cf = cfp.model.CellFlow.load(f"/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/combosciplex/{model_name}_CellFlow.pkl")

# %%
cf.trainer.training_logs.keys()
# Out:
# dict_keys(['loss', 'test_r_squared_mean', 'ood_r_squared_mean', 'test_mmd_mean', 'ood_mmd_mean', 'test_e_distance_mean', 'ood_e_distance_mean', 'pca_decoded_ood_r_squared_mean', 'pca_decoded_test_r_squared_mean', 'pca_decoded_ood_mmd_mean', 'pca_decoded_test_mmd_mean', 'pca_decoded_ood_e_distance_mean', 'pca_decoded_test_e_distance_mean'])

# %%
cf.trainer.training_logs['pca_decoded_ood_r_squared_mean']
# Out:
# [0.8854240694360506, 0.9720600279184204, 0.9884586794405363]

# %%
split = 2
adata_train_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_train_{split}.h5ad"
adata_test_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_test_{split}.h5ad"
adata_ood_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_train_{split}.h5ad"
adata_train = sc.read_h5ad(adata_train_path)
adata_test = sc.read_h5ad(adata_test_path)
adata_ood = sc.read_h5ad(adata_ood_path)
adata_train, adata_test, adata_ood = prepare_data(adata_train, adata_test, adata_ood)

# %%
adata_ood_ctrl = adata_ood[adata_ood.obs["condition"]=="control"]
adata_ood_ctrl.obs["control"] = True
covariate_data_ood = adata_ood[adata_ood.obs["condition"]!="control"].obs.drop_duplicates(subset=["condition"])
# Out:
# /tmp/ipykernel_3106895/3122405260.py:2: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_ood_ctrl.obs["control"] = True

# %%
covariate_data_ood
# Out:
#                                    sample Size_Factor n.umi RT_well  \
# Cell
# A01_A02_RT_BC_13_Lig_BC_1   sciPlex_theis    1.083277  2908   RT_13
# A01_A02_RT_BC_16_Lig_BC_2   sciPlex_theis    1.298964  3487   RT_16
# A01_A02_RT_BC_1_Lig_BC_3    sciPlex_theis    2.151281  5775    RT_1
# A01_A02_RT_BC_22_Lig_BC_17  sciPlex_theis    0.899999  2416   RT_22
# A01_A02_RT_BC_28_Lig_BC_12  sciPlex_theis    1.136175  3050   RT_28
# A01_A02_RT_BC_34_Lig_BC_21  sciPlex_theis    1.154800  3100   RT_34
# A01_A02_RT_BC_37_Lig_BC_14  sciPlex_theis    0.921233  2473   RT_37
# A01_A02_RT_BC_40_Lig_BC_18  sciPlex_theis    2.642630  7094   RT_40
# A01_A02_RT_BC_43_Lig_BC_4   sciPlex_theis    1.156663  3105   RT_43
# A01_A02_RT_BC_46_Lig_BC_22  sciPlex_theis    1.234519  3314   RT_46
# A01_A02_RT_BC_49_Lig_BC_10  sciPlex_theis    2.406455  6460   RT_49
# A01_A02_RT_BC_4_Lig_BC_15   sciPlex_theis    0.932036  2502    RT_4
# A01_A02_RT_BC_52_Lig_BC_32  sciPlex_theis    2.259311  6065   RT_52
# A01_A02_RT_BC_55_Lig_BC_22  sciPlex_theis    2.782324  7469   RT_55
# A01_A02_RT_BC_61_Lig_BC_1   sciPlex_theis    0.897019  2408   RT_61
# A01_A02_RT_BC_64_Lig_BC_29  sciPlex_theis    0.473096  1270   RT_64
# A01_A02_RT_BC_70_Lig_BC_12  sciPlex_theis    1.894990  5087   RT_70
# A01_A02_RT_BC_73_Lig_BC_11  sciPlex_theis    0.539404  1448   RT_73
# A01_A02_RT_BC_76_Lig_BC_58  sciPlex_theis    0.489859  1315   RT_76
# A01_A02_RT_BC_79_Lig_BC_57  sciPlex_theis    0.772226  2073   RT_79
# A01_A02_RT_BC_82_Lig_BC_10  sciPlex_theis    1.392838  3739   RT_82
# A01_A02_RT_BC_88_Lig_BC_49  sciPlex_theis    0.730877  1962   RT_88
# A01_A02_RT_BC_91_Lig_BC_15  sciPlex_theis    0.967425  2597   RT_91
# A01_A02_RT_BC_94_Lig_BC_16  sciPlex_theis    0.407905  1095   RT_94
#
#                                    Drug1         Drug2 Well n_genes  \
# Cell
# A01_A02_RT_BC_13_Lig_BC_1      Cediranib     PCI-34051   B1    1896
# A01_A02_RT_BC_16_Lig_BC_2     Givinostat       SRT1720   B4    2154
# A01_A02_RT_BC_1_Lig_BC_3    Panobinostat     PCI-34051   A1    3139
# A01_A02_RT_BC_22_Lig_BC_17       control    Dacinostat  B10    1572
# A01_A02_RT_BC_28_Lig_BC_12  Panobinostat     Sorafenib   C4    2015
# A01_A02_RT_BC_34_Lig_BC_21       control    Givinostat  C10    1987
# A01_A02_RT_BC_37_Lig_BC_14    Dacinostat    Danusertib   D1    1657
# A01_A02_RT_BC_40_Lig_BC_18  Panobinostat     Dasatinib   D4    3767
# A01_A02_RT_BC_43_Lig_BC_4     Givinostat  Tanespimycin   D7    2013
# A01_A02_RT_BC_46_Lig_BC_22    Givinostat      Carmofur  D10    2123
# A01_A02_RT_BC_49_Lig_BC_10  Panobinostat       SRT2104   E1    3453
# A01_A02_RT_BC_4_Lig_BC_15   Panobinostat       SRT1720   A4    1649
# A01_A02_RT_BC_52_Lig_BC_32  Panobinostat    Crizotinib   E4    3262
# A01_A02_RT_BC_55_Lig_BC_22  Alvespimycin   Pirarubicin   E7    3590
# A01_A02_RT_BC_61_Lig_BC_1     Givinostat       SRT2104   F1    1607
# A01_A02_RT_BC_64_Lig_BC_29    Givinostat     Sorafenib   F4     977
# A01_A02_RT_BC_70_Lig_BC_12       control  Alvespimycin  F10    2801
# A01_A02_RT_BC_73_Lig_BC_11  Panobinostat      Curcumin   G1    1114
# A01_A02_RT_BC_76_Lig_BC_58    Givinostat     Dasatinib   G4    1011
# A01_A02_RT_BC_79_Lig_BC_57       SRT2104  Alvespimycin   G7    1459
# A01_A02_RT_BC_82_Lig_BC_10       control       SRT2104  G10    2273
# A01_A02_RT_BC_88_Lig_BC_49    Givinostat    Crizotinib   H4    1396
# A01_A02_RT_BC_91_Lig_BC_15       SRT3025     Cediranib   H7    1756
# A01_A02_RT_BC_94_Lig_BC_16       control     Dasatinib  H10     867
#
#                            n_genes_by_counts total_counts  ...  split control  \
# Cell                                                       ...
# A01_A02_RT_BC_13_Lig_BC_1               1895       2907.0  ...  train       0
# A01_A02_RT_BC_16_Lig_BC_2               2152       3485.0  ...  train       0
# A01_A02_RT_BC_1_Lig_BC_3                3138       5774.0  ...  train       0
# A01_A02_RT_BC_22_Lig_BC_17              1569       2412.0  ...  train       0
# A01_A02_RT_BC_28_Lig_BC_12              2015       3050.0  ...  train       0
# A01_A02_RT_BC_34_Lig_BC_21              1985       3098.0  ...  train       0
# A01_A02_RT_BC_37_Lig_BC_14              1656       2472.0  ...  train       0
# A01_A02_RT_BC_40_Lig_BC_18              3760       7087.0  ...  train       0
# A01_A02_RT_BC_43_Lig_BC_4               2011       3103.0  ...  train       0
# A01_A02_RT_BC_46_Lig_BC_22              2123       3314.0  ...  train       0
# A01_A02_RT_BC_49_Lig_BC_10              3451       6458.0  ...  train       0
# A01_A02_RT_BC_4_Lig_BC_15               1649       2502.0  ...  train       0
# A01_A02_RT_BC_52_Lig_BC_32              3260       6063.0  ...  train       0
# A01_A02_RT_BC_55_Lig_BC_22              3589       7468.0  ...  train       0
# A01_A02_RT_BC_61_Lig_BC_1               1607       2408.0  ...  train       0
# A01_A02_RT_BC_64_Lig_BC_29               977       1270.0  ...  train       0
# A01_A02_RT_BC_70_Lig_BC_12              2800       5086.0  ...  train       0
# A01_A02_RT_BC_73_Lig_BC_11              1113       1447.0  ...  train       0
# A01_A02_RT_BC_76_Lig_BC_58              1011       1315.0  ...  train       0
# A01_A02_RT_BC_79_Lig_BC_57              1456       2070.0  ...  train       0
# A01_A02_RT_BC_82_Lig_BC_10              2273       3739.0  ...  train       0
# A01_A02_RT_BC_88_Lig_BC_49              1396       1962.0  ...  train       0
# A01_A02_RT_BC_91_Lig_BC_15              1754       2595.0  ...  train       0
# A01_A02_RT_BC_94_Lig_BC_16               867       1095.0  ...  train       0
#
#                            cell_type cell_line  \
# Cell
# A01_A02_RT_BC_13_Lig_BC_1       A549      A549
# A01_A02_RT_BC_16_Lig_BC_2       A549      A549
# A01_A02_RT_BC_1_Lig_BC_3        A549      A549
# A01_A02_RT_BC_22_Lig_BC_17      A549      A549
# A01_A02_RT_BC_28_Lig_BC_12      A549      A549
# A01_A02_RT_BC_34_Lig_BC_21      A549      A549
# A01_A02_RT_BC_37_Lig_BC_14      A549      A549
# A01_A02_RT_BC_40_Lig_BC_18      A549      A549
# A01_A02_RT_BC_43_Lig_BC_4       A549      A549
# A01_A02_RT_BC_46_Lig_BC_22      A549      A549
# A01_A02_RT_BC_49_Lig_BC_10      A549      A549
# A01_A02_RT_BC_4_Lig_BC_15       A549      A549
# A01_A02_RT_BC_52_Lig_BC_32      A549      A549
# A01_A02_RT_BC_55_Lig_BC_22      A549      A549
# A01_A02_RT_BC_61_Lig_BC_1       A549      A549
# A01_A02_RT_BC_64_Lig_BC_29      A549      A549
# A01_A02_RT_BC_70_Lig_BC_12      A549      A549
# A01_A02_RT_BC_73_Lig_BC_11      A549      A549
# A01_A02_RT_BC_76_Lig_BC_58      A549      A549
# A01_A02_RT_BC_79_Lig_BC_57      A549      A549
# A01_A02_RT_BC_82_Lig_BC_10      A549      A549
# A01_A02_RT_BC_88_Lig_BC_49      A549      A549
# A01_A02_RT_BC_91_Lig_BC_15      A549      A549
# A01_A02_RT_BC_94_Lig_BC_16      A549      A549
#
#                                                                 smiles_drug_1  \
# Cell
# A01_A02_RT_BC_13_Lig_BC_1   CC1=CC2=C(N1)C=CC(=C2F)OC3=NC=NC4=CC(=C(C=C43)...
# A01_A02_RT_BC_16_Lig_BC_2   CCN(CC)CC1=CC2=C(C=C1)C=C(C=C2)COC(=O)NC3=CC=C...
# A01_A02_RT_BC_1_Lig_BC_3    CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_22_Lig_BC_17                                                NaN
# A01_A02_RT_BC_28_Lig_BC_12  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_34_Lig_BC_21                                                NaN
# A01_A02_RT_BC_37_Lig_BC_14  C1=CC=C2C(=C1)C(=CN2)CCN(CCO)CC3=CC=C(C=C3)/C=...
# A01_A02_RT_BC_40_Lig_BC_18  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_43_Lig_BC_4   CCN(CC)CC1=CC2=C(C=C1)C=C(C=C2)COC(=O)NC3=CC=C...
# A01_A02_RT_BC_46_Lig_BC_22  CCN(CC)CC1=CC2=C(C=C1)C=C(C=C2)COC(=O)NC3=CC=C...
# A01_A02_RT_BC_49_Lig_BC_10  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_4_Lig_BC_15   CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_52_Lig_BC_32  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_55_Lig_BC_22  C[C@H]1C[C@@H]([C@@H]([C@H](/C=C(/[C@@H]([C@H]...
# A01_A02_RT_BC_61_Lig_BC_1   CCN(CC)CC1=CC2=C(C=C1)C=C(C=C2)COC(=O)NC3=CC=C...
# A01_A02_RT_BC_64_Lig_BC_29  CCN(CC)CC1=CC2=C(C=C1)C=C(C=C2)COC(=O)NC3=CC=C...
# A01_A02_RT_BC_70_Lig_BC_12                                                NaN
# A01_A02_RT_BC_73_Lig_BC_11  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_76_Lig_BC_58  CCN(CC)CC1=CC2=C(C=C1)C=C(C=C2)COC(=O)NC3=CC=C...
# A01_A02_RT_BC_79_Lig_BC_57  CC1=C(SC(=N1)C2=CN=CC=C2)C(=O)NC3=CC=CC=C3C4=C...
# A01_A02_RT_BC_82_Lig_BC_10                                                NaN
# A01_A02_RT_BC_88_Lig_BC_49  CCN(CC)CC1=CC2=C(C=C1)C=C(C=C2)COC(=O)NC3=CC=C...
# A01_A02_RT_BC_91_Lig_BC_15  COCCCC1=C(N=C(S1)C2=CC=CC=C2)C(=O)NC3=CC=CC=C3...
# A01_A02_RT_BC_94_Lig_BC_16                                                NaN
#
#                                                                 smiles_drug_2  \
# Cell
# A01_A02_RT_BC_13_Lig_BC_1          COC1=CC=C(C=C1)CN2C=CC3=C2C=C(C=C3)C(=O)NO
# A01_A02_RT_BC_16_Lig_BC_2   C1CN(CCN1)CC2=CSC3=NC(=CN23)C4=CC=CC=C4NC(=O)C...
# A01_A02_RT_BC_1_Lig_BC_3           COC1=CC=C(C=C1)CN2C=CC3=C2C=C(C=C3)C(=O)NO
# A01_A02_RT_BC_22_Lig_BC_17  C1=CC=C2C(=C1)C(=CN2)CCN(CCO)CC3=CC=C(C=C3)/C=...
# A01_A02_RT_BC_28_Lig_BC_12  CNC(=O)C1=NC=CC(=C1)OC2=CC=C(C=C2)NC(=O)NC3=CC...
# A01_A02_RT_BC_34_Lig_BC_21  CCN(CC)CC1=CC2=C(C=C1)C=C(C=C2)COC(=O)NC3=CC=C...
# A01_A02_RT_BC_37_Lig_BC_14  CN1CCN(CC1)C2=CC=C(C=C2)C(=O)NC3=NNC4=C3CN(C4)...
# A01_A02_RT_BC_40_Lig_BC_18  CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=CC(=NC(...
# A01_A02_RT_BC_43_Lig_BC_4   C[C@H]1C[C@@H]([C@@H]([C@H](/C=C(/[C@@H]([C@H]...
# A01_A02_RT_BC_46_Lig_BC_22                     CCCCCCNC(=O)N1C=C(C(=O)NC1=O)F
# A01_A02_RT_BC_49_Lig_BC_10  CC1=C(SC(=N1)C2=CN=CC=C2)C(=O)NC3=CC=CC=C3C4=C...
# A01_A02_RT_BC_4_Lig_BC_15   C1CN(CCN1)CC2=CSC3=NC(=CN23)C4=CC=CC=C4NC(=O)C...
# A01_A02_RT_BC_52_Lig_BC_32  C[C@H](C1=C(C=CC(=C1Cl)F)Cl)OC2=C(N=CC(=C2)C3=...
# A01_A02_RT_BC_55_Lig_BC_22  C[C@H]1[C@H]([C@H](C[C@@H](O1)O[C@H]2C[C@@](CC...
# A01_A02_RT_BC_61_Lig_BC_1   CC1=C(SC(=N1)C2=CN=CC=C2)C(=O)NC3=CC=CC=C3C4=C...
# A01_A02_RT_BC_64_Lig_BC_29  CNC(=O)C1=NC=CC(=C1)OC2=CC=C(C=C2)NC(=O)NC3=CC...
# A01_A02_RT_BC_70_Lig_BC_12  C[C@H]1C[C@@H]([C@@H]([C@H](/C=C(/[C@@H]([C@H]...
# A01_A02_RT_BC_73_Lig_BC_11  COC1=C(C=CC(=C1)/C=C/C(=O)CC(=O)/C=C/C2=CC(=C(...
# A01_A02_RT_BC_76_Lig_BC_58  CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=CC(=NC(...
# A01_A02_RT_BC_79_Lig_BC_57  C[C@H]1C[C@@H]([C@@H]([C@H](/C=C(/[C@@H]([C@H]...
# A01_A02_RT_BC_82_Lig_BC_10  CC1=C(SC(=N1)C2=CN=CC=C2)C(=O)NC3=CC=CC=C3C4=C...
# A01_A02_RT_BC_88_Lig_BC_49  C[C@H](C1=C(C=CC(=C1Cl)F)Cl)OC2=C(N=CC(=C2)C3=...
# A01_A02_RT_BC_91_Lig_BC_15  CC1=CC2=C(N1)C=CC(=C2F)OC3=NC=NC4=CC(=C(C=C43)...
# A01_A02_RT_BC_94_Lig_BC_16  CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=CC(=NC(...
#
#                                              ood_1    ood_2  \
# Cell
# A01_A02_RT_BC_13_Lig_BC_1                  not ood  not ood
# A01_A02_RT_BC_16_Lig_BC_2       Givinostat+SRT1720  not ood
# A01_A02_RT_BC_1_Lig_BC_3    Panobinostat+PCI-34051  not ood
# A01_A02_RT_BC_22_Lig_BC_17                 not ood  not ood
# A01_A02_RT_BC_28_Lig_BC_12                 not ood  not ood
# A01_A02_RT_BC_34_Lig_BC_21                 not ood  not ood
# A01_A02_RT_BC_37_Lig_BC_14                 not ood  not ood
# A01_A02_RT_BC_40_Lig_BC_18  Panobinostat+Dasatinib  not ood
# A01_A02_RT_BC_43_Lig_BC_4                  not ood  not ood
# A01_A02_RT_BC_46_Lig_BC_22                 not ood  not ood
# A01_A02_RT_BC_49_Lig_BC_10    Panobinostat+SRT2104  not ood
# A01_A02_RT_BC_4_Lig_BC_15                  not ood  not ood
# A01_A02_RT_BC_52_Lig_BC_32                 not ood  not ood
# A01_A02_RT_BC_55_Lig_BC_22                 not ood  not ood
# A01_A02_RT_BC_61_Lig_BC_1                  not ood  not ood
# A01_A02_RT_BC_64_Lig_BC_29                 not ood  not ood
# A01_A02_RT_BC_70_Lig_BC_12                 not ood  not ood
# A01_A02_RT_BC_73_Lig_BC_11                 not ood  not ood
# A01_A02_RT_BC_76_Lig_BC_58    Givinostat+Dasatinib  not ood
# A01_A02_RT_BC_79_Lig_BC_57                 not ood  not ood
# A01_A02_RT_BC_82_Lig_BC_10                 not ood  not ood
# A01_A02_RT_BC_88_Lig_BC_49                 not ood  not ood
# A01_A02_RT_BC_91_Lig_BC_15       SRT3025+Cediranib  not ood
# A01_A02_RT_BC_94_Lig_BC_16       control+Dasatinib  not ood
#
#                                               ood_3                  ood_4
# Cell
# A01_A02_RT_BC_13_Lig_BC_1                   not ood    Cediranib+PCI-34051
# A01_A02_RT_BC_16_Lig_BC_2                   not ood                not ood
# A01_A02_RT_BC_1_Lig_BC_3                    not ood                not ood
# A01_A02_RT_BC_22_Lig_BC_17       control+Dacinostat                not ood
# A01_A02_RT_BC_28_Lig_BC_12   Panobinostat+Sorafenib                not ood
# A01_A02_RT_BC_34_Lig_BC_21                  not ood     control+Givinostat
# A01_A02_RT_BC_37_Lig_BC_14                  not ood                not ood
# A01_A02_RT_BC_40_Lig_BC_18                  not ood                not ood
# A01_A02_RT_BC_43_Lig_BC_4                   not ood                not ood
# A01_A02_RT_BC_46_Lig_BC_22                  not ood                not ood
# A01_A02_RT_BC_49_Lig_BC_10                  not ood                not ood
# A01_A02_RT_BC_4_Lig_BC_15      Panobinostat+SRT1720                not ood
# A01_A02_RT_BC_52_Lig_BC_32  Panobinostat+Crizotinib                not ood
# A01_A02_RT_BC_55_Lig_BC_22                  not ood                not ood
# A01_A02_RT_BC_61_Lig_BC_1                   not ood     Givinostat+SRT2104
# A01_A02_RT_BC_64_Lig_BC_29                  not ood   Givinostat+Sorafenib
# A01_A02_RT_BC_70_Lig_BC_12     control+Alvespimycin                not ood
# A01_A02_RT_BC_73_Lig_BC_11    Panobinostat+Curcumin                not ood
# A01_A02_RT_BC_76_Lig_BC_58                  not ood                not ood
# A01_A02_RT_BC_79_Lig_BC_57     SRT2104+Alvespimycin                not ood
# A01_A02_RT_BC_82_Lig_BC_10                  not ood        control+SRT2104
# A01_A02_RT_BC_88_Lig_BC_49                  not ood  Givinostat+Crizotinib
# A01_A02_RT_BC_91_Lig_BC_15                  not ood                not ood
# A01_A02_RT_BC_94_Lig_BC_16                  not ood                not ood
#
# [24 rows x 26 columns]

# %%
preds_ood = cf.predict(adata=adata_ood_ctrl, sample_rep="X_pca", condition_id_key="condition", covariate_data=covariate_data_ood)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 preds_ood = cf.predict(adata=adata_ood_ctrl, sample_rep="X_pca", condition_id_key="condition", covariate_data=covariate_data_ood)
#
# NameError: name 'cf' is not defined

# %%
import pandas as pd
import seaborn as sns
import scanpy as sc
import matplotlib.pyplot as plt

# %%
split = 1
path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_ood_{split}.h5ad"
adata_ood = sc.read(path)
ood_conditions = adata_ood.obs["condition"].cat.categories

# %%
df = pd.read_csv("gse_score_1.csv")
df = df.drop(columns=["Unnamed: 0"])
df = df.T
df["score"] = df[0]
df["condition"] = df.index

# %%
def get_mode(x):
    if "pred" in x["condition"]:
        return "ood_pred"
    if x["condition"] in ood_conditions:
        return "ood_true"
    return "seen"

# %%
df["mode"] = df.apply(get_mode, axis=1)

# %%
df.head()
# Out:
#                                  0     score                 condition  mode
# Alvespimycin+Pirarubicin -0.859834 -0.859834  Alvespimycin+Pirarubicin  seen
# Cediranib+PCI-34051       0.663615  0.663615       Cediranib+PCI-34051  seen
# Dacinostat+Danusertib    -0.869584 -0.869584     Dacinostat+Danusertib  seen
# Dacinostat+Dasatinib     -0.864269 -0.864269      Dacinostat+Dasatinib  seen
# Dacinostat+PCI-34051     -0.851803 -0.851803      Dacinostat+PCI-34051  seen

# %%
df_true = df[df["mode"]=="ood_true"]
df_pred = df[df["mode"]=="ood_pred"]

# %%
df_true["rank_true"] = df_true["score"].rank()
df_pred["rank_pred"] = df_pred["score"].rank()
# Out:
# /tmp/ipykernel_853928/1674682805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_true["rank_true"] = df_true["score"].rank()
# /tmp/ipykernel_853928/1674682805.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pred["rank_pred"] = df_pred["score"].rank()

# %%
df_pred["condition"] = df_pred.index
df_pred["condition"] = df_pred.apply(lambda x: x["condition"].split('_', 1)[0], axis=1)
# Out:
# /tmp/ipykernel_853928/2401045840.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pred["condition"] = df_pred.index
# /tmp/ipykernel_853928/2401045840.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pred["condition"] = df_pred.apply(lambda x: x["condition"].split('_', 1)[0], axis=1)

# %%
df_pred = df_pred.set_index("condition")

# %%
df_res = pd.concat((df_true, df_pred), axis=1)

# %%
df_res
# Out:
#                                0     score               condition      mode  \
# Givinostat+Dasatinib   -0.824149 -0.824149    Givinostat+Dasatinib  ood_true
# Givinostat+SRT1720     -0.824797 -0.824797      Givinostat+SRT1720  ood_true
# Panobinostat+Dasatinib -0.786168 -0.786168  Panobinostat+Dasatinib  ood_true
# Panobinostat+PCI-34051 -0.795763 -0.795763  Panobinostat+PCI-34051  ood_true
# Panobinostat+SRT2104   -0.789049 -0.789049    Panobinostat+SRT2104  ood_true
# SRT3025+Cediranib       0.282327  0.282327       SRT3025+Cediranib  ood_true
# control+Dasatinib      -0.894212 -0.894212       control+Dasatinib  ood_true
#
#                         rank_true         0     score      mode  rank_pred
# Givinostat+Dasatinib          3.0 -0.885040 -0.885040  ood_pred        2.0
# Givinostat+SRT1720            2.0 -0.886288 -0.886288  ood_pred        1.0
# Panobinostat+Dasatinib        6.0 -0.795624 -0.795624  ood_pred        4.0
# Panobinostat+PCI-34051        4.0 -0.791184 -0.791184  ood_pred        5.0
# Panobinostat+SRT2104          5.0 -0.784808 -0.784808  ood_pred        6.0
# SRT3025+Cediranib             7.0 -0.807948 -0.807948  ood_pred        3.0
# control+Dasatinib             1.0 -0.741075 -0.741075  ood_pred        7.0

# %%
sns.scatterplot(df_res, x="rank_true", y="rank_pred")
for i in range(df_res.shape[0]):
    plt.text(df_res['rank_true'][i] + 0.05, df_res['rank_pred'][i], df_res['condition'][i], fontsize=9)
plt.xlabel("True rank among OOD drugs of pathway activation")
plt.ylabel("Predicted rank among OOD\n drugs of pathway activation")
# Out:
# /tmp/ipykernel_853928/3574232351.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df_res['rank_true'][i] + 0.05, df_res['rank_pred'][i], df_res['condition'][i], fontsize=9)
# Text(0, 0.5, 'Predicted rank among OOD\n drugs of pathway activation')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.set(style="ticks")

# Create scatterplot with labels
ax = sns.scatterplot(data=df_res, x="rank_true", y="rank_pred", s=100)

# Add labels to each point
for i in range(df_res.shape[0]):
    if df_res['rank_true'][i] > 5:  # Adjusting for true rank > 5
        ax.text(df_res['rank_true'][i] - 0.1, df_res['rank_pred'][i], df_res['condition'][i], fontsize=10, color='black', ha='right')
    else:
        ax.text(df_res['rank_true'][i] + 0.1, df_res['rank_pred'][i], df_res['condition'][i], fontsize=10, color='black')


# Set axis labels and title
plt.xlabel("True rank", fontsize=12)
plt.ylabel("Predicted rank", fontsize=12)
plt.title("True vs Predicted Rank of OOD Drugs on CCNB1 Pathway Activation", fontsize=14)

sns.despine()
# Display the plot
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_853928/2991197323.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if df_res['rank_true'][i] > 5:  # Adjusting for true rank > 5
# /tmp/ipykernel_853928/2991197323.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(df_res['rank_true'][i] + 0.1, df_res['rank_pred'][i], df_res['condition'][i], fontsize=10, color='black')
# /tmp/ipykernel_853928/2991197323.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(df_res['rank_true'][i] - 0.1, df_res['rank_pred'][i], df_res['condition'][i], fontsize=10, color='black', ha='right')

# %%
import matplotlib.pyplot as plt
sns.barplot(df, y="condition", x="score", hue="mode")
plt.xticks(rotation=0)
plt.yticks(fontsize=8) 
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
import matplotlib.pyplot as plt
sns.barplot(df, y="condition", x="score", hue="mode")
plt.xticks(rotation=0)
plt.yticks(fontsize=8) 
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

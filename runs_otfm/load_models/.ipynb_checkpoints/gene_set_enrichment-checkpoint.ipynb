# %%
import scanpy as sc
import anndata as ad

# %%
split = 1

# %%
adata_pred_ood = sc.read(f"/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/combosciplex/adata_ood_with_predictions_{split}.h5ad")
adata_pred_test = sc.read(f"/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/combosciplex/adata_test_with_predictions_{split}.h5ad")

# %%
adata_pred_ood.X = adata_pred_ood.layers["X_recon_pred"]
adata_pred_test.X = adata_pred_test.layers["X_recon_pred"]

# %%
adata_train_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_train_{split}.h5ad"
adata_test_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_test_{split}.h5ad"
adata_ood_path = f"/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/adata_ood_{split}.h5ad"

# %%
adata_train = sc.read(adata_train_path)
adata_test = sc.read(adata_test_path)
adata_ood = sc.read(adata_ood_path)

# %%
adata_ood = adata_ood[adata_ood.obs["condition"]!="control"]

# %%
adata_pred_ood.var_names = adata_ood.var_names
adata_pred_test.var_names = adata_test.var_names

# %%
bdata_ood = ad.concat((adata_train, adata_ood, adata_pred_ood), label="mode", keys=["train", "ood_true", "ood_pred"])

# %%
sc.pp.pca(bdata_ood)
sc.pp.neighbors(bdata_ood)
sc.tl.umap(bdata_ood)

# %%
sc.pl.umap(bdata_ood, color=["condition"])

# %%
bdata_ood.obs["mode_with_control"] = bdata_ood.obs.apply(lambda x: "control" if x["condition"] == "control" else x["mode"], axis=1)

# %%
palette = {"control": "#8f97a8" , "ood_pred": "#a4fa6e" , "ood_true": "#1099c7" , "train": "#d3d3d3"}
sc.pl.umap(bdata_ood, color=["mode_with_control"], palette=palette, size=5)

# %%
def get_mode_condition(x):
    if x["mode"] == "train":
        return "train"
    return x["mode"] + "_" + x["condition"]

def get_condition_only(x, condition):
    if x["condition"] == condition:
        return x["condition"] + "_" + x["mode"]
    return "other"

# %%
bdata_ood.obs["mode_condition"] = bdata_ood.obs.apply(get_mode_condition, axis=1)

# %%
for cond in adata_ood.obs["condition"].cat.categories:
    bdata_ood.obs[cond] = bdata_ood.obs.apply(lambda x: get_condition_only(x, cond), axis=1)

# %%
bdata_ood.obs["Givinostat+Dasatinib"].value_counts()
# Out:
# Givinostat+Dasatinib
# other                            61557
# Givinostat+Dasatinib_ood_true     2421
# Givinostat+Dasatinib_ood_pred      500
# Name: count, dtype: int64

# %%
palette = {}
for col in bdata_ood.obs[adata_ood.obs["condition"].cat.categories]:
    categories = bdata_ood.obs[col].unique()
    for cat in categories:
        if cat == "other":
            palette[cat] =  "#d3d3d3"
        elif "true" in cat:
            palette[cat] = "#1099c7"
        elif "pred" in cat:
            palette[cat] = "#a4fa6e"

# %%
conditions = set(adata_ood.obs["condition"].cat.categories) - set(('control',))

# %%
sc.pl.umap(bdata_ood, color=conditions, palette=palette, ncols=1, size=5)

# %%
set(adata_train.var_names).intersection(set(["AKT2", "KMT2B", "CCNE1", "CIC"]))
# Out:
# set()

# %%
"AKT2", "KMT2B", "CCNE1", "CIC"

# %%
[el for el in adata_train.var_names if el.startswith("CCN")]
# Out:
# ['CCND1', 'CCNB1']

# %%
sc.pl.umap(adata_train, color=['CCND1', 'CCNB1', 'CD79A', 'control'])

# %%
adata_train.obs.head()
# Out:
#                                    sample Size_Factor n.umi RT_well    Drug1  \
# Cell
# A01_A02_RT_BC_10_Lig_BC_18  sciPlex_theis    0.533816  1433   RT_10  control
# A01_A02_RT_BC_10_Lig_BC_25  sciPlex_theis    0.539404  1448   RT_10  control
# A01_A02_RT_BC_10_Lig_BC_48  sciPlex_theis    0.532326  1429   RT_10  control
# A01_A02_RT_BC_10_Lig_BC_51  sciPlex_theis    1.461754  3924   RT_10  control
# A01_A02_RT_BC_10_Lig_BC_72  sciPlex_theis    0.490976  1318   RT_10  control
#
#                                    Drug2 Well n_genes n_genes_by_counts  \
# Cell
# A01_A02_RT_BC_10_Lig_BC_18  Panobinostat  A10    1004              1004
# A01_A02_RT_BC_10_Lig_BC_25  Panobinostat  A10    1062              1062
# A01_A02_RT_BC_10_Lig_BC_48  Panobinostat  A10    1063              1063
# A01_A02_RT_BC_10_Lig_BC_51  Panobinostat  A10    2412              2411
# A01_A02_RT_BC_10_Lig_BC_72  Panobinostat  A10     960               960
#
#                            total_counts  ...  split control cell_type  \
# Cell                                     ...
# A01_A02_RT_BC_10_Lig_BC_18       1433.0  ...  train       0      A549
# A01_A02_RT_BC_10_Lig_BC_25       1448.0  ...  train       0      A549
# A01_A02_RT_BC_10_Lig_BC_48       1429.0  ...  train       0      A549
# A01_A02_RT_BC_10_Lig_BC_51       3923.0  ...  train       0      A549
# A01_A02_RT_BC_10_Lig_BC_72       1318.0  ...  train       0      A549
#
#                            cell_line smiles_drug_1  \
# Cell
# A01_A02_RT_BC_10_Lig_BC_18      A549           NaN
# A01_A02_RT_BC_10_Lig_BC_25      A549           NaN
# A01_A02_RT_BC_10_Lig_BC_48      A549           NaN
# A01_A02_RT_BC_10_Lig_BC_51      A549           NaN
# A01_A02_RT_BC_10_Lig_BC_72      A549           NaN
#
#                                                                 smiles_drug_2  \
# Cell
# A01_A02_RT_BC_10_Lig_BC_18  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_10_Lig_BC_25  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_10_Lig_BC_48  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_10_Lig_BC_51  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
# A01_A02_RT_BC_10_Lig_BC_72  CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)/C=C/C(=O)NO
#
#                               ood_1                 ood_2    ood_3    ood_4
# Cell
# A01_A02_RT_BC_10_Lig_BC_18  not ood  control+Panobinostat  not ood  not ood
# A01_A02_RT_BC_10_Lig_BC_25  not ood  control+Panobinostat  not ood  not ood
# A01_A02_RT_BC_10_Lig_BC_48  not ood  control+Panobinostat  not ood  not ood
# A01_A02_RT_BC_10_Lig_BC_51  not ood  control+Panobinostat  not ood  not ood
# A01_A02_RT_BC_10_Lig_BC_72  not ood  control+Panobinostat  not ood  not ood
#
# [5 rows x 26 columns]

# %%
sc.pl.dotplot(adata_ood, ["CCNB1", "MKI67"], groupby="condition")

# %%
sc.pl.dotplot(adata_pred_ood, ["CCNB1", "MKI67"], groupby="condition")

# %%
sc.pl.dotplot(adata_pred_ood, ["MKI67"], groupby="condition")

# %%
sc.pl.dotplot(adata_ood, ["MKI67"], groupby="condition")

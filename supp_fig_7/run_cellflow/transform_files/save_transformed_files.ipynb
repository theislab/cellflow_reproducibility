# %%
import os
import cfp
import scanpy as sc
import numpy as np
import optax
import hydra 
from omegaconf import DictConfig, OmegaConf
from functools import partial
from cfp.training import Metrics, PCADecodedMetrics
from cfp.metrics import compute_metrics, compute_metrics_fast
from sklearn.metrics import r2_score
import datetime
import yaml
import jax.numpy as jnp
import torch
from utils import Config, get_highest_checkpoint_file, reconstruct_data_fn
from cfp.data._dataloader import ValidationSampler
import pandas as pd
import jax.tree_util as jtu
import cfp.preprocessing as cfpp

import seaborn as sns
import anndata as ad
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## Load the data of split 0

# %%
path_to_splits = Path("/lustre/groups/ml01/workspace/ot_perturbation/data/satija/datasets/adata_ood_final_genes/adata_ood_final_genesIFNG_IFNB_TNFA_TGFB_INS_hvg-500_pca-100_counts_ms_0.5")

# %%
adata_train_path = path_to_splits / "adata_train_split_0.h5ad"
adata_test_path = path_to_splits / "adata_test_split_0.h5ad"
adata_ood_path = path_to_splits / "adata_ood_split_0.h5ad"
adata_train = sc.read_h5ad(adata_train_path)
adata_test = sc.read_h5ad(adata_test_path)
adata_ood = sc.read_h5ad(adata_ood_path)

# %% [markdown]
# Collect controls and perturbed

# %%
adata_ood_ctrl = adata_ood[adata_ood.obs["control"]]
adata_test_ctrl = adata_test[adata_test.obs["control"]]

covariate_data_ood = adata_ood[~adata_ood.obs["control"]].obs.drop_duplicates(subset=["perturbation_condition"])
covariate_data_test = adata_test[~adata_test.obs["control"]].obs.drop_duplicates(subset=["perturbation_condition"])

# %% [markdown]
# Read cellFlow from checkpoint

# %%
cf = cfp.model.CellFlow.load(f"/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/ckpt_split_0/satija_gene_ood_0_CellFlow.pkl")

# %%
preds_ood = cf.predict(adata=adata_ood_ctrl, sample_rep="X_pca", condition_id_key="perturbation_condition", covariate_data=covariate_data_ood)
# Out:
# /ictstr01/home/icb/alessandro.palma/environment/ot_pert/cell_flow_perturbation/src/cfp/data/_datamanager.py:551: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs[self._control_key] = adata.obs[self._control_key].astype(
# /ictstr01/home/icb/alessandro.palma/environment/ot_pert/cell_flow_perturbation/src/cfp/data/_datamanager.py:358: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _covariate_data["cell_index"] = _covariate_data.index
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2024-12-20 10:50:21.607355: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:21.616085: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:30.153043: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:30.153177: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:36.738704: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:36.738842: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:43.636396: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:43.636501: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:49.951056: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:49.951203: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:56.832904: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:50:56.833089: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:04.181864: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:04.182027: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:11.076455: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:11.076621: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:17.760041: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:17.760164: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:25.389317: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:25.389424: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:32.518543: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:32.518700: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:39.021022: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:39.021130: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:45.625337: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:45.625442: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:52.217918: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:52.218098: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:59.493299: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:51:59.493443: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:06.218386: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:06.218579: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:13.932656: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:13.932790: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:26.960080: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:26.960212: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:33.692995: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:33.693117: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:41.253498: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:41.253604: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:47.589112: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:47.589215: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:53.557653: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:53.557762: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:59.866390: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:52:59.866580: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:06.765410: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:06.765585: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:14.322094: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:14.322259: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:21.334808: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:21.334963: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:27.967453: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:27.967615: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:34.418375: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:34.418513: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:41.587202: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:41.587350: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:49.166978: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:49.167118: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:55.734913: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:53:55.735049: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:03.031174: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:03.031317: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:09.975341: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:09.975484: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:17.274585: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:17.274756: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:24.015878: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:24.016021: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:31.201929: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:31.202104: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:37.967381: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:37.967529: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:45.232775: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:45.232897: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:51.331036: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:54:51.331143: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:00.572537: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:00.572657: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:13.762479: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:13.763073: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:25.583951: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:25.584067: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:32.460384: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:32.460512: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:38.742873: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:38.743004: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:45.833280: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:45.833435: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:52.717504: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:52.717708: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:59.434311: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:55:59.434423: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:05.637300: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:05.637505: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:12.336558: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:12.336653: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:18.314258: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:18.314412: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:25.693036: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:25.693176: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:31.971360: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:31.971572: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:38.397557: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:38.397700: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:45.450106: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:45.450223: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:52.065962: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:52.066102: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:58.639221: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:56:58.639359: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:05.185438: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:05.185540: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:11.384639: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:11.384781: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:19.541594: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:19.541785: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:27.035423: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:27.035601: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:33.829551: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:33.829665: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:41.848502: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:41.848656: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:48.859579: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:48.859744: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:55.352313: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:57:55.352467: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:02.814630: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:02.815113: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:09.283613: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:09.283762: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:16.296243: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:16.296406: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:22.509920: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:22.510082: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:29.418130: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:29.418257: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:35.505300: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:35.505427: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:41.844151: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:41.844276: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:48.514015: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:48.514166: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:54.565866: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:58:54.566023: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:00.909835: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:00.909965: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:10.662257: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:10.662439: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:18.235230: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:18.235418: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:25.607851: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:25.608061: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:32.054994: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:32.055159: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:39.573061: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:39.573185: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:45.919773: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:45.919994: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:52.627710: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:52.627878: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:59.588394: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 10:59:59.588556: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:08.428165: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:08.428325: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:15.458179: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:15.458343: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:22.418886: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:22.419086: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:28.749036: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:28.749196: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:36.736423: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:36.736596: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:43.918435: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:43.918605: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:49.971594: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:49.971753: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:55.865620: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:00:55.865787: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:01:04.679434: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:01:04.679581: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:01:10.646266: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# ...
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:19.348528: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:19.348691: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:25.363229: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:25.363439: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:31.576023: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:31.576162: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:37.744609: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:37.744759: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:44.470594: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:44.470752: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:50.643627: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:50.643781: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:56.784005: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:09:56.784178: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:03.904878: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:03.905010: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:10.506994: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:10.507208: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:20.045296: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:20.045801: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:27.664679: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:27.664782: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:37.926972: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:37.927163: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:44.616545: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:44.616705: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:51.126021: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:51.126224: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:57.587672: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:10:57.587862: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:05.150381: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:05.150579: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:12.445024: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:12.445201: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:19.511665: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:19.511894: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:25.940204: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:25.940364: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:31.947585: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:31.947745: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:38.126079: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:38.126206: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:44.300843: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:44.301009: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:51.309084: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:51.309247: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:57.955124: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:11:57.955295: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:04.309845: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:04.310014: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:11.520447: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:11.520601: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:18.169683: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:18.169867: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:24.694996: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:24.695183: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:31.618608: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:31.618760: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:38.385582: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:38.385754: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:44.800520: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:12:44.800705: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.

# %%
# del adata_train

# %% [markdown]
# ## Assamble and save

# %%
all_data = []
conditions = []

# %%
for condition, array in preds_ood.items():
    all_data.append(array)
    conditions.extend([condition] * array.shape[0])

# %%
# Stack all data vertically to create a single array
all_data_array = np.vstack(all_data)

# Create a DataFrame for the .obs attribute
obs_data = pd.DataFrame({
    'perturbation_condition': conditions
})

# %% [markdown]
# **Predict on OOD**

# %%
# Create the Anndata object
adata_ood_result = ad.AnnData(X=np.empty((len(all_data_array), 8265)), obs=obs_data)
adata_ood_result.obsm["X_pca_pred"] = all_data_array
# Out:
# /home/icb/alessandro.palma/miniconda3/envs/ot_pert/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata_ood_result
# Out:
# AnnData object with n_obs × n_vars = 19300 × 8265
#     obs: 'perturbation_condition'
#     obsm: 'X_pca_pred'

# %%
cfpp.reconstruct_pca(query_adata=adata_ood_result, use_rep="X_pca_pred", ref_adata=adata_train, layers_key_added="X_recon_pred")

# %%
adata_ood_result.write("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/generated_data/adata_ood_split_0.h5ad")

# %% [markdown]
# **Predict on test**

# %%
preds_test = cf.predict(adata=adata_test_ctrl, sample_rep="X_pca", condition_id_key="perturbation_condition", covariate_data=covariate_data_test)
# Out:
# /ictstr01/home/icb/alessandro.palma/environment/ot_pert/cell_flow_perturbation/src/cfp/data/_datamanager.py:551: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs[self._control_key] = adata.obs[self._control_key].astype(
# /ictstr01/home/icb/alessandro.palma/environment/ot_pert/cell_flow_perturbation/src/cfp/data/_datamanager.py:358: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _covariate_data["cell_index"] = _covariate_data.index
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2024-12-20 11:13:08.203331: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:08.203448: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:14.902107: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:14.902256: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:21.944867: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:21.944995: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:28.053809: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:28.053938: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:35.348109: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:35.348276: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:46.973683: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:46.973812: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:53.106122: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:13:53.106274: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:01.406594: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:01.406760: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:08.523640: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:08.523795: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:15.041142: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:15.041276: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:21.121572: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:21.121703: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:28.044754: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:28.044881: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:35.595228: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:35.595365: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:42.953574: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:42.953706: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:49.136352: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:49.136479: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:55.432371: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:14:55.432523: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:02.069170: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:02.069303: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:10.273297: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:10.273415: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:19.368534: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:19.368925: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:26.491482: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:26.491615: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:34.028780: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:34.028924: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:42.610641: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:42.610898: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:49.550243: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:49.550430: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:56.226899: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:15:56.227049: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:03.406990: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:03.407191: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:10.413793: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:10.413959: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:16.740345: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:16.740500: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:23.341077: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:23.341228: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:29.462725: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:29.462880: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:36.519764: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:36.519896: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:42.626399: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:42.626579: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:49.545895: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:49.546037: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:55.947745: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:16:55.947926: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:07.109778: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:07.109940: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:13.093170: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:13.093318: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:19.241382: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:19.241557: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:26.222476: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:26.222647: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:33.414531: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:33.414659: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:39.751437: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:39.751588: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:47.174357: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:47.174534: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:53.969400: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:17:53.969582: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:00.232010: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:00.232189: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:07.142361: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:07.142550: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:13.792658: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:13.792809: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:19.986274: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:19.986449: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:26.399772: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:26.399916: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:33.679611: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:33.679736: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:40.450734: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:40.450892: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:46.984237: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:46.984368: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:54.348951: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:18:54.349163: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:01.056591: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:01.056706: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:07.809911: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:07.810086: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:15.093371: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:15.093564: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:21.706662: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:21.706811: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:27.828190: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:27.828344: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:34.788912: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:34.789066: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:41.877989: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:41.878135: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:48.170756: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:48.170926: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:54.692167: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:19:54.692287: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:20:01.040682: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:20:01.040808: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:20:07.176930: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.
# 2024-12-20 11:20:07.177054: W external/xla/xla/service/gpu/ir_emitter_unnested.cc:1171] Unable to parse backend config for custom call: Could not convert JSON string to proto: : Root element must be a message.
# Fall back to parse the raw backend config str.

# %%
all_data = []
conditions = []

for condition, array in preds_test.items():
    all_data.append(array)
    conditions.extend([condition] * array.shape[0])

# %%
# Stack all data vertically to create a single array
all_data_array = np.vstack(all_data)

# Create a DataFrame for the .obs attribute
obs_data = pd.DataFrame({
    'condition': conditions
})

# %%
# Create the Anndata object
adata_test_result = ad.AnnData(X=np.empty((len(all_data_array), 8265)), obs=obs_data)
adata_test_result.obsm["X_pca_pred"] = all_data_array

# %%
cfpp.reconstruct_pca(query_adata=adata_test_result, use_rep="X_pca_pred", ref_adata=adata_train, layers_key_added="X_recon_pred")

# %%
adata_test_result.write("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/generated_data/adata_test_split_0.h5ad")

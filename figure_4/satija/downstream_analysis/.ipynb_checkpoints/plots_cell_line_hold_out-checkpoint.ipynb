# %%
library(tidyverse)
library(dplyr)
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.2.3”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
color_dict = c(
    "CellFlow"= "#B12F8C",
    "Mean model"= "#88afd7",
    "Identity"="#E1C8AC")

# %%
output_dir <- "/lustre/groups/ml01/workspace/ot_perturbation/figures/satija/benchmark/gene_hold_out"

# %%
df <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/figures/satija/benchmark/gene_held_out/metrics_decoded.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 2424 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): ...1, OOD combination, Model
# dbl (4): r_squared, e_distance, mmd, quantile
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
df$Model <- factor(df$Model, 
                                levels = c("Identity", "Mean", "CellFlow"),
                                labels = c("Identity", "Mean model", "CellFlow"))  # Correct factorization
df$quantile <- as.character(df$quantile)

df$quantile <- factor(df$quantile, 
                                    levels = sort(as.numeric(unique(df$quantile))))

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

p <- ggplot(df, aes(x=quantile, y=r_squared, fill=Model)) +
  geom_boxplot(outlier.size=2
    ) +
  labs(
    x="Perturbation effect group",
    y="R squared decoded",
    fill="Model"
  ) +
  scale_fill_manual(values=color_dict) +  # Replace with your actual color dictionary
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16),
    axis.title.y = element_text(size=16),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "r_squared_decoded.pdf"), plot = p, device = "pdf",width = 15, height = 5)

# %%
df <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/figures/satija/benchmark/gene_held_out/metrics_deg.csv")

df$Model <- factor(df$Model, 
                                levels = c("Identity", "Mean", "CellFlow"),
                                labels = c("Identity", "Mean model", "CellFlow"))  # Correct factorization
df$quantile <- as.character(df$quantile)

df$quantile <- factor(df$quantile, 
                                    levels = sort(as.numeric(unique(df$quantile))))
# Out:
# New names:
# • `` -> `...1`
# Rows: 2424 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): ...1, OOD combination, Model
# dbl (7): r_squared, sinkhorn_div_1, sinkhorn_div_10, sinkhorn_div_100, e_dis...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

p <- ggplot(df, aes(x=quantile, y=r_squared, fill=Model)) +
  geom_boxplot(outlier.size=2
    ) +
  labs(
    x="Perturbation effect group",
    y="R squared DEG",
    fill="Model"
  ) +
  scale_fill_manual(values=color_dict) +  # Replace with your actual color dictionary
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16),
    axis.title.y = element_text(size=16),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  ) +
    ylim(-1.0, NA)
p
# Out:
# Warning message:
# “Removed 214 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %%
ggsave(file.path(output_dir, "r_squared_deg_cut.pdf"), plot = p, device = "pdf",width = 15, height = 5)
# Out:
# Warning message:
# “Removed 214 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

p <- ggplot(df, aes(x=quantile, y=r_squared, fill=Model)) +
  geom_boxplot(outlier.size=2
    ) +
  labs(
    x="Perturbation effect group",
    y="R squared DEG",
    fill="Model"
  ) +
  scale_fill_manual(values=color_dict) +  # Replace with your actual color dictionary
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16),
    axis.title.y = element_text(size=16),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  ) #+
    #ylim(-1.0, NA)
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "r_squared_deg.pdf"), plot = p, device = "pdf",width = 15, height = 5)

# %%
df <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/figures/satija/benchmark/gene_held_out/metrics_encoded.csv")

df$Model <- factor(df$Model, 
                                levels = c("Identity", "Mean", "CellFlow"),
                                labels = c("Identity", "Mean model", "CellFlow"))  # Correct factorization
df$quantile <- as.character(df$quantile)

df$quantile <- factor(df$quantile, 
                                    levels = sort(as.numeric(unique(df$quantile))))
# Out:
# New names:
# • `` -> `...1`
# Rows: 2424 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): ...1, OOD combination, Model
# dbl (8): r_squared, sinkhorn_div_1, sinkhorn_div_10, sinkhorn_div_100, e_dis...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

p <- ggplot(df, aes(x=quantile, y=e_distance, fill=Model)) +
  geom_boxplot(outlier.size=2
    ) +
  labs(
    x="Perturbation effect group",
    y="E distance",
    fill="Model"
  ) +
  scale_fill_manual(values=color_dict) +  # Replace with your actual color dictionary
  theme_bw() +
  scale_y_log10() + 
  theme(
    axis.title.x = element_text(size=16),
    axis.title.y = element_text(size=16),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  ) 
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "e_distance_encoded.pdf"), plot = p, device = "pdf",width = 15, height = 5)

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

p <- ggplot(df, aes(x=quantile, y=mmd, fill=Model)) +
  geom_boxplot(outlier.size=2
    ) +
  labs(
    x="Perturbation effect group",
    y="MMD",
    fill="Model"
  ) +
  scale_fill_manual(values=color_dict) +  # Replace with your actual color dictionary
  theme_bw() +
  scale_y_log10() + 
  theme(
    axis.title.x = element_text(size=16),
    axis.title.y = element_text(size=16),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  ) 
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "mmd_encoded.pdf"), plot = p, device = "pdf",width = 15, height = 5)

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

p <- ggplot(df, aes(x=quantile, y=sinkhorn_div, fill=Model)) +
  geom_boxplot(outlier.size=2
    ) +
  labs(
    x="Perturbation effect group",
    y="Sinkhorn divergence",
    fill="Model"
  ) +
  scale_fill_manual(values=color_dict) +  # Replace with your actual color dictionary
  theme_bw() +
  scale_y_log10() + 
  theme(
    axis.title.x = element_text(size=16),
    axis.title.y = element_text(size=16),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  ) 
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "sinkhorn_div_encoded.pdf"), plot = p, device = "pdf",width = 15, height = 5)

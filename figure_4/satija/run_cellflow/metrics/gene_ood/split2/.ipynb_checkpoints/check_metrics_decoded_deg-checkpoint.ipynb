# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Identity metrics

# %%
identity_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split2/identity_ood_metrics_ood_2.csv",
                              index_col=0)

# %%
identity_metrics.mean(1)
# Out:
# r_squared          -108.675480
# sinkhorn_div_1       10.572076
# sinkhorn_div_10       3.572825
# sinkhorn_div_100      2.876472
# e_distance            5.690277
# mmd                   0.043098
# dtype: float64

# %% [markdown]
# CellFlow

# %%
cellflow_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split2/ood_metrics_ood_2.csv",
                              index_col=0)

# %%
cellflow_metrics.mean(1)
# Out:
# r_squared          -14.394154
# sinkhorn_div_1       6.851198
# sinkhorn_div_10      2.332917
# sinkhorn_div_100     1.941567
# e_distance           3.818566
# mmd                  0.090242
# dtype: float64

# %% [markdown]
# Mean

# %%
mean_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split2/mean_test_metrics_test_2.csv",
                              index_col=0)

# %%
mean_metrics.mean(1)
# Out:
# r_squared            0.744240
# sinkhorn_div_1      11.184629
# sinkhorn_div_10      2.522992
# sinkhorn_div_100     1.776947
# e_distance           3.474141
# mmd                  0.018232
# dtype: float64

# %% [markdown]
# # Plot comparisons

# %%
merged = pd.concat([identity_metrics, mean_metrics, cellflow_metrics], axis=1).T

# %%
merged["Model"] = ["Identity"]*identity_metrics.shape[1] + ["Mean"]*mean_metrics.shape[1] + ["cellFlow"]*cellflow_metrics.shape[1]

# %%
merged.groupby("Model").mean()
# Out:
#            r_squared  sinkhorn_div_1  sinkhorn_div_10  sinkhorn_div_100  \
# Model
# Identity -108.675480       10.572076         3.572825          2.876472
# Mean        0.744240       11.184629         2.522992          1.776947
# cellFlow  -14.394154        6.851198         2.332917          1.941567
#
#           e_distance       mmd
# Model
# Identity    5.690277  0.043098
# Mean        3.474141  0.018232
# cellFlow    3.818566  0.090242

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("R-squared", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324505/2883819879.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("E-distance", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324505/589852575.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 1", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324505/3219815350.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 10", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324505/1099198500.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 100", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324505/2513894603.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("MMD", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324505/2838519543.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

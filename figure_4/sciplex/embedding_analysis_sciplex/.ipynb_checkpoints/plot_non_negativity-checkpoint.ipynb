# %%
library(tidyverse)
library(glue)
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.2.3”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ...

# %%
fig_dir <- "/lustre/groups/ml01/workspace/ot_perturbation/figures/sciplex/data"

# %%
df_ood <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/reconstruction/reconstruction_ood_allocated.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 332 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): ...1, embedding
# dbl (8): r_squared, sinkhorn_div_1, sinkhorn_div_10, sinkhorn_div_100, e_dis...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
color_dict <- c("PCA 50"= "#e9dfb4", "PCA 100"= "#b8c88d", "PCA 300"="#44562f" , "VAE"= "#efbfb3")
df_ood$embedding <- factor(df_ood$embedding, levels = c("VAE", "PC_50", "PC_100", "PC_300"), labels = c("VAE", "PCA 50", "PCA 100", "PCA 300"))  # Correct factorization
df_ood$dose <- factor(df_ood$dose, levels = c(10, 100, 1000, 10000), labels = c("10", "100", "1000", "100000"))


p <- ggplot(df_ood, aes(x=dose, y=r_squared, fill=embedding)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Dose", y="R squared") +
  scale_fill_manual(values=color_dict) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
ggsave(file.path(fig_dir, "ood_reconstruction_r_squared.pdf"), plot = p, device = "pdf")
p
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
p <- ggplot(df_ood, aes(x=dose, y=e_distance, fill=embedding)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Dose", y="Energy distance") +
  scale_fill_manual(values=color_dict) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
ggsave(file.path(fig_dir, "ood_reconstruction_e_distance.pdf"), plot = p, device = "pdf")
p
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
p <- ggplot(df_ood, aes(x=dose, y=mmd, fill=embedding)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Dose", y="MMD") +
  scale_fill_manual(values=color_dict) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
ggsave(file.path(fig_dir, "ood_reconstruction_mmd.pdf"), plot = p, device = "pdf")
p
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
p <- ggplot(df_ood, aes(x=dose, y=sinkhorn_div, fill=embedding)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Dose", y="Sinkhorn div") +
  scale_fill_manual(values=color_dict) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(fig_dir, "ood_reconstruction_sinkhorn_div.pdf"), plot = p, device = "pdf")
# Out:
# Saving 7 x 7 in image

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Identity metrics

# %%
identity_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split2/identity_ood_metrics_encoded_2.csv",
                              index_col=0)

# %%
identity_metrics.mean(1)
# Out:
# r_squared            0.965534
# sinkhorn_div_1      11.786129
# sinkhorn_div_10      4.740608
# sinkhorn_div_100     2.801964
# e_distance           5.354712
# mmd                  0.019975
# dtype: float64

# %% [markdown]
# CellFlow

# %%
cellflow_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split2/ood_metrics_encoded_2.csv",
                              index_col=0)

# %%
cellflow_metrics.mean(1)
# Out:
# r_squared            0.972984
# sinkhorn_div_1      12.050151
# sinkhorn_div_10      4.819572
# sinkhorn_div_100     2.363162
# e_distance           4.366682
# mmd                  0.018165
# dtype: float64

# %% [markdown]
# Metrics

# %%
mean_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split2/mean_train_metrics_encoded_2.csv",
                              index_col=0)

# %%
mean_metrics.mean(1)
# Out:
# r_squared           0.967706
# sinkhorn_div_1      9.680126
# sinkhorn_div_10     3.769996
# sinkhorn_div_100    2.645398
# e_distance          5.087785
# mmd                 0.013745
# dtype: float64

# %% [markdown]
# # Plot comparisons

# %%
merged = pd.concat([identity_metrics, mean_metrics, cellflow_metrics], axis=1).T

# %%
merged["Model"] = ["Identity"]*identity_metrics.shape[1] + ["Mean"]*mean_metrics.shape[1] + ["cellFlow"]*cellflow_metrics.shape[1]

# %%
merged.groupby("Model").mean()
# Out:
#           r_squared  sinkhorn_div_1  sinkhorn_div_10  sinkhorn_div_100  \
# Model
# Identity   0.965534       11.786129         4.740608          2.801964
# Mean       0.967706        9.680126         3.769996          2.645398
# cellFlow   0.972984       12.050151         4.819572          2.363162
#
#           e_distance       mmd
# Model
# Identity    5.354712  0.019975
# Mean        5.087785  0.013745
# cellFlow    4.366682  0.018165

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Boxplot of Values by Condition", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.xticks(rotation=45)
plt.title("R-squared", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1324482/1240770930.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Boxplot of Values by Condition", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.xticks(rotation=45)
plt.title("E-distance", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1324482/3053985752.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Boxplot of Values by Condition", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.title("Sinkhorn divergence 1", fontsize=16)
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324482/3287200252.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.title("Sinkhorn divergence 10", fontsize=16)
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324482/1673104571.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.title("Sinkhorn divergence 100", fontsize=16)
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324482/2521868030.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("MMD", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1324482/2838519543.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

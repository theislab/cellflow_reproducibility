# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Identity metrics

# %%
identity_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split0/identity_ood_metrics_ood_0.csv",
                              index_col=0)

# %%
identity_metrics.mean(1)
# Out:
# r_squared          -73.671819
# sinkhorn_div_1      10.492750
# sinkhorn_div_10      3.740757
# sinkhorn_div_100     3.029838
# e_distance           5.994426
# mmd                  0.046801
# dtype: float64

# %% [markdown]
# CellFlow

# %%
cellflow_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split0/ood_metrics_ood_0.csv",
                              index_col=0)

# %%
cellflow_metrics.mean(1)
# Out:
# r_squared          -116.137249
# sinkhorn_div_1        5.660743
# sinkhorn_div_10       1.713406
# sinkhorn_div_100      1.403286
# e_distance            2.757408
# mmd                   0.084458
# dtype: float64

# %% [markdown]
# Mean

# %%
mean_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split0/mean_train_metrics_train_0.csv",
                              index_col=0)

# %%
mean_metrics.mean(1)
# Out:
# r_squared          -77.475611
# sinkhorn_div_1       7.925983
# sinkhorn_div_10      2.042475
# sinkhorn_div_100     1.713237
# e_distance           3.377944
# mmd                  0.029821
# dtype: float64

# %% [markdown]
# # Plot comparisons

# %%
merged = pd.concat([identity_metrics, mean_metrics, cellflow_metrics], axis=1).T

# %%
merged["Model"] = ["Identity"]*identity_metrics.shape[1] + ["Mean"]*mean_metrics.shape[1] + ["cellFlow"]*cellflow_metrics.shape[1]

# %%
merged.groupby("Model").mean()
# Out:
#            r_squared  sinkhorn_div_1  sinkhorn_div_10  sinkhorn_div_100  \
# Model
# Identity  -73.671819       10.492750         3.740757          3.029838
# Mean      -77.475611        7.925983         2.042475          1.713237
# cellFlow -116.137249        5.660743         1.713406          1.403286
#
#           e_distance       mmd
# Model
# Identity    5.994426  0.046801
# Mean        3.377944  0.029821
# cellFlow    2.757408  0.084458

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("R-squared", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316968/2883819879.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("E-distance", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316968/589852575.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 1", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316968/3219815350.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 10", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316968/1099198500.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 100", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316968/2513894603.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("MMD", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316968/2838519543.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

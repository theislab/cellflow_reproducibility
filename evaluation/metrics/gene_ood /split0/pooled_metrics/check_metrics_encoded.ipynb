# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Identity metrics

# %%
identity_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split0/identity_ood_metrics_encoded_0.csv",
                              index_col=0)

# %%
identity_metrics.mean(1)
# Out:
# r_squared            0.963931
# sinkhorn_div_1      11.837149
# sinkhorn_div_10      4.921997
# sinkhorn_div_100     2.946391
# e_distance           5.568437
# mmd                  0.020400
# dtype: float64

# %% [markdown]
# CellFlow

# %%
cellflow_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split0/ood_metrics_encoded_0.csv",
                              index_col=0)

# %%
cellflow_metrics.mean(1)
# Out:
# r_squared            0.978724
# sinkhorn_div_1      11.473537
# sinkhorn_div_10      4.169060
# sinkhorn_div_100     1.870529
# e_distance           3.423865
# mmd                  0.015985
# dtype: float64

# %% [markdown]
# Metrics

# %%
mean_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split0/mean_train_metrics_encoded_0.csv",
                              index_col=0)

# %%
mean_metrics.mean(1)
# Out:
# r_squared           0.972502
# sinkhorn_div_1      9.235087
# sinkhorn_div_10     3.320483
# sinkhorn_div_100    2.142840
# e_distance          4.069049
# mmd                 0.012696
# dtype: float64

# %% [markdown]
# # Plot comparisons

# %%
merged = pd.concat([identity_metrics, mean_metrics, cellflow_metrics], axis=1).T

# %%
merged["Model"] = ["Identity"]*identity_metrics.shape[1] + ["Mean"]*mean_metrics.shape[1] + ["cellFlow"]*cellflow_metrics.shape[1]

# %%
merged.groupby("Model").mean()
# Out:
#           r_squared  sinkhorn_div_1  sinkhorn_div_10  sinkhorn_div_100  \
# Model
# Identity   0.963931       11.837149         4.921997          2.946391
# Mean       0.972502        9.235087         3.320483          2.142840
# cellFlow   0.978724       11.473537         4.169060          1.870529
#
#           e_distance       mmd
# Model
# Identity    5.568437  0.020400
# Mean        4.069049  0.012696
# cellFlow    3.423865  0.015985

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Boxplot of Values by Condition", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.xticks(rotation=45)
plt.title("R-squared", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1316973/1240770930.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Boxplot of Values by Condition", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.xticks(rotation=45)
plt.title("E-distance", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1316973/3053985752.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Boxplot of Values by Condition", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.title("Sinkhorn divergence 1", fontsize=16)
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316973/3287200252.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.title("Sinkhorn divergence 10", fontsize=16)
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316973/1673104571.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.title("Sinkhorn divergence 100", fontsize=16)
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316973/2521868030.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("MMD", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1316973/2838519543.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

# %%
s

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Identity metrics

# %%
identity_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split3/identity_ood_metrics_ood_3.csv",
                              index_col=0)

# %%
identity_metrics.mean(1)
# Out:
# r_squared          -86.884563
# sinkhorn_div_1      11.375209
# sinkhorn_div_10      3.447493
# sinkhorn_div_100     2.641179
# e_distance           5.218469
# mmd                  0.035374
# dtype: float64

# %% [markdown]
# CellFlow

# %%
cellflow_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split3/ood_metrics_ood_3.csv",
                              index_col=0)

# %%
cellflow_metrics.mean(1)
# Out:
# r_squared          -12.963462
# sinkhorn_div_1       7.775738
# sinkhorn_div_10      2.866184
# sinkhorn_div_100     2.443500
# e_distance           4.818992
# mmd                  0.089109
# dtype: float64

# %% [markdown]
# Mean

# %%
mean_metrics = pd.read_csv("/lustre/groups/ml01/workspace/alessandro.palma/ot_pert/out/results_metrics/metrics/split3/mean_train_metrics_train_3.csv",
                              index_col=0)

# %%
mean_metrics.mean(1)
# Out:
# r_squared           -7.106569
# sinkhorn_div_1      10.265588
# sinkhorn_div_10      2.906098
# sinkhorn_div_100     2.461861
# e_distance           4.866832
# mmd                  0.027919
# dtype: float64

# %% [markdown]
# # Plot comparisons

# %%
merged = pd.concat([identity_metrics, mean_metrics, cellflow_metrics], axis=1).T

# %%
merged["Model"] = ["Identity"]*identity_metrics.shape[1] + ["Mean"]*mean_metrics.shape[1] + ["cellFlow"]*cellflow_metrics.shape[1]

# %%
merged.groupby("Model").mean()
# Out:
#           r_squared  sinkhorn_div_1  sinkhorn_div_10  sinkhorn_div_100  \
# Model
# Identity -86.884563       11.375209         3.447493          2.641179
# Mean      -7.106569       10.265588         2.906098          2.461861
# cellFlow -12.963462        7.775738         2.866184          2.443500
#
#           e_distance       mmd
# Model
# Identity    5.218469  0.035374
# Mean        4.866832  0.027919
# cellFlow    4.818992  0.089109

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("R-squared", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1327667/2883819879.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="r_squared", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("E-distance", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1327667/589852575.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="e_distance", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 1", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1327667/3219815350.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_1", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 10", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1327667/1099198500.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_10", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("Sinkhorn 100", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1327667/2513894603.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="sinkhorn_div_100", data=merged, palette="Set2", showfliers=False)

# %%
plt.figure(figsize=(2, 4))
sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

# Add labels and title
plt.title("MMD", fontsize=16)
plt.xlabel("Condition", fontsize=14)
plt.ylabel("Value", fontsize=14)

# Show the plot
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1327667/2838519543.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Model", y="mmd", data=merged, palette="Set2", showfliers=False)

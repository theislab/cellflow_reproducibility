# %%
import scanpy as sc
import os

# %%
output_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex"
adata_ood = sc.read(os.path.join(output_dir, "adata_ood_30.h5ad"))
# Out:
# /home/icb/dominik.klein/mambaforge/envs/ot_pert_genot_scvi/lib/python3.12/site-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata_ood.layers
# Out:
# Layers with keys: counts

# %%
adata_ood.X[0].data
# Out:
# array([0.6350778, 1.2978748, 0.6350778, 1.2978748, 2.091537 , 1.0204121,
#        0.6350778, 1.0204121, 0.6350778, 1.0204121, 0.6350778, 1.0204121,
#        0.6350778, 0.6350778, 2.091537 , 0.6350778, 0.6350778, 0.6350778,
#        1.0204121, 0.6350778, 1.2978748, 0.6350778, 0.6350778, 1.0204121,
#        1.0204121, 0.6350778, 1.0204121, 1.0204121, 0.6350778, 1.0204121,
#        0.6350778, 0.6350778, 1.0204121, 1.5148362, 0.6350778, 1.0204121,
#        0.6350778, 1.2978748, 0.6350778, 1.0204121, 1.2978748, 1.0204121,
#        0.6350778, 0.6350778, 0.6350778, 0.6350778, 0.6350778, 0.6350778,
#        1.0204121, 1.5148362, 0.6350778, 0.6350778, 1.2978748, 0.6350778,
#        1.0204121, 1.0204121, 1.0204121, 0.6350778, 1.0204121, 0.6350778,
#        1.2978748, 0.6350778, 1.2978748, 1.0204121, 1.0204121, 0.6350778,
#        1.0204121, 1.2978748, 0.6350778, 1.0204121, 1.844196 , 0.6350778,
#        1.2978748, 0.6350778, 0.6350778, 0.6350778, 1.0204121, 0.6350778,
#        0.6350778, 1.0204121, 0.6350778, 1.0204121, 0.6350778, 1.0204121,
#        0.6350778, 1.2978748, 1.5148362, 1.0204121, 0.6350778, 1.0204121,
#        0.6350778, 1.0204121, 0.6350778, 1.0204121, 1.2978748, 0.6350778,
#        0.6350778, 1.0204121, 0.6350778, 0.6350778, 0.6350778, 1.0204121,
#        0.6350778, 1.5148362, 1.0204121, 1.2978748, 0.6350778, 0.6350778,
#        0.6350778, 1.0204121, 0.6350778, 1.0204121, 0.6350778, 0.6350778,
#        1.0204121, 0.6350778, 0.6350778, 0.6350778, 0.6350778, 0.6350778,
#        0.6350778, 0.6350778, 0.6350778, 0.6350778, 0.6350778, 1.2978748,
#        0.6350778, 0.6350778, 1.0204121, 0.6350778, 0.6350778, 0.6350778,
#        0.6350778, 0.6350778, 1.0204121, 1.0204121, 0.6350778, 0.6350778,
#        0.6350778, 0.6350778, 1.0204121, 1.9754943, 1.844196 , 0.6350778,
#        0.6350778, 1.693015 , 1.2978748, 1.2978748, 1.0204121, 0.6350778,
#        0.6350778, 1.5148362, 0.6350778, 0.6350778, 1.844196 , 0.6350778,
#        1.0204121, 1.2978748, 0.6350778, 1.2978748, 4.5064993, 0.6350778,
#        1.0204121, 1.5148362, 0.6350778, 0.6350778, 0.6350778, 0.6350778,
#        1.0204121, 0.6350778, 0.6350778, 0.6350778, 1.0204121, 0.6350778,
#        3.1432564, 0.6350778, 0.6350778, 0.6350778, 0.6350778, 1.0204121,
#        0.6350778, 1.0204121, 0.6350778, 1.5148362, 0.6350778],
#       dtype=float32)

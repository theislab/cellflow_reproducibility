# %%
import os

import pandas as pd
import seaborn as sns

# %%
cpa_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/results/cpa"
id_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/results/identity"
genot_dir = None
otfm_dir = None

# %%
model_dirs = {"CPA": cpa_dir, "id": id_dir}

# %%
metrics_files = {"ood_encoded": "ood_metrics_encoded.csv", "ood_decoded": "ood_metrics_decoded.csv"}

# %%
metrics_file = "ood_metrics_encoded.csv"
dfs = {}
for model, model_dir in model_dirs.items():
    dfs[model] = pd.read_csv(os.path.join(model_dir, metrics_file), index_col=0)
    dfs[model]["model"] = model

# %%
result_df = pd.concat(dfs.values(), ignore_index=False)

# %%
result_df["metric"] = result_df.index

# %%
metrics = result_df["metric"].unique()

# %%
result_df
# Out:
#                   Cediranib+PCI-34051  Givinostat+SRT1720  \
# r_squared                    0.512775            0.145153
# sinkhorn_div_1              13.288227           13.870828
# sinkhorn_div_10              7.638247            7.945141
# sinkhorn_div_100             6.761440            7.092617
# e_distance                  13.319667           13.984304
# mmd                          0.095916            0.098685
# r_squared                    0.974681            0.422534
# sinkhorn_div_1              10.584558           16.048632
# sinkhorn_div_10              0.694153            5.318348
# sinkhorn_div_100             0.356144            4.751503
# e_distance                   0.692176            9.446668
# mmd                         -0.579147            4.060974
#
#                   Panobinostat+Crizotinib  Panobinostat+PCI-34051  \
# r_squared                        0.536919                0.528108
# sinkhorn_div_1                  21.460855               18.659237
# sinkhorn_div_10                 16.447922               13.263216
# sinkhorn_div_100                15.193371               12.024872
# e_distance                      30.044826               23.741077
# mmd                              0.180695                0.162800
# r_squared                       -1.467268               -1.782773
# sinkhorn_div_1                  98.848442               88.604652
# sinkhorn_div_10                 83.956665               73.687218
# sinkhorn_div_100                80.447540               70.368889
# e_distance                     160.077051              140.002553
# mmd                             79.370590               69.831894
#
#                   SRT2104+Alvespimycin model            metric
# r_squared                     0.585622   CPA         r_squared
# sinkhorn_div_1               12.850885   CPA    sinkhorn_div_1
# sinkhorn_div_10               6.213585   CPA   sinkhorn_div_10
# sinkhorn_div_100              5.475540   CPA  sinkhorn_div_100
# e_distance                   10.800750   CPA        e_distance
# mmd                           0.109682   CPA               mmd
# r_squared                     0.357131    id         r_squared
# sinkhorn_div_1               20.836151    id    sinkhorn_div_1
# sinkhorn_div_10               9.254139    id   sinkhorn_div_10
# sinkhorn_div_100              8.431534    id  sinkhorn_div_100
# e_distance                   16.756335    id        e_distance
# mmd                           7.934921    id               mmd

# %%
df2 = pd.melt(result_df, id_vars=["model", "metric"])

# %%
df2.head()
# Out:
#   model            metric             variable      value
# 0   CPA         r_squared  Cediranib+PCI-34051   0.512775
# 1   CPA    sinkhorn_div_1  Cediranib+PCI-34051  13.288227
# 2   CPA   sinkhorn_div_10  Cediranib+PCI-34051   7.638247
# 3   CPA  sinkhorn_div_100  Cediranib+PCI-34051   6.761440
# 4   CPA        e_distance  Cediranib+PCI-34051  13.319667

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
k = len(metrics)

fig, axes = plt.subplots(nrows=int(np.ceil(k / 2)), ncols=2, figsize=(10, 15))  # Adjust layout format
axes = axes.flatten()  # Flatten if more than one row

# Loop through categories and plot each as a barplot
for i, metric in enumerate(metrics):
    # Filter the DataFrame
    subset = df2[df2["metric"] == metric]
    # Create the barplot
    sns.barplot(subset, x="variable", y="value", hue="model", ax=axes[i])
    axes[i].set_title(f"{metric}")
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_3031410/1429008180.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1429008180.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1429008180.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1429008180.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1429008180.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1429008180.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)

# %%
k = len(metrics)

fig, axes = plt.subplots(nrows=int(np.ceil(k / 2)), ncols=2, figsize=(10, 15))  # Adjust layout format
axes = axes.flatten()  # Flatten if more than one row

# Loop through categories and plot each as a barplot
for i, metric in enumerate(metrics):
    # Filter the DataFrame
    subset = df2[df2["metric"] == metric]
    # Create the barplot
    sns.barplot(subset, x="model", y="value", ax=axes[i])
    axes[i].set_title(f"{metric}")
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_3031410/1240271388.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1240271388.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1240271388.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1240271388.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1240271388.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)
# /tmp/ipykernel_3031410/1240271388.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=90)

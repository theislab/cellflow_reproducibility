# %%
import pandas as pd
import seaborn as sns

# %%
df_1_cf = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/runs_otfm/load_models/combosciplex/attention_token/spearman_corrs_1.csv')
df_2_cf = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/runs_otfm/load_models/combosciplex/attention_token/spearman_corrs_2.csv')
df_3_cf = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/runs_otfm/load_models/combosciplex/attention_token/spearman_corrs_3.csv')
df_4_cf = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/runs_otfm/load_models/combosciplex/attention_token/spearman_corrs_4.csv')

df_1_add = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/additive_model/add_spearman_corrs_1.csv')
df_2_add = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/additive_model/add_spearman_corrs_2.csv')
df_3_add = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/additive_model/add_spearman_corrs_3.csv')
df_4_add = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/additive_model/add_spearman_corrs_4.csv')

df_1_cpa = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/CPA/spearman_corrs_1.csv')
df_2_cpa = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/CPA/spearman_corrs_2.csv')
df_3_cpa = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/CPA/spearman_corrs_3.csv')
df_4_cpa = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/CPA/spearman_corrs_4.csv')

df_1_ccpa = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/chemCPA/spearman_corrs_1.csv')
df_2_ccpa = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/chemCPA/spearman_corrs_2.csv')
df_3_ccpa = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/chemCPA/spearman_corrs_3.csv')
df_4_ccpa = pd.read_csv('/home/icb/dominik.klein/git_repos/ot_pert_new/competing_methods/combosciplex/chemCPA/spearman_corrs_4.csv')

# %%
#to_remove = ["REACTOME_CELL_CYCLE_MITOTIC", "REACTOME_CLASS_I_MHC_MEDIATED_ANTIGEN_PROCESSING_PRESENTATION"]

# %%
#df_1 = df_1[~df_1["Unnamed: 0"].isin(to_remove)]
#df_2 = df_2[~df_2["Unnamed: 0"].isin(to_remove)]
#df_3 = df_3[~df_3["Unnamed: 0"].isin(to_remove)]
#df_4 = df_4[~df_4["Unnamed: 0"].isin(to_remove)]

#d_1 = d_1[~d_1["Unnamed: 0"].isin(to_remove)]
#d_2 = d_2[~d_2["Unnamed: 0"].isin(to_remove)]
#d_3 = d_3[~d_3["Unnamed: 0"].isin(to_remove)]
#d_4 = d_4[~d_4["Unnamed: 0"].isin(to_remove)]

# %%
df_1_cf["model"] = "CellFlow"
df_2_cf["model"] = "CellFlow"
df_3_cf["model"] = "CellFlow"
df_4_cf["model"] = "CellFlow"

df_1_add["model"] = "additive"
df_2_add["model"] = "additive"
df_3_add["model"] = "additive"
df_4_add["model"] = "additive"

df_1_cpa["model"] = "CPA"
df_2_cpa["model"] = "CPA"
df_3_cpa["model"] = "CPA"
df_4_cpa["model"] = "CPA"

df_1_ccpa["model"] = "chemCPA"
df_2_ccpa["model"] = "chemCPA"
df_3_ccpa["model"] = "chemCPA"
df_4_ccpa["model"] = "chemCPA"

# %%
dff_1 = pd.concat((df_1_cf, df_1_add, df_1_cpa, df_1_ccpa))

# %%
dff_1.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/results/allocation/GSEA_results_1.csv")

# %%
ax = sns.boxplot(dff_1, x="model", y="spearman_correlation")
ax.set_ylim([-1, 1])
# Out:
# (-1.0, 1.0)

# %%
dff_2 = pd.concat((df_2_cf, df_2_add, df_2_cpa, df_2_ccpa))
dff_2.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/results/allocation/GSEA_results_2.csv")
ax = sns.boxplot(dff_2, x="model", y="spearman_correlation")
ax.set_ylim([-1, 1])
# Out:
# (-1.0, 1.0)

# %%
dff_3 = pd.concat((df_3_cf, df_3_add, df_3_cpa, df_3_ccpa))
dff_3.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/results/allocation/GSEA_results_3.csv")
ax = sns.boxplot(dff_3, x="model", y="spearman_correlation")
ax.set_ylim([-1, 1])
# Out:
# (-1.0, 1.0)

# %%
dff_4 = pd.concat((df_4_cf, df_4_add, df_4_cpa, df_4_ccpa))
dff_4.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/combosciplex/results/allocation/GSEA_results_4.csv")
ax = sns.boxplot(dff_4, x="model", y="spearman_correlation")
ax.set_ylim([-1, 1])
# Out:
# (-1.0, 1.0)

# %%
df_all = pd.concat((df_1_cf, df_2_cf, df_3_cf, df_4_cf, df_1_add, df_2_add, df_3_add, df_4_add, df_1_cpa, df_2_cpa, df_3_cpa, df_4_cpa, df_1_cpa, df_2_ccpa, df_3_ccpa, df_4_ccpa,))

# %%
ax = sns.boxplot(df_all, x="model", y="spearman_correlation")

# %%
import matplotlib.pyplot as plt
ax = sns.boxplot(df_all, x="Unnamed: 0", y="spearman_correlation", hue="model")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'REACTOME_APOPTOSIS'),
#   Text(1, 0, 'REACTOME_ONCOGENIC_MAPK_SIGNALING'),
#   Text(2, 0, 'REACTOME_CASPASE_ACTIVATION_VIA_EXTRINSIC_APOPTOTIC_SIGNALLING_PATHWAY'),
#   Text(3, 0, 'REACTOME_CELL_CYCLE_MITOTIC'),
#   Text(4, 0, 'REACTOME_CELL_CYCLE'),
#   Text(5, 0, 'REACTOME_ANTIGEN_PROCESSING_CROSS_PRESENTATION'),
#   Text(6, 0, 'REACTOME_INTERFERON_SIGNALING'),
#   Text(7, 0, 'REACTOME_CLASS_I_MHC_MEDIATED_ANTIGEN_PROCESSING_PRESENTATION')])

# %%
import matplotlib.pyplot as plt
ax = sns.boxplot(df_all, x="Unnamed: 0", y="spearman_correlation", hue="model")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'REACTOME_APOPTOSIS'),
#   Text(1, 0, 'REACTOME_ONCOGENIC_MAPK_SIGNALING'),
#   Text(2, 0, 'REACTOME_CASPASE_ACTIVATION_VIA_EXTRINSIC_APOPTOTIC_SIGNALLING_PATHWAY'),
#   Text(3, 0, 'REACTOME_CELL_CYCLE_MITOTIC'),
#   Text(4, 0, 'REACTOME_CELL_CYCLE'),
#   Text(5, 0, 'REACTOME_ANTIGEN_PROCESSING_CROSS_PRESENTATION'),
#   Text(6, 0, 'REACTOME_INTERFERON_SIGNALING'),
#   Text(7, 0, 'REACTOME_CLASS_I_MHC_MEDIATED_ANTIGEN_PROCESSING_PRESENTATION')])

# %%
df_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_1
#
# NameError: name 'df_1' is not defined

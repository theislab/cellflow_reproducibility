# %%
library(tidyverse)
library(glue)
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 4.2.3”
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.2.3”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Warning message:
# “package ‘glue’ was built under R version 4.2.3”

# %%
color_dict = c("genot"= "#317d01",
    "CellFlow"= "#59d1d6",
    "chemCPA"= "#e6b1fc",
    "Biolord"= "#008000",
    "Baseline"="#8f97a8",
    "CondOT"="#e63946")

# %%
split_to_filter <- 5
dosage_to_filter <- "1000\\.0$"
dosage_to_filter_str <- sub("\\\\.*", "", dosage_to_filter)

# %%
output_dir <- glue("/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/plots_{split_to_filter}_{dosage_to_filter_str}")

# %%
output_dir
# Out:
# /lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/plots_5_1000

# %% [markdown]
# # Decoded

# %%
results_decoded <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/allocation/ood_metrics_decoded.csv") 
results_decoded <- results_decoded %>%
  filter(grepl(dosage_to_filter, variable) & split == split_to_filter)
# Out:
# New names:
# • `` -> `...1`
# Rows: 8832 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): model, metric, variable
# dbl (3): ...1, value, split
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
results_decoded$model <- factor(results_decoded$model, 
                            levels = c("id", "condot", "biolord", "otfm"),
                            labels = c("Baseline", "CondOT", "Biolord", "CellFlow"))  # Correct factorization

p <- ggplot(results_decoded, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y=glue("R squared normalized gene expression")) +
  scale_fill_manual(values=color_dict) +  # Removed labels argument
  scale_x_discrete(labels=c("")) +  # Keep this if you want no x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "ood_r_squared_decoded.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %% [markdown]
# # Encoded

# %%
results_encoded <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/allocation/ood_metrics_encoded.csv") 
results_encoded <- results_encoded %>%
  filter(grepl(dosage_to_filter, variable) & split == split_to_filter)
# Out:
# New names:
# • `` -> `...1`
# Rows: 35328 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): model, metric, variable
# dbl (3): ...1, value, split
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
results <- results_encoded %>% filter(metric == "r_squared")

results$model <- factor(results$model, 
                                levels = c("id", "condot", "biolord", "otfm"),
                            labels = c("Baseline", "CondOT", "Biolord", "CellFlow"))  # Correct factorization

p <- ggplot(results, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="R squared latent space") +
  scale_fill_manual(values=color_dict) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )

p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "ood_r_squared_encoded.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %%
results <- results_encoded %>% filter(metric == "e_distance")

results$model <- factor(results$model, 
                                levels = c("id", "condot", "biolord", "otfm"),
                                labels = c("Baseline", "CondOT", "Biolord", "CellFlow"))  # Correct factorization

p <- ggplot(results, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Energy distance latent space") +
  scale_fill_manual(values=color_dict) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "ood_e_distance_encoded.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %%
results <- results_encoded %>% filter(metric == "mmd")

results$model <- factor(results$model, 
                                levels = c("id", "condot", "biolord", "otfm"),
                                labels = c("Baseline", "CondOT", "Biolord", "CellFlow"))  # Correct factorization

p <- ggplot(results, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="MMD latent space") +
  scale_fill_manual(values=color_dict) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "ood_mmd_distance_encoded.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %%
results <- results_encoded %>% filter(metric == "sinkhorn_div")

results$model <- factor(results$model, 
                                levels = c("id", "condot", "biolord", "otfm"),
                                labels = c("Baseline", "CondOT", "Biolord", "CellFlow"))  # Correct factorization

p <- ggplot(results, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Sinkhorn divergence latent space") +
  scale_fill_manual(values=color_dict, c("Baseline", "CondOT", "Biolord", "CellFlow")) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "ood_sink_div_encoded.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %% [markdown]
# # DEG

# %%
results_deg <- read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/sciplex/results/allocation/ood_metrics_deg.csv") 
results_deg <- results_deg %>%
  filter(grepl(dosage_to_filter, variable) & split == split_to_filter)
# Out:
# New names:
# • `` -> `...1`
# Rows: 432 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): model, metric, variable
# dbl (3): ...1, value, split
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
results
# Out:
#    ...1 model    metric       variable
# 1   67  Baseline sinkhorn_div A549_Belinostat_(PXD101)_1000.0
# 2   71  Biolord  sinkhorn_div A549_Belinostat_(PXD101)_1000.0
# 3   75  CellFlow sinkhorn_div A549_Belinostat_(PXD101)_1000.0
# 4   79  CondOT   sinkhorn_div A549_Belinostat_(PXD101)_1000.0
# 5  115  Baseline sinkhorn_div A549_Dacinostat_(LAQ824)_1000.0
# 6  119  Biolord  sinkhorn_div A549_Dacinostat_(LAQ824)_1000.0
# 7  123  CellFlow sinkhorn_div A549_Dacinostat_(LAQ824)_1000.0
# 8  127  CondOT   sinkhorn_div A549_Dacinostat_(LAQ824)_1000.0
# 9  163  Baseline sinkhorn_div A549_Flavopiridol_HCl_1000.0
# 10 167  Biolord  sinkhorn_div A549_Flavopiridol_HCl_1000.0
# 11 171  CellFlow sinkhorn_div A549_Flavopiridol_HCl_1000.0
# 12 175  CondOT   sinkhorn_div A549_Flavopiridol_HCl_1000.0
# 13 227  Baseline sinkhorn_div A549_Givinostat_(ITF2357)_1000.0
# 14 231  Biolord  sinkhorn_div A549_Givinostat_(ITF2357)_1000.0
# 15 235  CellFlow sinkhorn_div A549_Givinostat_(ITF2357)_1000.0
# 16 239  CondOT   sinkhorn_div A549_Givinostat_(ITF2357)_1000.0
# 17 291  Baseline sinkhorn_div A549_Hesperadin_1000.0
# 18 295  Biolord  sinkhorn_div A549_Hesperadin_1000.0
# 19 299  CellFlow sinkhorn_div A549_Hesperadin_1000.0
# 20 303  CondOT   sinkhorn_div A549_Hesperadin_1000.0
# 21 371  Baseline sinkhorn_div A549_TAK-901_1000.0
# 22 375  Biolord  sinkhorn_div A549_TAK-901_1000.0
# 23 379  CellFlow sinkhorn_div A549_TAK-901_1000.0
# 24 383  CondOT   sinkhorn_div A549_TAK-901_1000.0
# 25 419  Baseline sinkhorn_div A549_Tanespimycin_(17-AAG)_1000.0
# 26 423  Biolord  sinkhorn_div A549_Tanespimycin_(17-AAG)_1000.0
# 27 427  CellFlow sinkhorn_div A549_Tanespimycin_(17-AAG)_1000.0
# 28 431  CondOT   sinkhorn_div A549_Tanespimycin_(17-AAG)_1000.0
# 29 467  Baseline sinkhorn_div K562_Alvespimycin_(17-DMAG)_HCl_1000.0
# 30 471  Biolord  sinkhorn_div K562_Alvespimycin_(17-DMAG)_HCl_1000.0
# ⋮  ⋮    ⋮        ⋮            ⋮
# 55  859 CellFlow sinkhorn_div MCF7_Alvespimycin_(17-DMAG)_HCl_1000.0
# 56  863 CondOT   sinkhorn_div MCF7_Alvespimycin_(17-DMAG)_HCl_1000.0
# 57  899 Baseline sinkhorn_div MCF7_Belinostat_(PXD101)_1000.0
# 58  903 Biolord  sinkhorn_div MCF7_Belinostat_(PXD101)_1000.0
# 59  907 CellFlow sinkhorn_div MCF7_Belinostat_(PXD101)_1000.0
# 60  911 CondOT   sinkhorn_div MCF7_Belinostat_(PXD101)_1000.0
# 61  963 Baseline sinkhorn_div MCF7_Dacinostat_(LAQ824)_1000.0
# 62  967 Biolord  sinkhorn_div MCF7_Dacinostat_(LAQ824)_1000.0
# 63  971 CellFlow sinkhorn_div MCF7_Dacinostat_(LAQ824)_1000.0
# 64  975 CondOT   sinkhorn_div MCF7_Dacinostat_(LAQ824)_1000.0
# 65 1059 Baseline sinkhorn_div MCF7_Givinostat_(ITF2357)_1000.0
# 66 1063 Biolord  sinkhorn_div MCF7_Givinostat_(ITF2357)_1000.0
# 67 1067 CellFlow sinkhorn_div MCF7_Givinostat_(ITF2357)_1000.0
# 68 1071 CondOT   sinkhorn_div MCF7_Givinostat_(ITF2357)_1000.0
# 69 1123 Baseline sinkhorn_div MCF7_Hesperadin_1000.0
# 70 1127 Biolord  sinkhorn_div MCF7_Hesperadin_1000.0
# 71 1131 CellFlow sinkhorn_div MCF7_Hesperadin_1000.0
# 72 1135 CondOT   sinkhorn_div MCF7_Hesperadin_1000.0
# 73 1187 Baseline sinkhorn_div MCF7_Quisinostat_(JNJ-26481585)_2HCl_1000.0
# 74 1191 Biolord  sinkhorn_div MCF7_Quisinostat_(JNJ-26481585)_2HCl_1000.0
# 75 1195 CellFlow sinkhorn_div MCF7_Quisinostat_(JNJ-26481585)_2HCl_1000.0
# 76 1199 CondOT   sinkhorn_div MCF7_Quisinostat_(JNJ-26481585)_2HCl_1000.0
# 77 1251 Baseline sinkhorn_div MCF7_TAK-901_1000.0
# 78 1255 Biolord  sinkhorn_div MCF7_TAK-901_1000.0
# 79 1259 CellFlow sinkhorn_div MCF7_TAK-901_1000.0
# 80 1263 CondOT   sinkhorn_div MCF7_TAK-901_1000.0
# 81 1299 Baseline sinkhorn_div MCF7_Tanespimycin_(17-AAG)_1000.0
# 82 1303 Biolord  sinkhorn_div MCF7_Tanespimycin_(17-AAG)_1000.0
# 83 1307 CellFlow sinkhorn_div MCF7_Tanespimycin_(17-AAG)_1000.0
# 84 1311 CondOT   sinkhorn_div MCF7_Tanespimycin_(17-AAG)_1000.0
#    value      split
# 1   4.5604143 5
# 2   2.0943820 5
# 3  43.4706370 5
# 4   9.7556562 5
# 5  28.3392455 5
# 6   8.3471702 5
# 7  18.1984348 5
# 8   8.6916990 5
# 9   1.1674294 5
# 10  2.0811666 5
# 11 34.3998604 5
# 12  1.9562298 5
# 13  4.6821264 5
# 14  1.6826897 5
# 15 39.3783684 5
# 16  2.4291979 5
# 17  0.3877549 5
# 18  0.5505003 5
# 19 37.8055166 5
# 20  1.6318153 5
# 21  0.5823258 5
# 22  0.8329285 5
# 23 43.1684341 5
# 24  2.5862515 5
# 25  0.9299483 5
# 26  1.4910873 5
# 27 42.1715062 5
# 28  2.3832545 5
# 29  2.0154317 5
# 30  1.8472619 5
# ⋮  ⋮          ⋮
# 55 15.2494586 5
# 56  5.8147022 5
# 57  3.2940441 5
# 58  0.9514130 5
# 59 18.4404367 5
# 60  2.4387566 5
# 61 24.3909245 5
# 62  1.3078676 5
# 63 17.7469432 5
# 64  4.0375773 5
# 65  3.1902162 5
# 66  0.8447293 5
# 67 19.6463070 5
# 68  1.4284458 5
# 69  0.8990542 5
# 70  0.8143904 5
# 71 16.5082668 5
# 72  0.9099884 5
# 73 31.9449972 5
# 74  4.1224887 5
# 75 15.9344908 5
# 76  3.0036530 5
# 77  0.2568311 5
# 78  0.4154104 5
# 79 14.4635204 5
# 80  0.2452915 5
# 81  1.4186179 5
# 82  1.2141027 5
# 83 15.3435287 5
# 84  3.0715724 5

# %%
results <- results_deg %>% filter(metric == "r_squared")


results$model <- factor(results$model, 
                                levels = c("id", "condot", "biolord", "otfm"),
                                labels = c("Baseline", "CondOT", "Biolord", "CellFlow"))  # Correct factorization

p <- ggplot(results, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="R squared DEG") +
    scale_fill_manual(values=color_dict, c("Baseline", "CondOT", "Biolord", "CellFlow")) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# Warning message in rep(yes, length.out = len):
# “'x' is NULL so the result will be NULL”
# ERROR while rich displaying an object: Error in ans[ypos] <- rep(yes, length.out = len)[ypos]: replacement has length zero
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 6. repr::mime2repr[[mime]](obj)
# 7. repr_text.default(obj)
# 8. paste(capture.output(print(obj)), collapse = "\n")
# 9. capture.output(print(obj))
# 10. withVisible(...elt(i))
# 11. print(obj)
# 12. print.ggplot(obj)
# 13. ggplot_build(x)
# 14. ggplot_build.ggplot(x)
# 15. layout$setup_panel_params()
# 16. setup_panel_params(..., self = self)
# 17. Map(setup_panel_params, scales_x, scales_y)
# 18. mapply(FUN = f, ..., SIMPLIFY = FALSE)
# 19. (function (scale_x, scale_y)
#   . {
#   .     self$coord$setup_panel_params(scale_x, scale_y, params = self$coord_params)
#   . })(dots[[1L]][[1L]], dots[[2L]][[1L]])
# 20. self$coord$setup_panel_params(scale_x, scale_y, params = self$coord_params)
# 21. setup_panel_params(..., self = self)
# 22. view_scales_from_scale(scale_x, self$limits$x, self$expand)
# 23. expand_limits_scale(scale, expansion, limits, coord_limits = coord_limits)
# 24. expand_limits_discrete(limits, expand, coord_limits, range_continuous = scale$range_c$range)
# 25. expand_limits_discrete_trans(limits, expand, coord_limits, range_continuous = range_continuous)
# 26. expand_limits_continuous_trans(range_continuous, expand, coord_limits,
#   .     trans)
# 27. ifelse(is.na(coord_limits), limits, coord_limits)

# %%
ggsave(file.path(output_dir, "ood_r_squared_deg.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %%
results <- results_deg %>% filter(metric == "sinkhorn_div")


results$model <- factor(results$model, 
                                levels = c("add", "CPA", "chemCPA", "otfm"),
                                labels = c("Additive", "CPA", "chemCPA", "CellFlow"))  # Rename levels

p <- ggplot(results, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Sinkhorn divergence DEG") +
    scale_fill_manual(values=color_dict, labels=c("Additive", "CPA", "chemCPA", "CellFlow")) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "ood_sink_div_deg.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %%
results <- results_deg %>% filter(metric == "e_distance")


results$model <- factor(results$model, 
                                levels = c("add", "CPA", "chemCPA", "otfm"),
                                labels = c("Additive", "CPA", "chemCPA", "CellFlow"))  # Rename levels

p <- ggplot(results, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="Energy distance DEG") +
    scale_fill_manual(values=color_dict, labels=c("Additive", "CPA", "chemCPA", "CellFlow")) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "ood_e_distance_deg.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %%
results <- results_deg %>% filter(metric == "mmd")


results$model <- factor(results$model, 
                                levels = c("add", "CPA", "chemCPA", "otfm"),
                                labels = c("Additive", "CPA", "chemCPA", "CellFlow"))  # Rename levels

p <- ggplot(results, aes(x=metric, y=value, fill=model)) +
  geom_boxplot(outlier.size=2) +
  labs(x="Model", y="MMD DEG") +
    scale_fill_manual(values=color_dict, labels=c("Additive", "CPA", "chemCPA", "CellFlow")) +
  scale_x_discrete(labels=c("")) +  # Change x-axis labels
  theme_bw() +
  theme(
    axis.title.x = element_text(size=16, face="bold"),
    axis.title.y = element_text(size=16, face="bold"),
    axis.text.x = element_text(size=14),
    axis.text.y = element_text(size=14),
    legend.title = element_text(size=14),
    legend.text = element_text(size=12),
    legend.position = "right",
    legend.box.background = element_rect(color="black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )
p
# Out:
# plot without title

# %%
ggsave(file.path(output_dir, "ood_mmd_deg.pdf"), plot = p, device = "pdf")
# Out:
# Saving 6.67 x 6.67 in image

# %%
def rank_genes_groups_by_cov(
    adata,
    groupby,
    control_group,
    covariate,
    n_genes=50,
    rankby_abs=True,
    key_added="rank_genes_groups_cov",
    return_dict=False,
):
    gene_dict = {}
    cov_categories = adata.obs[covariate].unique()
    for cov_cat in cov_categories:
        # name of the control group in the groupby obs column
        control_group_cov = control_group  # "_".join([cov_cat, control_group])
        # subset adata to cells belonging to a covariate category
        adata_cov = adata[adata.obs[covariate] == cov_cat]
        # compute DEGs
        sc.tl.rank_genes_groups(
            adata_cov,
            groupby=groupby,
            reference=control_group_cov,
            rankby_abs=rankby_abs,
            n_genes=n_genes,
            use_raw=False,
        )
        # add entries to dictionary of gene sets
        de_genes = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["names"])
        for group in de_genes:
            gene_dict[group] = de_genes[group].tolist()
    adata.uns[key_added] = gene_dict
    if return_dict:
        return gene_dict


def get_DE_genes(adata):
    adata.obs.loc[:, "control"] = adata.obs.condition.apply(lambda x: 1 if x == "control" else 0)
    adata.obs = adata.obs.astype("category")
    rank_genes_groups_by_cov(
        adata,
        groupby="condition",
        covariate="cell_line",
        control_group="ctrl",
        n_genes=50,
        key_added="rank_genes_groups_cov_all",
    )
    return adata

# %% [markdown]
# ### First split.

# %%
import scanpy as sc
import pickle
import os
import anndata
import numpy as np
import pandas as pd

output_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/norman"

# %%
train = sc.read_h5ad(os.path.join(output_dir, "adata_train_2_seen_genes.h5ad"))
ood = sc.read_h5ad(os.path.join(output_dir, "adata_ood_2_seen_genes.h5ad"))
test = sc.read_h5ad(os.path.join(output_dir, "adata_test_2_seen_genes.h5ad"))

# %%
custom_split = {}

# %%
train.obs.condition = train.obs.condition.str.replace('control', 'ctrl')
ood.obs.condition = ood.obs.condition.str.replace('control', 'ctrl')
test.obs.condition = test.obs.condition.str.replace('control', 'ctrl')

# %%
def modify_condition(condition):
    if '+' not in condition:
        if condition == 'ctrl':
            return condition
        else:
            return condition + '+ctrl'
    else:
        return condition

def modify_condition_name(condition):
    if condition != 'ctrl':
        return 'K562_'+ condition + '_1+1'
    else:
        return 'K562_'+ condition + '+1'

# Apply the function to the condition column
train.obs['condition'] = train.obs['condition'].apply(modify_condition)
ood.obs['condition'] = ood.obs['condition'].apply(modify_condition)
test.obs['condition'] = test.obs['condition'].apply(modify_condition)

train.obs['condition_name'] = train.obs['condition']
train.obs['condition_name'] = train.obs['condition'].apply(modify_condition_name)
ood.obs['condition_name'] = ood.obs['condition']
ood.obs['condition_name'] = ood.obs['condition'].apply(modify_condition_name)
test.obs['condition_name'] = test.obs['condition']
test.obs['condition_name'] = test.obs['condition'].apply(modify_condition_name)

# %%
ood.obs.condition
# Out:
# index
# AAACCTGAGGCCCTTG-1     KLF1+MAP2K6
# AAACCTGGTTCACCTC-1     MAP2K6+SPI1
# AAACCTGTCCATTCTA-1     FOXA1+FOXA3
# AAACGGGAGCGATTCT-1    IKZF3+MAP2K6
# AAACGGGGTAGCAAAT-1      FOXA1+KLF1
#                           ...
# TGTATTCTCACAAACC-8            ctrl
# TTAGGACAGGCTCATT-8            ctrl
# TTCCCAGCACGAAACG-8            ctrl
# TTGAACGTCACTTACT-8            ctrl
# TTGACTTGTATCAGTC-8            ctrl
# Name: condition, Length: 15112, dtype: object

# %%
train_list = []
ood_list = []

for pert in train.obs.condition.unique():
    if pert != 'ctrl':
        train_list.append(pert)

for pert in ood.obs.condition.unique():
    if pert != 'ctrl':
        ood_list.append(pert)

custom_split['train'] = train_list
custom_split['test'] = ood_list
custom_split['val'] = [train_list[1]]

# %%
custom_split['train'] = [pert for pert in custom_split['train'] if not pert in (['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]
custom_split['test'] = [pert for pert in custom_split['train'] if not pert in (['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]

# %%
gears_2seen = anndata.concat([train,ood,test])
gears_2seen.var['gene_name'] = gears_2seen.var.index.values
# Out:
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
gears_2seen
# Out:
# AnnData object with n_obs × n_vars = 111755 × 2000
#     obs: 'guide_identity', 'read_count', 'UMI_count', 'coverage', 'gemgroup', 'good_coverage', 'number_of_cells', 'guide_AHR', 'guide_ARID1A', 'guide_ARRDC3', 'guide_ATL1', 'guide_BAK1', 'guide_BCL2L11', 'guide_BCORL1', 'guide_BPGM', 'guide_C19orf26', 'guide_C3orf72', 'guide_CBFA2T3', 'guide_CBL', 'guide_CDKN1A', 'guide_CDKN1B', 'guide_CDKN1C', 'guide_CEBPA', 'guide_CEBPB', 'guide_CEBPE', 'guide_CELF2', 'guide_CITED1', 'guide_CKS1B', 'guide_CLDN6', 'guide_CNN1', 'guide_CNNM4', 'guide_COL1A1', 'guide_COL2A1', 'guide_CSRNP1', 'guide_DLX2', 'guide_DUSP9', 'guide_EGR1', 'guide_ELMSAN1', 'guide_ETS2', 'guide_FEV', 'guide_FOSB', 'guide_FOXA1', 'guide_FOXA3', 'guide_FOXF1', 'guide_FOXL2', 'guide_FOXO4', 'guide_GLB1L2', 'guide_HES7', 'guide_HK2', 'guide_HNF4A', 'guide_HOXA13', 'guide_HOXB9', 'guide_HOXC13', 'guide_IER5L', 'guide_IGDCC3', 'guide_IKZF3', 'guide_IRF1', 'guide_ISL2', 'guide_JUN', 'guide_KIAA1804', 'guide_KIF18B', 'guide_KIF2C', 'guide_KLF1', 'guide_KMT2A', 'guide_LHX1', 'guide_LYL1', 'guide_MAML2', 'guide_MAP2K3', 'guide_MAP2K6', 'guide_MAP4K3', 'guide_MAP4K5', 'guide_MAP7D1', 'guide_MAPK1', 'guide_MEIS1', 'guide_MIDN', 'guide_NCL', 'guide_NIT1', 'guide_OSR2', 'guide_PLK4', 'guide_POU3F2', 'guide_PRDM1', 'guide_PRTG', 'guide_PTPN1', 'guide_PTPN12', 'guide_PTPN13', 'guide_PTPN9', 'guide_RHOXF2', 'guide_RREB1', 'guide_RUNX1T1', 'guide_S1PR2', 'guide_SAMD1', 'guide_SET', 'guide_SGK1', 'guide_SLC38A2', 'guide_SLC4A1', 'guide_SLC6A9', 'guide_SNAI1', 'guide_SPI1', 'guide_STIL', 'guide_TBX2', 'guide_TBX3', 'guide_TGFBR2', 'guide_TMSB4X', 'guide_TP73', 'guide_TSC22D1', 'guide_UBASH3A', 'guide_UBASH3B', 'guide_ZBTB1', 'guide_ZBTB10', 'guide_ZBTB25', 'guide_ZC3HAV1', 'guide_ZNF318', 'guide_ids', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'condition', 'perturbation_type', 'perturbation_value', 'perturbation_unit', 'gene_1', 'gene_2', 'cell_line', 'ood', 'is_ood', 'control', 'condition_name'
#     var: 'gene_name'
#     obsm: 'X_pca', 'X_umap', 'emb_1', 'emb_2'
#     layers: 'centered_X', 'counts'

# %%
get_DE_genes(gears_2seen)

# %%
gears_2seen_final = anndata.concat([train,ood])

# %%
gears_2seen_final = anndata.concat([train,ood])
gears_2seen_final.uns = gears_2seen.uns
gears_2seen_final.var = gears_2seen.var

# %%
gears_2seen_final = gears_2seen_final[~gears_2seen_final.obs.condition.isin(['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]

# %%
train.obs
# Out:
#                                             guide_identity read_count  \
# index
# AAACCTGAGAAGAAGC-1    NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0       1252
# AAACCTGCACGAAGCA-1  NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0        958
# AAACCTGCAGACGTAG-1            CEBPE_RUNX1T1__CEBPE_RUNX1T1        244
# AAACCTGCAGCCTTGG-1          MAML2_NegCtrl0__MAML2_NegCtrl0       1525
# AAACCTGCATCTCCCA-1          NegCtrl0_CEBPE__NegCtrl0_CEBPE        499
# ...                                                    ...        ...
# TTTGTCAGTCCATGAT-8        TGFBR2_C19orf26__TGFBR2_C19orf26       1306
# TTTGTCATCAGTACGT-8          FOXA3_NegCtrl0__FOXA3_NegCtrl0       2068
# TTTGTCATCCACTCCA-8          CELF2_NegCtrl0__CELF2_NegCtrl0        829
# TTTGTCATCCCAACGG-8        BCORL1_NegCtrl0__BCORL1_NegCtrl0        136
# TTTGTCATCCTCCTAG-8            ZBTB10_PTPN12__ZBTB10_PTPN12       1254
#
#                    UMI_count   coverage gemgroup good_coverage  \
# index
# AAACCTGAGAAGAAGC-1        67  18.686567        1          True
# AAACCTGCACGAAGCA-1        39  24.564103        1          True
# AAACCTGCAGACGTAG-1        14  17.428571        1          True
# AAACCTGCAGCCTTGG-1        66  23.106061        1          True
# AAACCTGCATCTCCCA-1        30  16.633333        1          True
# ...                      ...        ...      ...           ...
# TTTGTCAGTCCATGAT-8        66  19.787879        8          True
# TTTGTCATCAGTACGT-8        95  21.768421        8          True
# TTTGTCATCCACTCCA-8        33  25.121212        8          True
# TTTGTCATCCCAACGG-8         9  15.111111        8          True
# TTTGTCATCCTCCTAG-8        59  21.254237        8          True
#
#                    number_of_cells guide_AHR guide_ARID1A guide_ARRDC3  ...  \
# index                                                                   ...
# AAACCTGAGAAGAAGC-1               2         0            0            0  ...
# AAACCTGCACGAAGCA-1               1         0            0            0  ...
# AAACCTGCAGACGTAG-1               1         0            0            0  ...
# AAACCTGCAGCCTTGG-1               1         0            0            0  ...
# AAACCTGCATCTCCCA-1               1         0            0            0  ...
# ...                            ...       ...          ...          ...  ...
# TTTGTCAGTCCATGAT-8               2         0            0            0  ...
# TTTGTCATCAGTACGT-8               1         0            0            0  ...
# TTTGTCATCCACTCCA-8               1         0            0            0  ...
# TTTGTCATCCCAACGG-8               1         0            0            0  ...
# TTTGTCATCCTCCTAG-8               3         0            0            0  ...
#
#                    perturbation_value perturbation_unit    gene_1   gene_2  \
# index
# AAACCTGAGAAGAAGC-1                NaN               NaN   control  control
# AAACCTGCACGAAGCA-1                NaN               NaN   control  control
# AAACCTGCAGACGTAG-1                NaN               NaN     CEBPE  RUNX1T1
# AAACCTGCAGCCTTGG-1                NaN               NaN     MAML2  control
# AAACCTGCATCTCCCA-1                NaN               NaN     CEBPE  control
# ...                               ...               ...       ...      ...
# TTTGTCAGTCCATGAT-8                NaN               NaN  C19orf26   TGFBR2
# TTTGTCATCAGTACGT-8                NaN               NaN     FOXA3  control
# TTTGTCATCCACTCCA-8                NaN               NaN     CELF2  control
# TTTGTCATCCCAACGG-8                NaN               NaN    BCORL1  control
# TTTGTCATCCTCCTAG-8                NaN               NaN    PTPN12   ZBTB10
#
#                    cell_line      ood is_ood  split control  \
# index
# AAACCTGAGAAGAAGC-1      K562  not ood  False  train       1
# AAACCTGCACGAAGCA-1      K562  not ood  False  train       1
# AAACCTGCAGACGTAG-1      K562  not ood  False  train       0
# AAACCTGCAGCCTTGG-1      K562  not ood  False  train       0
# AAACCTGCATCTCCCA-1      K562  not ood  False  train       0
# ...                      ...      ...    ...    ...     ...
# TTTGTCAGTCCATGAT-8      K562  not ood  False  train       0
# TTTGTCATCAGTACGT-8      K562  not ood  False  train       0
# TTTGTCATCCACTCCA-8      K562  not ood  False  train       0
# TTTGTCATCCCAACGG-8      K562  not ood  False  train       0
# TTTGTCATCCTCCTAG-8      K562  not ood  False  train       0
#
#                               condition_name
# index
# AAACCTGAGAAGAAGC-1               K562_ctrl+1
# AAACCTGCACGAAGCA-1               K562_ctrl+1
# AAACCTGCAGACGTAG-1    K562_CEBPE+RUNX1T1_1+1
# AAACCTGCAGCCTTGG-1       K562_MAML2+ctrl_1+1
# AAACCTGCATCTCCCA-1       K562_CEBPE+ctrl_1+1
# ...                                      ...
# TTTGTCAGTCCATGAT-8  K562_C19orf26+TGFBR2_1+1
# TTTGTCATCAGTACGT-8       K562_FOXA3+ctrl_1+1
# TTTGTCATCCACTCCA-8       K562_CELF2+ctrl_1+1
# TTTGTCATCCCAACGG-8      K562_BCORL1+ctrl_1+1
# TTTGTCATCCTCCTAG-8    K562_PTPN12+ZBTB10_1+1
#
# [83643 rows x 131 columns]

# %%
len(gears_2seen_final.obs_names)
# Out:
# 97652

# %%
len(set(gears_2seen_final.obs_names))
# Out:
# 97652

# %%
gears_2seen_final.write(os.path.join(output_dir, "gears", "2seen", "perturb_processed.h5ad"))
# Out:
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1209: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1209: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c

# %%
train.write(os.path.join(output_dir, "gears", "2seen", "train_processed.h5ad"))
ood.write(os.path.join(output_dir, "gears", "2seen", "ood_processed.h5ad"))
test.write(os.path.join(output_dir, "gears", "2seen", "test_processed.h5ad"))

# %%
with open(os.path.join(output_dir, "gears", "2seen", "custom_split_2seen.pkl"), 'wb') as fp:
    pickle.dump(custom_split, fp)

# %%
train.obs
# Out:
#                                             guide_identity read_count  \
# index
# AAACCTGAGAAGAAGC-1    NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0       1252
# AAACCTGCACGAAGCA-1  NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0        958
# AAACCTGCAGACGTAG-1            CEBPE_RUNX1T1__CEBPE_RUNX1T1        244
# AAACCTGCAGCCTTGG-1          MAML2_NegCtrl0__MAML2_NegCtrl0       1525
# AAACCTGCATCTCCCA-1          NegCtrl0_CEBPE__NegCtrl0_CEBPE        499
# ...                                                    ...        ...
# TTTGTCAGTCCATGAT-8        TGFBR2_C19orf26__TGFBR2_C19orf26       1306
# TTTGTCATCAGTACGT-8          FOXA3_NegCtrl0__FOXA3_NegCtrl0       2068
# TTTGTCATCCACTCCA-8          CELF2_NegCtrl0__CELF2_NegCtrl0        829
# TTTGTCATCCCAACGG-8        BCORL1_NegCtrl0__BCORL1_NegCtrl0        136
# TTTGTCATCCTCCTAG-8            ZBTB10_PTPN12__ZBTB10_PTPN12       1254
#
#                    UMI_count   coverage gemgroup good_coverage  \
# index
# AAACCTGAGAAGAAGC-1        67  18.686567        1          True
# AAACCTGCACGAAGCA-1        39  24.564103        1          True
# AAACCTGCAGACGTAG-1        14  17.428571        1          True
# AAACCTGCAGCCTTGG-1        66  23.106061        1          True
# AAACCTGCATCTCCCA-1        30  16.633333        1          True
# ...                      ...        ...      ...           ...
# TTTGTCAGTCCATGAT-8        66  19.787879        8          True
# TTTGTCATCAGTACGT-8        95  21.768421        8          True
# TTTGTCATCCACTCCA-8        33  25.121212        8          True
# TTTGTCATCCCAACGG-8         9  15.111111        8          True
# TTTGTCATCCTCCTAG-8        59  21.254237        8          True
#
#                    number_of_cells guide_AHR guide_ARID1A guide_ARRDC3  ...  \
# index                                                                   ...
# AAACCTGAGAAGAAGC-1               2         0            0            0  ...
# AAACCTGCACGAAGCA-1               1         0            0            0  ...
# AAACCTGCAGACGTAG-1               1         0            0            0  ...
# AAACCTGCAGCCTTGG-1               1         0            0            0  ...
# AAACCTGCATCTCCCA-1               1         0            0            0  ...
# ...                            ...       ...          ...          ...  ...
# TTTGTCAGTCCATGAT-8               2         0            0            0  ...
# TTTGTCATCAGTACGT-8               1         0            0            0  ...
# TTTGTCATCCACTCCA-8               1         0            0            0  ...
# TTTGTCATCCCAACGG-8               1         0            0            0  ...
# TTTGTCATCCTCCTAG-8               3         0            0            0  ...
#
#                    perturbation_value perturbation_unit    gene_1   gene_2  \
# index
# AAACCTGAGAAGAAGC-1                NaN               NaN   control  control
# AAACCTGCACGAAGCA-1                NaN               NaN   control  control
# AAACCTGCAGACGTAG-1                NaN               NaN     CEBPE  RUNX1T1
# AAACCTGCAGCCTTGG-1                NaN               NaN     MAML2  control
# AAACCTGCATCTCCCA-1                NaN               NaN     CEBPE  control
# ...                               ...               ...       ...      ...
# TTTGTCAGTCCATGAT-8                NaN               NaN  C19orf26   TGFBR2
# TTTGTCATCAGTACGT-8                NaN               NaN     FOXA3  control
# TTTGTCATCCACTCCA-8                NaN               NaN     CELF2  control
# TTTGTCATCCCAACGG-8                NaN               NaN    BCORL1  control
# TTTGTCATCCTCCTAG-8                NaN               NaN    PTPN12   ZBTB10
#
#                    cell_line      ood is_ood  split control  \
# index
# AAACCTGAGAAGAAGC-1      K562  not ood  False  train       1
# AAACCTGCACGAAGCA-1      K562  not ood  False  train       1
# AAACCTGCAGACGTAG-1      K562  not ood  False  train       0
# AAACCTGCAGCCTTGG-1      K562  not ood  False  train       0
# AAACCTGCATCTCCCA-1      K562  not ood  False  train       0
# ...                      ...      ...    ...    ...     ...
# TTTGTCAGTCCATGAT-8      K562  not ood  False  train       0
# TTTGTCATCAGTACGT-8      K562  not ood  False  train       0
# TTTGTCATCCACTCCA-8      K562  not ood  False  train       0
# TTTGTCATCCCAACGG-8      K562  not ood  False  train       0
# TTTGTCATCCTCCTAG-8      K562  not ood  False  train       0
#
#                               condition_name
# index
# AAACCTGAGAAGAAGC-1               K562_ctrl+1
# AAACCTGCACGAAGCA-1               K562_ctrl+1
# AAACCTGCAGACGTAG-1    K562_CEBPE+RUNX1T1_1+1
# AAACCTGCAGCCTTGG-1       K562_MAML2+ctrl_1+1
# AAACCTGCATCTCCCA-1       K562_CEBPE+ctrl_1+1
# ...                                      ...
# TTTGTCAGTCCATGAT-8  K562_C19orf26+TGFBR2_1+1
# TTTGTCATCAGTACGT-8       K562_FOXA3+ctrl_1+1
# TTTGTCATCCACTCCA-8       K562_CELF2+ctrl_1+1
# TTTGTCATCCCAACGG-8      K562_BCORL1+ctrl_1+1
# TTTGTCATCCTCCTAG-8    K562_PTPN12+ZBTB10_1+1
#
# [83643 rows x 131 columns]

# %% [markdown]
# ### Second split.

# %%
import scanpy as sc
import pickle
import os
import anndata
import numpy as np
import pandas as pd

output_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/norman"

# %%
train = sc.read_h5ad(os.path.join(output_dir, "adata_train_1_seen_genes.h5ad"))
ood = sc.read_h5ad(os.path.join(output_dir, "adata_ood_1_seen_genes.h5ad"))
test = sc.read_h5ad(os.path.join(output_dir, "adata_test_1_seen_genes.h5ad"))

# %%
custom_split = {}

# %%
train.obs.condition = train.obs.condition.str.replace('control', 'ctrl')
ood.obs.condition = ood.obs.condition.str.replace('control', 'ctrl')
test.obs.condition = test.obs.condition.str.replace('control', 'ctrl')

# %%
def modify_condition(condition):
    if '+' not in condition:
        if condition == 'ctrl':
            return condition
        else:
            return condition + '+ctrl'
    else:
        return condition

def modify_condition_name(condition):
    if condition != 'ctrl':
        return 'K562_'+ condition + '_1+1'
    else:
        return 'K562_'+ condition + '+1'

# Apply the function to the condition column
train.obs['condition'] = train.obs['condition'].apply(modify_condition)
ood.obs['condition'] = ood.obs['condition'].apply(modify_condition)
test.obs['condition'] = test.obs['condition'].apply(modify_condition)

train.obs['condition_name'] = train.obs['condition']
train.obs['condition_name'] = train.obs['condition'].apply(modify_condition_name)
ood.obs['condition_name'] = ood.obs['condition']
ood.obs['condition_name'] = ood.obs['condition'].apply(modify_condition_name)
test.obs['condition_name'] = test.obs['condition']
test.obs['condition_name'] = test.obs['condition'].apply(modify_condition_name)

# %%
ood.obs.condition
# Out:
# index
# AAACCTGAGGCCCTTG-1      KLF1+MAP2K6
# AAACGGGAGCGATTCT-1     IKZF3+MAP2K6
# AAAGATGAGAGTACAT-1    PTPN9+UBASH3B
# AAAGATGAGCCTCGTG-1    IGDCC3+ZBTB25
# AAAGCAAAGCTAGTCT-1    MAP2K3+MAP2K6
#                           ...
# TGTATTCTCACAAACC-8             ctrl
# TTAGGACAGGCTCATT-8             ctrl
# TTCCCAGCACGAAACG-8             ctrl
# TTGAACGTCACTTACT-8             ctrl
# TTGACTTGTATCAGTC-8             ctrl
# Name: condition, Length: 7772, dtype: object

# %%
train.obs.condition_name.unique()

# %%
train_list = []
ood_list = []

for pert in train.obs.condition.unique():
    if pert != 'ctrl':
        train_list.append(pert)

for pert in ood.obs.condition.unique():
    if pert != 'ctrl':
        ood_list.append(pert)

custom_split['train'] = train_list
custom_split['test'] = ood_list
custom_split['val'] = [train_list[1]]

# %%
custom_split['train'] = [pert for pert in custom_split['train'] if not pert in (['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]
custom_split['test'] = [pert for pert in custom_split['train'] if not pert in (['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]

# %%
gears_2seen = anndata.concat([train,ood,test])
gears_2seen.var['gene_name'] = gears_2seen.var.index.values
# Out:
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
gears_2seen
# Out:
# AnnData object with n_obs × n_vars = 100988 × 2000
#     obs: 'guide_identity', 'read_count', 'UMI_count', 'coverage', 'gemgroup', 'good_coverage', 'number_of_cells', 'guide_AHR', 'guide_ARID1A', 'guide_ARRDC3', 'guide_ATL1', 'guide_BAK1', 'guide_BCL2L11', 'guide_BCORL1', 'guide_BPGM', 'guide_C19orf26', 'guide_C3orf72', 'guide_CBFA2T3', 'guide_CBL', 'guide_CDKN1A', 'guide_CDKN1B', 'guide_CDKN1C', 'guide_CEBPA', 'guide_CEBPB', 'guide_CEBPE', 'guide_CELF2', 'guide_CITED1', 'guide_CKS1B', 'guide_CLDN6', 'guide_CNN1', 'guide_CNNM4', 'guide_COL1A1', 'guide_COL2A1', 'guide_CSRNP1', 'guide_DLX2', 'guide_DUSP9', 'guide_EGR1', 'guide_ELMSAN1', 'guide_ETS2', 'guide_FEV', 'guide_FOSB', 'guide_FOXA1', 'guide_FOXA3', 'guide_FOXF1', 'guide_FOXL2', 'guide_FOXO4', 'guide_GLB1L2', 'guide_HES7', 'guide_HK2', 'guide_HNF4A', 'guide_HOXA13', 'guide_HOXB9', 'guide_HOXC13', 'guide_IER5L', 'guide_IGDCC3', 'guide_IKZF3', 'guide_IRF1', 'guide_ISL2', 'guide_JUN', 'guide_KIAA1804', 'guide_KIF18B', 'guide_KIF2C', 'guide_KLF1', 'guide_KMT2A', 'guide_LHX1', 'guide_LYL1', 'guide_MAML2', 'guide_MAP2K3', 'guide_MAP2K6', 'guide_MAP4K3', 'guide_MAP4K5', 'guide_MAP7D1', 'guide_MAPK1', 'guide_MEIS1', 'guide_MIDN', 'guide_NCL', 'guide_NIT1', 'guide_OSR2', 'guide_PLK4', 'guide_POU3F2', 'guide_PRDM1', 'guide_PRTG', 'guide_PTPN1', 'guide_PTPN12', 'guide_PTPN13', 'guide_PTPN9', 'guide_RHOXF2', 'guide_RREB1', 'guide_RUNX1T1', 'guide_S1PR2', 'guide_SAMD1', 'guide_SET', 'guide_SGK1', 'guide_SLC38A2', 'guide_SLC4A1', 'guide_SLC6A9', 'guide_SNAI1', 'guide_SPI1', 'guide_STIL', 'guide_TBX2', 'guide_TBX3', 'guide_TGFBR2', 'guide_TMSB4X', 'guide_TP73', 'guide_TSC22D1', 'guide_UBASH3A', 'guide_UBASH3B', 'guide_ZBTB1', 'guide_ZBTB10', 'guide_ZBTB25', 'guide_ZC3HAV1', 'guide_ZNF318', 'guide_ids', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'condition', 'perturbation_type', 'perturbation_value', 'perturbation_unit', 'gene_1', 'gene_2', 'cell_line', 'ood', 'is_ood', 'control', 'condition_name'
#     var: 'gene_name'
#     obsm: 'X_pca', 'X_umap', 'emb_1', 'emb_2'
#     layers: 'centered_X', 'counts'

# %%
get_DE_genes(gears_2seen)

# %%
gears_2seen_final = anndata.concat([train,ood])
gears_2seen_final.uns = gears_2seen.uns
gears_2seen_final.var = gears_2seen.var

# %%
gears_2seen_final = gears_2seen_final[~gears_2seen_final.obs.condition.isin(['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]

# %%
train.obs
# Out:
#                                             guide_identity read_count  \
# index
# AAACCTGAGAAGAAGC-1    NegCtrl0_NegCtrl0__NegCtrl0_NegCtrl0       1252
# AAACCTGCACGAAGCA-1  NegCtrl10_NegCtrl0__NegCtrl10_NegCtrl0        958
# AAACCTGCAGACGTAG-1            CEBPE_RUNX1T1__CEBPE_RUNX1T1        244
# AAACCTGCAGCCTTGG-1          MAML2_NegCtrl0__MAML2_NegCtrl0       1525
# AAACCTGCATTACCTT-1                ETS2_MAP7D1__ETS2_MAP7D1          4
# ...                                                    ...        ...
# TTTGTCAGTCATGCAT-8                  RHOXF2_SET__RHOXF2_SET       1138
# TTTGTCATCCACTCCA-8          CELF2_NegCtrl0__CELF2_NegCtrl0        829
# TTTGTCATCCCAACGG-8        BCORL1_NegCtrl0__BCORL1_NegCtrl0        136
# TTTGTCATCCTCCTAG-8            ZBTB10_PTPN12__ZBTB10_PTPN12       1254
# TTTGTCATCTGGCGAC-8        MAP4K3_NegCtrl0__MAP4K3_NegCtrl0       1226
#
#                    UMI_count   coverage gemgroup good_coverage  \
# index
# AAACCTGAGAAGAAGC-1        67  18.686567        1          True
# AAACCTGCACGAAGCA-1        39  24.564103        1          True
# AAACCTGCAGACGTAG-1        14  17.428571        1          True
# AAACCTGCAGCCTTGG-1        66  23.106061        1          True
# AAACCTGCATTACCTT-1         1   4.000000        1         False
# ...                      ...        ...      ...           ...
# TTTGTCAGTCATGCAT-8        45  25.288889        8          True
# TTTGTCATCCACTCCA-8        33  25.121212        8          True
# TTTGTCATCCCAACGG-8         9  15.111111        8          True
# TTTGTCATCCTCCTAG-8        59  21.254237        8          True
# TTTGTCATCTGGCGAC-8        59  20.779661        8          True
#
#                    number_of_cells guide_AHR guide_ARID1A guide_ARRDC3  ...  \
# index                                                                   ...
# AAACCTGAGAAGAAGC-1               2         0            0            0  ...
# AAACCTGCACGAAGCA-1               1         0            0            0  ...
# AAACCTGCAGACGTAG-1               1         0            0            0  ...
# AAACCTGCAGCCTTGG-1               1         0            0            0  ...
# AAACCTGCATTACCTT-1               0         0            0            0  ...
# ...                            ...       ...          ...          ...  ...
# TTTGTCAGTCATGCAT-8               1         0            0            0  ...
# TTTGTCATCCACTCCA-8               1         0            0            0  ...
# TTTGTCATCCCAACGG-8               1         0            0            0  ...
# TTTGTCATCCTCCTAG-8               3         0            0            0  ...
# TTTGTCATCTGGCGAC-8               1         0            0            0  ...
#
#                    perturbation_value perturbation_unit   gene_1   gene_2  \
# index
# AAACCTGAGAAGAAGC-1                NaN               NaN  control  control
# AAACCTGCACGAAGCA-1                NaN               NaN  control  control
# AAACCTGCAGACGTAG-1                NaN               NaN    CEBPE  RUNX1T1
# AAACCTGCAGCCTTGG-1                NaN               NaN    MAML2  control
# AAACCTGCATTACCTT-1                NaN               NaN     ETS2   MAP7D1
# ...                               ...               ...      ...      ...
# TTTGTCAGTCATGCAT-8                NaN               NaN   RHOXF2      SET
# TTTGTCATCCACTCCA-8                NaN               NaN    CELF2  control
# TTTGTCATCCCAACGG-8                NaN               NaN   BCORL1  control
# TTTGTCATCCTCCTAG-8                NaN               NaN   PTPN12   ZBTB10
# TTTGTCATCTGGCGAC-8                NaN               NaN   MAP4K3  control
#
#                    cell_line      ood is_ood  split control  \
# index
# AAACCTGAGAAGAAGC-1      K562  not ood  False  train       1
# AAACCTGCACGAAGCA-1      K562  not ood  False  train       1
# AAACCTGCAGACGTAG-1      K562  not ood  False  train       0
# AAACCTGCAGCCTTGG-1      K562  not ood  False  train       0
# AAACCTGCATTACCTT-1      K562  not ood  False  train       0
# ...                      ...      ...    ...    ...     ...
# TTTGTCAGTCATGCAT-8      K562  not ood  False  train       0
# TTTGTCATCCACTCCA-8      K562  not ood  False  train       0
# TTTGTCATCCCAACGG-8      K562  not ood  False  train       0
# TTTGTCATCCTCCTAG-8      K562  not ood  False  train       0
# TTTGTCATCTGGCGAC-8      K562  not ood  False  train       0
#
#                             condition_name
# index
# AAACCTGAGAAGAAGC-1             K562_ctrl+1
# AAACCTGCACGAAGCA-1             K562_ctrl+1
# AAACCTGCAGACGTAG-1  K562_CEBPE+RUNX1T1_1+1
# AAACCTGCAGCCTTGG-1     K562_MAML2+ctrl_1+1
# AAACCTGCATTACCTT-1    K562_ETS2+MAP7D1_1+1
# ...                                    ...
# TTTGTCAGTCATGCAT-8     K562_RHOXF2+SET_1+1
# TTTGTCATCCACTCCA-8     K562_CELF2+ctrl_1+1
# TTTGTCATCCCAACGG-8    K562_BCORL1+ctrl_1+1
# TTTGTCATCCTCCTAG-8  K562_PTPN12+ZBTB10_1+1
# TTTGTCATCTGGCGAC-8    K562_MAP4K3+ctrl_1+1
#
# [80316 rows x 131 columns]

# %%
gears_2seen_final
# Out:
# View of AnnData object with n_obs × n_vars = 86985 × 2000
#     obs: 'guide_identity', 'read_count', 'UMI_count', 'coverage', 'gemgroup', 'good_coverage', 'number_of_cells', 'guide_AHR', 'guide_ARID1A', 'guide_ARRDC3', 'guide_ATL1', 'guide_BAK1', 'guide_BCL2L11', 'guide_BCORL1', 'guide_BPGM', 'guide_C19orf26', 'guide_C3orf72', 'guide_CBFA2T3', 'guide_CBL', 'guide_CDKN1A', 'guide_CDKN1B', 'guide_CDKN1C', 'guide_CEBPA', 'guide_CEBPB', 'guide_CEBPE', 'guide_CELF2', 'guide_CITED1', 'guide_CKS1B', 'guide_CLDN6', 'guide_CNN1', 'guide_CNNM4', 'guide_COL1A1', 'guide_COL2A1', 'guide_CSRNP1', 'guide_DLX2', 'guide_DUSP9', 'guide_EGR1', 'guide_ELMSAN1', 'guide_ETS2', 'guide_FEV', 'guide_FOSB', 'guide_FOXA1', 'guide_FOXA3', 'guide_FOXF1', 'guide_FOXL2', 'guide_FOXO4', 'guide_GLB1L2', 'guide_HES7', 'guide_HK2', 'guide_HNF4A', 'guide_HOXA13', 'guide_HOXB9', 'guide_HOXC13', 'guide_IER5L', 'guide_IGDCC3', 'guide_IKZF3', 'guide_IRF1', 'guide_ISL2', 'guide_JUN', 'guide_KIAA1804', 'guide_KIF18B', 'guide_KIF2C', 'guide_KLF1', 'guide_KMT2A', 'guide_LHX1', 'guide_LYL1', 'guide_MAML2', 'guide_MAP2K3', 'guide_MAP2K6', 'guide_MAP4K3', 'guide_MAP4K5', 'guide_MAP7D1', 'guide_MAPK1', 'guide_MEIS1', 'guide_MIDN', 'guide_NCL', 'guide_NIT1', 'guide_OSR2', 'guide_PLK4', 'guide_POU3F2', 'guide_PRDM1', 'guide_PRTG', 'guide_PTPN1', 'guide_PTPN12', 'guide_PTPN13', 'guide_PTPN9', 'guide_RHOXF2', 'guide_RREB1', 'guide_RUNX1T1', 'guide_S1PR2', 'guide_SAMD1', 'guide_SET', 'guide_SGK1', 'guide_SLC38A2', 'guide_SLC4A1', 'guide_SLC6A9', 'guide_SNAI1', 'guide_SPI1', 'guide_STIL', 'guide_TBX2', 'guide_TBX3', 'guide_TGFBR2', 'guide_TMSB4X', 'guide_TP73', 'guide_TSC22D1', 'guide_UBASH3A', 'guide_UBASH3B', 'guide_ZBTB1', 'guide_ZBTB10', 'guide_ZBTB25', 'guide_ZC3HAV1', 'guide_ZNF318', 'guide_ids', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'condition', 'perturbation_type', 'perturbation_value', 'perturbation_unit', 'gene_1', 'gene_2', 'cell_line', 'ood', 'is_ood', 'control', 'condition_name'
#     var: 'gene_name'
#     uns: 'rank_genes_groups_cov_all'
#     obsm: 'X_pca', 'X_umap', 'emb_1', 'emb_2'
#     layers: 'centered_X', 'counts'

# %%
gears_2seen_final.write(os.path.join(output_dir, "gears", "1seen", "perturb_processed.h5ad"))
# Out:
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1209: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1209: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c

# %%
train.write(os.path.join(output_dir, "gears", "1seen", "train_processed.h5ad"))
ood.write(os.path.join(output_dir, "gears", "1seen", "ood_processed.h5ad"))
test.write(os.path.join(output_dir, "gears", "1seen", "test_processed.h5ad"))

# %%
with open(os.path.join(output_dir, "gears", "1seen", "custom_split_1seen.pkl"), 'wb') as fp:
    pickle.dump(custom_split, fp)

# %%
len(gears_2seen_final.obs_names)
# Out:
# 86985

# %% [markdown]
# ### Third split.

# %%
import scanpy as sc
import pickle
import os
import anndata
import numpy as np
import pandas as pd

output_dir = "/lustre/groups/ml01/workspace/ot_perturbation/data/norman"

# %%
train = sc.read_h5ad(os.path.join(output_dir, "adata_train_0_seen_genes.h5ad"))
ood = sc.read_h5ad(os.path.join(output_dir, "adata_ood_0_seen_genes.h5ad"))
test = sc.read_h5ad(os.path.join(output_dir, "adata_test_0_seen_genes.h5ad"))

# %%
custom_split = {}

# %%
train.obs.condition = train.obs.condition.str.replace('control', 'ctrl')
ood.obs.condition = ood.obs.condition.str.replace('control', 'ctrl')
test.obs.condition = test.obs.condition.str.replace('control', 'ctrl')

# %%
def modify_condition(condition):
    if '+' not in condition:
        if condition == 'ctrl':
            return condition
        else:
            return condition + '+ctrl'
    else:
        return condition

def modify_condition_name(condition):
    if condition != 'ctrl':
        return 'K562_'+ condition + '_1+1'
    else:
        return 'K562_'+ condition + '+1'

# Apply the function to the condition column
train.obs['condition'] = train.obs['condition'].apply(modify_condition)
ood.obs['condition'] = ood.obs['condition'].apply(modify_condition)
test.obs['condition'] = test.obs['condition'].apply(modify_condition)

train.obs['condition_name'] = train.obs['condition']
train.obs['condition_name'] = train.obs['condition'].apply(modify_condition_name)
ood.obs['condition_name'] = ood.obs['condition']
ood.obs['condition_name'] = ood.obs['condition'].apply(modify_condition_name)
test.obs['condition_name'] = test.obs['condition']
test.obs['condition_name'] = test.obs['condition'].apply(modify_condition_name)

# %%
ood.obs.condition
# Out:
# index
# AAACCTGGTTCACCTC-1    MAP2K6+SPI1
# AAACGGGGTAGCAAAT-1     FOXA1+KLF1
# AAAGATGTCCACGAAT-1    BAK1+TMSB4X
# AAAGCAAAGGCGATAC-1     MAPK1+PRTG
# AAAGCAAGTCTCTCTG-1    MAP2K6+SPI1
#                          ...
# TGTATTCTCACAAACC-8           ctrl
# TTAGGACAGGCTCATT-8           ctrl
# TTCCCAGCACGAAACG-8           ctrl
# TTGAACGTCACTTACT-8           ctrl
# TTGACTTGTATCAGTC-8           ctrl
# Name: condition, Length: 4987, dtype: object

# %%
train_list = []
ood_list = []

for pert in train.obs.condition.unique():
    if pert != 'ctrl':
        train_list.append(pert)

for pert in ood.obs.condition.unique():
    if pert != 'ctrl':
        ood_list.append(pert)

custom_split['train'] = train_list
custom_split['test'] = ood_list
custom_split['val'] = [train_list[1]]

# %%
custom_split['train'] = [pert for pert in custom_split['train'] if not pert in (['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]
custom_split['test'] = [pert for pert in custom_split['train'] if not pert in (['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]

# %%
gears_2seen = anndata.concat([train,ood,test])
gears_2seen.var['gene_name'] = gears_2seen.var.index.values
# Out:
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
get_DE_genes(gears_2seen)

# %%
gears_2seen_final = anndata.concat([train,ood])
gears_2seen_final.uns = gears_2seen.uns
gears_2seen_final.var = gears_2seen.var

# %%
gears_2seen_final = gears_2seen_final[~gears_2seen_final.obs.condition.isin(['KIAA1804+ctrl', 'IER5L+LYL1', 'IER5L+ctrl'])]

# %%
gears_2seen_final.write(os.path.join(output_dir, "gears", "0seen", "perturb_processed.h5ad"))
# Out:
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1209: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/icb/alejandro.tejada/miniforge3/envs/gears/lib/python3.12/site-packages/anndata/_core/anndata.py:1209: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c

# %%
train.write(os.path.join(output_dir, "gears", "0seen", "train_processed.h5ad"))
ood.write(os.path.join(output_dir, "gears", "0seen", "ood_processed.h5ad"))
test.write(os.path.join(output_dir, "gears", "0seen", "test_processed.h5ad"))

# %%
with open(os.path.join(output_dir, "gears", "0seen", "custom_split_0seen.pkl"), 'wb') as fp:
    pickle.dump(custom_split, fp)

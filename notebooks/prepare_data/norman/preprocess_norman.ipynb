# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **Additional dependencies to use gene splitting implemented in gears:** \
# `pip install torch_geometric` \
# `pip install cell-gears`

# %% [markdown]
# **Instructions to download dataset:**\
# (mostly following [biolord documentation](https://github.com/nitzanlab/biolord_reproducibility))
# 1. Download data from [here](https://dataverse.harvard.edu/api/access/datafile/6894431 ) to obtain `norman2019_gears.zip`
# 2. Run `unzip norman2019_gears.zip` to obtain the directory `norman2019` with files `essential_norman.pkl`, `go_essential_norman.csv` and `norman2019.tar.gz`
# 3. Run `tar -xzvf norman2019.tar.gz` to uncompress the tar file. This creates a directory `norman2019` with files `perturb_processed.h5ad`, `data_pyg/`, `data_pyg/cell_graphs.pkl`, `splits/`
# 4. Copy all of the above files to their parent directory, e.g. `<path>/norman2019/norman2019/data_pyg` should instead be `<path>/norman2019/data_pyg`

# %%
import os
import glob
import torch
import anndata
import numpy as np
import pandas as pd
import scanpy as sc

from sklearn.model_selection import train_test_split
from gears import PertData
from cfp import preprocessing as cfpp

# %%
N_PCA_COMPONENTS = 100

# %%
def rank_genes_groups_by_cov(
    adata,
    groupby,
    control_group,
    covariate,
    n_genes=50,
    rankby_abs=True,
    key_added="rank_genes_groups_cov",
    return_dict=False,
):
    gene_dict = {}
    cov_categories = adata.obs[covariate].unique()
    for cov_cat in cov_categories:
        # name of the control group in the groupby obs column
        control_group_cov = control_group  # "_".join([cov_cat, control_group])
        # subset adata to cells belonging to a covariate category
        adata_cov = adata[adata.obs[covariate] == cov_cat]
        # compute DEGs
        sc.tl.rank_genes_groups(
            adata_cov,
            groupby=groupby,
            reference=control_group_cov,
            rankby_abs=rankby_abs,
            n_genes=n_genes,
            use_raw=False,
        )
        # add entries to dictionary of gene sets
        de_genes = pd.DataFrame(adata_cov.uns["rank_genes_groups"]["names"])
        for group in de_genes:
            gene_dict[group] = de_genes[group].tolist()
    adata.uns[key_added] = gene_dict
    if return_dict:
        return gene_dict


def get_DE_genes(adata):
    adata.obs.loc[:, "control"] = adata.obs.condition.apply(lambda x: 1 if x == "control" else 0)
    adata.obs = adata.obs.astype("category")
    rank_genes_groups_by_cov(
        adata,
        groupby="condition",
        covariate="cell_line",
        control_group="ctrl",
        n_genes=50,
        key_added="rank_genes_groups_cov_all",
    )
    return adata

# %% [markdown]
# #### Data loading via GEARS

# %%
data_dir = "/home/haicu/soeren.becker/repos/ot_pert_reproducibility/norman2019"
pert_data = PertData(data_dir,  gene_set_path=os.path.join(data_dir, "essential_norman.pkl"))
pert_data.load(data_path = data_dir)

pert_data.adata.obs.loc[:, "cell_line"] = "A549"
pert_data.adata.obs.loc[:, ["gene_1", "gene_2"]] = pert_data.adata.obs.condition.str.split("+", expand=True).values
print(f"Found nans before fillna(): {pert_data.adata.obs.isna().any()}")
pert_data.adata.obs.gene_2.fillna("ctrl", inplace=True)
print(f"Found nans before fillna(): {pert_data.adata.obs.isna().any()}")

kategories = {2: "ctrl", 1: "single", 0: "double"} 
pert_data.adata.obs.loc[:, "num_control"] = \
    (pert_data.adata.obs.loc[:, "gene_1"] == "ctrl").astype(int) + \
    (pert_data.adata.obs.loc[:, "gene_2"] == "ctrl").astype(int)
pert_data.adata.obs.loc[:, "kategory"] = pert_data.adata.obs.loc[:, "num_control"].map(kategories)
pert_data.adata.obs.loc[:, "control"] = (pert_data.adata.obs.loc[:, "gene_1"] == "ctrl") & (pert_data.adata.obs.loc[:, "gene_2"] == "ctrl")

display(pert_data.adata)
display(pert_data.adata.obs)

# are all gene targets of double knock-ins also contained in single knock-in conditions?
single_targets = np.unique(pert_data.adata.obs.loc[pert_data.adata.obs.kategory == "single", ["gene_1", "gene_2"]].values)
double_targets = np.unique(pert_data.adata.obs.loc[pert_data.adata.obs.kategory == "double", ["gene_1", "gene_2"]].values)

print(
    "Fraction of targets in single condition that also appear as combo target condition: " +\
    f"{np.isin(single_targets, double_targets).sum()}/{len(single_targets)}"
)

print(
    "Fraction of targets in combo condition that also appear as single target condition: " +\
    f"{np.isin(double_targets, single_targets).sum()}/{len(double_targets)}"
)
# Out:
# Found local copy...
# These perturbations are not in the GO graph and their perturbation can thus not be predicted
# ['RHOXF2BB+ctrl' 'LYL1+IER5L' 'ctrl+IER5L' 'KIAA1804+ctrl' 'IER5L+ctrl'
#  'RHOXF2BB+ZBTB25' 'RHOXF2BB+SET']
# Local copy of pyg dataset is detected. Loading...
# Done!
# Found nans before fillna(): condition         False
# cell_type         False
# dose_val          False
# control           False
# condition_name    False
# cell_line         False
# gene_1            False
# gene_2             True
# dtype: bool
# Found nans before fillna(): condition         False
# cell_type         False
# dose_val          False
# control           False
# condition_name    False
# cell_line         False
# gene_1            False
# gene_2            False
# dtype: bool
# AnnData object with n_obs × n_vars = 89357 × 5045
#     obs: 'condition', 'cell_type', 'dose_val', 'control', 'condition_name', 'cell_line', 'gene_1', 'gene_2', 'num_control', 'kategory'
#     var: 'gene_name'
#     uns: 'non_dropout_gene_idx', 'non_zeros_gene_idx', 'rank_genes_groups_cov_all', 'top_non_dropout_de_20', 'top_non_zero_de_20'
#     layers: 'counts'
#                         condition cell_type dose_val  control  \
# cell_barcode
# AAACCTGAGGCATGTG-1   TSC22D1+ctrl      A549      1+1    False
# AAACCTGAGGCCCTTG-1    KLF1+MAP2K6      A549      1+1    False
# AAACCTGCACGAAGCA-1           ctrl      A549        1     True
# AAACCTGCAGACGTAG-1  CEBPE+RUNX1T1      A549      1+1    False
# AAACCTGCAGCCTTGG-1     MAML2+ctrl      A549      1+1    False
# ...                           ...       ...      ...      ...
# TTTGTCAGTCAGAATA-8           ctrl      A549        1     True
# TTTGTCATCAGTACGT-8     FOXA3+ctrl      A549      1+1    False
# TTTGTCATCCACTCCA-8     CELF2+ctrl      A549      1+1    False
# TTTGTCATCCCAACGG-8    BCORL1+ctrl      A549      1+1    False
# TTTGTCATCTGGCGAC-8    MAP4K3+ctrl      A549      1+1    False
#
#                             condition_name cell_line   gene_1   gene_2  \
# cell_barcode
# AAACCTGAGGCATGTG-1   A549_TSC22D1+ctrl_1+1      A549  TSC22D1     ctrl
# AAACCTGAGGCCCTTG-1    A549_KLF1+MAP2K6_1+1      A549     KLF1   MAP2K6
# AAACCTGCACGAAGCA-1             A549_ctrl_1      A549     ctrl     ctrl
# AAACCTGCAGACGTAG-1  A549_CEBPE+RUNX1T1_1+1      A549    CEBPE  RUNX1T1
# AAACCTGCAGCCTTGG-1     A549_MAML2+ctrl_1+1      A549    MAML2     ctrl
# ...                                    ...       ...      ...      ...
# TTTGTCAGTCAGAATA-8             A549_ctrl_1      A549     ctrl     ctrl
# TTTGTCATCAGTACGT-8     A549_FOXA3+ctrl_1+1      A549    FOXA3     ctrl
# TTTGTCATCCACTCCA-8     A549_CELF2+ctrl_1+1      A549    CELF2     ctrl
# TTTGTCATCCCAACGG-8    A549_BCORL1+ctrl_1+1      A549   BCORL1     ctrl
# TTTGTCATCTGGCGAC-8    A549_MAP4K3+ctrl_1+1      A549   MAP4K3     ctrl
#
#                     num_control kategory
# cell_barcode
# AAACCTGAGGCATGTG-1            1   single
# AAACCTGAGGCCCTTG-1            0   double
# AAACCTGCACGAAGCA-1            2     ctrl
# AAACCTGCAGACGTAG-1            0   double
# AAACCTGCAGCCTTGG-1            1   single
# ...                         ...      ...
# TTTGTCAGTCAGAATA-8            2     ctrl
# TTTGTCATCAGTACGT-8            1   single
# TTTGTCATCCACTCCA-8            1   single
# TTTGTCATCCCAACGG-8            1   single
# TTTGTCATCTGGCGAC-8            1   single
#
# [89357 rows x 10 columns]
# Fraction of targets in single condition that also appear as combo target condition: 71/103
# Fraction of targets in combo condition that also appear as single target condition: 71/71

# %% [markdown]
# #### Add ESM2 embeddings to adata.uns

# %%
# Specify the folder path
folder_path = '/lustre/groups/ml01/workspace/ot_perturbation/pert_embeddings/norman/norman/'

# Use glob to get all .pt files in the folder
pt_files = glob.glob(folder_path + '*.pt')
print(f"Found {len(pt_files)} files.")

ensembleID_to_esm2_embedding = {}

for path in pt_files:
    split_path = path.split('_')
    gene = split_path[3]
    loaded = torch.load(path)
    ensembleID_to_esm2_embedding[gene] = loaded['mean_representations'][36]

adata = pert_data.adata
perturbed_genes = np.unique(adata.obs.loc[:, ["gene_1", "gene_2"]].values)
_mapping = adata.var.loc[adata.var.gene_name.isin(perturbed_genes)]
gene_name_to_ensemble_id = dict(zip(_mapping.gene_name, _mapping.index))

adata.obs.loc[:, ["gene_1", "gene_2"]] = adata.obs.condition.str.split("+", expand=True).values
# display(adata.obs.isna().any())
adata.obs.gene_1.fillna("ctrl", inplace=True)
adata.obs.gene_2.fillna("ctrl", inplace=True)
# display(adata.obs.isna().any())

gene_name_to_embedding = {}

for gene_name in perturbed_genes:
    if gene_name in ["ctrl", "control"]: 
        # add after loop when we know embedding dim
        continue
    ensemble_id = gene_name_to_ensemble_id[gene_name]
    esm2_embedding = ensembleID_to_esm2_embedding[ensemble_id]
    gene_name_to_embedding[gene_name] = esm2_embedding.numpy()
gene_name_to_embedding["ctrl"] = np.zeros_like(esm2_embedding)

print(f"Added esm2 embeddings for {len(gene_name_to_embedding.keys())} genes.")
print(f"esm2 embeddings have shape {gene_name_to_embedding["ctrl"].shape}")

adata.uns['esm2'] = gene_name_to_embedding

adata.X = adata.layers["counts"]
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, inplace=True, n_top_genes=2000, subset=True)

get_DE_genes(adata) # updates adata in-place
assert "rank_genes_groups_cov_all" in adata.uns.keys()
# Out:
# Found 105 files.
# Added esm2 embeddings for 103 genes.
# esm2 embeddings have shape (2560,)

# %%
if False:
    # Optionally check dataset against version available in pertpy
    import pertpy as pt
    adata_pertpy = pt.dt.norman_2019()
    adata_pertpy
    
    pd.options.display.max_columns = None
    display(adata_pertpy.obs)
    
    conditions_pertpy = np.unique(adata_pertpy.obs.loc[:, "perturbation_name"].str.split("+", expand=True).fillna("control").values)
    print(len(conditions_pertpy))
    print(conditions_pertpy)
    
    adata_biolord = pert_data.adata.obs.loc[:, "condition"].str.split("+", expand=True).fillna("control")
    adata_biolord.loc[:, 0] = adata_biolord.loc[:, 0].apply(lambda x: "control" if x == "ctrl" else x)
    adata_biolord.loc[:, 1] = adata_biolord.loc[:, 1].apply(lambda x: "control" if x == "ctrl" else x)
    
    conditions_biolord = np.unique(adata_biolord.values)
    print(len(conditions_biolord))
    print(conditions_biolord)
    
    pertpy_condition_is_in_biolord = np.isin(conditions_pertpy, conditions_biolord)
    print(f"{pertpy_condition_is_in_biolord.sum()} / {len(conditions_pertpy)}")
    
    biolord_condition_is_in_pertpy = np.isin(conditions_biolord, conditions_pertpy)
    print(f"{biolord_condition_is_in_pertpy.sum()} / {len(conditions_biolord)}")
    
    print(sorted(conditions_pertpy[~pertpy_condition_is_in_biolord]))

# %% [markdown]
# ### Create data splits

# %%
def verify_split_integrity(pert_data: PertData, split_dict: dict):

    df_train = pd.DataFrame(split_dict["train"]).rename({0: "target_genes"}, axis=1)
    df_train.loc[:, ["gene1", "gene2"]] = df_train.target_genes.str.split("+", expand=True).values
    df_train.fillna("ctrl", inplace=True)
    train_genes = np.unique(df_train.gene1.unique().tolist() + df_train.gene2.unique().tolist())
    print(f"Found {len(train_genes)} unique genes in train split")
    
    df_val = pd.DataFrame(split_dict["val"]).rename({0: "target_genes"}, axis=1)
    df_val.loc[:, ["gene1", "gene2"]] = df_val.target_genes.str.split("+", expand=True).values
    df_val.fillna("ctrl", inplace=True)
    val_genes = np.unique(df_val.gene1.unique().tolist() + df_val.gene2.unique().tolist())
    print(f"Found {len(val_genes)} unique genes in val split")
    
    train_and_val_genes = np.unique(train_genes.tolist() + val_genes.tolist())
    print(f"Found {len(train_and_val_genes)} unique genes in train + val split")
    
    def create_df_from_subgroup(
        pert_data: PertData,
        subgroup: str
    ) -> pd.DataFrame:
    
        df_seen0 = pd.DataFrame().from_dict(pert_data.subgroup[subgroup]["combo_seen0"])
        df_seen0.loc[:, "kategory"] = "combo_seen0"
        df_seen1 = pd.DataFrame().from_dict(pert_data.subgroup[subgroup]["combo_seen1"])
        df_seen1.loc[:, "kategory"] = "combo_seen1"
        df_seen2 = pd.DataFrame().from_dict(pert_data.subgroup[subgroup]["combo_seen2"])
        df_seen2.loc[:, "kategory"] = "combo_seen2"
        df_single = pd.DataFrame().from_dict(pert_data.subgroup[subgroup]["unseen_single"])
        df_single.loc[:, "kategory"] = "single1"
        df = pd.concat([df_seen0, df_seen1, df_seen2, df_single], axis=0, ignore_index=True)
        df.rename({0: "target_genes"}, axis=1, inplace=True)
        df.loc[:, ["gene1", "gene2"]] = df.target_genes.str.split("+", expand=True).loc[:, [0, 1]].values
        mask = (df.gene1 == "ctrl") & (df.gene2 != "ctrl")
        df.loc[mask, "gene1"] = df.loc[mask, "gene2"]
        df.loc[mask, "gene2"] = "ctrl"
        return df
        
    df_test = create_df_from_subgroup(pert_data, subgroup="test_subgroup")
    df_test.loc[:, "gene1_is_in_train_or_val"] = np.isin(df_test.gene1.values, train_and_val_genes)
    df_test.loc[:, "gene2_is_in_train_or_val"] = np.isin(df_test.gene2.values, train_and_val_genes)

    # combo_seen0: Neither gene1 nor gene2 is contained in the train or val genes (neither in single knock-ins not knock-in combinations).
    print("combo_seen0")
    display(df_test.loc[df_test.kategory == "combo_seen0"])
    assert not any(
        df_test.loc[df_test.kategory == "combo_seen0"].gene1_is_in_train_or_val | 
        df_test.loc[df_test.kategory == "combo_seen0"].gene2_is_in_train_or_val
    )
    
    # xor gene1 or gene2 (i.e., exactly one of the two) is contained in the train or val genes.
    display(df_test.loc[df_test.kategory == "combo_seen1"])
    assert (
        np.all(
            (
                df_test.loc[df_test.kategory == "combo_seen1"].gene1_is_in_train_or_val.astype(int) + 
                df_test.loc[df_test.kategory == "combo_seen1"].gene2_is_in_train_or_val.astype(int)
            )
            == 1
        )
    )

    # both gene1 and gene2 are contained in train or val genes.
    display(df_test.loc[df_test.kategory == "combo_seen2"])
    assert all(
        df_test.loc[df_test.kategory == "combo_seen2"].gene1_is_in_train_or_val &
        df_test.loc[df_test.kategory == "combo_seen2"].gene2_is_in_train_or_val
    )

    # none of the single knock-in genes in contained in the train or val genes.
    display(df_test.loc[df_test.kategory == "single1"])
    assert (not any(df_test.loc[df_test.kategory == "single1"].gene1_is_in_train_or_val))
    print("All assertions passed.")

# %%
# for some reason the 'True' entries control column get lost?
pert_data.adata.obs.loc[:, "control"] = pert_data.adata.obs.loc[:, "num_control"] == 2

# %%
OUTPUT_DIR = os.path.join(data_dir, "./norman_preprocessed_adata")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# save entire dataset
pert_data.adata.write_h5ad(os.path.join(OUTPUT_DIR, "adata_all.h5ad"))

# we split control cells in train and test. Test control cells are the same in val and test though.
num_control_cells_in_test = 500
train_idcs_ctrl, test_and_val_idcs_ctrl = train_test_split(
    pert_data.adata.obs.loc[pert_data.adata.obs.control].index, 
    test_size=num_control_cells_in_test, 
    random_state=2024, 
    shuffle=True, 
)

for split_idx, seed in enumerate(range(1, 6)):
    
    # we follow data splitting of biolord reproducibility notebook: 
    # https://github.com/nitzanlab/biolord_reproducibility?tab=readme-ov-file
    
    pert_data.prepare_split(split = "simulation", seed = seed)
    
    # adjust the path to the splits according to the output of pert_data.prepare_split()
    # path_to_splits = f"/home/haicu/soeren.becker/repos/ot_pert_reproducibility/norman2019/splits/norman2019_simulation_{seed}_0.75.pkl"
    path_to_splits = os.path.join(data_dir, f"splits/norman2019_simulation_{seed}_0.75.pkl")
    split_dict = pd.read_pickle(path_to_splits)
    verify_split_integrity(pert_data, split_dict)

    train_conditions = split_dict["train"]
    val_conditions = split_dict["val"]
    test_conditions = split_dict["test"]

    # filter out ctrl cells, which we treat separately
    train_conditions = [c for c in train_conditions if c != "ctrl"]
    val_conditions = [c for c in val_conditions if c != "ctrl"]
    test_conditions = [c for c in test_conditions if c != "ctrl"]
    
    assert(len(np.intersect1d(train_conditions, val_conditions)) == 0)
    assert(len(np.intersect1d(train_conditions, test_conditions)) == 0)
    assert(len(np.intersect1d(val_conditions, test_conditions)) == 0)

    train_mask = pert_data.adata.obs.condition.isin(train_conditions) | pert_data.adata.obs.index.isin(train_idcs_ctrl)
    val_mask = pert_data.adata.obs.condition.isin(val_conditions) | pert_data.adata.obs.index.isin(test_and_val_idcs_ctrl)
    test_mask = pert_data.adata.obs.condition.isin(test_conditions) | pert_data.adata.obs.index.isin(test_and_val_idcs_ctrl)
    
    adata_train = pert_data.adata[train_mask].to_memory()
    adata_val = pert_data.adata[val_mask].to_memory()
    adata_test = pert_data.adata[test_mask].to_memory()
    
    print("all", pert_data.adata.shape)
    print("train", adata_train.shape)
    print("val", adata_val.shape)
    print("test", adata_test.shape)
    
    cfpp.centered_pca(adata_train, n_comps=N_PCA_COMPONENTS)
    cfpp.project_pca(query_adata = adata_val, ref_adata=adata_train)
    cfpp.project_pca(query_adata = adata_test, ref_adata=adata_train)

    adata_train.write_h5ad(os.path.join(OUTPUT_DIR, f"adata_train_pca_{N_PCA_COMPONENTS}_split_{split_idx}.h5ad"))
    adata_val.write_h5ad(os.path.join(OUTPUT_DIR, f"adata_val_pca_{N_PCA_COMPONENTS}_split_{split_idx}.h5ad"))
    adata_test.write_h5ad(os.path.join(OUTPUT_DIR, f"adata_test_pca_{N_PCA_COMPONENTS}_split_{split_idx}.h5ad"))
# Out:
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:9
# combo_seen1:43
# combo_seen2:19
# unseen_single:36
# Done!
# here1
# Found 69 unique genes in train split
# Found 27 unique genes in val split
# Found 77 unique genes in train + val split
# combo_seen0
#     target_genes     kategory    gene1   gene2  gene1_is_in_train_or_val  \
# 0      CBL+PTPN9  combo_seen0      CBL   PTPN9                     False
# 1     DUSP9+PRTG  combo_seen0    DUSP9    PRTG                     False
# 2    FOXL2+MEIS1  combo_seen0    FOXL2   MEIS1                     False
# 3     CEBPB+OSR2  combo_seen0    CEBPB    OSR2                     False
# 4      JUN+CEBPB  combo_seen0      JUN   CEBPB                     False
# 5  CDKN1C+CDKN1B  combo_seen0   CDKN1C  CDKN1B                     False
# 6  CDKN1C+CDKN1A  combo_seen0   CDKN1C  CDKN1A                     False
# 7  CDKN1B+CDKN1A  combo_seen0   CDKN1B  CDKN1A                     False
# 8  C3orf72+FOXL2  combo_seen0  C3orf72   FOXL2                     False
#
#    gene2_is_in_train_or_val
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# 5                     False
# 6                     False
# 7                     False
# 8                     False
#       target_genes     kategory    gene1    gene2  gene1_is_in_train_or_val  \
# 9      MAP2K6+SPI1  combo_seen1   MAP2K6     SPI1                      True
# 10     DUSP9+MAPK1  combo_seen1    DUSP9    MAPK1                     False
# 11    UBASH3B+OSR2  combo_seen1  UBASH3B     OSR2                      True
# 12      DUSP9+ETS2  combo_seen1    DUSP9     ETS2                     False
# 13    ZNF318+FOXL2  combo_seen1   ZNF318    FOXL2                      True
# 14   UBASH3B+PTPN9  combo_seen1  UBASH3B    PTPN9                      True
# 15       JUN+CEBPA  combo_seen1      JUN    CEBPA                     False
# 16      MAPK1+PRTG  combo_seen1    MAPK1     PRTG                      True
# 17     KLF1+COL2A1  combo_seen1     KLF1   COL2A1                      True
# 18     PTPN12+OSR2  combo_seen1   PTPN12     OSR2                      True
# 19    POU3F2+FOXL2  combo_seen1   POU3F2    FOXL2                      True
# 20  BCL2L11+TGFBR2  combo_seen1  BCL2L11   TGFBR2                     False
# 21     CEBPB+CEBPA  combo_seen1    CEBPB    CEBPA                     False
# 22    PTPN12+PTPN9  combo_seen1   PTPN12    PTPN9                      True
# 23      FOSB+CEBPB  combo_seen1     FOSB    CEBPB                      True
# 24    BCL2L11+BAK1  combo_seen1  BCL2L11     BAK1                     False
# 25        CBL+CNN1  combo_seen1      CBL     CNN1                     False
# 26   ZBTB10+PTPN12  combo_seen1   ZBTB10   PTPN12                     False
# 27     CBL+UBASH3B  combo_seen1      CBL  UBASH3B                     False
# 28    CEBPB+PTPN12  combo_seen1    CEBPB   PTPN12                     False
# 29     CEBPB+MAPK1  combo_seen1    CEBPB    MAPK1                     False
# 30    DUSP9+IGDCC3  combo_seen1    DUSP9   IGDCC3                     False
# 31      CBL+PTPN12  combo_seen1      CBL   PTPN12                     False
# 32      SGK1+S1PR2  combo_seen1     SGK1    S1PR2                      True
# 33      DUSP9+KLF1  combo_seen1    DUSP9     KLF1                     False
# 34      CEBPE+SPI1  combo_seen1    CEBPE     SPI1                      True
# 35      CBL+TGFBR2  combo_seen1      CBL   TGFBR2                     False
# 36     FOXA1+FOXL2  combo_seen1    FOXA1    FOXL2                      True
# 37     FOXF1+FOXL2  combo_seen1    FOXF1    FOXL2                      True
# 38       ETS2+PRTG  combo_seen1     ETS2     PRTG                      True
# 39      LYL1+CEBPB  combo_seen1     LYL1    CEBPB                      True
# 40     DUSP9+SNAI1  combo_seen1    DUSP9    SNAI1                     False
# 41     TGFBR2+PRTG  combo_seen1   TGFBR2     PRTG                      True
# 42       FOSB+OSR2  combo_seen1     FOSB     OSR2                      True
# 43     FOXL2+HOXB9  combo_seen1    FOXL2    HOXB9                     False
# 44  ZBTB10+ELMSAN1  combo_seen1   ZBTB10  ELMSAN1                     False
# 45    ZBTB10+SNAI1  combo_seen1   ZBTB10    SNAI1                     False
# 46     CEBPE+CEBPB  combo_seen1    CEBPE    CEBPB                      True
# 47   PRDM1+CBFA2T3  combo_seen1    PRDM1  CBFA2T3                     False
# 48     FOXA3+FOXL2  combo_seen1    FOXA3    FOXL2                      True
# 49     ZBTB10+DLX2  combo_seen1   ZBTB10     DLX2                     False
# 50     CBL+UBASH3A  combo_seen1      CBL  UBASH3A                     False
# 51     IGDCC3+PRTG  combo_seen1   IGDCC3     PRTG                      True
#
#     gene2_is_in_train_or_val
# 9                      False
# 10                      True
# 11                     False
# 12                      True
# 13                     False
# 14                     False
# 15                      True
# 16                     False
# 17                     False
# 18                     False
# 19                     False
# 20                      True
# 21                      True
# 22                     False
# 23                     False
# 24                      True
# 25                      True
# 26                      True
# 27                      True
# 28                      True
# 29                      True
# 30                      True
# 31                      True
# 32                     False
# 33                      True
# 34                     False
# 35                      True
# 36                     False
# 37                     False
# 38                     False
# 39                     False
# 40                      True
# 41                     False
# 42                     False
# 43                      True
# 44                      True
# 45                      True
# 46                     False
# 47                      True
# 48                     False
# 49                      True
# 50                      True
# 51                     False
#       target_genes     kategory    gene1    gene2  gene1_is_in_train_or_val  \
# 52        AHR+KLF1  combo_seen2      AHR     KLF1                      True
# 53      CEBPE+CNN1  combo_seen2    CEBPE     CNN1                      True
# 54      CEBPE+KLF1  combo_seen2    CEBPE     KLF1                      True
# 55      CNN1+MAPK1  combo_seen2     CNN1    MAPK1                      True
# 56      ETS2+CEBPE  combo_seen2     ETS2    CEBPE                      True
# 57       ETS2+CNN1  combo_seen2     ETS2     CNN1                      True
# 58      ETS2+MAPK1  combo_seen2     ETS2    MAPK1                      True
# 59        FEV+ISL2  combo_seen2      FEV     ISL2                      True
# 60      FOSB+CEBPE  combo_seen2     FOSB    CEBPE                      True
# 61     FOXA1+HOXB9  combo_seen2    FOXA1    HOXB9                      True
# 62     FOXA3+HOXB9  combo_seen2    FOXA3    HOXB9                      True
# 63      KLF1+FOXA1  combo_seen2     KLF1    FOXA1                      True
# 64    MAP2K3+IKZF3  combo_seen2   MAP2K3    IKZF3                      True
# 65  POU3F2+CBFA2T3  combo_seen2   POU3F2  CBFA2T3                      True
# 66      SNAI1+DLX2  combo_seen2    SNAI1     DLX2                      True
# 67       TBX3+TBX2  combo_seen2     TBX3     TBX2                      True
# 68  UBASH3B+PTPN12  combo_seen2  UBASH3B   PTPN12                      True
# 69  UBASH3B+ZBTB25  combo_seen2  UBASH3B   ZBTB25                      True
# 70  ZC3HAV1+HOXC13  combo_seen2  ZC3HAV1   HOXC13                      True
#
#     gene2_is_in_train_or_val
# 52                      True
# 53                      True
# 54                      True
# 55                      True
# 56                      True
# 57                      True
# 58                      True
# 59                      True
# 60                      True
# 61                      True
# 62                      True
# 63                      True
# 64                      True
# 65                      True
# 66                      True
# 67                      True
# 68                      True
# 69                      True
# 70                      True
#      target_genes kategory    gene1 gene2  gene1_is_in_train_or_val  \
# 71     DUSP9+ctrl  single1    DUSP9  ctrl                     False
# 72    BCORL1+ctrl  single1   BCORL1  ctrl                     False
# 73     MEIS1+ctrl  single1    MEIS1  ctrl                     False
# 74       CBL+ctrl  single1      CBL  ctrl                     False
# 75    SLC4A1+ctrl  single1   SLC4A1  ctrl                     False
# 76    COL2A1+ctrl  single1   COL2A1  ctrl                     False
# 77     S1PR2+ctrl  single1    S1PR2  ctrl                     False
# 78     CELF2+ctrl  single1    CELF2  ctrl                     False
# 79    CDKN1A+ctrl  single1   CDKN1A  ctrl                     False
# 80     ctrl+MEIS1  single1    MEIS1  ctrl                     False
# 81     CKS1B+ctrl  single1    CKS1B  ctrl                     False
# 82      PRTG+ctrl  single1     PRTG  ctrl                     False
# 83   C3orf72+ctrl  single1  C3orf72  ctrl                     False
# 84     FOXL2+ctrl  single1    FOXL2  ctrl                     False
# 85    ctrl+CDKN1A  single1   CDKN1A  ctrl                     False
# 86    ARID1A+ctrl  single1   ARID1A  ctrl                     False
# 87    ctrl+COL2A1  single1   COL2A1  ctrl                     False
# 88   BCL2L11+ctrl  single1  BCL2L11  ctrl                     False
# 89      OSR2+ctrl  single1     OSR2  ctrl                     False
# 90      ctrl+SPI1  single1     SPI1  ctrl                     False
# 91     CEBPB+ctrl  single1    CEBPB  ctrl                     False
# 92      ctrl+PRTG  single1     PRTG  ctrl                     False
# 93    CDKN1B+ctrl  single1   CDKN1B  ctrl                     False
# 94       JUN+ctrl  single1      JUN  ctrl                     False
# 95    ZBTB10+ctrl  single1   ZBTB10  ctrl                     False
# 96    PTPN13+ctrl  single1   PTPN13  ctrl                     False
# 97     PTPN9+ctrl  single1    PTPN9  ctrl                     False
# 98     ctrl+CEBPB  single1    CEBPB  ctrl                     False
# 99     PRDM1+ctrl  single1    PRDM1  ctrl                     False
# 100    ctrl+PTPN9  single1    PTPN9  ctrl                     False
# 101     ctrl+OSR2  single1     OSR2  ctrl                     False
# 102    ctrl+FOXL2  single1    FOXL2  ctrl                     False
# 103     SPI1+ctrl  single1     SPI1  ctrl                     False
# 104     EGR1+ctrl  single1     EGR1  ctrl                     False
# 105   CDKN1C+ctrl  single1   CDKN1C  ctrl                     False
# 106   ctrl+CDKN1B  single1   CDKN1B  ctrl                     False
#
#      gene2_is_in_train_or_val
# 71                       True
# 72                       True
# 73                       True
# 74                       True
# 75                       True
# 76                       True
# 77                       True
# 78                       True
# 79                       True
# 80                       True
# 81                       True
# 82                       True
# 83                       True
# 84                       True
# 85                       True
# 86                       True
# 87                       True
# 88                       True
# 89                       True
# 90                       True
# 91                       True
# 92                       True
# 93                       True
# 94                       True
# 95                       True
# 96                       True
# 97                       True
# 98                       True
# 99                       True
# 100                      True
# 101                      True
# 102                      True
# 103                      True
# 104                      True
# 105                      True
# 106                      True
# All assertions passed.
# all (89357, 2000)
# train (49349, 2000)
# val (11254, 2000)
# test (29254, 2000)
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:12
# combo_seen1:52
# combo_seen2:16
# unseen_single:37
# Done!
# here1
# Found 69 unique genes in train split
# Found 22 unique genes in val split
# Found 77 unique genes in train + val split
# combo_seen0
#       target_genes     kategory   gene1    gene2  gene1_is_in_train_or_val  \
# 0   MAP2K3+SLC38A2  combo_seen0  MAP2K3  SLC38A2                     False
# 1       MAPK1+PRTG  combo_seen0   MAPK1     PRTG                     False
# 2     MAP2K3+IKZF3  combo_seen0  MAP2K3    IKZF3                     False
# 3      MAPK1+IKZF3  combo_seen0   MAPK1    IKZF3                     False
# 4        ETS2+CNN1  combo_seen0    ETS2     CNN1                     False
# 5       CNN1+MAPK1  combo_seen0    CNN1    MAPK1                     False
# 6     CNN1+UBASH3A  combo_seen0    CNN1  UBASH3A                     False
# 7       ETS2+MAPK1  combo_seen0    ETS2    MAPK1                     False
# 8      FOXA1+FOXL2  combo_seen0   FOXA1    FOXL2                     False
# 9        ETS2+PRTG  combo_seen0    ETS2     PRTG                     False
# 10      ETS2+IKZF3  combo_seen0    ETS2    IKZF3                     False
# 11      FOSB+IKZF3  combo_seen0    FOSB    IKZF3                     False
#
#     gene2_is_in_train_or_val
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 9                      False
# 10                     False
# 11                     False
#        target_genes     kategory    gene1    gene2  gene1_is_in_train_or_val  \
# 12      TGFBR2+ETS2  combo_seen1   TGFBR2     ETS2                      True
# 13        SGK1+TBX3  combo_seen1     SGK1     TBX3                     False
# 14      FOXA3+FOXA1  combo_seen1    FOXA3    FOXA1                      True
# 15      ETS2+IGDCC3  combo_seen1     ETS2   IGDCC3                     False
# 16     MAP2K6+IKZF3  combo_seen1   MAP2K6    IKZF3                      True
# 17       KLF1+FOXA1  combo_seen1     KLF1    FOXA1                      True
# 18      DUSP9+MAPK1  combo_seen1    DUSP9    MAPK1                      True
# 19       DUSP9+ETS2  combo_seen1    DUSP9     ETS2                      True
# 20     ZNF318+FOXL2  combo_seen1   ZNF318    FOXL2                      True
# 21        KLF1+BAK1  combo_seen1     KLF1     BAK1                      True
# 22     IGDCC3+MAPK1  combo_seen1   IGDCC3    MAPK1                      True
# 23        JUN+CEBPA  combo_seen1      JUN    CEBPA                      True
# 24  UBASH3B+UBASH3A  combo_seen1  UBASH3B  UBASH3A                      True
# 25    MAP2K3+MAP2K6  combo_seen1   MAP2K3   MAP2K6                     False
# 26      TMSB4X+BAK1  combo_seen1   TMSB4X     BAK1                      True
# 27       BPGM+SAMD1  combo_seen1     BPGM    SAMD1                     False
# 28       ETS2+CEBPE  combo_seen1     ETS2    CEBPE                     False
# 29     POU3F2+FOXL2  combo_seen1   POU3F2    FOXL2                      True
# 30       DUSP9+PRTG  combo_seen1    DUSP9     PRTG                      True
# 31     KIF18B+KIF2C  combo_seen1   KIF18B    KIF2C                     False
# 32      CEBPB+CEBPA  combo_seen1    CEBPB    CEBPA                      True
# 33   PTPN12+UBASH3A  combo_seen1   PTPN12  UBASH3A                      True
# 34      FOXL2+MEIS1  combo_seen1    FOXL2    MEIS1                     False
# 35     MAPK1+TGFBR2  combo_seen1    MAPK1   TGFBR2                     False
# 36       FOSB+CEBPE  combo_seen1     FOSB    CEBPE                     False
# 37       FOSB+CEBPB  combo_seen1     FOSB    CEBPB                     False
# 38     BCL2L11+BAK1  combo_seen1  BCL2L11     BAK1                      True
# 39       KLF1+CEBPA  combo_seen1     KLF1    CEBPA                      True
# 40   MAP2K3+ELMSAN1  combo_seen1   MAP2K3  ELMSAN1                     False
# 41      CEBPE+CEBPA  combo_seen1    CEBPE    CEBPA                      True
# 42       CEBPE+CNN1  combo_seen1    CEBPE     CNN1                      True
# 43         CBL+CNN1  combo_seen1      CBL     CNN1                      True
# 44     UBASH3B+CNN1  combo_seen1  UBASH3B     CNN1                      True
# 45      CEBPB+MAPK1  combo_seen1    CEBPB    MAPK1                      True
# 46     FOSB+UBASH3B  combo_seen1     FOSB  UBASH3B                     False
# 47       SGK1+S1PR2  combo_seen1     SGK1    S1PR2                     False
# 48         FEV+ISL2  combo_seen1      FEV     ISL2                      True
# 49      FOXA1+HOXB9  combo_seen1    FOXA1    HOXB9                     False
# 50        SGK1+TBX2  combo_seen1     SGK1     TBX2                     False
# 51      ETS2+MAP7D1  combo_seen1     ETS2   MAP7D1                     False
# 52      FOXF1+FOXL2  combo_seen1    FOXF1    FOXL2                      True
# 53      TGFBR2+PRTG  combo_seen1   TGFBR2     PRTG                      True
# 54      FOSB+PTPN12  combo_seen1     FOSB   PTPN12                     False
# 55        FOSB+OSR2  combo_seen1     FOSB     OSR2                     False
# 56      FOXL2+HOXB9  combo_seen1    FOXL2    HOXB9                     False
# 57       BPGM+ZBTB1  combo_seen1     BPGM    ZBTB1                     False
# 58      FOXA3+FOXL2  combo_seen1    FOXA3    FOXL2                      True
# 59    ZC3HAV1+CEBPA  combo_seen1  ZC3HAV1    CEBPA                      True
# 60      FOXA1+FOXF1  combo_seen1    FOXA1    FOXF1                     False
# 61      CBL+UBASH3A  combo_seen1      CBL  UBASH3A                      True
# 62      IGDCC3+PRTG  combo_seen1   IGDCC3     PRTG                      True
# 63    C3orf72+FOXL2  combo_seen1  C3orf72    FOXL2                      True
#
#     gene2_is_in_train_or_val
# 12                     False
# 13                      True
# 14                     False
# 15                      True
# 16                     False
# 17                     False
# 18                     False
# 19                     False
# 20                     False
# 21                     False
# 22                     False
# 23                     False
# 24                     False
# 25                      True
# 26                     False
# 27                      True
# 28                      True
# 29                     False
# 30                     False
# 31                      True
# 32                     False
# 33                     False
# 34                      True
# 35                      True
# 36                      True
# 37                      True
# 38                     False
# 39                     False
# 40                      True
# 41                     False
# 42                     False
# 43                     False
# 44                     False
# 45                     False
# 46                      True
# 47                      True
# 48                     False
# 49                      True
# 50                      True
# 51                      True
# 52                     False
# 53                     False
# 54                      True
# 55                      True
# 56                      True
# 57                      True
# 58                     False
# 59                     False
# 60                      True
# 61                     False
# 62                     False
# 63                     False
#       target_genes     kategory    gene1    gene2  gene1_is_in_train_or_val  \
# 64   CDKN1B+CDKN1A  combo_seen2   CDKN1B   CDKN1A                      True
# 65   CDKN1C+CDKN1A  combo_seen2   CDKN1C   CDKN1A                      True
# 66    CEBPB+PTPN12  combo_seen2    CEBPB   PTPN12                      True
# 67   CEBPE+RUNX1T1  combo_seen2    CEBPE  RUNX1T1                      True
# 68      DUSP9+KLF1  combo_seen2    DUSP9     KLF1                      True
# 69      FEV+MAP7D1  combo_seen2      FEV   MAP7D1                      True
# 70     FOXA3+FOXF1  combo_seen2    FOXA3    FOXF1                      True
# 71     KLF1+TGFBR2  combo_seen2     KLF1   TGFBR2                      True
# 72  MAP2K6+ELMSAN1  combo_seen2   MAP2K6  ELMSAN1                      True
# 73    PTPN12+PTPN9  combo_seen2   PTPN12    PTPN9                      True
# 74    SAMD1+PTPN12  combo_seen2    SAMD1   PTPN12                      True
# 75   SAMD1+UBASH3B  combo_seen2    SAMD1  UBASH3B                      True
# 76       SET+CEBPE  combo_seen2      SET    CEBPE                      True
# 77      SNAI1+DLX2  combo_seen2    SNAI1     DLX2                      True
# 78   UBASH3B+PTPN9  combo_seen2  UBASH3B    PTPN9                      True
# 79  ZC3HAV1+HOXC13  combo_seen2  ZC3HAV1   HOXC13                      True
#
#     gene2_is_in_train_or_val
# 64                      True
# 65                      True
# 66                      True
# 67                      True
# 68                      True
# 69                      True
# 70                      True
# 71                      True
# 72                      True
# 73                      True
# 74                      True
# 75                      True
# 76                      True
# 77                      True
# 78                      True
# 79                      True
#      target_genes kategory    gene1 gene2  gene1_is_in_train_or_val  \
# 80     ctrl+FOXA1  single1    FOXA1  ctrl                     False
# 81    GLB1L2+ctrl  single1   GLB1L2  ctrl                     False
# 82      BAK1+ctrl  single1     BAK1  ctrl                     False
# 83      ctrl+ETS2  single1     ETS2  ctrl                     False
# 84    SLC6A9+ctrl  single1   SLC6A9  ctrl                     False
# 85      HES7+ctrl  single1     HES7  ctrl                     False
# 86     FOXO4+ctrl  single1    FOXO4  ctrl                     False
# 87      ctrl+CNN1  single1     CNN1  ctrl                     False
# 88    MAP2K3+ctrl  single1   MAP2K3  ctrl                     False
# 89      FOSB+ctrl  single1     FOSB  ctrl                     False
# 90     MAPK1+ctrl  single1    MAPK1  ctrl                     False
# 91     IKZF3+ctrl  single1    IKZF3  ctrl                     False
# 92     CKS1B+ctrl  single1    CKS1B  ctrl                     False
# 93      ETS2+ctrl  single1     ETS2  ctrl                     False
# 94      PRTG+ctrl  single1     PRTG  ctrl                     False
# 95      BPGM+ctrl  single1     BPGM  ctrl                     False
# 96      SGK1+ctrl  single1     SGK1  ctrl                     False
# 97     FOXL2+ctrl  single1    FOXL2  ctrl                     False
# 98      CNN1+ctrl  single1     CNN1  ctrl                     False
# 99     ctrl+CEBPA  single1    CEBPA  ctrl                     False
# 100    HNF4A+ctrl  single1    HNF4A  ctrl                     False
# 101     ISL2+ctrl  single1     ISL2  ctrl                     False
# 102  ctrl+UBASH3A  single1  UBASH3A  ctrl                     False
# 103     ctrl+BAK1  single1     BAK1  ctrl                     False
# 104    ctrl+IKZF3  single1    IKZF3  ctrl                     False
# 105     ctrl+PRTG  single1     PRTG  ctrl                     False
# 106    CEBPA+ctrl  single1    CEBPA  ctrl                     False
# 107     NIT1+ctrl  single1     NIT1  ctrl                     False
# 108    FOXA1+ctrl  single1    FOXA1  ctrl                     False
# 109   PTPN13+ctrl  single1   PTPN13  ctrl                     False
# 110    ctrl+MAPK1  single1    MAPK1  ctrl                     False
# 111  UBASH3A+ctrl  single1  UBASH3A  ctrl                     False
# 112     ctrl+ISL2  single1     ISL2  ctrl                     False
# 113  ctrl+SLC38A2  single1  SLC38A2  ctrl                     False
# 114   HOXA13+ctrl  single1   HOXA13  ctrl                     False
# 115    ctrl+FOXL2  single1    FOXL2  ctrl                     False
# 116   KIF18B+ctrl  single1   KIF18B  ctrl                     False
#
#      gene2_is_in_train_or_val
# 80                       True
# 81                       True
# 82                       True
# 83                       True
# 84                       True
# 85                       True
# 86                       True
# 87                       True
# 88                       True
# 89                       True
# 90                       True
# 91                       True
# 92                       True
# 93                       True
# 94                       True
# 95                       True
# 96                       True
# 97                       True
# 98                       True
# 99                       True
# 100                      True
# 101                      True
# 102                      True
# 103                      True
# 104                      True
# 105                      True
# 106                      True
# 107                      True
# 108                      True
# 109                      True
# 110                      True
# 111                      True
# 112                      True
# 113                      True
# 114                      True
# 115                      True
# 116                      True
# All assertions passed.
# all (89357, 2000)
# train (50535, 2000)
# val (4550, 2000)
# test (34772, 2000)
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:4
# combo_seen1:51
# combo_seen2:19
# unseen_single:35
# Done!
# here1
# Found 69 unique genes in train split
# Found 27 unique genes in val split
# Found 77 unique genes in train + val split
# combo_seen0
#      target_genes     kategory    gene1   gene2  gene1_is_in_train_or_val  \
# 0  UBASH3B+PTPN12  combo_seen0  UBASH3B  PTPN12                     False
# 1      MAPK1+PRTG  combo_seen0    MAPK1    PRTG                     False
# 2      CNN1+MAPK1  combo_seen0     CNN1   MAPK1                     False
# 3    UBASH3B+CNN1  combo_seen0  UBASH3B    CNN1                     False
#
#    gene2_is_in_train_or_val
# 0                     False
# 1                     False
# 2                     False
# 3                     False
#        target_genes     kategory    gene1    gene2  gene1_is_in_train_or_val  \
# 4       DUSP9+MAPK1  combo_seen1    DUSP9    MAPK1                      True
# 5      UBASH3B+OSR2  combo_seen1  UBASH3B     OSR2                     False
# 6    UBASH3B+ZBTB25  combo_seen1  UBASH3B   ZBTB25                     False
# 7         SET+CEBPE  combo_seen1      SET    CEBPE                     False
# 8     UBASH3B+PTPN9  combo_seen1  UBASH3B    PTPN9                     False
# 9      IGDCC3+MAPK1  combo_seen1   IGDCC3    MAPK1                      True
# 10  UBASH3B+UBASH3A  combo_seen1  UBASH3B  UBASH3A                     False
# 11      PTPN12+OSR2  combo_seen1   PTPN12     OSR2                     False
# 12       DUSP9+PRTG  combo_seen1    DUSP9     PRTG                      True
# 13      MAPK1+IKZF3  combo_seen1    MAPK1    IKZF3                     False
# 14     KIF18B+KIF2C  combo_seen1   KIF18B    KIF2C                     False
# 15         AHR+KLF1  combo_seen1      AHR     KLF1                     False
# 16   PTPN12+UBASH3A  combo_seen1   PTPN12  UBASH3A                     False
# 17        ETS2+CNN1  combo_seen1     ETS2     CNN1                      True
# 18     MAPK1+TGFBR2  combo_seen1    MAPK1   TGFBR2                     False
# 19     PTPN12+PTPN9  combo_seen1   PTPN12    PTPN9                     False
# 20         SET+KLF1  combo_seen1      SET     KLF1                     False
# 21     PTPN12+SNAI1  combo_seen1   PTPN12    SNAI1                     False
# 22     CNN1+UBASH3A  combo_seen1     CNN1  UBASH3A                     False
# 23      FOXA3+HOXB9  combo_seen1    FOXA3    HOXB9                      True
# 24         IRF1+SET  combo_seen1     IRF1      SET                      True
# 25       CEBPE+CNN1  combo_seen1    CEBPE     CNN1                      True
# 26         CBL+CNN1  combo_seen1      CBL     CNN1                      True
# 27    ZBTB10+PTPN12  combo_seen1   ZBTB10   PTPN12                      True
# 28      CBL+UBASH3B  combo_seen1      CBL  UBASH3B                      True
# 29      FOXF1+HOXB9  combo_seen1    FOXF1    HOXB9                      True
# 30     CEBPB+PTPN12  combo_seen1    CEBPB   PTPN12                      True
# 31      CEBPB+MAPK1  combo_seen1    CEBPB    MAPK1                      True
# 32     FOSB+UBASH3B  combo_seen1     FOSB  UBASH3B                      True
# 33       ETS2+MAPK1  combo_seen1     ETS2    MAPK1                      True
# 34    SNAI1+UBASH3B  combo_seen1    SNAI1  UBASH3B                      True
# 35       CBL+PTPN12  combo_seen1      CBL   PTPN12                      True
# 36     CEBPE+PTPN12  combo_seen1    CEBPE   PTPN12                      True
# 37    SAMD1+UBASH3B  combo_seen1    SAMD1  UBASH3B                      True
# 38       KLF1+CLDN6  combo_seen1     KLF1    CLDN6                      True
# 39   POU3F2+CBFA2T3  combo_seen1   POU3F2  CBFA2T3                      True
# 40      FOXA1+HOXB9  combo_seen1    FOXA1    HOXB9                      True
# 41        ETS2+PRTG  combo_seen1     ETS2     PRTG                      True
# 42          AHR+FEV  combo_seen1      AHR      FEV                     False
# 43      FEV+CBFA2T3  combo_seen1      FEV  CBFA2T3                      True
# 44       LYL1+CEBPB  combo_seen1     LYL1    CEBPB                     False
# 45    PTPN12+ZBTB25  combo_seen1   PTPN12   ZBTB25                     False
# 46      TGFBR2+PRTG  combo_seen1   TGFBR2     PRTG                      True
# 47      FOSB+PTPN12  combo_seen1     FOSB   PTPN12                      True
# 48     SAMD1+PTPN12  combo_seen1    SAMD1   PTPN12                      True
# 49      FOXL2+HOXB9  combo_seen1    FOXL2    HOXB9                      True
# 50    PRDM1+CBFA2T3  combo_seen1    PRDM1  CBFA2T3                      True
# 51    CDKN1C+CDKN1B  combo_seen1   CDKN1C   CDKN1B                     False
# 52    CDKN1C+CDKN1A  combo_seen1   CDKN1C   CDKN1A                     False
# 53        PLK4+STIL  combo_seen1     PLK4     STIL                     False
# 54      IGDCC3+PRTG  combo_seen1   IGDCC3     PRTG                      True
#
#     gene2_is_in_train_or_val
# 4                      False
# 5                       True
# 6                       True
# 7                       True
# 8                       True
# 9                      False
# 10                      True
# 11                      True
# 12                     False
# 13                      True
# 14                      True
# 15                      True
# 16                      True
# 17                     False
# 18                      True
# 19                      True
# 20                      True
# 21                      True
# 22                      True
# 23                     False
# 24                     False
# 25                     False
# 26                     False
# 27                     False
# 28                     False
# 29                     False
# 30                     False
# 31                     False
# 32                     False
# 33                     False
# 34                     False
# 35                     False
# 36                     False
# 37                     False
# 38                     False
# 39                     False
# 40                     False
# 41                     False
# 42                      True
# 43                     False
# 44                      True
# 45                      True
# 46                     False
# 47                     False
# 48                     False
# 49                     False
# 50                     False
# 51                      True
# 52                      True
# 53                      True
# 54                     False
#      target_genes     kategory    gene1    gene2  gene1_is_in_train_or_val  \
# 55   BCL2L11+BAK1  combo_seen2  BCL2L11     BAK1                      True
# 56     BPGM+ZBTB1  combo_seen2     BPGM    ZBTB1                      True
# 57     CEBPB+OSR2  combo_seen2    CEBPB     OSR2                      True
# 58  CEBPE+RUNX1T1  combo_seen2    CEBPE  RUNX1T1                      True
# 59   DUSP9+IGDCC3  combo_seen2    DUSP9   IGDCC3                      True
# 60    DUSP9+SNAI1  combo_seen2    DUSP9    SNAI1                      True
# 61     ETS2+CEBPE  combo_seen2     ETS2    CEBPE                      True
# 62    ETS2+IGDCC3  combo_seen2     ETS2   IGDCC3                      True
# 63       FEV+ISL2  combo_seen2      FEV     ISL2                      True
# 64     FOSB+CEBPB  combo_seen2     FOSB    CEBPB                      True
# 65      FOSB+OSR2  combo_seen2     FOSB     OSR2                      True
# 66    FOXA3+FOXA1  combo_seen2    FOXA3    FOXA1                      True
# 67      JUN+CEBPA  combo_seen2      JUN    CEBPA                      True
# 68      JUN+CEBPB  combo_seen2      JUN    CEBPB                      True
# 69     KLF1+CEBPA  combo_seen2     KLF1    CEBPA                      True
# 70    KLF1+MAP2K6  combo_seen2     KLF1   MAP2K6                      True
# 71   SAMD1+TGFBR2  combo_seen2    SAMD1   TGFBR2                      True
# 72    SAMD1+ZBTB1  combo_seen2    SAMD1    ZBTB1                      True
# 73   ZBTB10+SNAI1  combo_seen2   ZBTB10    SNAI1                      True
#
#     gene2_is_in_train_or_val
# 55                      True
# 56                      True
# 57                      True
# 58                      True
# 59                      True
# 60                      True
# 61                      True
# 62                      True
# 63                      True
# 64                      True
# 65                      True
# 66                      True
# 67                      True
# 68                      True
# 69                      True
# 70                      True
# 71                      True
# 72                      True
# 73                      True
#      target_genes kategory    gene1 gene2  gene1_is_in_train_or_val  \
# 74    GLB1L2+ctrl  single1   GLB1L2  ctrl                     False
# 75       ctrl+SET  single1      SET  ctrl                     False
# 76   UBASH3B+ctrl  single1  UBASH3B  ctrl                     False
# 77   CBFA2T3+ctrl  single1  CBFA2T3  ctrl                     False
# 78       AHR+ctrl  single1      AHR  ctrl                     False
# 79     FOXO4+ctrl  single1    FOXO4  ctrl                     False
# 80   ctrl+CBFA2T3  single1  CBFA2T3  ctrl                     False
# 81      ctrl+CNN1  single1     CNN1  ctrl                     False
# 82    MAP4K3+ctrl  single1   MAP4K3  ctrl                     False
# 83    PTPN12+ctrl  single1   PTPN12  ctrl                     False
# 84     MAPK1+ctrl  single1    MAPK1  ctrl                     False
# 85     HOXB9+ctrl  single1    HOXB9  ctrl                     False
# 86   ctrl+UBASH3B  single1  UBASH3B  ctrl                     False
# 87     ctrl+HOXB9  single1    HOXB9  ctrl                     False
# 88     CKS1B+ctrl  single1    CKS1B  ctrl                     False
# 89     CLDN6+ctrl  single1    CLDN6  ctrl                     False
# 90    COL1A1+ctrl  single1   COL1A1  ctrl                     False
# 91      PRTG+ctrl  single1     PRTG  ctrl                     False
# 92      PLK4+ctrl  single1     PLK4  ctrl                     False
# 93    ARRDC3+ctrl  single1   ARRDC3  ctrl                     False
# 94      LYL1+ctrl  single1     LYL1  ctrl                     False
# 95      CNN1+ctrl  single1     CNN1  ctrl                     False
# 96     ctrl+CLDN6  single1    CLDN6  ctrl                     False
# 97    CSRNP1+ctrl  single1   CSRNP1  ctrl                     False
# 98    ARID1A+ctrl  single1   ARID1A  ctrl                     False
# 99       NCL+ctrl  single1      NCL  ctrl                     False
# 100      SET+ctrl  single1      SET  ctrl                     False
# 101     ctrl+PRTG  single1     PRTG  ctrl                     False
# 102     ATL1+ctrl  single1     ATL1  ctrl                     False
# 103    ctrl+MAPK1  single1    MAPK1  ctrl                     False
# 104   CITED1+ctrl  single1   CITED1  ctrl                     False
# 105   ctrl+PTPN12  single1   PTPN12  ctrl                     False
# 106      HK2+ctrl  single1      HK2  ctrl                     False
# 107   KIF18B+ctrl  single1   KIF18B  ctrl                     False
# 108   CDKN1C+ctrl  single1   CDKN1C  ctrl                     False
#
#      gene2_is_in_train_or_val
# 74                       True
# 75                       True
# 76                       True
# 77                       True
# 78                       True
# 79                       True
# 80                       True
# 81                       True
# 82                       True
# 83                       True
# 84                       True
# 85                       True
# 86                       True
# 87                       True
# 88                       True
# 89                       True
# 90                       True
# 91                       True
# 92                       True
# 93                       True
# 94                       True
# 95                       True
# 96                       True
# 97                       True
# 98                       True
# 99                       True
# 100                      True
# 101                      True
# 102                      True
# 103                      True
# 104                      True
# 105                      True
# 106                      True
# 107                      True
# 108                      True
# All assertions passed.
# all (89357, 2000)
# train (47615, 2000)
# val (11472, 2000)
# test (30770, 2000)
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:4
# combo_seen1:52
# combo_seen2:18
# unseen_single:37
# Done!
# here1
# Found 69 unique genes in train split
# Found 23 unique genes in val split
# Found 77 unique genes in train + val split
# combo_seen0
#     target_genes     kategory   gene1   gene2  gene1_is_in_train_or_val  \
# 0  TGFBR2+IGDCC3  combo_seen0  TGFBR2  IGDCC3                     False
# 1    FOXF1+HOXB9  combo_seen0   FOXF1   HOXB9                     False
# 2    TGFBR2+PRTG  combo_seen0  TGFBR2    PRTG                     False
# 3    IGDCC3+PRTG  combo_seen0  IGDCC3    PRTG                     False
#
#    gene2_is_in_train_or_val
# 0                     False
# 1                     False
# 2                     False
# 3                     False
#        target_genes     kategory    gene1     gene2  gene1_is_in_train_or_val  \
# 4       TGFBR2+ETS2  combo_seen1   TGFBR2      ETS2                     False
# 5       MAP2K6+SPI1  combo_seen1   MAP2K6      SPI1                      True
# 6       ETS2+IGDCC3  combo_seen1     ETS2    IGDCC3                      True
# 7    MAP2K3+SLC38A2  combo_seen1   MAP2K3   SLC38A2                     False
# 8         SET+CEBPE  combo_seen1      SET     CEBPE                     False
# 9     IGDCC3+ZBTB25  combo_seen1   IGDCC3    ZBTB25                     False
# 10     IGDCC3+MAPK1  combo_seen1   IGDCC3     MAPK1                     False
# 11        JUN+CEBPA  combo_seen1      JUN     CEBPA                     False
# 12    ZC3HAV1+CEBPE  combo_seen1  ZC3HAV1     CEBPE                     False
# 13  UBASH3B+UBASH3A  combo_seen1  UBASH3B   UBASH3A                      True
# 14    MAP2K3+MAP2K6  combo_seen1   MAP2K3    MAP2K6                     False
# 15       MAPK1+PRTG  combo_seen1    MAPK1      PRTG                      True
# 16     MAP2K3+IKZF3  combo_seen1   MAP2K3     IKZF3                     False
# 17      TMSB4X+BAK1  combo_seen1   TMSB4X      BAK1                     False
# 18       DUSP9+PRTG  combo_seen1    DUSP9      PRTG                      True
# 19     LHX1+ELMSAN1  combo_seen1     LHX1   ELMSAN1                     False
# 20     KIF18B+KIF2C  combo_seen1   KIF18B     KIF2C                      True
# 21   BCL2L11+TGFBR2  combo_seen1  BCL2L11    TGFBR2                      True
# 22         AHR+KLF1  combo_seen1      AHR      KLF1                     False
# 23   PTPN12+UBASH3A  combo_seen1   PTPN12   UBASH3A                      True
# 24     MAPK1+TGFBR2  combo_seen1    MAPK1    TGFBR2                      True
# 25         SET+KLF1  combo_seen1      SET      KLF1                     False
# 26     PTPN12+SNAI1  combo_seen1   PTPN12     SNAI1                      True
# 27     CNN1+UBASH3A  combo_seen1     CNN1   UBASH3A                      True
# 28      FOXA3+HOXB9  combo_seen1    FOXA3     HOXB9                      True
# 29         IRF1+SET  combo_seen1     IRF1       SET                      True
# 30   MAP2K3+ELMSAN1  combo_seen1   MAP2K3   ELMSAN1                     False
# 31   ZC3HAV1+HOXC13  combo_seen1  ZC3HAV1    HOXC13                     False
# 32    SNAI1+UBASH3B  combo_seen1    SNAI1   UBASH3B                     False
# 33     DUSP9+IGDCC3  combo_seen1    DUSP9    IGDCC3                      True
# 34       KLF1+CLDN6  combo_seen1     KLF1     CLDN6                      True
# 35      FOXA1+HOXB9  combo_seen1    FOXA1     HOXB9                      True
# 36     SAMD1+TGFBR2  combo_seen1    SAMD1    TGFBR2                      True
# 37       CEBPE+SPI1  combo_seen1    CEBPE      SPI1                      True
# 38       CBL+TGFBR2  combo_seen1      CBL    TGFBR2                      True
# 39      FOXF1+FOXL2  combo_seen1    FOXF1     FOXL2                     False
# 40        ETS2+PRTG  combo_seen1     ETS2      PRTG                      True
# 41          AHR+FEV  combo_seen1      AHR       FEV                     False
# 42      KLF1+TGFBR2  combo_seen1     KLF1    TGFBR2                      True
# 43       LYL1+CEBPB  combo_seen1     LYL1     CEBPB                     False
# 44      DUSP9+SNAI1  combo_seen1    DUSP9     SNAI1                      True
# 45      FOXL2+HOXB9  combo_seen1    FOXL2     HOXB9                      True
# 46        JUN+CEBPB  combo_seen1      JUN     CEBPB                     False
# 47     ZBTB10+SNAI1  combo_seen1   ZBTB10     SNAI1                      True
# 48      FOXA3+FOXF1  combo_seen1    FOXA3     FOXF1                      True
# 49  TGFBR2+C19orf26  combo_seen1   TGFBR2  C19orf26                     False
# 50    ZC3HAV1+CEBPA  combo_seen1  ZC3HAV1     CEBPA                     False
# 51      FOXA1+FOXF1  combo_seen1    FOXA1     FOXF1                      True
# 52        PLK4+STIL  combo_seen1     PLK4      STIL                     False
# 53      CBL+UBASH3A  combo_seen1      CBL   UBASH3A                      True
# 54       SNAI1+DLX2  combo_seen1    SNAI1      DLX2                     False
# 55    C3orf72+FOXL2  combo_seen1  C3orf72     FOXL2                     False
#
#     gene2_is_in_train_or_val
# 4                       True
# 5                      False
# 6                      False
# 7                       True
# 8                       True
# 9                       True
# 10                      True
# 11                      True
# 12                      True
# 13                     False
# 14                      True
# 15                     False
# 16                      True
# 17                      True
# 18                     False
# 19                      True
# 20                     False
# 21                     False
# 22                      True
# 23                     False
# 24                     False
# 25                      True
# 26                     False
# 27                     False
# 28                     False
# 29                     False
# 30                      True
# 31                      True
# 32                      True
# 33                     False
# 34                     False
# 35                     False
# 36                     False
# 37                     False
# 38                     False
# 39                      True
# 40                     False
# 41                      True
# 42                     False
# 43                      True
# 44                     False
# 45                     False
# 46                      True
# 47                     False
# 48                     False
# 49                      True
# 50                      True
# 51                     False
# 52                      True
# 53                     False
# 54                      True
# 55                      True
#       target_genes     kategory    gene1    gene2  gene1_is_in_train_or_val  \
# 56      BPGM+SAMD1  combo_seen2     BPGM    SAMD1                      True
# 57        CBL+CNN1  combo_seen2      CBL     CNN1                      True
# 58   CDKN1C+CDKN1B  combo_seen2   CDKN1C   CDKN1B                      True
# 59     FOSB+PTPN12  combo_seen2     FOSB   PTPN12                      True
# 60     FOXA1+FOXL2  combo_seen2    FOXA1    FOXL2                      True
# 61     FOXA3+FOXL2  combo_seen2    FOXA3    FOXL2                      True
# 62       KLF1+BAK1  combo_seen2     KLF1     BAK1                      True
# 63     KLF1+COL2A1  combo_seen2     KLF1   COL2A1                      True
# 64     KLF1+MAP2K6  combo_seen2     KLF1   MAP2K6                      True
# 65  POU3F2+CBFA2T3  combo_seen2   POU3F2  CBFA2T3                      True
# 66   PRDM1+CBFA2T3  combo_seen2    PRDM1  CBFA2T3                      True
# 67   PTPN12+ZBTB25  combo_seen2   PTPN12   ZBTB25                      True
# 68   SAMD1+UBASH3B  combo_seen2    SAMD1  UBASH3B                      True
# 69     SAMD1+ZBTB1  combo_seen2    SAMD1    ZBTB1                      True
# 70    UBASH3B+OSR2  combo_seen2  UBASH3B     OSR2                      True
# 71  UBASH3B+ZBTB25  combo_seen2  UBASH3B   ZBTB25                      True
# 72  ZBTB10+ELMSAN1  combo_seen2   ZBTB10  ELMSAN1                      True
# 73   ZBTB10+PTPN12  combo_seen2   ZBTB10   PTPN12                      True
#
#     gene2_is_in_train_or_val
# 56                      True
# 57                      True
# 58                      True
# 59                      True
# 60                      True
# 61                      True
# 62                      True
# 63                      True
# 64                      True
# 65                      True
# 66                      True
# 67                      True
# 68                      True
# 69                      True
# 70                      True
# 71                      True
# 72                      True
# 73                      True
#      target_genes kategory    gene1 gene2  gene1_is_in_train_or_val  \
# 74     MAML2+ctrl  single1    MAML2  ctrl                     False
# 75       ctrl+SET  single1      SET  ctrl                     False
# 76      LHX1+ctrl  single1     LHX1  ctrl                     False
# 77       AHR+ctrl  single1      AHR  ctrl                     False
# 78     FOXO4+ctrl  single1    FOXO4  ctrl                     False
# 79    MAP2K3+ctrl  single1   MAP2K3  ctrl                     False
# 80     PTPN1+ctrl  single1    PTPN1  ctrl                     False
# 81     HOXB9+ctrl  single1    HOXB9  ctrl                     False
# 82     ctrl+HOXB9  single1    HOXB9  ctrl                     False
# 83     CLDN6+ctrl  single1    CLDN6  ctrl                     False
# 84     FOXF1+ctrl  single1    FOXF1  ctrl                     False
# ...
# 96       NCL+ctrl  single1      NCL  ctrl                     False
# 97   ZC3HAV1+ctrl  single1  ZC3HAV1  ctrl                     False
# 98       SET+ctrl  single1      SET  ctrl                     False
# 99      ctrl+SPI1  single1     SPI1  ctrl                     False
# 100     ctrl+PRTG  single1     PRTG  ctrl                     False
# 101     ATL1+ctrl  single1     ATL1  ctrl                     False
# 102   TGFBR2+ctrl  single1   TGFBR2  ctrl                     False
# 103      JUN+ctrl  single1      JUN  ctrl                     False
# 104  UBASH3A+ctrl  single1  UBASH3A  ctrl                     False
# 105    ctrl+SNAI1  single1    SNAI1  ctrl                     False
# 106    ctrl+FOXF1  single1    FOXF1  ctrl                     False
# 107   ctrl+IGDCC3  single1   IGDCC3  ctrl                     False
# 108   ctrl+TGFBR2  single1   TGFBR2  ctrl                     False
# 109     SPI1+ctrl  single1     SPI1  ctrl                     False
# 110    SNAI1+ctrl  single1    SNAI1  ctrl                     False
#
#      gene2_is_in_train_or_val
# 74                       True
# 75                       True
# 76                       True
# 77                       True
# 78                       True
# 79                       True
# 80                       True
# 81                       True
# 82                       True
# 83                       True
# 84                       True
# 85                       True
# 86                       True
# 87                       True
# 88                       True
# 89                       True
# 90                       True
# 91                       True
# 92                       True
# 93                       True
# 94                       True
# 95                       True
# 96                       True
# 97                       True
# 98                       True
# 99                       True
# 100                      True
# 101                      True
# 102                      True
# 103                      True
# 104                      True
# 105                      True
# 106                      True
# 107                      True
# 108                      True
# 109                      True
# 110                      True
# All assertions passed.
# all (89357, 2000)
# train (51692, 2000)
# val (8205, 2000)
# test (29960, 2000)
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:3
# combo_seen1:56
# combo_seen2:18
# unseen_single:40
# Done!
# here1
# Found 69 unique genes in train split
# Found 26 unique genes in val split
# Found 77 unique genes in train + val split
# combo_seen0
#   target_genes     kategory  gene1  gene2  gene1_is_in_train_or_val  \
# 0   BPGM+SAMD1  combo_seen0   BPGM  SAMD1                     False
# 1  CEBPB+CEBPA  combo_seen0  CEBPB  CEBPA                     False
# 2   KLF1+CEBPA  combo_seen0   KLF1  CEBPA                     False
#
#    gene2_is_in_train_or_val
# 0                     False
# 1                     False
# 2                     False
#        target_genes     kategory    gene1     gene2  gene1_is_in_train_or_val  \
# 3       KLF1+MAP2K6  combo_seen1     KLF1    MAP2K6                     False
# 4     CEBPE+RUNX1T1  combo_seen1    CEBPE   RUNX1T1                      True
# 5         CBL+PTPN9  combo_seen1      CBL     PTPN9                      True
# 6      MAP2K6+IKZF3  combo_seen1   MAP2K6     IKZF3                      True
# 7        KLF1+FOXA1  combo_seen1     KLF1     FOXA1                     False
# 8        CEBPE+KLF1  combo_seen1    CEBPE      KLF1                      True
# 9    UBASH3B+ZBTB25  combo_seen1  UBASH3B    ZBTB25                      True
# 10    UBASH3B+PTPN9  combo_seen1  UBASH3B     PTPN9                      True
# 11    IGDCC3+ZBTB25  combo_seen1   IGDCC3    ZBTB25                      True
# 12        KLF1+BAK1  combo_seen1     KLF1      BAK1                     False
# 13        JUN+CEBPA  combo_seen1      JUN     CEBPA                      True
# 14  UBASH3B+UBASH3A  combo_seen1  UBASH3B   UBASH3A                      True
# 15     MAP2K3+IKZF3  combo_seen1   MAP2K3     IKZF3                      True
# 16      KLF1+COL2A1  combo_seen1     KLF1    COL2A1                     False
# 17      TMSB4X+BAK1  combo_seen1   TMSB4X      BAK1                     False
# 18      MAPK1+IKZF3  combo_seen1    MAPK1     IKZF3                      True
# 19     LHX1+ELMSAN1  combo_seen1     LHX1   ELMSAN1                      True
# 20         AHR+KLF1  combo_seen1      AHR      KLF1                      True
# 21   PTPN12+UBASH3A  combo_seen1   PTPN12   UBASH3A                      True
# 22       FEV+MAP7D1  combo_seen1      FEV    MAP7D1                      True
# 23     PTPN12+PTPN9  combo_seen1   PTPN12     PTPN9                      True
# 24       FOSB+CEBPB  combo_seen1     FOSB     CEBPB                      True
# 25         SET+KLF1  combo_seen1      SET      KLF1                      True
# 26     CNN1+UBASH3A  combo_seen1     CNN1   UBASH3A                      True
# 27   MAP2K6+ELMSAN1  combo_seen1   MAP2K6   ELMSAN1                      True
# 28      SAMD1+ZBTB1  combo_seen1    SAMD1     ZBTB1                     False
# 29      FOXA3+HOXB9  combo_seen1    FOXA3     HOXB9                      True
# 30   MAP2K3+ELMSAN1  combo_seen1   MAP2K3   ELMSAN1                      True
# 31      CEBPE+CEBPA  combo_seen1    CEBPE     CEBPA                      True
# 32      FOXF1+HOXB9  combo_seen1    FOXF1     HOXB9                      True
# 33     CEBPB+PTPN12  combo_seen1    CEBPB    PTPN12                     False
# 34      CEBPB+MAPK1  combo_seen1    CEBPB     MAPK1                     False
# 35       CEBPB+OSR2  combo_seen1    CEBPB      OSR2                     False
# 36       DUSP9+KLF1  combo_seen1    DUSP9      KLF1                      True
# 37    SAMD1+UBASH3B  combo_seen1    SAMD1   UBASH3B                     False
# 38       KLF1+CLDN6  combo_seen1     KLF1     CLDN6                     False
# 39      FOXA1+HOXB9  combo_seen1    FOXA1     HOXB9                      True
# 40     SAMD1+TGFBR2  combo_seen1    SAMD1    TGFBR2                     False
# 41      ETS2+MAP7D1  combo_seen1     ETS2    MAP7D1                      True
# 42      KLF1+TGFBR2  combo_seen1     KLF1    TGFBR2                     False
# 43       ETS2+IKZF3  combo_seen1     ETS2     IKZF3                      True
# 44       LYL1+CEBPB  combo_seen1     LYL1     CEBPB                      True
# 45    PTPN12+ZBTB25  combo_seen1   PTPN12    ZBTB25                      True
# 46       FOSB+IKZF3  combo_seen1     FOSB     IKZF3                      True
# 47     SAMD1+PTPN12  combo_seen1    SAMD1    PTPN12                     False
# 48      FOXL2+HOXB9  combo_seen1    FOXL2     HOXB9                      True
# 49   ZBTB10+ELMSAN1  combo_seen1   ZBTB10   ELMSAN1                      True
# 50        JUN+CEBPB  combo_seen1      JUN     CEBPB                      True
# 51       BPGM+ZBTB1  combo_seen1     BPGM     ZBTB1                     False
# 52      CEBPE+CEBPB  combo_seen1    CEBPE     CEBPB                      True
# 53  TGFBR2+C19orf26  combo_seen1   TGFBR2  C19orf26                      True
# 54    ZC3HAV1+CEBPA  combo_seen1  ZC3HAV1     CEBPA                      True
# 55      ZBTB10+DLX2  combo_seen1   ZBTB10      DLX2                      True
# 56      CBL+UBASH3A  combo_seen1      CBL   UBASH3A                      True
# 57       SNAI1+DLX2  combo_seen1    SNAI1      DLX2                      True
# 58    C3orf72+FOXL2  combo_seen1  C3orf72     FOXL2                     False
#
#     gene2_is_in_train_or_val
# 3                       True
# 4                      False
# 5                      False
# 6                      False
# 7                       True
# 8                      False
# 9                      False
# 10                     False
# 11                     False
# 12                      True
# 13                     False
# 14                     False
# 15                     False
# 16                      True
# 17                      True
# 18                     False
# 19                     False
# 20                     False
# 21                     False
# 22                     False
# 23                     False
# 24                     False
# 25                     False
# 26                     False
# 27                     False
# 28                      True
# 29                     False
# 30                     False
# 31                     False
# 32                     False
# 33                      True
# 34                      True
# 35                      True
# 36                     False
# 37                      True
# 38                      True
# 39                     False
# 40                      True
# 41                     False
# 42                      True
# 43                     False
# 44                     False
# 45                     False
# 46                     False
# 47                      True
# 48                     False
# 49                     False
# 50                     False
# 51                      True
# 52                     False
# 53                     False
# 54                     False
# 55                     False
# 56                     False
# 57                     False
# 58                      True
#       target_genes     kategory    gene1    gene2  gene1_is_in_train_or_val  \
# 59   CDKN1B+CDKN1A  combo_seen2   CDKN1B   CDKN1A                      True
# 60   CDKN1C+CDKN1A  combo_seen2   CDKN1C   CDKN1A                      True
# 61      CEBPE+SPI1  combo_seen2    CEBPE     SPI1                      True
# 62      CNN1+MAPK1  combo_seen2     CNN1    MAPK1                      True
# 63    DUSP9+IGDCC3  combo_seen2    DUSP9   IGDCC3                      True
# 64     DUSP9+MAPK1  combo_seen2    DUSP9    MAPK1                      True
# 65       FOSB+OSR2  combo_seen2     FOSB     OSR2                      True
# 66     FOXA1+FOXF1  combo_seen2    FOXA1    FOXF1                      True
# 67        IRF1+SET  combo_seen2     IRF1      SET                      True
# 68      MAPK1+PRTG  combo_seen2    MAPK1     PRTG                      True
# 69    POU3F2+FOXL2  combo_seen2   POU3F2    FOXL2                      True
# 70   PRDM1+CBFA2T3  combo_seen2    PRDM1  CBFA2T3                      True
# 71      SGK1+S1PR2  combo_seen2     SGK1    S1PR2                      True
# 72    UBASH3B+CNN1  combo_seen2  UBASH3B     CNN1                      True
# 73    UBASH3B+OSR2  combo_seen2  UBASH3B     OSR2                      True
# 74   ZBTB10+PTPN12  combo_seen2   ZBTB10   PTPN12                      True
# 75  ZC3HAV1+HOXC13  combo_seen2  ZC3HAV1   HOXC13                      True
# 76    ZNF318+FOXL2  combo_seen2   ZNF318    FOXL2                      True
#
#     gene2_is_in_train_or_val
# 59                      True
# 60                      True
# 61                      True
# 62                      True
# 63                      True
# 64                      True
# 65                      True
# 66                      True
# 67                      True
# 68                      True
# 69                      True
# 70                      True
# 71                      True
# 72                      True
# 73                      True
# 74                      True
# 75                      True
# 76                      True
#       target_genes kategory     gene1 gene2  gene1_is_in_train_or_val  \
# 77    TSC22D1+ctrl  single1   TSC22D1  ctrl                     False
# 78    ctrl+ELMSAN1  single1   ELMSAN1  ctrl                     False
# 79       KLF1+ctrl  single1      KLF1  ctrl                     False
# 80       ctrl+KLF1  single1      KLF1  ctrl                     False
# 81      RREB1+ctrl  single1     RREB1  ctrl                     False
# 82     ctrl+ZBTB25  single1    ZBTB25  ctrl                     False
# 83     MAP4K5+ctrl  single1    MAP4K5  ctrl                     False
# 84       MIDN+ctrl  single1      MIDN  ctrl                     False
# 85       DLX2+ctrl  single1      DLX2  ctrl                     False
# 86    ctrl+RUNX1T1  single1   RUNX1T1  ctrl                     False
# 87      CELF2+ctrl  single1     CELF2  ctrl                     False
# 88     ZBTB25+ctrl  single1    ZBTB25  ctrl                     False
# 89      PTPN1+ctrl  single1     PTPN1  ctrl                     False
# 90    RUNX1T1+ctrl  single1   RUNX1T1  ctrl                     False
# 91       TP73+ctrl  single1      TP73  ctrl                     False
# 92     ctrl+MAP7D1  single1    MAP7D1  ctrl                     False
# 93   C19orf26+ctrl  single1  C19orf26  ctrl                     False
# 94      IKZF3+ctrl  single1     IKZF3  ctrl                     False
# 95      HOXB9+ctrl  single1     HOXB9  ctrl                     False
# 96      ctrl+HOXB9  single1     HOXB9  ctrl                     False
# 97      ctrl+SAMD1  single1     SAMD1  ctrl                     False
# 98       BPGM+ctrl  single1      BPGM  ctrl                     False
# 99    C3orf72+ctrl  single1   C3orf72  ctrl                     False
# 100      ctrl+DLX2  single1      DLX2  ctrl                     False
# 101     ctrl+CEBPA  single1     CEBPA  ctrl                     False
# 102    MAP7D1+ctrl  single1    MAP7D1  ctrl                     False
# 103    TMSB4X+ctrl  single1    TMSB4X  ctrl                     False
# 104  ctrl+C19orf26  single1  C19orf26  ctrl                     False
# 105   ctrl+UBASH3A  single1   UBASH3A  ctrl                     False
# 106     ctrl+IKZF3  single1     IKZF3  ctrl                     False
# 107     CEBPB+ctrl  single1     CEBPB  ctrl                     False
# 108     CEBPA+ctrl  single1     CEBPA  ctrl                     False
# 109     SAMD1+ctrl  single1     SAMD1  ctrl                     False
# 110   ELMSAN1+ctrl  single1   ELMSAN1  ctrl                     False
# 111    PTPN13+ctrl  single1    PTPN13  ctrl                     False
# 112   UBASH3A+ctrl  single1   UBASH3A  ctrl                     False
# 113     PTPN9+ctrl  single1     PTPN9  ctrl                     False
# 114     ctrl+CEBPB  single1     CEBPB  ctrl                     False
# 115       HK2+ctrl  single1       HK2  ctrl                     False
# 116     ctrl+PTPN9  single1     PTPN9  ctrl                     False
#
#      gene2_is_in_train_or_val
# 77                       True
# 78                       True
# 79                       True
# 80                       True
# 81                       True
# 82                       True
# 83                       True
# 84                       True
# 85                       True
# 86                       True
# 87                       True
# 88                       True
# 89                       True
# 90                       True
# 91                       True
# 92                       True
# 93                       True
# 94                       True
# 95                       True
# 96                       True
# 97                       True
# 98                       True
# 99                       True
# 100                      True
# 101                      True
# 102                      True
# 103                      True
# 104                      True
# 105                      True
# 106                      True
# 107                      True
# 108                      True
# 109                      True
# 110                      True
# 111                      True
# 112                      True
# 113                      True
# 114                      True
# 115                      True
# 116                      True
# All assertions passed.
# all (89357, 2000)
# train (47694, 2000)
# val (8568, 2000)
# test (33595, 2000)

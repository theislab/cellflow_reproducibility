# %%
import os
import pandas as pd

# %%
ablation_type = "batch_size"
dir = f"/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_{ablation_type}"
ls = os.listdir(dir)

# %%
h5ad_files = [el for el in ls if ".h5ad" in el]

# %%
import json
with open('/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_batch_size.json', 'w') as f:
    json.dump(h5ad_files, f, indent=4)

# %%
ablation_type = "unbalancedness"
dir = f"/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_{ablation_type}"
ls = os.listdir(dir)

# %%
h5ad_files = [el for el in ls if ".h5ad" in el]
len(h5ad_files)
# Out:
# 1590

# %%
import json
with open('/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_unbalancedness.json', 'w') as f:
    json.dump(h5ad_files, f, indent=4)

# %%
ablation_type = "epsilon"
dir = f"/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_{ablation_type}"
ls = os.listdir(dir)

# %%
h5ad_files = [el for el in ls if ".h5ad" in el]

# %%
import json
with open('/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_epsilon.json', 'w') as f:
    json.dump(h5ad_files, f, indent=4)

# %%
import pandas as pd
import os

# %%
data_dir = "/lustre/groups/ml01/workspace/ot_perturbation/models/additive_model/pbmc_new_cytokine/closest_embedding"

# %%
dfs = []
for el in os.listdir(data_dir):
    if el.endswith(".csv"):
        df_tmp = pd.read_csv(os.path.join(data_dir, el), index_col=0)
        if 'decoded_ood_r_squared' not in df_tmp.index:
            continue
        dfs.append(df_tmp)

# %%
len(dfs)
# Out:
# 2628

# %%
len(dfs)
# Out:
# 2628

# %%
df = pd.concat([el.T for el in dfs])

# %%
df.head()
# Out:
#                mean_decoded_r_sq_per_cell_type mean_e_distance_per_cell_type  \
# Donor9_IL-13_5              0.8271036701542991             86.78665643989439
# Donor2_BAFF_2               0.9694335027174517            11.913366583881931
# Donor2_ADSF_3                0.973956653050014            10.978713937402636
# Donor1_BAFF_2               0.9377968668937683             39.48640271540371
# Donor6_IL-15_4              0.9048151160989489              77.7218427927322
#
#                mean_mmd_per_cell_type mean_sdiv_10_per_cell_type  \
# Donor9_IL-13_5            0.038373742                        NaN
# Donor2_BAFF_2             0.010054966                        NaN
# Donor2_ADSF_3             0.010037305                        NaN
# Donor1_BAFF_2             0.019330747                        NaN
# Donor6_IL-15_4             0.03300346                        NaN
#
#                mean_sdiv_100_per_cell_type mean_deg_r_sq_per_cell_type  \
# Donor9_IL-13_5                         NaN          0.5619757345744542
# Donor2_BAFF_2                          NaN          0.8614676757292314
# Donor2_ADSF_3                          NaN          0.9324382884161813
# Donor1_BAFF_2                          NaN          0.7997966249783833
# Donor6_IL-15_4                         NaN         0.42905887961387634
#
#                mean_deg_e_distance_per_cell_type mean_deg_mmd_per_cell_type  \
# Donor9_IL-13_5                 62.94529179164341                0.023992952
# Donor2_BAFF_2                 15.851179643110795                0.010119332
# Donor2_ADSF_3                  8.904864719935826                0.008535203
# Donor1_BAFF_2                 25.703684488932293                0.016108593
# Donor6_IL-15_4                 89.40967777797154                  0.0253144
#
#                mean_deg_sdiv_10_per_cell_type mean_deg_sdiv_100_per_cell_type  \
# Donor9_IL-13_5                            NaN                             NaN
# Donor2_BAFF_2                             NaN                             NaN
# Donor2_ADSF_3                             NaN                             NaN
# Donor1_BAFF_2                             NaN                             NaN
# Donor6_IL-15_4                            NaN                             NaN
#
#                 ... decoded_r_squared_pDC      e_distance_pDC      mmd_pDC  \
# Donor9_IL-13_5  ...                   NaN                 NaN          NaN
# Donor2_BAFF_2   ...                   NaN                 NaN          NaN
# Donor2_ADSF_3   ...                   NaN                 NaN          NaN
# Donor1_BAFF_2   ...    0.9730033874511719  13.693052858843402  0.031156221
# Donor6_IL-15_4  ...                   NaN                 NaN          NaN
#
#                div_10_pDC div_100_pDC deg_decoded_r_squared_pDC  \
# Donor9_IL-13_5        NaN         NaN                       NaN
# Donor2_BAFF_2         NaN         NaN                       NaN
# Donor2_ADSF_3         NaN         NaN                       NaN
# Donor1_BAFF_2         NaN         NaN        0.8916010856628418
# Donor6_IL-15_4        NaN         NaN                       NaN
#
#                deg_e_distance_pDC deg_mmd_pDC deg_div_10_pDC deg_div_100_pDC
# Donor9_IL-13_5                NaN         NaN            NaN             NaN
# Donor2_BAFF_2                 NaN         NaN            NaN             NaN
# Donor2_ADSF_3                 NaN         NaN            NaN             NaN
# Donor1_BAFF_2     19.439697265625  0.03468139            NaN             NaN
# Donor6_IL-15_4                NaN         NaN            NaN             NaN
#
# [5 rows x 166 columns]

# %%
df["donor_cytokine_split-idx"] = df.index
df["donor"] = df.apply(lambda x: x["donor_cytokine_split-idx"].split("_")[0], axis=1)
df["cytokine"] = df.apply(lambda x: x["donor_cytokine_split-idx"].split("_")[1], axis=1)
df["split-idx"] = df.apply(lambda x: x["donor_cytokine_split-idx"].split("_")[2], axis=1)
# Out:
# /tmp/ipykernel_2943964/2560909508.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["donor_cytokine_split-idx"] = df.index
# /tmp/ipykernel_2943964/2560909508.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["donor"] = df.apply(lambda x: x["donor_cytokine_split-idx"].split("_")[0], axis=1)
# /tmp/ipykernel_2943964/2560909508.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cytokine"] = df.apply(lambda x: x["donor_cytokine_split-idx"].split("_")[1], axis=1)
# /tmp/ipykernel_2943964/2560909508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["split-idx"] = df.apply(lambda x: x["donor_cytokine_split-idx"].split("_")[2], axis=1)

# %%
df["donor"].value_counts()
# Out:
# donor
# Donor5     234
# Donor12    228
# Donor8     225
# Donor7     222
# Donor9     221
# Donor10    221
# Donor2     217
# Donor3     216
# Donor11    215
# Donor1     214
# Donor4     209
# Donor6     206
# Name: count, dtype: int64

# %%
df["donor"].value_counts()
# Out:
# donor
# Donor5     234
# Donor12    228
# Donor8     225
# Donor7     222
# Donor9     221
# Donor10    221
# Donor2     217
# Donor3     216
# Donor11    215
# Donor1     214
# Donor4     209
# Donor6     206
# Name: count, dtype: int64

# %%
df["cytokine"].value_counts()
# Out:
# cytokine
# IL-13          219
# BAFF           219
# ADSF           219
# IL-15          219
# 4-1BBL         219
# IFN-beta       219
# C5a            219
# OSM            219
# APRIL          219
# IFN-epsilon    219
# OX40L          219
# Noggin         219
# Name: count, dtype: int64

# %%
df.to_csv(os.path.join(data_dir, "metrics_new_cytokine.csv"))

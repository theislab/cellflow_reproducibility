# %%
import pickle

with open("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/degs_different_top_k.pkl", "rb") as pickle_file:
    deg_genes = pickle.load(pickle_file)

# %%
deg_genes.keys()
# Out:
# dict_keys([20, 50, 100, 200, 500, 1000])

# %%
for d in deg_genes.items():

# %%
deg_genes.keys()
# Out:
# dict_keys([20, 50, 100, 200, 500, 1000])

# %%
deg_genes[20]
# Out:
# {'Donor10_CD8 Naive_4-1BBL': ['SLCO5A1',
#   '7SK',
#   'ENSG00000232855',
#   'TRBC1',
#   'LINC01619',
#   'SESN3',
#   'SAMD4A',
#   'IL7R',
#   'FTL',
#   'CD8B',
#   'TNFSF10',
#   'CTSB',
#   'RUNX2',
#   'LAMP3',
#   'BIRC3',
#   'EXT1',
#   'FAR2',
#   'LINC02446',
#   'NELL2',
#   'PRKN'],
#  'Donor10_CD8 Naive_ADSF': ['IFIT3',
#   'LYZ',
#   '7SK',
#   'NELL2',
#   'ISG15',
#   'LEF1-AS1',
#   'CD8A',
#   'SLC8A1',
#   'ZEB2',
#   'NRCAM',
#   'CXCL10',
#   'LAMP3',
#   'STRBP',
#   'LYN',
#   'MT2A',
#   'SH3RF3',
#   'BIRC3',
#   'FCGBP',
#   'PDE4B',
#   'TSHZ2'],
#  'Donor10_CD8 Naive_APRIL': ['IFIT3',
#   'RSAD2',
#   'NRCAM',
#   'LAMP3',
#   'NELL2',
#   'IFIT2',
#   'LEF1-AS1',
#   'TNFSF10',
#   'ISG15',
#   'SPON1',
#   'CTSS',
#   '7SK',
#   'IL7R',
#   'SAT1',
#   'ENSG00000232855',
#   'ABTB3',
#   'KCNQ5',
#   'CD74',
#   'PRR5',
#   'SAMD4A'],
#  'Donor10_CD8 Naive_BAFF': ['7SK',
#   'CAMK2D',
#   'MT2A',
#   'MTHFD1L',
#   'SAMD12',
#   'IFIT2',
#   'LRRN3',
#   'ZSWIM5',
#   'AGA-DT',
#   'SLC38A4-AS1',
#   'LINC02446',
#   'TTN',
#   'CTSS',
#   'IFIT3',
#   'PTK2',
#   'KANK1',
#   'RALGPS2',
#   'NEPRO-AS1',
#   'CD8A',
#   'LINC01934'],
#  'Donor10_CD8 Naive_C3a': ['NELL2',
#   'IFIT2',
#   'IFIT3',
#   'RSAD2',
#   'IL7R',
#   'SAT1',
#   'CTSS',
#   'PDE4B',
#   'LAMP3',
#   'ISG15',
#   'AK5',
#   'LINC01934',
#   'INPP4B',
#   'TNFSF10',
#   'MTHFD1L',
#   'NRCAM',
#   '7SK',
#   'ENSG00000286330',
#   'PRR5',
#   'PSAP'],
#  'Donor10_CD8 Naive_C5a': ['7SK',
#   'LRRN3',
#   'IL7R',
#   'SLCO5A1',
#   'BCL2',
#   'LAMP3',
#   'ENSG00000232855',
#   'CD8A',
#   'KLRC4-KLRK1',
#   'CAMK2D',
#   'THEMIS',
#   'LINC02446',
#   'RUNX2',
#   'LEF1-AS1',
#   'ENSG00000241962',
#   'NRCAM',
#   'RAB30',
#   'LINC01934',
#   'PLCB1',
#   'TTN'],
#  'Donor10_CD8 Naive_CD27L': ['7SK',
#   'IFIT3',
#   'NELL2',
#   'ISG15',
#   'SLCO5A1',
#   'IFIT2',
#   'NRCAM',
#   'TNFSF10',
#   'MT2A',
#   'LINC01619',
#   'LAMP3',
#   'ABTB3',
#   'IL7R',
#   'SPON1',
#   'LEF1-AS1',
#   'LRRN3',
#   'PRR5',
#   'SAT1',
#   'SH3RF3',
#   'SIRPG'],
#  'Donor10_CD8 Naive_CD30L': ['SLCO5A1',
#   '7SK',
#   'IFIT3',
#   'ISG15',
#   'IFIT2',
#   'TRBC1',
#   'THEMIS',
#   'LINC01619',
#   'EIF1B-AS1',
#   'MT2A',
#   'NELL2',
#   'SAMD12',
#   'CMAHP',
#   'SAMD4A',
#   'C12orf42',
#   'ENSG00000286330',
#   'LEF1-AS1',
#   'RSAD2',
#   'CCDC102B',
#   'BIRC3'],
#  'Donor10_CD8 Naive_CD40L': ['7SK',
#   'RSAD2',
#   'IFIT3',
#   'THEMIS',
#   'BCL2',
#   'NELL2',
#   'IFIT2',
#   'ISG15',
#   'PRR5',
#   'SH3RF3',
#   'RUNX2',
#   'CTSS',
#   'FAAH2',
#   'CD8B',
#   'SAMD3',
#   'TNFSF10',
#   'TRBC1',
#   'MT2A',
#   'LEF1-AS1',
#   'ABTB3'],
#  'Donor10_CD8 Naive_CT-1': ['7SK',
#   'ISG15',
#   'IFIT3',
#   'SLCO5A1',
#   'NRCAM',
#   'NELL2',
#   'SPON1',
#   'KLRC4-KLRK1',
#   'C12orf42',
#   'TTN',
#   'SIRPG',
#   'LEF1-AS1',
#   'BCL9',
#   'SAT1',
#   'IL7R',
#   'MT2A',
#   'SH3RF3',
#   'SLC16A10',
#   'RSAD2',
#   'AOAH'],
#  'Donor10_CD8 Naive_Decorin': ['7SK',
#   'SLCO5A1',
#   'NELL2',
#   'SAT1',
#   'ENSG00000286330',
#   'ISG15',
#   'MT2A',
#   'LINC01934',
#   'NRCAM',
#   'TRBC1',
#   'PDE4D',
#   'UBE2E2',
#   'BIRC3',
#   'RSAD2',
#   'SAMD3',
#   'TNFSF10',
#   'FTL',
#   'LYZ',
#   'KLRC4-KLRK1',
#   'PTPRK'],
#  'Donor10_CD8 Naive_EGF': ['7SK',
#   'SLCO5A1',
#   'NRCAM',
#   'ISG15',
#   'ZEB2',
#   'LYZ',
#   'IL7R',
#   'SPON1',
#   'IFIT3',
#   'LEF1-AS1',
#   'LINC01619',
#   'AOAH',
#   'NELL2',
#   'RSAD2',
#   'MT2A',
#   'KLF3-AS1',
#   'SIRPG',
#   'LRRN3',
#   'IFIT2',
#   'SAT1'],
#  'Donor10_CD8 Naive_EPO': ['SLCO5A1',
#   'IFIT3',
#   'NRCAM',
#   '7SK',
#   'NELL2',
#   'RSAD2',
#   'ISG15',
#   'LAMP3',
#   'IL7R',
#   'CD74',
#   'LEF1-AS1',
#   'AOAH',
#   'BIRC3',
#   'MT2A',
#   'SAT1',
#   'TTTY14',
#   'KCNQ5',
#   'ENSG00000229151',
#   'IFIT2',
#   'LINC01619'],
#  'Donor10_CD8 Naive_FGF-beta': ['SLCO5A1',
#   '7SK',
#   'ISG15',
#   'LEF1-AS1',
#   'IL7R',
#   'IFIT3',
#   'NELL2',
#   'LINC02964',
#   'IFIT2',
#   'LINC02446',
#   'CTSS',
#   'SUCLG2-DT',
#   'TTN',
#   'ZFAT',
#   'SAT1',
#   'FTH1',
#   'TSHZ2',
#   'RBFOX2',
#   'ZC3H12B',
#   'ENSG00000237356'],
#  'Donor10_CD8 Naive_FLT3L': ['SLCO5A1',
#   'CTSS',
#   'NELL2',
#   'ISG15',
#   'LAMP3',
#   '7SK',
#   'PRR5',
#   'ENSG00000249806',
#   'ZC3H12B',
#   'TRBC1',
#   'LINC01934',
#   'LINC01619',
#   'TSHZ2',
#   'ZSWIM5',
#   'ST6GALNAC3',
#   'MAML3',
#   'FTL',
#   'LTB',
#   'SIRPG',
#   'CD74'],
#  'Donor10_CD8 Naive_FasL': ['7SK',
#   'RSAD2',
#   'ISG15',
#   'SLCO5A1',
#   'IFIT2',
#   'IFIT3',
#   'NELL2',
#   'LAMP3',
#   'IL7R',
#   'TNFSF10',
#   'SH3RF3',
#   'MT2A',
#   'NRCAM',
#   'FTL',
#   'SAT1',
#   'LEF1-AS1',
#   'LINC01619',
#   'FAAH2',
#   'SAMD3',
#   'TTN'],
#  'Donor10_CD8 Naive_G-CSF': ['IFIT3',
#   'RSAD2',
#   'NRCAM',
#   'ISG15',
#   'NELL2',
#   'IFIT2',
#   'LAMP3',
#   'ABTB3',
#   'TNFSF10',
#   'LEF1-AS1',
#   'SAT1',
#   'IL7R',
#   'LINC01619',
#   'AOAH',
#   'SPON1',
#   '7SK',
#   'MT2A',
#   'SH3RF3',
#   'CTSS',
#   'CSGALNACT1'],
#  'Donor10_CD8 Naive_GDNF': ['RSAD2',
#   'IFIT3',
#   'ISG15',
#   'LAMP3',
#   'NELL2',
#   'NRCAM',
#   'SLCO5A1',
#   'PRR5',
#   'IL7R',
#   'TNFSF10',
#   'IFIT2',
#   'MT2A',
#   'AOAH',
#   'SAT1',
#   'ABTB3',
#   'MAST4',
#   'SPON1',
#   '7SK',
#   'NCALD',
#   'LEF1-AS1'],
#  'Donor10_CD8 Naive_GITRL': ['IFIT3',
#   'RSAD2',
#   'NRCAM',
#   'IFIT2',
#   'LAMP3',
#   'ISG15',
#   'NELL2',
#   'SH3RF3',
#   'TNFSF10',
#   'SLCO5A1',
#   'SAT1',
#   'KCNQ5',
#   'AOAH',
#   'ABTB3',
#   'LEF1-AS1',
#   'PRR5',
#   'LINC01619',
#   'MT2A',
#   'AK5',
#   'SPON1'],
#  'Donor10_CD8 Naive_GM-CSF': ['RSAD2',
#   'IFIT2',
#   'ENSG00000232855',
#   'FAAH2',
#   'TNFSF10',
#   'IFIT3',
#   'SNED1',
#   'NRCAM',
#   'LAMP3',
#   'CTSS',
#   'CMAHP',
#   'NEXN',
#   'LINC01934',
#   'FAR2',
#   '7SK',
#   'DNAI3',
#   'BCL2',
#   'PTK2',
#   'RUNX2',
#   'EIF1B-AS1'],
#  'Donor10_CD8 Naive_HGF': ['RSAD2',
#   'LAMP3',
#   'NRCAM',
#   'IFIT2',
#   'IFIT3',
#   'ABTB3',
#   'NELL2',
#   'IL7R',
#   'ISG15',
#   'SLCO5A1',
#   'TNFSF10',
#   'SAT1',
#   'PRR5',
#   'KCNQ5',
#   'LRRN3',
#   'NEXN',
#   'ENSG00000232855',
#   'AOAH',
#   'CSGALNACT1',
#   'SNED1'],
#  'Donor10_CD8 Naive_IFN-alpha1': ['IL7R',
#   '7SK',
#   'LRRN3',
#   'PDE4D',
#   'KCNQ1OT1',
#   'CALCB',
#   'NELL2',
#   'IFIT3',
#   'SAMD3',
#   'NRCAM',
#   'LINC01619',
#   'RUNX2',
#   'FHIT',
#   'CTSB',
#   'BIRC3',
#   'CD74',
#   'ENSG00000232855',
#   'ABTB3',
#   'LEF1-AS1',
#   'DOCK4'],
#  'Donor10_CD8 Naive_IFN-beta': ['IFIT2',
#   'ENSG00000232855',
#   'IFIT3',
#   'ABTB3',
#   'KCNQ1OT1',
#   'IL7R',
#   'PDE4D',
#   'LAMP3',
#   'LRRN3',
#   'PRR5',
#   'RSAD2',
#   'KCNQ5',
#   'SLCO5A1',
#   'FHIT',
#   'CD38',
#   'TNFSF10',
#   'MT2A',
#   'NRCAM',
#   'LINC02446',
#   'SAT1'],
#  'Donor10_CD8 Naive_IFN-epsilon': ['7SK',
#   'LRRN3',
#   'NELL2',
#   'SLCO5A1',
#   'IL7R',
#   'LINC01619',
#   'PDE4D',
#   'RSAD2',
#   'TNFSF10',
#   'FHIT',
#   'PRR5',
#   'MTHFD1L',
#   'SNED1',
#   'SPON1',
#   'CD74',
#   'SOD2',
#   'LEF1-AS1',
#   'BIRC3',
#   'CTSS',
#   'PTPRK-AS1'],
#  'Donor10_CD8 Naive_IFN-gamma': ['ENSG00000232855',
#   'SAMD4A',
#   'KCNQ1OT1',
#   'PDE4D',
#   'LINC01619',
#   'ABTB3',
#   'KCNQ5',
#   'CD38',
#   'WARS1',
#   'FHIT',
#   'NELL2',
#   'IFIT2',
#   'CD74',
#   '7SK',
#   'UBE2E2',
#   'LEF1-AS1',
#   'LRRN3',
#   'NRCAM',
#   'SAT1',
#   'ENSG00000287100'],
#  'Donor10_CD8 Naive_IFN-lambda1': ['SLCO5A1',
#   'NELL2',
#   'IFIT3',
#   'CAMK2D',
#   'LRRN3',
#   'LAMP3',
#   'BIRC3',
#   'THEMIS',
#   'PRR5',
#   'MCTP2',
#   'IL7R',
#   'LINC02446',
#   'KLRC4-KLRK1',
#   'PKIA',
#   'TNFSF10',
#   'CACHD1',
#   'RSAD2',
#   'NRCAM',
#   'CTSB',
#   'SLC8A1'],
#  'Donor10_CD8 Naive_IFN-lambda2': ['7SK',
#   'SLCO5A1',
#   'IL7R',
#   'ABTB3',
#   'RSAD2',
#   'CTSB',
#   'ENSG00000229151',
#   'TRBC1',
#   'FAAH2',
#   'KANK1',
#   'C12orf42',
#   'LEF1-AS1',
#   'LRRN3',
#   'AGA-DT',
#   'FNIP2',
#   'WARS1',
#   'LY6E-DT',
#   'LINC02446',
#   'NRCAM',
#   'ZC3H12B'],
#  'Donor10_CD8 Naive_IFN-lambda3': ['SLCO5A1',
#   'LRRN3',
#   'IFIT3',
#   'KCNQ5',
#   'NELL2',
#   'CTSS',
#   'CAMK2D',
#   'ABTB3',
#   'ZC3H12B',
#   'FCGBP',
#   'LY6E-DT',
#   'ENSG00000287100',
#   'RPL34-DT',
#   'CFAP418-AS1',
#   'DOCK3',
#   'ENSG00000251600',
#   'OR51B5',
#   'LTB',
#   'CXCL10',
#   'DAB1'],
#  'Donor10_CD8 Naive_IFN-omega': ['PDE4D',
#   'IL7R',
#   'LINC01619',
#   'LRRN3',
#   'ABTB3',
#   'KCNQ1OT1',
#   'CD74',
#   'SLCO5A1',
#   'IFIT3',
#   'RUNX2',
#   'CD8A',
#   'ENSG00000232855',
#   'CD38',
#   'FHIT',
#   'NELL2',
#   'LINC02446',
#   '7SK',
#   'IFIT2',
#   'KCNQ5',
#   'LEF1-AS1'],
#  'Donor10_CD8 Naive_IGF-1': ['7SK',
#   'SLCO5A1',
#   'LAMP3',
#   'IFIT3',
#   'NELL2',
#   'THEMIS',
#   'PRR5',
#   'TNFSF10',
#   'IFIT2',
#   'SIRPG',
#   'RSAD2',
#   'ENSG00000237356',
#   'PDE4B',
#   'SLC38A4-AS1',
#   'SAMD3',
#   'ISG15',
#   'CD74',
#   'TRBC1',
#   'ABTB3',
#   'FHIT'],
#  'Donor10_CD8 Naive_IL-1-alpha': ['ENSG00000232855',
#   'IFIT3',
#   'KCNQ5',
#   'PDE4D',
#   'NRCAM',
#   'SLCO5A1',
#   'IFIT2',
#   'CD8A',
#   'RSAD2',
#   'TNFSF10',
#   'SAT1',
#   'ABTB3',
#   'CD74',
#   'KCNQ1OT1',
#   'SH3RF3',
#   'LAMP3',
#   'PRR5',
#   'NELL2',
#   'CD38',
#   'SAMD4A'],
#  'Donor10_CD8 Naive_IL-1-beta': ['7SK',
#   'NELL2',
#   'LAMP3',
#   'IL7R',
#   'CD8A',
#   'KCNQ5',
#   'RSAD2',
#   'PRR5',
#   'SAT1',
#   'ENSG00000232855',
#   'IFIT2',
#   'TNFSF10',
#   'IFIT3',
#   'ABTB3',
#   'NRCAM',
#   'SLCO5A1',
#   'WARS1',
#   'THEMIS',
#   'SH3RF3',
#   'CD38'],
#  'Donor10_CD8 Naive_IL-1Ra': ['LAMP3',
#   '7SK',
#   'RSAD2',
#   'NELL2',
#   'IFIT3',
#   'IFIT2',
#   'TNFSF10',
#   'SAT1',
#   'NRCAM',
#   'IL7R',
#   'CTSS',
#   'LINC02446',
#   'SLCO5A1',
#   'PRR5',
#   'ISG15',
#   'SAMD4A',
#   'LINC01934',
#   'ENSG00000232855',
#   'SPON1',
#   'NEXN'],
#  'Donor10_CD8 Naive_IL-2': ['WARS1',
#   'IFIT3',
#   'TNFSF10',
#   'ENSG00000232855',
#   'CD38',
#   'RSAD2',
#   'KCNQ5',
#   'IFIT2',
#   'ABTB3',
#   'LAMP3',
#   'LRRN3',
#   'KCNQ1OT1',
#   'INPP4B',
#   'SH3RF3',
#   'PDE4B',
#   'NELL2',
#   'PDE4D',
#   'SAT1',
#   'NRCAM',
#   'ISG15'],
#  'Donor10_CD8 Naive_IL-3': ['LRRN3',
#   'IFIT3',
#   'SH3RF3',
#   'CMSS1',
#   'ABTB3',
#   'FAAH2',
#   'MAL',
#   'ISG15',
#   'LEF1-AS1',
#   'SLC38A4-AS1',
#   'KCNQ5',
#   'ENSG00000237356',
#   'SAMD4A',
#   'KANK1',
#   'CTSS',
#   'IFIT2',
#   'MT2A',
#   'SIRPG',
#   'ZNRF1',
#   'ENSG00000267320'],
#  'Donor10_CD8 Naive_IL-5': ['LAMP3',
#   'NRCAM',
#   'IFIT3',
#   'NELL2',
#   'IL7R',
#   'SLCO5A1',
#   'ISG15',
#   'SAT1',
#   'TNFSF10',
#   'CTSS',
#   'PRR5',
#   'IFIT2',
#   'LINC01934',
#   'ABTB3',
#   'LEF1-AS1',
#   '7SK',
#   'SAMD4A',
#   'MTHFD1L',
#   'LINC01619',
#   'FAR2'],
#  'Donor10_CD8 Naive_IL-6': ['IFIT2',
#   'SH3RF3',
#   'KCNQ5',
#   'IL7R',
#   'LRRN3',
#   'IFIT3',
#   'ENSG00000232855',
#   'ZNRF1',
#   'SAMD4A',
#   'MT2A',
#   'ABTB3',
#   '7SK',
#   'LAMP3',
#   'TRBC1',
#   'LINC02446',
#   'CTSS',
#   'ENSG00000237356',
#   'SNTG2',
#   'LINC01619',
#   'ISG15'],
#  'Donor10_CD8 Naive_IL-7': ['WARS1',
#   'BCL2',
#   'NELL2',
#   'TNFSF10',
#   'IFIT3',
#   'CD38',
#   'IFIT2',
#   'DPP4',
#   'LRRN3',
#   'PDE4B',
#   'LAMP3',
#   'RSAD2',
#   'CDK6',
#   'INPP4B',
#   'LINC01619',
#   'RUNX2',
#   'LTB',
#   'ENSG00000232855',
#   'KCNQ5',
#   'SH3RF3'],
#  'Donor10_CD8 Naive_IL-8': ['7SK',
#   'NELL2',
#   'SLCO5A1',
#   'RSAD2',
#   'LINC01619',
#   'IFIT3',
#   'RUNX2',
#   'TNFSF10',
#   'IL7R',
#   'ABTB3',
#   'ENSG00000237356',
#   'CD8B',
#   'FHIT',
#   'LINC01934',
#   'THEMIS',
#   'STRBP',
#   'SUCLG2-DT',
#   'BCL2',
#   'EFCAB2',
#   'LRRN3'],
#  'Donor10_CD8 Naive_IL-9': ['7SK',
#   'SLCO5A1',
#   'CAMK2D',
#   'NRCAM',
#   'NELL2',
#   'LINC02446',
#   'MT2A',
#   'CD74',
#   'IFIT2',
#   'EXT1',
#   'LAMP3',
#   'FTL',
#   'LEF1-AS1',
#   'PDE4B',
#   'KLF3-AS1',
#   'SAMD3',
#   'IL7R',
#   'TNFSF10',
#   'BCL2',
#   'CACHD1'],
#  'Donor10_CD8 Naive_IL-10': ['IFIT3',
#   'RSAD2',
#   'IFIT2',
#   'LAMP3',
#   'NRCAM',
#   'SH3RF3',
#   'ISG15',
#   'SAT1',
#   'NELL2',
#   'SPON1',
#   'TNFSF10',
#   'AOAH',
#   'KCNQ5',
#   'LY6E-DT',
#   'CTSS',
#   'MT2A',
#   'FAAH2',
#   'SAMD4A',
#   'PRR5',
#   'CSGALNACT1'],
#  'Donor10_CD8 Naive_IL-11': ['SLCO5A1',
#   '7SK',
#   'ISG15',
#   'NRCAM',
#   'MT2A',
#   'LEF1-AS1',
#   'ANK3',
#   'TRBC1',
#   'FNDC3B',
#   'ZEB2',
#   'LTB',
#   'MAL',
#   'LRRN3',
#   'SUGCT',
#   'JAZF1',
#   'FHIT',
#   'LYZ',
#   'MIR31HG',
#   'SH3RF3',
#   'KLRC4-KLRK1'],
#  'Donor10_CD8 Naive_IL-12': ['7SK',
#   'ENSG00000232855',
#   'KCNQ5',
#   'SAT1',
#   'IFIT2',
#   'SLCO5A1',
#   'TNFSF10',
#   'PRR5',
#   'KCNQ1OT1',
#   'CD38',
#   'CTSS',
#   'NRCAM',
#   'LRRN3',
#   'IFIT3',
#   'ZC3H12B',
#   'PDE4D',
#   'SAMD4A',
#   'LINC01358',
#   'ABTB3',
#   'SH3RF3'],
#  'Donor10_CD8 Naive_IL-13': ['IFIT3',
#   'RSAD2',
#   'IFIT2',
#   'LAMP3',
#   'NRCAM',
#   'NELL2',
#   'SH3RF3',
#   'ISG15',
#   'TNFSF10',
#   'SPON1',
#   '7SK',
#   'SAT1',
#   'AOAH',
#   'MT2A',
#   'LEF1-AS1',
#   'ABTB3',
#   'KCNQ5',
#   'CTSS',
#   'CSGALNACT1',
#   'PDE4D'],
#  'Donor10_CD8 Naive_IL-15': ['BCL2',
#   'WARS1',
#   'TNFSF10',
#   '7SK',
#   'IFIT3',
#   'RSAD2',
#   'CD38',
#   'NELL2',
#   'IFIT2',
#   'KCNQ5',
#   'LRRN3',
#   'DPP4',
#   'CD74',
#   'LAMP3',
#   'CD8A',
#   'ENSG00000232855',
#   'PDE4B',
#   'LINC01619',
#   'INPP4B',
#   'KCNQ1OT1'],
#  'Donor10_CD8 Naive_IL-16': ['7SK',
#   'LINC01619',
#   'SLCO5A1',
#   'SPON1',
#   'IFIT3',
#   'TTN',
#   'NELL2',
#   'MT2A',
#   'NKD1',
#   'NRCAM',
#   'ISG15',
#   'RUNX2',
#   'CD8A',
#   'IL7R',
#   'CD74',
#   'SIRPG',
#   'RSAD2',
#   'MARCHF3',
#   'CAMK2D',
#   'STX18-AS1'],
#  'Donor10_CD8 Naive_IL-17A': ['SLCO5A1',
#   'ABTB3',
#   '7SK',
#   'PSAP',
#   'RSAD2',
#   'ENSG00000290067',
#   'SIRPG',
#   'PRR5',
#   'EIF1B-AS1',
#   'MT2A',
#   'ZC3H12B',
#   'BCL2',
#   'LAMP3',
#   'NELL2',
#   'SH3RF3',
#   'NAALADL2',
#   'ENSG00000237356',
#   'CD8A',
#   'SLC16A10',
#   'TMEM182'],
#  'Donor10_CD8 Naive_IL-17B': ['7SK',
#   'IFIT3',
#   'NELL2',
#   'NRCAM',
#   'ISG15',
#   'FTL',
#   'MT2A',
#   'SAT1',
#   'LEF1-AS1',
#   'LINC02446',
#   'IL7R',
#   'RSAD2',
#   'CD74',
#   'CSGALNACT1',
#   'SAMD12',
#   'IFIT2',
#   'CACHD1',
#   'FAAH2',
#   'PRKN',
#   'RPL34-DT'],
#  'Donor10_CD8 Naive_IL-17C': ['IFIT3',
#   'NRCAM',
#   '7SK',
#   'RSAD2',
#   'LAMP3',
#   'NELL2',
#   'SLCO5A1',
#   'ISG15',
#   'IFIT2',
#   'CD74',
#   'TNFSF10',
#   'ABTB3',
#   'AOAH',
#   'SPON1',
#   'PRR5',
#   'LEF1-AS1',
#   'MT2A',
#   'IL7R',
#   'SAT1',
#   'PTPRK-AS1'],
#  'Donor10_CD8 Naive_IL-17D': ['7SK',
#   'IFIT3',
#   'SLCO5A1',
#   'NELL2',
#   'ISG15',
#   'NRCAM',
#   'IL7R',
#   'RSAD2',
#   'IFIT2',
#   'PRR5',
#   'LTB',
#   'SAT1',
#   'MT2A',
#   'CD74',
#   'TNFSF10',
#   'LEF1-AS1',
#   'THEMIS',
#   'PSAP',
#   'ABTB3',
#   'CTSS'],
#  'Donor10_CD8 Naive_IL-17E': ['ISG15',
#   'FTL',
#   'NELL2',
#   'MT2A',
#   'LTB',
#   'SAT1',
#   '7SK',
#   'TTN',
#   'TNFSF10',
#   'CD74',
#   'NRCAM',
#   'LEF1-AS1',
#   'KANK1',
#   'ZSWIM5',
#   'MARCHF3',
#   'KLRC4-KLRK1',
#   'FAR2',
#   'TRBC1',
#   'PDE4B',
#   'LINC01619'],
#  'Donor10_CD8 Naive_IL-17F': ['7SK',
#   'IFIT3',
#   'SLCO5A1',
#   'ISG15',
#   'NELL2',
#   'MT2A',
#   'IFIT2',
#   'RSAD2',
#   'SAT1',
#   'KLRC4-KLRK1',
#   'NRCAM',
#   'ENSG00000229151',
#   'TRBC1',
#   'AOAH',
#   'SAMD12',
#   'SH3RF3',
#   'PKIA',
#   'PTPRK-AS1',
#   'THEMIS',
#   'ENSG00000286330'],
#  'Donor10_CD8 Naive_IL-18': ['IFIT3',
#   'SLCO5A1',
#   'NELL2',
#   '7SK',
#   'NRCAM',
#   'RSAD2',
#   'IFIT2',
#   'ABTB3',
#   'LAMP3',
#   'SAT1',
#   'ISG15',
#   'TNFSF10',
#   'TRBC1',
#   'LINC02446',
#   'THEMIS',
#   'INPP4B',
#   'MT2A',
#   'SAMD3',
#   'PRR5',
#   'LINC01934'],
#  'Donor10_CD8 Naive_IL-19': ['7SK',
#   'IFIT3',
#   'ISG15',
#   'RSAD2',
#   'NRCAM',
#   'SH3RF3',
#   'SIRPG',
#   'SLCO5A1',
#   'LEF1-AS1',
#   'MT2A',
#   'NELL2',
#   'ENSG00000286330',
#   'IFIT2',
#   'KLRC4-KLRK1',
#   'SLC8A1',
#   'AOAH',
#   'UBA6-DT',
#   'PRR5',
#   'SAT1',
#   'RPL34-DT'],
#  'Donor10_CD8 Naive_IL-20': ['NELL2',
#   'IFIT2',
#   'RSAD2',
#   'ISG15',
#   '7SK',
#   'IFIT3',
#   'NRCAM',
#   'TNFSF10',
#   'SLCO5A1',
#   'LEF1-AS1',
#   'LRRN3',
#   'LAMP3',
#   'MT2A',
#   'SH3RF3',
#   'CTSS',
#   'IL7R',
#   'LINC01619',
#   'SNTG2',
#   'SAMD3',
#   'CD8B'],
#  'Donor10_CD8 Naive_IL-21': ['7SK',
#   'BCL2',
#   'CD8A',
#   'FAAH2',
#   'PTPRK-AS1',
#   'SLC38A4-AS1',
#   'SAMD3',
#   'IL2RB',
#   'KCNQ1OT1',
#   'DAB1',
#   'PRR5',
#   'ANK3',
#   'PDE4D',
#   'NRCAM',
#   'SNED1',
#   'ENSG00000232855',
#   'CTSS',
#   'LINC02615',
#   'EIF1B-AS1',
#   'ENSG00000227486'],
#  'Donor10_CD8 Naive_IL-22': ['LRRN3',
#   'IFIT3',
#   'SLCO5A1',
#   'LAMP3',
#   'RSAD2',
#   'IFIT2',
#   '7SK',
#   'SAT1',
#   'LINC01725',
#   'NRCAM',
#   'THEMIS',
#   'ENSG00000232855',
#   'ANK3',
#   'LEF1-AS1',
#   'AOAH',
#   'CD8B',
#   'SAMD3',
#   'ABTB3',
#   'ENSG00000287100',
#   'CTSS'],
#  'Donor10_CD8 Naive_IL-23': ['SLCO5A1',
#   'ENSG00000232855',
#   'CD74',
#   'KCNQ5',
#   'TNFSF10',
#   'RSAD2',
#   'ABTB3',
#   'ENSG00000287100',
#   'IFIT2',
#   'LAMP3',
#   'LTB',
#   'CD38',
#   'NRCAM',
#   'PDE4D',
#   'KCNQ1OT1',
#   'IFIT3',
#   'WARS1',
#   'PRR5',
#   'LRRN3',
#   'TRBC1'],
#  'Donor10_CD8 Naive_IL-24': ['7SK',
#   'RSAD2',
#   'IFIT3',
#   'SNED1',
#   'NRCAM',
#   'TMEM117',
#   'LINC01619',
#   'MT2A',
#   'ENSG00000232855',
#   'SAT1',
#   'TNFSF10',
#   'STEAP1B',
#   'PARD3B',
#   'EXT1',
#   'LINC01934',
#   'CD8A',
#   'MYB',
#   'CTSS',
#   'RUNX2',
#   'AOAH'],
#  'Donor10_CD8 Naive_IL-26': ['IFIT3',
#   'RSAD2',
#   'IFIT2',
#   'NELL2',
#   'KCNQ5',
#   'NRCAM',
#   'SAT1',
#   'LAMP3',
#   'ISG15',
#   'ABTB3',
#   'SLCO5A1',
#   'PRR5',
#   'TNFSF10',
#   'SH3RF3',
#   'LEF1-AS1',
#   'AOAH',
#   'CTSS',
#   'ENSG00000229151',
#   'SAMD4A',
#   'PALM2AKAP2'],
#  'Donor10_CD8 Naive_IL-27': ['RSAD2',
#   'SLCO5A1',
#   'NELL2',
#   'ISG15',
#   'NRCAM',
#   'MT2A',
#   'CMAHP',
#   '7SK',
#   'ENSG00000232855',
#   'IL7R',
#   'TRBC1',
#   'ANK3',
#   'TTN',
#   'IFIT3',
#   'BIRC3',
#   'LINC01619',
#   'PSAP',
#   'CD38',
#   'IFIT2',
#   'LEF1-AS1'],
#  'Donor10_CD8 Naive_IL-31': ['7SK',
#   'NELL2',
#   'RSAD2',
#   'SLCO5A1',
#   'ISG15',
#   'IL7R',
#   'LAMP3',
#   'NRCAM',
#   'IFIT2',
#   'ABTB3',
#   'IFIT3',
#   'CD74',
#   'TNFSF10',
#   'ENSG00000232855',
#   'LEF1-AS1',
#   'SH3RF3',
#   'TRBC1',
#   'SNED1',
#   'PRR5',
#   'LINC01619'],
#  'Donor10_CD8 Naive_IL-32-beta': ['IFIT3',
#   'RSAD2',
#   'IFIT2',
#   'FAAH2',
#   'LAMP3',
#   'SH3RF3',
#   'ISG15',
#   'SPON1',
#   'PDE4D',
#   'SAT1',
#   'AOAH',
#   'SDK1',
#   'LY6E-DT',
#   'NELL2',
#   'TNFSF10',
#   'ZNRF1',
#   'BIRC3',
#   'LINC01619',
#   'LRRN3',
#   'MAML3'],
#  'Donor10_CD8 Naive_IL-33': ['SLCO5A1',
#   'NELL2',
#   'NRCAM',
#   'IFIT3',
#   'LEF1-AS1',
#   'TNFSF10',
#   'RSAD2',
#   'ISG15',
#   'CAMK2D',
#   'MT2A',
#   'LINC01934',
#   'IFIT2',
#   'SAT1',
#   'LAMP3',
#   'CTSS',
#   'SPON1',
#   'CD74',
#   'CRADD',
#   'ABTB3',
#   'SH3RF3'],
#  'Donor10_CD8 Naive_IL-34': ['SLCO5A1',
#   'IFIT3',
#   'ABTB3',
#   'KCNQ5',
#   'FTL',
#   'NRCAM',
#   'FAAH2',
#   'LRRN3',
#   'SESN3',
#   'ENSG00000232855',
#   'TTTY10',
#   'NAALADL2',
#   'LTB',
#   'TRBC1',
#   'TNFSF10',
#   'BCL2',
#   'MAL',
#   'STEAP1B',
#   'KLRC4-KLRK1',
#   'EXPH5'],
#  'Donor10_CD8 Naive_IL-35': ['SLCO5A1',
#   '7SK',
#   'CD74',
#   'PRR5',
#   'ABTB3',
#   'BIRC3',
#   'PDE4D',
#   'TRBC1',
#   'SAT1',
#   'MIR31HG',
#   'FNDC3B',
#   'RUNX2',
#   'BDNF-AS',
#   'ANK3',
#   'FTL',
#   'ENSG00000287100',
#   'LRRN3',
#   'CMAHP',
#   'ENSG00000232855',
#   'AGA-DT'],
#  'Donor10_CD8 Naive_IL-36-alpha': ['IL7R',
#   '7SK',
#   'ISG15',
#   'SAT1',
#   'LAMP3',
#   'ENSG00000287100',
#   'FAR2',
#   'PTPRK',
#   'PRR5',
#   'RSAD2',
#   'MT2A',
#   'DAB1',
#   'ABTB3',
#   'KCNQ5',
#   'FTL',
#   'SOD2',
#   'LINC01934',
#   'CEP112',
#   'ENSG00000272369',
#   'RPL34-DT'],
#  'Donor10_CD8 Naive_IL-36Ra': ['7SK',
#   'SLCO5A1',
#   'CD74',
#   'NELL2',
#   'MAL',
#   'RUNX2',
#   'ISG15',
#   'SAMD3',
#   'SAT1',
#   'IFIT3',
#   'MT2A',
#   'SPON1',
#   'CD68',
#   'ENSG00000241962',
#   'FTH1',
#   'NKD1',
#   'LY6E-DT',
#   'LEF1-AS1',
#   'SIRPG',
#   'KLRC4-KLRK1'],
#  'Donor10_CD8 Naive_LIF': ['7SK',
#   'SLCO5A1',
#   'TNFSF10',
#   'RSAD2',
#   'LAMP3',
#   'IL7R',
#   'NELL2',
#   'PRR5',
#   'ABTB3',
#   'FAAH2',
#   'SAT1',
#   'LRRN3',
#   'ISG15',
#   'CD74',
#   'FCGBP',
#   'TRBC1',
#   'ENSG00000232855',
#   'LTB',
#   'RUNX2',
#   'KCNQ1OT1'],
#  'Donor10_CD8 Naive_LIGHT': ['SLCO5A1',
#   '7SK',
#   'ABTB3',
#   'ISG15',
#   'LIMK2',
#   'LY6E-DT',
#   'LEF1-AS1',
#   'MARCHF3',
#   'RSAD2',
#   'PDE4B',
#   'LINC01358',
#   'BCL9',
#   'FTL',
#   'PRR5',
#   'RGS5',
#   'GRIP1',
#   'TRBC1',
#   'LINC01376',
#   'ADAMTS6',
#   'CD8A'],
#  'Donor10_CD8 Naive_LT-alpha1-beta2': ['RSAD2',
#   'IFIT3',
#   'NELL2',
#   'IFIT2',
#   'LAMP3',
#   'TNFSF10',
#   '7SK',
#   'ABTB3',
#   'ISG15',
#   'SAT1',
#   'PRR5',
#   'IL7R',
#   'CTSS',
#   'ENSG00000232855',
#   'NRCAM',
#   'SLCO5A1',
#   'LY6E-DT',
#   'KCNQ5',
#   'CD74',
#   'TRBC1'],
#  'Donor10_CD8 Naive_LT-alpha2-beta1': ['SLCO5A1',
#   'LAMP3',
#   'NELL2',
#   '7SK',
#   'RSAD2',
#   'THEMIS',
#   'IFIT3',
#   'TNFSF10',
#   'SAT1',
#   'IFIT2',
#   'ISG15',
#   'SPON1',
#   'ABTB3',
#   'IL7R',
#   'CAMK2D',
#   'ENSG00000229151',
#   'PRR5',
#   'NRCAM',
#   'LINC01934',
#   'LINC01619'],
#  'Donor10_CD8 Naive_Leptin': ['IFIT3',
#   '7SK',
#   'SLCO5A1',
#   'NELL2',
#   'NRCAM',
#   'IFIT2',
#   'TRBC1',
#   'IL7R',
#   'ISG15',
#   'RSAD2',
#   'SPON1',
#   'SAT1',
#   'ENSG00000237356',
#   'SAMD12',
#   'CTSS',
#   'TNFSF10',
#   'MT2A',
#   'C16orf74',
#   'ZEB2',
#   'GLIS3'],
#  'Donor10_CD8 Naive_M-CSF': ['7SK',
#   'TTN',
#   'IFIT3',
#   'PRR5',
#   'RSAD2',
#   'NRCAM',
#   'SLCO5A1',
#   'IFIT2',
#   'SAMD3',
#   'SIRPG',
#   'PALM2AKAP2',
#   'TRBC1',
#   'SAMD12',
#   'ENSG00000232855',
#   'TMEM117',
#   'ABTB3',
#   'THEMIS',
#   'AOAH',
#   'ZSWIM5',
#   'SDK2'],
#  'Donor10_CD8 Naive_Noggin': ['7SK',
#   'SLCO5A1',
#   'IFIT3',
#   'IFIT2',
#   'MT2A',
#   'ISG15',
#   'CD74',
#   'ABTB3',
#   'KLRC4-KLRK1',
#   'FTL',
#   'LINC01619',
#   'NELL2',
#   'RSAD2',
#   'NCALD',
#   'NRCAM',
#   'LEF1-AS1',
#   'ENSG00000232855',
#   'TRBC1',
#   'ATP10D',
#   'TNFSF10'],
#  'Donor10_CD8 Naive_OSM': ['7SK',
#   'NELL2',
#   'SLCO5A1',
#   'IL7R',
#   'NRCAM',
#   'LAMP3',
#   'TTN',
#   'ISG15',
#   'SAMD12',
#   'CD74',
#   'KLRC4-KLRK1',
#   'BIRC3',
#   'CD8B',
#   'LEF1-AS1',
#   'RSAD2',
#   'LINC01619',
#   'RUNX2',
#   'IFIT2',
#   'ADAMTS6',
#   'MAL'],
#  'Donor10_CD8 Naive_OX40L': ['CD74',
#   'NELL2',
#   'IFIT3',
#   'RSAD2',
#   'TNFSF10',
#   'SAT1',
#   'PRR5',
#   'SLCO5A1',
#   'ENSG00000232855',
#   'NRCAM',
#   'IL7R',
#   'LAMP3',
#   'KLRC4-KLRK1',
#   'IFIT2',
#   'PALM2AKAP2',
#   'SAMD4A',
#   'CTSB',
#   'PDE4B',
#   'CD8A',
#   'PDE4D'],
#  'Donor10_CD8 Naive_PRL': ['SLCO5A1',
#   'SAMD12',
#   'TRBC1',
#   'ENSG00000232855',
#   'FAAH2',
#   'ZC3H12B',
#   '7SK',
#   'SLC38A4-AS1',
#   'LINC01619',
#   'LINC02446',
#   'RSAD2',
#   'SAT1',
#   'PSAP',
#   'LINC01934',
#   'KCNQ5',
#   'AK5',
#   'KANK1',
#   'ABTB3',
#   'AFF3',
#   'CNNM2'],
#  'Donor10_CD8 Naive_PSPN': ['7SK',
#   'IL7R',
#   'RSAD2',
#   'IFIT2',
#   'TNFSF10',
#   'IFIT3',
#   'LEF1-AS1',
#   'NELL2',
#   'SLCO5A1',
#   'ISG15',
#   'LINC01619',
#   'NRCAM',
#   'TTN',
#   'SAMD3',
#   'LAMP3',
#   'SPON1',
#   'AOAH',
#   'MAL',
#   'ABTB3',
#   'PSAP'],
#  'Donor10_CD8 Naive_RANKL': ['SLCO5A1',
#   'IFIT3',
#   'NELL2',
#   'LEF1-AS1',
#   'TNFSF10',
#   'RSAD2',
#   'ISG15',
#   'NRCAM',
#   'LAMP3',
#   'IL7R',
#   'PRR5',
#   'ENSG00000237356',
#   'KLF3-AS1',
#   'IFIT2',
#   'BCL2',
#   'TTN',
#   'AOAH',
#   'CD74',
#   'LINC01876',
#   '7SK'],
#  'Donor10_CD8 Naive_SCF': ['SLCO5A1',
#   'NELL2',
#   'TNFSF10',
#   'MARCHF3',
#   'GRIP1',
#   'RSAD2',
#   'IFIT2',
#   'PSAP',
#   'LY6E-DT',
#   'ISG15',
#   'FAR2',
#   'EIF1B-AS1',
#   'IL7R',
#   'BCL9',
#   'LAMP3',
#   'FTL',
#   'FNDC3B',
#   'LRRN3',
#   'PRKN',
#   'KANK1'],
#  'Donor10_CD8 Naive_TGF-beta1': ['NELL2',
#   'IL7R',
#   'IFIT3',
#   'ISG15',
#   'LRRN3',
#   'RSAD2',
#   'RUNX2',
#   'EXT1',
#   'SLCO5A1',
#   'LEF1-AS1',
#   'NRCAM',
#   'SUCLG2-DT',
#   'TNFSF10',
#   'KLF3-AS1',
#   'CD8B',
#   'PKIA',
#   'ENSG00000286330',
#   'PTPRK-AS1',
#   'SAMD3',
#   'BIRC3'],
#  'Donor10_CD8 Naive_TL1A': ['7SK',
#   'TNFSF10',
#   'LAMP3',
#   'CD74',
#   'SAT1',
#   'IFIT2',
#   'KCNQ5',
#   'ENSG00000232855',
#   'PRR5',
#   'ABTB3',
#   'IFIT3',
#   'RSAD2',
#   'CD38',
#   'SAMD4A',
#   'FAR2',
#   'THEMIS',
#   'BCL2',
#   'BIRC3',
#   'WARS1',
#   'NRCAM'],
#  'Donor10_CD8 Naive_TNF-alpha': ['7SK',
#   'NELL2',
#   'SLCO5A1',
#   'RSAD2',
#   'IFIT3',
#   'IFIT2',
#   'CD74',
#   'ISG15',
#   'ABTB3',
#   'LAMP3',
#   'TNFSF10',
#   'PRR5',
#   'FNDC3B',
#   'SAMD4A',
#   'SAT1',
#   'THEMIS',
#   'NRCAM',
#   'CAMK2D',
#   'UBA6-DT',
#   'SAMD12'],
#  'Donor10_CD8 Naive_TPO': ['SLCO5A1',
#   '7SK',
#   'NELL2',
#   'SAT1',
#   'PRR5',
#   'CD74',
#   'SAMD12',
#   'IFIT2',
#   'MT2A',
#   'TNFSF10',
#   'IL2RB',
#   'SNED1',
#   'RSAD2',
#   'LINC01934',
#   'TRBC1',
#   'SLC8A1',
#   'ANK3',
#   'FHIT',
#   'LYZ',
#   'CAMK2D'],
#  'Donor10_CD8 Naive_TRAIL': ['NELL2',
#   'IL7R',
#   '7SK',
#   'ENSG00000232855',
#   'ISG15',
#   'FTL',
#   'LINC02446',
#   'BIRC3',
#   'RSAD2',
#   'LAMP3',
#   'THEMIS',
#   'STEAP1B',
#   'PRKN',
#   'SESN3',
#   'HS3ST3B1',
#   'MCTP2',
#   'LRRN3',
#   'TNFSF10',
#   'ENSG00000248969',
#   'INPP4B'],
#  'Donor10_CD8 Naive_TSLP': ['7SK',
#   'LAMP3',
#   'CD74',
#   'IL7R',
#   'ABTB3',
#   'TNFSF10',
#   'PDE4D',
#   'SAMD4A',
#   'NRCAM',
#   'RSAD2',
#   'PRR5',
#   'KCNQ5',
#   'IFIT2',
#   'SLCO5A1',
#   'PALM2AKAP2',
#   'ENSG00000287100',
#   'BCL9',
#   'FAR2',
#   'CTSB',
#   'FTL'],
#  'Donor10_CD8 Naive_TWEAK': ['SLCO5A1',
#   'NELL2',
#   'ISG15',
#   'IFIT2',
#   '7SK',
#   'IL7R',
#   'PRR5',
#   'CTSS',
#   'RSAD2',
#   'CD74',
#   'TNFSF10',
#   'PDE4B',
#   'IFIT3',
#   'SAT1',
#   'ABTB3',
#   'SPON1',
#   'NRCAM',
#   'MTHFD1L',
#   'EXT1',
#   'NEXN'],
#  'Donor10_CD8 Naive_VEGF': ['7SK',
#   'SLCO5A1',
#   'SPON1',
#   'IL7R',
#   'ENSG00000241962',
#   'ZSWIM5',
#   'IFIT3',
#   'ENSG00000229151',
#   'SGO1-AS1',
#   'CRTAM',
#   'LYZ',
#   'INPP4B',
#   'TSPAN5',
#   'NEXN',
#   'BIRC3',
#   'NELL2',
#   'GRIP1',
#   'LAMP3',
#   'CD38',
#   'FNDC3B'],
#  'Donor10_B Naive_4-1BBL': ['CD74',
#   '7SK',
#   'CDK14',
#   'TNFSF10',
#   'RHEX',
#   'BCL2',
#   'TCF4',
#   'SAMD4A',
#   'SLCO5A1',
#   'MTSS1',
#   'IGHD',
#   'IGKC',
#   'HVCN1',
#   'PAX5',
#   'EBF1',
#   'NIBAN3',
#   'CNR2',
#   'GNG7',
#   'ENTPD1',
#   'FCRL1'],
#  'Donor10_B Naive_ADSF': ['CD74',
#   'LYZ',
#   'SAMD4A',
#   '7SK',
#   'NAV2',
#   'BCL2',
#   'DLEU1',
#   'CXCL10',
#   'HLA-DRA',
#   'ANK3',
#   'FCRL1',
#   'ADAM7-AS1',
#   'SESN3',
#   'C12orf42',
#   'CCNT2-AS1',
#   'COBLL1',
#   'RHEX',
#   'AOAH',
#   'MCTP2',
#   'PAWR'],
#  'Donor10_B Naive_APRIL': ['CCSER1',
#   'PDE4D',
#   'CD74',
#   'COL19A1',
#   'TNFSF10',
#   'OSBPL10',
#   'IFIT3',
#   'SAMD4A',
#   'ENSG00000287100',
#   '7SK',
#   'WARS1',
#   'LINC00926',
#   'C16orf74',
#   'ZDHHC14',
#   'LYN',
#   'BCL11A',
#   'ENSG00000224610',
#   'CD38',
#   'ENSG00000285744',
#   'PTK2'],
#  'Donor10_B Naive_BAFF': ['7SK',
#   'BIRC3',
#   'WDFY4',
#   'BCAR3',
#   'CD83',
#   'FCRL1',
#   'AFF3',
#   'SEMA7A',
#   'CIITA',
#   'WARS1',
#   'TMCC3',
#   'PDE4D',
#   'ADAM19',
#   'AUTS2',
#   'ADAM28',
#   'ANKRD33B',
#   'CD74',
#   'KHDRBS2',
#   'IGKC',
#   'PTK2'],
#  'Donor10_B Naive_C3a': ['7SK',
#   'CD74',
#   'IFIT3',
#   'STAP1',
#   'TNFSF10',
#   'AFF3',
#   'CD38',
#   'TCL1A',
#   'ADAM28',
#   'MARCHF3',
#   'BCL11A',
#   'HLA-DRA',
#   'LINC00926',
#   'LRRK2',
#   'ADAM7-AS1',
#   'IGHM',
#   'CNR2',
#   'SAMD4A',
#   'BLK',
#   'STRBP'],
#  'Donor10_B Naive_C5a': ['7SK',
#   'MTSS1',
#   'IKZF2',
#   'WDFY4',
#   'IGHM',
#   'EBF1',
#   'PAX5',
#   'SLCO5A1',
#   'BLK',
#   'IFIT3',
#   'STEAP1B',
#   'PTK2',
#   'DMD',
#   'BIRC3',
#   'SESN3',
#   'CD83',
#   'PDE7B',
#   'PDE4B',
#   'CIITA',
#   'SAMD4A'],
#  'Donor10_B Naive_CD27L': ['7SK',
#   'CD74',
#   'IFIT3',
#   'COBLL1',
#   'HLA-DRA',
#   'PAX5',
#   'WARS1',
#   'HLA-DRB1',
#   'COL19A1',
#   'SESN3',
#   'RUBCNL',
#   'IFIT2',
#   'LINC00926',
#   'SLCO5A1',
#   'OSBPL10',
#   'ZDHHC14',
#   'IGKC',
#   'C16orf74',
#   'BTLA',
#   'LINC02245'],
#  'Donor10_B Naive_CD30L': ['7SK',
#   'CD74',
#   'BLK',
#   'KYNU',
#   'CCSER1',
#   'ATP10D',
#   'SLCO5A1',
#   'PTK2',
#   'WDFY4',
#   'KHDRBS2',
#   'IFIT3',
#   'PPFIBP1',
#   'TMCC3',
#   'LINC01619',
#   'FAM30A',
#   'MEF2C-AS1',
#   'ENSG00000261218',
#   'IGKC',
#   'SLC38A4-AS1',
#   'L3MBTL4'],
#  'Donor10_B Naive_CD40L': ['7SK',
#   'AFF3',
#   'CCSER1',
#   'PDE4D',
#   'CD74',
#   'ANKRD33B',
#   'C12orf42',
#   'GNG7',
#   'IFIT3',
#   'BCAR3',
#   'BANK1',
#   'ACSM3',
#   'ZEB2',
#   'MIR155HG',
#   'DLEU1',
#   'TLR10',
#   'GFOD1',
#   'MARCHF3',
#   'BIRC3',
#   'AUTS2'],
#  'Donor10_B Naive_CT-1': ['7SK',
#   'COL19A1',
#   'ZDHHC14',
#   'ENSG00000224610',
#   'LINC02422',
#   'LARGE1',
#   'PDE4D',
#   'TTN',
#   'IFIT3',
#   'IGKC',
#   'IGHM',
#   'CIITA',
#   'LRRK2',
#   'FCRL2',
#   'BTLA',
#   'ENSG00000290020',
#   'COBLL1',
#   'OSBPL10',
#   'E2F5',
#   'ATP10D'],
#  'Donor10_B Naive_Decorin': ['7SK',
#   'ADAM19',
#   'HLA-DRA',
#   'WDFY4',
#   'SLCO5A1',
#   'LINC00926',
#   'IFI30',
#   'IFNLR1',
#   'SAT1',
#   'SETBP1',
#   'PTK2',
#   'LARGE1',
#   'BANK1',
#   'P2RY14',
#   'CIITA',
#   'ANKRD33B',
#   'CBFA2T3',
#   'PLEKHG1',
#   'L3MBTL4',
#   'MCTP2'],
#  'Donor10_B Naive_EGF': ['7SK',
#   'CD74',
#   'BCL11A',
#   'DMD',
#   'HLA-DRA',
#   'IKZF2',
#   'IFIT3',
#   'C12orf42',
#   'ZDHHC14',
#   'C16orf74',
#   'PDE4D',
#   'SAT1',
#   'COL19A1',
#   'AUTS2',
#   'SLCO5A1',
#   'ENSG00000287100',
#   'PKIG',
#   'CIITA',
#   'ADAM7-AS1',
#   'LINC02245'],
#  'Donor10_B Naive_EPO': ['CD74',
#   'SLCO5A1',
#   '7SK',
#   'IFIT3',
#   'LINC00926',
#   'COL19A1',
#   'BCL11A',
#   'C16orf74',
#   'ZDHHC14',
#   'OSBPL10',
#   'COBLL1',
#   'TNFSF10',
#   'PDE4D',
#   'CD38',
#   'SESN3',
#   'NAV2',
#   'WARS1',
#   'BCL2',
#   'HLA-DRA',
#   'RAB30'],
#  'Donor10_B Naive_FGF-beta': ['SLCO5A1',
#   'IGHM',
#   'IGHD',
#   'DENND5B',
#   'LINC00926',
#   '7SK',
#   'MTSS1',
#   'IFIT3',
#   'GEN1',
#   'CD38',
#   'CIITA',
#   'COBLL1',
#   'MEF2C',
#   'BCL2',
#   'ENSG00000224610',
#   'CD79B',
#   'LINC02422',
#   'SYT17',
#   'OSBPL10',
#   'FTL'],
#  'Donor10_B Naive_FLT3L': ['SLCO5A1',
#   'CD74',
#   'PAX5',
#   'AUTS2',
#   'IGHD',
#   'HVCN1',
#   'ADAM28',
#   'E2F5',
#   'ENSG00000289963',
#   '7SK',
#   'IGHM',
#   'GFOD1',
#   'RHEX',
#   'PLEKHG1',
#   'TNFSF10',
#   'BASP1',
#   'RALGPS2',
#   'ALCAM',
#   'CD22',
#   'RUBCNL'],
#  'Donor10_B Naive_FasL': ['7SK',
#   'CD74',
#   'IFIT3',
#   'CD83',
#   'IGHM',
#   'CD79A',
#   'HLA-DRA',
#   'BLK',
#   'CIITA',
#   'TMCC3',
#   'RAB30',
#   'BCL11A',
#   'ENSG00000227486',
#   'PALM2AKAP2',
#   'COL19A1',
#   'FAM30A',
#   'WDFY4',
#   'PRKN',
#   'IGKC',
#   'ARHGAP24'],
#  'Donor10_B Naive_G-CSF': ['CD74',
#   'IFIT3',
#   'COL19A1',
#   'PDE4D',
#   'CCSER1',
#   'LINC00926',
#   'OSBPL10',
#   'TNFSF10',
#   'ZDHHC14',
#   'C16orf74',
#   'HLA-DRA',
#   'WARS1',
#   'COBLL1',
#   'BCL11A',
#   'CD38',
#   'SESN3',
#   'ENSG00000285744',
#   'C12orf42',
#   'ROR1',
#   'ISG15'],
#  'Donor10_B Naive_GDNF': ['LYN',
#   'COL19A1',
#   'FCRL1',
#   '7SK',
#   'MS4A1',
#   'PDE4D',
#   'CD74',
#   'KHDRBS2',
#   'IFIT3',
#   'PAX5',
#   'BLK',
#   'BASP1',
#   'ZDHHC14',
#   'BCL11A',
#   'TNFSF10',
#   'CD22',
#   'NAV2',
#   'IGKC',
#   'OSBPL10',
#   'FCRL2'],
#  'Donor10_B Naive_GITRL': ['CCSER1',
#   'LINC00926',
#   'COL19A1',
#   'IFIT3',
#   'WARS1',
#   'TNFSF10',
#   'C12orf42',
#   'COBLL1',
#   'IGHD',
#   'BCL11A',
#   'PDE4D',
#   'ISG15',
#   'TBC1D9',
#   '7SK',
#   'IGKC',
#   'C16orf74',
#   'ENSG00000224610',
#   'ZDHHC14',
#   'HLA-DRB1',
#   'PDE7B'],
#  'Donor10_B Naive_GM-CSF': ['CCSER1',
#   'RSAD2',
#   'TNFSF10',
#   'MACROD2',
#   'STAP1',
#   'PTK2',
#   'TMCC3',
#   'CD74',
#   'LINC02422',
#   'CCR6',
#   'SAMD4A',
#   'PDE4D',
#   'ADAM19',
#   'CXCL10',
#   'FCRL2',
#   'PLEKHG1',
#   'LINC00926',
#   'IFIT2',
#   'LINC02964',
#   'LAMP3'],
#  'Donor10_B Naive_HGF': ['COL19A1',
#   'PDE4D',
#   'SAMD4A',
#   'COBLL1',
#   'TNFSF10',
#   'CD38',
#   'BCL11A',
#   'AFF3',
#   'IFIT3',
#   'CCSER1',
#   'PAX5',
#   'WARS1',
#   'ENSG00000224610',
#   'LINC00926',
#   'C16orf74',
#   'BLK',
#   'ZDHHC14',
#   'STAP1',
#   'IGHD',
#   'SESN3'],
#  'Donor10_B Naive_IFN-alpha1': ['MTSS1',
#   '7SK',
#   'EBF1',
#   'WDFY4',
#   'CD83',
#   'BLK',
#   'CCSER1',
#   'HLA-DRB1',
#   'HVCN1',
#   'IKZF2',
#   'COBLL1',
#   'BIRC3',
#   'RAB30',
#   'SESN3',
#   'ARHGAP24',
#   'PSAP',
#   'ENTPD1',
#   'MCTP2',
#   'LINC02964',
#   'WARS1'],
#  'Donor10_B Naive_IFN-beta': ['ARHGAP24',
#   'COL19A1',
#   'EBF1',
#   'IKZF2',
#   'PDE4B',
#   'WDFY4',
#   'CD38',
#   'CD74',
#   'TNFSF10',
#   'ADAM28',
#   'LINC02964',
#   'MTSS1',
#   'HDAC9',
#   'HVCN1',
#   'LARGE1',
#   'BCL11A',
#   'SLCO5A1',
#   'MCTP2',
#   'COBLL1',
#   'PSD3'],
#  'Donor10_B Naive_IFN-epsilon': ['7SK',
#   'IGHM',
#   'IKZF2',
#   'MS4A1',
#   'PAX5',
#   'CIITA',
#   'SLCO5A1',
#   'EBF1',
#   'MTSS1',
#   'IFIT3',
#   'PDE7B',
#   'WDFY4',
#   'CD79A',
#   'FCRL1',
#   'BIRC3',
#   'SAMD4A',
#   'BCL2',
#   'MCTP2',
#   'DMD',
#   'POU2AF1'],
#  'Donor10_B Naive_IFN-gamma': ['MTSS1',
#   'EBF1',
#   'WDFY4',
#   'ENTPD1',
#   'COL19A1',
#   'HVCN1',
#   'IKZF2',
#   'LINC02964',
#   'BLK',
#   'MCTP2',
#   'LYN',
#   'CD83',
#   'ARHGAP24',
#   'CD38',
#   'HDAC9',
#   'KHDRBS2',
#   'ADAM19',
#   'COBLL1',
#   'IRF8',
#   'TNFRSF13C'],
#  'Donor10_B Naive_IFN-lambda1': ['SLCO5A1',
#   'BIRC3',
#   'LINC02245',
#   'PAX5',
#   'IGHD',
#   'MS4A1',
#   'TMCC3',
#   'IKZF2',
#   '7SK',
#   'PDE7B',
#   'RSAD2',
#   'IFIT3',
#   'MOXD1',
#   'ZC3H12B',
#   'LINC02964',
#   'CCSER1',
#   'WARS1',
#   'KYNU',
#   'PKIG',
#   'MCTP2'],
#  'Donor10_B Naive_IFN-lambda2': ['7SK',
#   'MS4A1',
#   'SLCO5A1',
#   'RUBCNL',
#   'WARS1',
#   'CYBB',
#   'DENND5B',
#   'AFF3',
#   'CD83',
#   'LY6E-DT',
#   'NEXN',
#   'GFOD1',
#   'IFIT3',
#   'ENSG00000257275',
#   'CD79A',
#   'HLA-DRA',
#   'CAMK2D',
#   'TCF4',
#   'SLC38A11',
#   'RHEX'],
#  'Donor10_B Naive_IFN-lambda3': ['7SK',
#   'IGHD',
#   'TNFSF10',
#   'WDFY4',
#   'ISG15',
#   'PLEKHG1',
#   'ADAM28',
#   'COBLL1',
#   'RUBCNL',
#   'CD74',
#   'CYBB',
#   'CD79A',
#   'MARCHF3',
#   'SLCO5A1',
#   'SCN3A',
#   'IGHM',
#   'C12orf42',
#   'ADAM19',
#   'FCRL1',
#   'MCTP2'],
#  'Donor10_B Naive_IFN-omega': ['CD74',
#   'EBF1',
#   'MTSS1',
#   'IKZF2',
#   'HVCN1',
#   'WDFY4',
#   'CD38',
#   'ENTPD1',
#   'MCTP2',
#   'PDE4B',
#   'ARHGAP24',
#   'ENSG00000273118',
#   'HDAC9',
#   'LINC02964',
#   'CD83',
#   'LYN',
#   'PDE7B',
#   'LARGE1',
#   'PSD3',
#   'BLK'],
#  'Donor10_B Naive_IGF-1': ['7SK',
#   'CD74',
#   'IGHM',
#   'IGHD',
#   'SLCO5A1',
#   'BIRC3',
#   'AFF3',
#   'TNFSF10',
#   'CD83',
#   'PAX5',
#   'LINC01619',
#   'NAPSB',
#   'ENTPD1',
#   'RSAD2',
#   'WARS1',
#   'IFIT3',
#   'IGKC',
#   'IKZF2',
#   'ACSM3',
#   'BASP1'],
#  'Donor10_B Naive_IL-1-alpha': ['WDFY4',
#   'HLA-DRA',
#   'CD38',
#   'WARS1',
#   'BIRC3',
#   'IGKC',
#   'LINC02964',
#   'CXCL10',
#   'COL19A1',
#   'COBLL1',
#   'IRF8',
#   'IKZF2',
#   'BCL11A',
#   'ENSG00000224610',
#   'ADAM28',
#   'MCTP2',
#   'FCRL1',
#   'ARHGAP24',
#   'SLCO5A1',
#   'GNG7'],
#  'Donor10_B Naive_IL-1-beta': ['7SK',
#   'AFF3',
#   'PDE4D',
#   'TNFSF10',
#   'CD74',
#   'ADAM28',
#   'WDFY4',
#   'WARS1',
#   'COL19A1',
#   'CD38',
#   'BCL11A',
#   'LARGE1',
#   'COBLL1',
#   'LINC02245',
#   'LINC00926',
#   'CR2',
#   'RUBCNL',
#   'PTPRK',
#   'SLCO5A1',
#   'ADAM19'],
#  'Donor10_B Naive_IL-1Ra': ['7SK',
#   'TNFSF10',
#   'CD74',
#   'PDE4D',
#   'WARS1',
#   'AFF3',
#   'CD38',
#   'C16orf74',
#   'COL19A1',
#   'CCSER1',
#   'ENSG00000285744',
#   'RSAD2',
#   'NAPSB',
#   'LYN',
#   'C12orf42',
#   'FCRL1',
#   'SAMD4A',
#   'BCL11A',
#   'STAP1',
#   'PAX5'],
#  'Donor10_B Naive_IL-2': ['MCTP2',
#   'PDE4D',
#   'WDFY4',
#   'CD38',
#   'TNFSF10',
#   'WARS1',
#   'ADAM28',
#   'ZEB2',
#   'BCAR3',
#   'AFF3',
#   'COL19A1',
#   'BCL11A',
#   'PTK2',
#   'SEMA7A',
#   'EBF1',
#   'PDE4B',
#   'ENSG00000285744',
#   'COBLL1',
#   'LINC00926',
#   'ZDHHC14'],
#  'Donor10_B Naive_IL-3': ['CD74',
#   'IGHD',
#   'SETBP1',
#   'PDE4D',
#   'MTSS1',
#   'JAZF1',
#   'RALGPS2',
#   'IRF8',
#   'RUBCNL',
#   'SDK2',
#   'CIITA',
#   'ADAM19',
#   'HDAC9',
#   'CCSER1',
#   'MARCHF1',
#   'PAX5',
#   'LINC00926',
#   'TNS3',
#   'AUTS2',
#   'BCL2'],
#  'Donor10_B Naive_IL-5': ['CCSER1',
#   'WARS1',
#   'CD38',
#   'TNFSF10',
#   'COL19A1',
#   'AFF3',
#   'SAMD4A',
#   'PDE4D',
#   'BCL11A',
#   '7SK',
#   'PTPRK',
#   'ENSG00000285744',
#   'STAP1',
#   'LYN',
#   'LINC00926',
#   'OSBPL10',
#   'ZDHHC14',
#   'ROR1',
#   'C16orf74',
#   'IRF8'],
#  'Donor10_B Naive_IL-6': ['CD74',
#   '7SK',
#   'WARS1',
#   'PDE4D',
#   'COL19A1',
#   'LINC00926',
#   'CCSER1',
#   'HLA-DRA',
#   'DENND5B',
#   'BCL2',
#   'AFF3',
#   'BCAR3',
#   'MARCHF3',
#   'C16orf74',
#   'ZDHHC14',
#   'COBLL1',
#   'BASP1',
#   'LINC01811',
#   'PAX5',
#   'ENSG00000224610'],
#  'Donor10_B Naive_IL-7': ['TNFSF10',
#   'CD38',
#   'WARS1',
#   'WDFY4',
#   'PDE4D',
#   '7SK',
#   'LYN',
#   'AFF3',
#   'CXCL11',
#   'BCAR3',
#   'COL19A1',
#   'ADAM28',
#   'CXCL10',
#   'MCTP2',
#   'BCL11A',
#   'BIRC3',
#   'ENSG00000285744',
#   'ADAM19',
#   'PDE4B',
#   'RSAD2'],
#  'Donor10_B Naive_IL-8': ['7SK',
#   'PAX5',
#   'ISG15',
#   'CIITA',
#   'FCRL1',
#   'SLCO5A1',
#   'LINC02397',
#   'PDE7B',
#   'AUTS2',
#   'AOAH',
#   'ANKRD33B',
#   'DLEU1',
#   'ZDHHC14',
#   'C12orf42',
#   'RALGPS2',
#   'GEN1',
#   'MIR4432HG',
#   'ADAM19',
#   'LYN',
#   'CD22'],
#  'Donor10_B Naive_IL-9': ['7SK',
#   'CD74',
#   'HLA-DRA',
#   'ENSG00000240040',
#   'TMCC3',
#   'PALM2AKAP2',
#   'BCL2',
#   'LARGE1',
#   'CD79A',
#   'RAB30',
#   'RSAD2',
#   'NAPSB',
#   'ENSG00000291230',
#   'IGKC',
#   'FTL',
#   'ADAM19',
#   'ZDHHC14',
#   'LAMC1',
#   'CD83',
#   'IGHM'],
#  'Donor10_B Naive_IL-10': ['CCSER1',
#   'IFIT3',
#   'SAMD4A',
#   'EBF1',
#   'PDE4D',
#   'C16orf74',
#   'TNFSF10',
#   'ZDHHC14',
#   'COL19A1',
#   'AFF3',
#   'RSAD2',
#   'ENSG00000255240',
#   'SESN3',
#   'WARS1',
#   'LINC00926',
#   'OSBPL10',
#   'ENSG00000285744',
#   'IFIT2',
#   'TBC1D9',
#   'AFF2'],
#  'Donor10_B Naive_IL-11': ['CD74',
#   '7SK',
#   'SLCO5A1',
#   'IGHM',
#   'GRAMD1C',
#   'ADAM19',
#   'TTN',
#   'L3MBTL4',
#   'STAP1',
#   'TMCC3',
#   'IRF8',
#   'KYNU',
#   'E2F5',
#   'CAMK2D',
#   'ENSG00000285744',
#   'ZDHHC14',
#   'LINC02422',
#   'FNDC3B',
#   'OSBPL10',
#   'STEAP1B'],
#  'Donor10_B Naive_IL-12': ['7SK',
#   'WDFY4',
#   'COL19A1',
#   'CCSER1',
#   'ADAM19',
#   'CD38',
#   'IKZF2',
#   'SAMD4A',
#   'MTSS1',
#   'ADAM28',
#   'LINC02964',
#   'MCTP2',
#   'PKIG',
#   'ENSG00000285744',
#   'LINC00926',
#   'WARS1',
#   'PDE4B',
#   'TNFSF10',
#   'DMD',
#   'SLCO5A1'],
#  'Donor10_B Naive_IL-13': ['PALM2AKAP2',
#   'IFIT3',
#   'CCSER1',
#   'CD74',
#   'POU2AF1',
#   'CD83',
#   'ANKRD33B',
#   'KHDRBS2',
#   'EBF1',
#   'TNFSF10',
#   'HVCN1',
#   '7SK',
#   'SLC39A8',
#   'AFF3',
#   'FCER2',
#   'SAMD4A',
#   'ENSG00000285744',
#   'MEF2C',
#   'SETBP1',
#   'IFIT2'],
#  'Donor10_B Naive_IL-15': ['7SK',
#   'WDFY4',
#   'CD38',
#   'CD74',
#   'TNFSF10',
#   'WARS1',
#   'ENSG00000290020',
#   'MCTP2',
#   'PDE4D',
#   'COL19A1',
#   'PDE4B',
#   'MTSS1',
#   'BCL11A',
#   'ENTPD1',
#   'LYN',
#   'KHDRBS2',
#   'MARCHF1',
#   'ADAM19',
#   'PTK2',
#   'EBF1'],
#  'Donor10_B Naive_IL-16': ['IGHM',
#   'CD74',
#   '7SK',
#   'CIITA',
#   'CCSER1',
#   'IFIT3',
#   'SESN3',
#   'C12orf42',
#   'LARGE1',
#   'ESR2',
#   'ZEB2',
#   'IGKC',
#   'TNFSF10',
#   'BLK',
#   'COL19A1',
#   'OSBPL10',
#   'LINC00926',
#   'WDFY4',
#   'PDE7B',
#   'C16orf74'],
#  'Donor10_B Naive_IL-17A': ['IGHD',
#   'FCRL1',
#   'ARHGAP24',
#   '7SK',
#   'MS4A1',
#   'CDK14',
#   'JAZF1',
#   'SLCO5A1',
#   'BCL2',
#   'ADAM19',
#   'CD79B',
#   'L3MBTL4',
#   'MACROD2',
#   'CTSS',
#   'IRF8',
#   'BANK1',
#   'POU2AF1',
#   'TTN',
#   'PDE4D',
#   'PAWR'],
#  'Donor10_B Naive_IL-17B': ['7SK',
#   'CD74',
#   'IFIT3',
#   'IGKC',
#   'IGHM',
#   'WDFY4',
#   'HLA-DRA',
#   'FTL',
#   'HLA-DRB1',
#   'EBF1',
#   'LINC02422',
#   'PDE4D',
#   'OSBPL10',
#   'LINC00926',
#   'RAPGEF5',
#   'C12orf42',
#   'FAM30A',
#   'HVCN1',
#   'MARCHF1',
#   'SAT1'],
#  'Donor10_B Naive_IL-17C': ['CD74',
#   '7SK',
#   'PDE4D',
#   'CCSER1',
#   'WARS1',
#   'WDFY4',
#   'COL19A1',
#   'HLA-DRA',
#   'CD38',
#   'ZDHHC14',
#   'TNFSF10',
#   'OSBPL10',
#   'ENSG00000285744',
#   'IGKC',
#   'DENND5B',
#   'GRAMD1C',
#   'HLA-DRB1',
#   'LINC01811',
#   'ISG15',
#   'BTLA'],
#  'Donor10_B Naive_IL-17D': ['7SK',
#   'CD74',
#   'ADAM19',
#   'SLCO5A1',
#   'IFIT3',
#   'CD38',
#   'SAMD4A',
#   'HLA-DRB1',
#   'ENSG00000289963',
#   'ADAM7-AS1',
#   'IGKC',
#   'IFIT2',
#   'NAPSB',
#   'TNFRSF13C',
#   'MCTP2',
#   'PDE4D',
#   'PAX5',
#   'WARS1',
#   'LY6E-DT',
#   'IRF8'],
#  'Donor10_B Naive_IL-17E': ['CD74',
#   'TCF4',
#   'HLA-DRA',
#   'IGKC',
#   '7SK',
#   'ISG15',
#   'AUTS2',
#   'WDFY4',
#   'MEF2C',
#   'MARCHF1',
#   'SLC38A4-AS1',
#   'LINC01572',
#   'LARGE1',
#   'TMCC3',
#   'RHEX',
#   'CTSS',
#   'DMD',
#   'LRRK2',
#   'IFIT3',
#   'IRF8'],
#  'Donor10_B Naive_IL-17F': ['7SK',
#   'LYN',
#   'IFIT3',
#   'ZDHHC14',
#   'IGKC',
#   'ARHGAP24',
#   'HLA-DRB1',
#   'IGHM',
#   'ISG15',
#   'PDE4D',
#   'TNFSF10',
#   'C12orf42',
#   'COL19A1',
#   'SLCO5A1',
#   'HLA-DRA',
#   'ST6GALNAC3',
#   'BTLA',
#   'SAT1',
#   'CD74',
#   'WARS1'],
#  'Donor10_B Naive_IL-18': ['IGHM',
#   'IFIT3',
#   'CD74',
#   'SAMD4A',
#   'SLCO5A1',
#   'PDE4D',
#   'IFIT2',
#   'WARS1',
#   'STAP1',
#   'ISG15',
#   'TNFSF10',
#   'MCTP2',
#   'PAX5',
#   'SAT1',
#   'LYN',
#   'COBLL1',
#   'AFF3',
#   'NAPSB',
#   'HLA-DRA',
#   'ADAM19'],
#  'Donor10_B Naive_IL-19': ['7SK',
#   'IGHM',
#   'IFIT3',
#   'BLK',
#   'IGKC',
#   'LRRK2',
#   'LYN',
#   'CIITA',
#   'CD74',
#   'BTLA',
#   'C16orf74',
#   'HLA-DRA',
#   'ISG15',
#   'SYT17',
#   'OSBPL10',
#   'SETBP1',
#   'BIRC3',
#   'COBLL1',
#   'COL19A1',
#   'KLHL14'],
#  'Donor10_B Naive_IL-20': ['7SK',
#   'PDE4D',
#   'LINC00926',
#   'PDE7B',
#   'COL19A1',
#   'MTSS1',
#   'FAM30A',
#   'ZDHHC14',
#   'C16orf74',
#   'CD74',
#   'C12orf42',
#   'IFIT3',
#   'SETBP1',
#   'TTN',
#   'SLCO5A1',
#   'FCRL1',
#   'IGKC',
#   'PALM2AKAP2',
#   'BLK',
#   'IRF8'],
#  'Donor10_B Naive_IL-21': ['7SK',
#   'EBF1',
#   'ARHGAP24',
#   'PDE4D',
#   'BCL2',
#   'SETBP1',
#   'ADAM28',
#   'CD74',
#   'BANK1',
#   'MARCHF1',
#   'MCTP2',
#   'WDFY4',
#   'CR2',
#   'PTPRK',
#   'WARS1',
#   'COL19A1',
#   'JAZF1',
#   'CCSER1',
#   'ZEB2',
#   'IFI30'],
#  'Donor10_B Naive_IL-22': ['7SK',
#   'ADAM28',
#   'MS4A1',
#   'SLCO5A1',
#   'IFIT3',
#   'CD74',
#   'PCDH9',
#   'ANKRD33B',
#   'ADAM7-AS1',
#   'SAMD4A',
#   'CTSS',
#   'AFF3',
#   'ABCB4',
#   'TCF4',
#   'MTSS1',
#   'UBE2E2',
#   'LYN',
#   'BTLA',
#   'AUTS2',
#   'LINC02397'],
#  'Donor10_B Naive_IL-23': ['SLCO5A1',
#   'WDFY4',
#   'CD38',
#   'ADAM19',
#   'CCSER1',
#   'IGHD',
#   'HLA-DRB1',
#   'COL19A1',
#   'PDE4B',
#   'IRF8',
#   'SAMD4A',
#   'CD74',
#   'BASP1',
#   'ADAM28',
#   'PALM2AKAP2',
#   'RSAD2',
#   'COBLL1',
#   'IGHM',
#   'WARS1',
#   'IFIT3'],
#  'Donor10_B Naive_IL-24': ['7SK',
#   'PDE4D',
#   'ADAM28',
#   'AFF3',
#   'C12orf42',
#   'CD74',
#   'SESN3',
#   'ADAM19',
#   'IGHM',
#   'IKZF2',
#   'PDE4B',
#   'SCN3A',
#   'CD22',
#   'ESR2',
#   'LINC00926',
#   'COBLL1',
#   'NAV2',
#   'ZDHHC14',
#   'PKIG',
#   'E2F5'],
#  'Donor10_B Naive_IL-26': ['CD38',
#   'COL19A1',
#   'WARS1',
#   'TNFSF10',
#   'BCL11A',
#   'IFIT3',
#   'CCSER1',
#   'COBLL1',
#   'ZDHHC14',
#   'C12orf42',
#   'C16orf74',
#   'AFF3',
#   'SAMD4A',
#   'CD74',
#   'PDE4D',
#   'DENND5B',
#   'MCTP2',
#   'ADAM19',
#   'PTPRK',
#   'LYN'],
#  'Donor10_B Naive_IL-27': ['7SK',
#   'AFF3',
#   'OSBPL10',
#   'COL19A1',
#   'FCRL2',
#   'LYN',
#   'ZEB2',
#   'SLCO5A1',
#   'LINC02422',
#   'TMCC3',
#   'FAM30A',
#   'PSAP',
#   'LINC00926',
#   'PDE7B',
#   'ZDHHC14',
#   'KYNU',
#   'ENSG00000224610',
#   'ISG15',
#   'IGKC',
#   'RAPGEF5'],
#  'Donor10_B Naive_IL-31': ['7SK',
#   'CD74',
#   'WARS1',
#   'SLCO5A1',
#   'FCRL1',
#   'BCL2',
#   'PDE4D',
#   'WDFY4',
#   'HVCN1',
#   'LARGE1',
#   'DENND5B',
#   'CD79B',
#   'SYT17',
#   'COL19A1',
#   'ADAM19',
#   'MS4A1',
#   'SETBP1',
#   'BCL11A',
#   'FCRL3',
#   'NAPSB'],
#  'Donor10_B Naive_IL-32-beta': ['CCSER1',
#   'EBF1',
#   'IFIT3',
#   'TNFSF10',
#   'SAMD4A',
#   'SETBP1',
#   'ZDHHC14',
#   'RSAD2',
#   'BCL2',
#   'IFIT2',
#   'BANK1',
#   'PLEKHG1',
#   'CD38',
#   'C16orf74',
#   'ENSG00000255240',
#   'ADAM19',
#   'CD83',
#   'PDE4D',
#   'TBC1D9',
#   'ISG15'],
#  'Donor10_B Naive_IL-33': ['CD74',
#   'HLA-DRB1',
#   'PDE4D',
#   'SLCO5A1',
#   'BCL2',
#   'CD22',
#   'HLA-DRA',
#   'IFIT3',
#   'ENSG00000289963',
#   'DENND5B',
#   'PTPRK',
#   'PAX5',
#   'MTSS1',
#   'LYN',
#   'AFF3',
#   'PSD3',
#   'NAV2',
#   'GAB1',
#   'PCDH9',
#   'IFI30'],
#  'Donor10_B Naive_IL-34': ['ADAM28',
#   'WDFY4',
#   'ADAM19',
#   'SAMD4A',
#   'PDE4D',
#   'BCL11A',
#   'MARCHF1',
#   'COL19A1',
#   'TNFSF10',
#   'LINC00926',
#   'PLEKHG1',
#   'NIBAN3',
#   'COBLL1',
#   'ZDHHC14',
#   'FCRL1',
#   'CAMK2D',
#   'ATP10D',
#   'BIRC3',
#   'RUBCNL',
#   'SESN3'],
#  'Donor10_B Naive_IL-35': ['SLCO5A1',
#   'CD74',
#   '7SK',
#   'CD83',
#   'IRF8',
#   'RSAD2',
#   'RALGPS2',
#   'IGHM',
#   'TMCC3',
#   'CD38',
#   'IKZF2',
#   'ANKRD33B',
#   'LINC02397',
#   'MARCHF1',
#   'TNFSF10',
#   'WDFY4',
#   'CXCL10',
#   'HLA-DRA',
#   'CD22',
#   'MEF2C'],
#  'Donor10_B Naive_IL-36-alpha': ['IGHM',
#   'CD74',
#   'CYBB',
#   'ADAM19',
#   'LINC02422',
#   '7SK',
#   'CCSER1',
#   'IRF8',
#   'RSAD2',
#   'PTPRK',
#   'ENSG00000285744',
#   'PTK2',
#   'WDFY4',
#   'L3MBTL4',
#   'AFF3',
#   'BCAR3',
#   'ADAM28',
#   'SETBP1',
#   'WARS1',
#   'KYNU'],
#  'Donor10_B Naive_IL-36Ra': ['7SK',
#   'IGHM',
#   'CIITA',
#   'LINC00926',
#   'CD74',
#   'IGKC',
#   'ZDHHC14',
#   'KYNU',
#   'BLK',
#   'CYBB',
#   'SLCO5A1',
#   'CNR2',
#   'IFIT3',
#   'TTN',
#   'POU2AF1',
#   'ENSG00000285744',
#   'OSBPL10',
#   'ADAM19',
#   'LINC02422',
#   'CD68'],
#  'Donor10_B Naive_LIF': ['7SK',
#   'TNFSF10',
#   'CD38',
#   'WDFY4',
#   'TCF4',
#   'ADAM19',
#   'ENSG00000285744',
#   'RSAD2',
#   'CD79B',
#   'PTK2',
#   'WARS1',
#   'COL19A1',
#   'RALGPS2',
#   'SAMD4A',
#   'BCL11A',
#   'NIBAN3',
#   'LINC00926',
#   'CR2',
#   'LINC02245',
#   'CCSER1'],
#  'Donor10_B Naive_LIGHT': ['SLCO5A1',
#   '7SK',
#   'CD74',
#   'WDFY4',
#   'PPFIBP1',
#   'CD83',
#   'IRF8',
#   'AUTS2',
#   'PTK2',
#   'CD38',
#   'ANKRD33B',
#   'TTN',
#   'CR2',
#   'CYBB',
#   'ADAM19',
#   'MS4A1',
#   'BIRC3',
#   'HLA-DRB1',
#   'FTL',
#   'LINC01619'],
#  'Donor10_B Naive_LT-alpha1-beta2': ['7SK',
#   'TNFSF10',
#   'CD74',
#   'WARS1',
#   'SAMD4A',
#   'BCL11A',
#   'CD38',
#   'LYN',
#   'IFIT3',
#   'COL19A1',
#   'PAX5',
#   'NAPSB',
#   'PDE4D',
#   'ADAM19',
#   'WDFY4',
#   'SESN3',
#   'IFIT2',
#   'IRF8',
#   'PTPRK',
#   'ENSG00000285744'],
#  'Donor10_B Naive_LT-alpha2-beta1': ['7SK',
#   'SLCO5A1',
#   'CD74',
#   'PDE7B',
#   'MCTP2',
#   'SESN3',
#   'MEF2C',
#   'IGKC',
#   'TNFSF10',
#   'HLA-DRA',
#   'PDE4D',
#   'LARGE1',
#   'SAT1',
#   'IGHM',
#   'DENND5B',
#   'C12orf42',
#   'OSBPL10',
#   'CD83',
#   'COL19A1',
#   'CD79A'],
#  'Donor10_B Naive_Leptin': ['IGHM',
#   'IGHD',
#   'IFIT3',
#   'CD74',
#   'SAT1',
#   'C16orf74',
#   '7SK',
#   'WARS1',
#   'AFF3',
#   'IFIT2',
#   'COBLL1',
#   'CCSER1',
#   'SLCO5A1',
#   'GNG7',
#   'CIITA',
#   'HLA-DRB1',
#   'TNFSF10',
#   'C12orf42',
#   'CD38',
#   'ENSG00000254777'],
#  'Donor10_B Naive_M-CSF': ['7SK',
#   'MACROD2',
#   'ADAM28',
#   'ISG15',
#   'EBF1',
#   'COL19A1',
#   'BCL2',
#   'FCRL1',
#   'PDE4D',
#   'ENSG00000290020',
#   'TMCC3',
#   'AFF3',
#   'SETBP1',
#   'SAMD4A',
#   'RSAD2',
#   'BTLA',
#   'DLEU1',
#   'SAT1',
#   'CD74',
#   'SESN3'],
#  'Donor10_B Naive_Noggin': ['7SK',
#   'SLCO5A1',
#   'SAMD4A',
#   'IFIT3',
#   'L3MBTL4',
#   'CD74',
#   'ADAM19',
#   'FAM30A',
#   'IGHD',
#   'LINC01619',
#   'ADAM28',
#   'IRF8',
#   'ISG15',
#   'PAX5',
#   'TTN',
#   'TMCC3',
#   'RAB30',
#   'CD83',
#   'WDFY4',
#   'LY6E-DT'],
#  'Donor10_B Naive_OSM': ['CD74',
#   '7SK',
#   'IGHM',
#   'HLA-DRA',
#   'LINC02422',
#   'CD83',
#   'IGKC',
#   'FCRL2',
#   'IKZF2',
#   'ZEB2',
#   'SLCO5A1',
#   'GRAMD1C',
#   'ARHGAP24',
#   'LRRK2',
#   'RAB30',
#   'IGHD',
#   'LYN',
#   'BTLA',
#   'ROR1',
#   'ENSG00000224610'],
#  'Donor10_B Naive_OX40L': ['CD74',
#   'WDFY4',
#   'PDE4D',
#   'ADAM28',
#   'PTK2',
#   'MCTP2',
#   'WARS1',
#   'CD38',
#   'MS4A1',
#   'COBLL1',
#   'PTPRK',
#   'PAX5',
#   'CR2',
#   'AFF3',
#   'TNFSF10',
#   'FCRL2',
#   'LYN',
#   'SLCO5A1',
#   'ZDHHC14',
#   'ENSG00000285744'],
#  'Donor10_B Naive_PRL': ['AFF3',
#   'WARS1',
#   'CCSER1',
#   'STRBP',
#   'ENSG00000287100',
#   'CXCL10',
#   'CYBB',
#   'ADAM28',
#   'ADAM19',
#   'HLA-DRB1',
#   'LINC02397',
#   'SAMD4A',
#   'SLCO5A1',
#   'PLEKHG1',
#   'RSAD2',
#   'COL19A1',
#   'IGHM',
#   'GNG7',
#   'TNFSF10',
#   'NAPSB'],
#  'Donor10_B Naive_PSPN': ['7SK',
#   'CD74',
#   'TNFSF10',
#   'SLCO5A1',
#   'PDE4D',
#   'ENSG00000227486',
#   'NAPSB',
#   'CR2',
#   'ZEB2',
#   'PAX5',
#   'TTN',
#   'PDE4B',
#   'IKZF2',
#   'MIR4432HG',
#   'C12orf42',
#   'IFIT3',
#   'LINC02384',
#   'COL19A1',
#   'DMD',
#   'STEAP1B'],
#  'Donor10_B Naive_RANKL': ['CD74',
#   'TNFSF10',
#   'HLA-DRB1',
#   'IRF8',
#   'SLCO5A1',
#   '7SK',
#   'SAMD4A',
#   'CD22',
#   'ENSG00000285744',
#   'IFIT3',
#   'BASP1',
#   'PDE4D',
#   'MCTP2',
#   'WARS1',
#   'CR2',
#   'ENSG00000287100',
#   'ENSG00000289963',
#   'HLA-DRA',
#   'IGHM',
#   'WDFY4'],
#  'Donor10_B Naive_SCF': ['CD74',
#   'RSAD2',
#   'CCSER1',
#   'IGHM',
#   'TMCC3',
#   'LAMP3',
#   'IGHD',
#   'LINC02422',
#   'CD38',
#   'PALM2AKAP2',
#   'HLA-DRA',
#   'SLCO5A1',
#   'SAMD4A',
#   'CAMK2D',
#   'HLA-DRB1',
#   'KHDRBS2',
#   'MIR4432HG',
#   'MIR155HG',
#   'IRF8',
#   'ADAM19'],
#  'Donor10_B Naive_TGF-beta1': ['CD74',
#   'PAX5',
#   'LINC02422',
#   'C12orf42',
#   'PDE7B',
#   'GEN1',
#   'IGKC',
#   'CCSER1',
#   'MACROD2',
#   'DMD',
#   'TCF4',
#   'ZC3H12B',
#   'PDE4D',
#   'SESN3',
#   'ZEB2',
#   'ACSM3',
#   'SYT9-AS1',
#   'ENSG00000254777',
#   'GFOD1',
#   'CD83'],
#  'Donor10_B Naive_TL1A': ['7SK',
#   'TNFSF10',
#   'WDFY4',
#   'ADAM19',
#   'WARS1',
#   'AFF3',
#   'CD74',
#   'CD38',
#   'COL19A1',
#   'PDE4D',
#   'IRF8',
#   'CXCL10',
#   'SESN3',
#   'RSAD2',
#   'SAMD4A',
#   'CCSER1',
#   'LYN',
#   'LAMP3',
#   'PLEKHG1',
#   'ADAM28'],
#  'Donor10_B Naive_TNF-alpha': ['7SK',
#   'CD74',
#   'ARHGAP24',
#   'IFIT3',
#   'COBLL1',
#   'CAMK2D',
#   'IGKC',
#   'STRBP',
#   'BLK',
#   'TMCC3',
#   'CD83',
#   'TNFSF10',
#   'CD79A',
#   'JAZF1',
#   'RHEX',
#   'SLC38A4-AS1',
#   'IFIT2',
#   'GRAMD1C',
#   'SESN3',
#   'ENTPD1'],
#  'Donor10_B Naive_TPO': ['7SK',
#   'CD74',
#   'IGHM',
#   'ISG15',
#   'SLCO5A1',
#   'PAX5',
#   'CD79A',
#   'HLA-DRB1',
#   'SAMD4A',
#   'HLA-DRA',
#   'FCRL1',
#   'RSAD2',
#   'PLEKHG1',
#   'ENSG00000227486',
#   'TNFSF10',
#   'SCN3A',
#   'ENSG00000285744',
#   'DENND5B',
#   'SESN3',
#   'P2RY14'],
#  'Donor10_B Naive_TRAIL': ['7SK',
#   'CD74',
#   'IGHM',
#   'IFIT3',
#   'NIBAN3',
#   'BCL2',
#   'CD83',
#   'PDE4D',
#   'HVCN1',
#   'BLK',
#   'HLA-DRA',
#   'CIITA',
#   'MTSS1',
#   'IGKC',
#   'STRBP',
#   'FCRL1',
#   'ZEB2',
#   'LINC01619',
#   'PCDH9',
#   'ENSG00000261218'],
#  'Donor10_B Naive_TSLP': ['7SK',
#   'IRF8',
#   'SAMD4A',
#   'WDFY4',
#   'CD74',
#   'BCL11A',
#   'TNFSF10',
#   'ADAM19',
#   'ADAM28',
#   'PTK2',
#   'WARS1',
#   'STAP1',
#   'CD79B',
#   'COL19A1',
#   'SDK2',
#   'ZFAT',
#   'MEF2C',
#   'PAX5',
#   'LAMP3',
#   'IFIT2'],
#  'Donor10_B Naive_TWEAK': ['MCTP2',
#   'CD74',
#   'BCL2',
#   'IGHM',
#   'DENND5B',
#   'WARS1',
#   'STRBP',
#   'IGHD',
#   'SLCO5A1',
#   'CTSS',
#   'IFIT3',
#   'CCSER1',
#   'IRF8',
#   'LYN',
#   'PSAP',
#   'HLA-DRB1',
#   'BASP1',
#   'CD79A',
#   'CD22',
#   'ENSG00000287100'],
#  'Donor10_B Naive_VEGF': ['7SK',
#   'FCRL1',
#   'CD74',
#   'ADAM28',
#   'MS4A1',
#   'IGHD',
#   'WDFY4',
#   'SLCO5A1',
#   'RAPGEF5',
#   'PDE4D',
#   'ENSG00000287092',
#   'IGKC',
#   'BANK1',
#   'HDAC9',
#   'PSAP',
#   'HLA-DRA',
#   'ISG15',
#   'GNG7',
#   'DENND5B',
#   'MEF2C-AS1'],
#  'Donor10_B Intermediate/Memory_4-1BBL': ['CD74',
#   'RSAD2',
#   'SLCO5A1',
#   'GEN1',
#   'ATP10D',
#   'PLEKHG7',
#   '7SK',
#   'HLA-DRA',
#   'LARGE1',
#   'LINC02422',
#   'IFIT3',
#   'HVCN1',
#   'ANK3',
#   'TNFSF10',
#   'FAM30A',
#   'ISG15',
#   'ADAM19',
#   'EBF1',
#   'SAMD4A',
#   'CDK6'],
#  'Donor10_B Intermediate/Memory_ADSF': ['CD74',
#   'AUTS2',
#   'LYZ',
#   'LRRK2',
#   'CDK6',
#   'HLA-DRA',
#   'PLEKHG1',
#   'IL7',
#   'ENSG00000285744',
#   'RSAD2',
#   '7SK',
#   'CTSB',
#   'ANK3',
#   'KHDRBS2',
#   'MAST4',
#   'LINC01619',
#   'BLK',
#   'ISG15',
#   'PDE4B',
#   'NLGN4Y'],
#  'Donor10_B Intermediate/Memory_APRIL': ['7SK',
#   'WARS1',
#   'CD74',
#   'AFF3',
#   'TNFSF10',
#   'LYN',
#   'SAMD4A',
#   'OSBPL10',
#   'SESN3',
#   'CD38',
#   'BCL11A',
#   'PRKN',
#   'CD22',
#   'TBC1D9',
#   'NAPSB',
#   'WDFY4',
#   'LINC00926',
#   'COL19A1',
#   'ISG15',
#   'ARHGAP24'],
#  'Donor10_B Intermediate/Memory_BAFF': ['7SK',
#   'IFIT3',
#   'BIRC3',
#   'SETBP1',
#   'IFIT2',
#   'OSBPL10',
#   'TNFSF10',
#   'ADAM28',
#   'WDFY4',
#   'SEMA7A',
#   'TTN',
#   'GPM6A',
#   'CIITA',
#   'SAMD4A',
#   'DENND5B',
#   'BCAR3',
#   'CALD1',
#   'SNED1',
#   'RFC3',
#   'CR2'],
#  'Donor10_B Intermediate/Memory_C3a': ['IFIT2',
#   'SAT1',
#   'ZEB2',
#   'SETBP1',
#   'TNFRSF13C',
#   'ARHGAP24',
#   'MACROD2',
#   'SLC9A7',
#   'IFIT3',
#   'IRF8',
#   'STAP1',
#   'NAPSB',
#   'ENTPD1',
#   'TNFSF10',
#   'LAMP3',
#   'IFNLR1',
#   'C12orf42',
#   '7SK',
#   'CYBB',
#   'IGHM'],
#  'Donor10_B Intermediate/Memory_C5a': ['7SK',
#   'ENTPD1',
#   'LINC02964',
#   'PAX5',
#   'SESN3',
#   'WDFY4',
#   'ADAM28',
# ...
#   'SRGAP3',
#   'THBS1',
#   'KLRC1',
#   'CTSW',
#   'ENSG00000251600',
#   'CYTH3',
#   'CD74',
#   'RUNX2',
#   'CMAHP',
#   'PDE4D',
#   'GZMB',
#   'TYROBP',
#   'IL2RB',
#   'TRD-AS1',
#   'KLRC3',
#   'STRBP',
#   'TRDC',
#   'ENSG00000273118'],
#  'Donor10_CD56-bright NK_IL-17C': ['7SK',
#   'CD74',
#   'PRF1',
#   'CTSW',
#   'IL2RB',
#   'WARS1',
#   'ITGA1',
#   'IFIT2',
#   'ENSG00000272369',
#   'LINC02384',
#   'GFOD1',
#   'TNFSF10',
#   'PALM2AKAP2',
#   'IRAK3',
#   'SAMD3',
#   'SLCO5A1',
#   'ATP8B4',
#   'RSAD2',
#   'ZMAT4',
#   'MED12L'],
#  'Donor10_CD56-bright NK_IL-17D': ['CD74',
#   'PRF1',
#   'IL2RB',
#   'SLC38A4-AS1',
#   'ENSG00000237356',
#   'CTSC',
#   'TNFSF10',
#   'ISG15',
#   'FASLG',
#   'NCALD',
#   'SLCO5A1',
#   'ENSG00000287100',
#   'TOX',
#   'CHN2',
#   '7SK',
#   'GSTCD',
#   'L3MBTL4',
#   'PLEK',
#   'GFOD1',
#   'LINC00426'],
#  'Donor10_CD56-bright NK_IL-17E': ['ISG15',
#   'HVCN1',
#   'KLRC1',
#   'CD74',
#   'PALM2AKAP2',
#   'FASLG',
#   'ADGRG3',
#   'CNNM2',
#   'CNR2',
#   'CTSS',
#   'TBXAS1',
#   'LINC01036',
#   'LIMK2',
#   'LARGE1',
#   'PYHIN1',
#   'NKG7',
#   'BANK1',
#   'ENSG00000237356',
#   'MAML3',
#   'LINC00996'],
#  'Donor10_CD56-bright NK_IL-17F': ['7SK',
#   'NELL2',
#   'IKZF2',
#   'NKG7',
#   'IL18RAP',
#   'ZMAT4',
#   'CYTH3',
#   'CMSS1',
#   'PLEK',
#   'PPP1R9A',
#   'ENSG00000273118',
#   'MAML3',
#   'ADGRG5',
#   'ELOVL6',
#   'ENSG00000228334',
#   'RAB27B',
#   'LINC00299',
#   'PTK2',
#   'FASLG',
#   'LRMDA'],
#  'Donor10_CD56-bright NK_IL-18': ['GFOD1',
#   'SLCO5A1',
#   'GNLY',
#   'PALM2AKAP2',
#   'GZMB',
#   'IFIT2',
#   'ENSG00000273118',
#   '7SK',
#   'KLRD1',
#   'CTSS',
#   'LINC01036',
#   'PDE7B',
#   'CD300A',
#   'PPP1R9A',
#   'PLEK',
#   'MT2A',
#   'PDE4B',
#   'GZMA',
#   'ENSG00000287100',
#   'LYN'],
#  'Donor10_CD56-bright NK_IL-19': ['7SK',
#   'PTGDR',
#   'IL12RB2',
#   'ISG15',
#   'RSAD2',
#   'TRGC2',
#   'AOAH',
#   'SPECC1',
#   'LINC00299',
#   'TNFRSF11A',
#   'BIRC3',
#   'TARP',
#   'ENSG00000273118',
#   'PPP2R2B',
#   'KLRC4-KLRK1',
#   'CD74',
#   'MTHFD1L',
#   'FNIP2',
#   'ADGRG5',
#   'CTSW'],
#  'Donor10_CD56-bright NK_IL-20': ['PTGDR',
#   'MCTP2',
#   'PDE7B',
#   'CD300A',
#   'ISG15',
#   'MRPL33',
#   'FASLG',
#   'LINC01814',
#   'TGFBR3',
#   'CTSW',
#   'PALM2AKAP2',
#   'MAML3',
#   'PDE4B',
#   'SPECC1',
#   'IL12RB2',
#   'CCL5',
#   'ENSG00000273118',
#   'FAR2',
#   'SLAMF7',
#   'YPEL1'],
#  'Donor10_CD56-bright NK_IL-21': ['7SK',
#   'KLRC1',
#   'PPP2R2B',
#   'IL18RAP',
#   'ZBTB16',
#   'CTSW',
#   'GZMB',
#   'CTSC',
#   'SAMD12',
#   'AUTS2',
#   'EXT1',
#   'ENSG00000228334',
#   'ZNRF1',
#   'ISG15',
#   'LRMDA',
#   'GAS7',
#   'PDGFD',
#   'IL12RB2',
#   'ATP8B4',
#   'GZMA'],
#  'Donor10_CD56-bright NK_IL-22': ['CD38',
#   'KIT',
#   'SLAMF7',
#   'IL12RB2',
#   'IL2RB',
#   'PDE7B',
#   'IFIT3',
#   'NCALD',
#   'EOMES',
#   'ENSG00000273118',
#   'SLCO5A1',
#   'SRGAP3',
#   'LYN',
#   'ITGA1',
#   'TCF4',
#   'PDE4B',
#   'RNF165',
#   'KIF26B',
#   'ENSG00000251600',
#   'LINC02964'],
#  'Donor10_CD56-bright NK_IL-23': ['SLCO5A1',
#   'IFIT3',
#   'KLRC3',
#   'CTSC',
#   'ENSG00000232855',
#   'CD74',
#   'LAMP3',
#   'LDB2',
#   'NELL2',
#   'ISG15',
#   'LINC00996',
#   'KCNQ5',
#   'SAMD3',
#   'TNFSF10',
#   'EFCAB2',
#   'SLAMF7',
#   'FASLG',
#   'RUNX2',
#   'DYSF',
#   'PDE4D'],
#  'Donor10_CD56-bright NK_IL-24': ['7SK',
#   'LDB2',
#   'MAML3',
#   'CMSS1',
#   'ADGRG5',
#   'SAMD12',
#   'CCSER1',
#   'PLXDC2',
#   'EXT1',
#   'GAS7',
#   'TTTY14',
#   'ENSG00000289359',
#   'CTSS',
#   'IFIT3',
#   'CDK6',
#   'FASLG',
#   'NCALD',
#   'L3MBTL4',
#   'ATP8B4',
#   'CYSLTR1'],
#  'Donor10_CD56-bright NK_IL-27': ['ENSG00000232855',
#   'KLRD1',
#   'NELL2',
#   'IL7R',
#   'GZMB',
#   'PAWR',
#   'RAB27B',
#   'CD38',
#   'SLCO5A1',
#   'AOAH',
#   'CYTH3',
#   'KLRC2',
#   'STAP1',
#   'CAMK2D',
#   'ISG15',
#   'TYROBP',
#   'TTTY14',
#   'IL18RAP',
#   'IFIT2',
#   'KCNQ5'],
#  'Donor10_CD56-bright NK_IL-31': ['CD74',
#   '7SK',
#   'PTGDR',
#   'TARP',
#   'CTSC',
#   'TBXAS1',
#   'SAMD3',
#   'GZMB',
#   'TRDC',
#   'SLCO5A1',
#   'LINC01871',
#   'GSTCD',
#   'ATP10D',
#   'NCR1',
#   'LINC00996',
#   'WARS1',
#   'SYTL2',
#   'JAZF1',
#   'HVCN1',
#   'COLGALT2'],
#  'Donor10_CD56-bright NK_IL-32-beta': ['RSAD2',
#   'IFIT3',
#   'IL12RB2',
#   'ISG15',
#   'CD38',
#   'ENTPD1',
#   'ENSG00000232855',
#   'MTSS1',
#   'IFIT2',
#   'TOX2',
#   'PALM2AKAP2',
#   'PDE4D',
#   'DUSP4',
#   'TNFSF10',
#   'EXT1',
#   'FNDC3B',
#   'ITGA1',
#   'KIF26B',
#   'ZNRF1',
#   'GAS7'],
#  'Donor10_CD56-bright NK_IL-33': ['KLRD1',
#   'NCR1',
#   'ZMAT4',
#   'SLCO5A1',
#   'HVCN1',
#   'ACSL1',
#   'TYROBP',
#   'JAZF1',
#   'CCSER1',
#   'CD74',
#   'CHN2',
#   'ZEB2',
#   'FASLG',
#   'ENSG00000273118',
#   'UBE2E2',
#   'SLC39A8',
#   'PTK2',
#   'WARS1',
#   'CDK6',
#   'KIF26B'],
#  'Donor10_CD56-bright NK_IL-34': ['TNFSF10',
#   'RUNX2',
#   'TOX',
#   'ELOVL6',
#   'TMEM241',
#   'IL18RAP',
#   'TTTY14',
#   'GZMA',
#   'SLCO5A1',
#   'IRAK3',
#   'PDE4B',
#   'PTGDR',
#   'PLCB1',
#   'TGFBR3',
#   'ZMAT4',
#   'NCALD',
#   'SAMD3',
#   'LYN',
#   'ATP10D',
#   'GSTCD'],
#  'Donor10_CD56-bright NK_IL-35': ['SLCO5A1',
#   'GNLY',
#   '7SK',
#   'FNDC3B',
#   'CD38',
#   'MYBL1',
#   'IL7R',
#   'SAMD3',
#   'ENTPD1',
#   'ZEB2',
#   'ADGRG5',
#   'TCF4',
#   'NEPRO-AS1',
#   'LINC00299',
#   'PALM2AKAP2',
#   'RNF165',
#   'ENSG00000224905',
#   'TGFBR3',
#   'ZDHHC14',
#   'ZBTB16'],
#  'Donor10_CD56-bright NK_IL-36-alpha': ['ZEB2',
#   'IL18RAP',
#   'KLRC2',
#   'ENSG00000232855',
#   'RUNX2',
#   'GAS7',
#   'KLRC3',
#   'IL2RB',
#   'ENSG00000273118',
#   'L3MBTL4',
#   'SLC38A4-AS1',
#   'FAM13A',
#   'ITGA1',
#   'ADAM28',
#   'FASLG',
#   'NCAM1',
#   'LINC01934',
#   'FNIP2',
#   'TRD-AS1',
#   'LINC00996'],
#  'Donor10_CD56-bright NK_IL-36Ra': ['7SK',
#   'TARP',
#   'PSAP',
#   'MIR646HG',
#   'PDE4D',
#   'SLCO5A1',
#   'KLRC4-KLRK1',
#   'ENSG00000228334',
#   'CMAHP',
#   'IL12RB2',
#   'PPP1R9A',
#   'CCNJL',
#   'RAB27B',
#   'PACSIN1',
#   'GZMB',
#   'LINC00996',
#   'ENSG00000273118',
#   'WHRN',
#   'NCALD',
#   'CABLES1'],
#  'Donor10_CD56-bright NK_LIF': ['7SK',
#   'TNFSF10',
#   'PYHIN1',
#   'ATP8B4',
#   'CD38',
#   'IFIT3',
#   'CTSC',
#   'SLCO5A1',
#   'ENSG00000232855',
#   'SGO1-AS1',
#   'ZEB2',
#   'KLRC3',
#   'CNR2',
#   'ENSG00000227240',
#   'MCTP2',
#   'ENSG00000287100',
#   'SAT1',
#   'FASLG',
#   'CCSER1',
#   'KLRC4-KLRK1'],
#  'Donor10_CD56-bright NK_LIGHT': ['SLCO5A1',
#   '7SK',
#   'PDE4D',
#   'PPP1R9A',
#   'CD74',
#   'FASLG',
#   'PALM2AKAP2',
#   'LDB2',
#   'ENSG00000232855',
#   'LINC01934',
#   'IL18RAP',
#   'FHIT',
#   'RSAD2',
#   'IL12RB2',
#   'LY6E-DT',
#   'ZBTB16',
#   'IRF8',
#   'MARCHF3',
#   'LRMDA',
#   'EXT1'],
#  'Donor10_CD56-bright NK_LT-alpha1-beta2': ['IL12RB2',
#   'IFIT2',
#   'PALM2AKAP2',
#   'RSAD2',
#   'GAS7',
#   'LDB2',
#   'CD38',
#   'AOAH',
#   'PTGDR',
#   'GNLY',
#   'MCTP2',
#   '7SK',
#   'LINC00996',
#   'MYBL1',
#   'FASLG',
#   'IL7R',
#   'CRIM1',
#   'BCL2',
#   'JAZF1',
#   'IFIT3'],
#  'Donor10_CD56-bright NK_LT-alpha2-beta1': ['SLCO5A1',
#   'CD74',
#   '7SK',
#   'SLAMF7',
#   'PTGDR',
#   'ADGRG5',
#   'PRF1',
#   'KLRF1',
#   'LDB2',
#   'CCSER1',
#   'IFIT3',
#   'PTK2',
#   'FNIP2',
#   'IFIT2',
#   'IGFBP7',
#   'EOMES',
#   'TRGC2',
#   'TAFA2',
#   'LINC00996',
#   'GZMA'],
#  'Donor10_CD56-bright NK_Leptin': ['IL2RB',
#   'PTK2',
#   'IFIT2',
#   'IL12RB2',
#   'CYTH3',
#   'GZMB',
#   'PLEK',
#   'CNR2',
#   'RGS5',
#   'FNDC3B',
#   'NFXL1',
#   'GSTCD',
#   'MTHFD1L',
#   'WARS1',
#   'CD300A',
#   'RNF165',
#   'ENSG00000286797',
#   'KIF26B',
#   'TGFBR3',
#   'EXT1'],
#  'Donor10_CD56-bright NK_M-CSF': ['7SK',
#   'MYBL1',
#   'PYHIN1',
#   'PDE7B',
#   'JAZF1',
#   'SRGAP3',
#   'CTSW',
#   'RSAD2',
#   'ISG15',
#   'CDK6',
#   'ADGRG5',
#   'TNFSF10',
#   'GZMB',
#   'NCR1',
#   'KLRC1',
#   'GSTCD',
#   'PDGFD',
#   'PRF1',
#   'TRDC',
#   'PTGDR'],
#  'Donor10_CD56-bright NK_Noggin': ['7SK',
#   'SLCO5A1',
#   'PPP2R2B',
#   'KLRC3',
#   'ISG15',
#   'PSAP',
#   'FASLG',
#   'LINC01934',
#   'KLRC4-KLRK1',
#   'GAS7',
#   'LINC00299',
#   'IL12RB2',
#   'MIR646HG',
#   'CCL5',
#   'RUNX2',
#   'GNLY',
#   'PLCB1',
#   'TTN',
#   'KIAA1671',
#   'CD244'],
#  'Donor10_CD56-bright NK_OSM': ['7SK',
#   'CD74',
#   'IL2RB',
#   'CTSW',
#   'MCTP2',
#   'CD300A',
#   'AFF3',
#   'KLRC4-KLRK1',
#   'ENSG00000227240',
#   'ISG15',
#   'GAS7',
#   'KLRC3',
#   'INPP4B',
#   'IL7R',
#   'LYN',
#   'GZMB',
#   'CAMK2D',
#   'SLCO5A1',
#   'PRF1',
#   'MYBL1'],
#  'Donor10_CD56-bright NK_OX40L': ['CD74',
#   'FASLG',
#   'CMAHP',
#   'IFIT3',
#   'SH2D1B',
#   'SAT1',
#   'KLRC4-KLRK1',
#   'CD244',
#   'WARS1',
#   'KCNQ5',
#   'ENSG00000232855',
#   'LINC02384',
#   'NELL2',
#   'AOAH',
#   'LINC00996',
#   'C1orf21',
#   'AFF3',
#   'NCR1',
#   'ENSG00000237356',
#   'PYHIN1'],
#  'Donor10_CD56-bright NK_PRL': ['PPP2R2B',
#   'GFOD1',
#   'ENSG00000232855',
#   'GZMB',
#   'STRBP',
#   'SLCO5A1',
#   'ALOX12P2-1',
#   'ATP8B4',
#   'SAMD3',
#   'TNFSF10',
#   'MAML3',
#   'CD38',
#   'LDB2',
#   'SLAMF7',
#   'PACSIN1',
#   'PLCB1',
#   'ENSG00000285835',
#   'KLRC1',
#   'CTSW',
#   'C1orf21'],
#  'Donor10_CD56-bright NK_PSPN': ['7SK',
#   'CD74',
#   'ENSG00000227240',
#   'CAMK2D',
#   'AFF3',
#   'PLEKHA5',
#   'PRF1',
#   'LRMDA',
#   'CTSW',
#   'PTGDR',
#   'LINC01934',
#   'PLEK',
#   'TNR',
#   'SLCO5A1',
#   'CTSS',
#   'FNDC3B',
#   'STAP1',
#   'RGS5',
#   'LDB2',
#   'JAZF1'],
#  'Donor10_CD56-bright NK_RANKL': ['CD74',
#   'AOAH',
#   'LYN',
#   'NCALD',
#   'GFOD1',
#   'SLCO5A1',
#   'GZMB',
#   'TNR',
#   'WARS1',
#   'PDE4B',
#   'ENSG00000226640',
#   '7SK',
#   'IL18RAP',
#   'NCAM1',
#   'PRF1',
#   'PLCB1',
#   'MTHFD1L',
#   'DPF3',
#   'JAZF1',
#   'KLRD1'],
#  'Donor10_CD56-bright NK_SCF': ['KLRC2',
#   'SLCO5A1',
#   'AFF3',
#   'FNDC3B',
#   'CTSC',
#   'PDE4D',
#   'GAS7',
#   'PYHIN1',
#   'CABLES1',
#   'IL12RB2',
#   'JAZF1',
#   'ACSL1',
#   'SAMD3',
#   'DUSP4',
#   'MT2A',
#   'PPP2R2B',
#   'IFIT3',
#   'ZEB2',
#   'ENSG00000232855',
#   'CTSD'],
#  'Donor10_CD56-bright NK_TGF-beta1': ['CTSC',
#   'CD300A',
#   'AUTS2',
#   'IL12RB2',
#   'GNLY',
#   'ATP8B4',
#   'IL2RB',
#   'MCTP2',
#   'SPRY3',
#   'PRR5',
#   'ZEB2',
#   'ADAM28',
#   'PLXNA4',
#   'BCAR3',
#   'TRD-AS1',
#   'IKZF2',
#   'CD38',
#   'PDE4B',
#   'MAST4',
#   'KLRB1'],
#  'Donor10_CD56-bright NK_TL1A': ['7SK',
#   'CD38',
#   'IFIT3',
#   'LAMP3',
#   'TNFSF10',
#   'FASLG',
#   'PDE4D',
#   'CD74',
#   'TCF4',
#   'PRF1',
#   'IFIT2',
#   'WARS1',
#   'SH2D1B',
#   'LDB2',
#   'CIITA',
#   'RNF165',
#   'L3MBTL4',
#   'HIF1A-AS3',
#   'ZDHHC14',
#   'TYROBP'],
#  'Donor10_CD56-bright NK_TNF-alpha': ['CTSC',
#   '7SK',
#   'INPP4B',
#   'ENSG00000232855',
#   'CD74',
#   'PLEK',
#   'FASLG',
#   'CTSW',
#   'KLRC1',
#   'RUNX2',
#   'AP1S3',
#   'SLCO5A1',
#   'KLRC3',
#   'COLGALT2',
#   'PRF1',
#   'SLC8A1',
#   'PDE4D',
#   'TTTY14',
#   'TTTY10',
#   'GFOD1'],
#  'Donor10_CD56-bright NK_TPO': ['IL12RB2',
#   'CD74',
#   '7SK',
#   'PDE4B',
#   'GZMB',
#   'THBS1',
#   'CCSER1',
#   'SLCO5A1',
#   'KLRC1',
#   'GSTCD',
#   'PALM2AKAP2',
#   'IL2RB',
#   'LINC01934',
#   'SAMD3',
#   'GAB1',
#   'LINC01619',
#   'CHN2',
#   'RNF165',
#   'PTGDR',
#   'IL7R'],
#  'Donor10_CD56-bright NK_TRAIL': ['7SK',
#   'CTSS',
#   'RSAD2',
#   'TYROBP',
#   'ISG15',
#   'CD74',
#   'GZMA',
#   'ENSG00000273118',
#   'HVCN1',
#   'ZBTB16',
#   'STYK1',
#   'LINC01871',
#   'NELL2',
#   'CTSC',
#   'AOAH',
#   'CYTH3',
#   'SAMD12',
#   'TGFBR3',
#   'NCAM1',
#   'LINC02422'],
#  'Donor10_CD56-bright NK_TSLP': ['7SK',
#   'FASLG',
#   'RNF165',
#   'MTHFD1L',
#   'MYBL1',
#   'FNDC3B',
#   'BIRC3',
#   'MCTP2',
#   'WARS1',
#   'TARP',
#   'IL2RB',
#   'TNFSF10',
#   'CMAHP',
#   'IRF8',
#   'ELOVL6',
#   'TRGC2',
#   'ENSG00000227486',
#   'ENSG00000251600',
#   'PDE4D',
#   'GZMB'],
#  'Donor10_CD56-bright NK_TWEAK': ['WARS1',
#   'CD74',
#   'SLCO5A1',
#   'AUTS2',
#   'C1orf21',
#   'JAZF1',
#   'TRGC2',
#   'TRDC',
#   'MTHFD1L',
#   'GFOD1',
#   'LINC02964',
#   'ISG15',
#   'TOX',
#   'PTK2',
#   'CDK6',
#   'GZMB',
#   'MYBL1',
#   'GSTCD',
#   'IRAK3',
#   'CD300A'],
#  'Donor10_CD56-bright NK_VEGF': ['7SK',
#   'SYTL2',
#   'LYN',
#   'IL12RB2',
#   'ENSG00000232855',
#   'AOAH',
#   'CD74',
#   'AUTS2',
#   'CDK6',
#   'PPP1R9A',
#   'TTN',
#   'SAT1',
#   'KCNQ5',
#   'PAWR',
#   'IL7R',
#   'PRF1',
#   'HVCN1',
#   'ITGA1',
#   'EXT1',
#   'SLCO5A1'],
#  'Donor10_MAIT_4-1BBL': ['SLCO5A1',
#   'AUTS2',
#   '7SK',
#   'TRBC1',
#   'ENSG00000232855',
#   'RSAD2',
#   'ADAM19',
#   'TSPAN5',
#   'NCALD',
#   'PSAP',
#   'INPP4B',
#   'NEXN',
#   'SAMD12',
#   'SLC4A10',
#   'PYHIN1',
#   'PRR5',
#   'ENSG00000237773',
#   'IFIT3',
#   'CDK6',
#   'CXCL10'],
#  'Donor10_MAIT_ADSF': ['IL7R',
#   'LINC01814',
#   'FNDC3B',
#   'SPON1',
#   'LYZ',
#   'CAMK2D',
#   'ZEB2',
#   'ARHGAP10',
#   'PLCB1',
#   'ANK3',
#   'UBE2E2',
#   'CTSB',
#   'MYBL1',
#   'RUNX2',
#   'LY6E-DT',
#   'ZDHHC14',
#   'SAT1',
#   'SAMD3',
#   'MCF2L2',
#   'TAFA2'],
#  'Donor10_MAIT_APRIL': ['IFIT3',
#   'ISG15',
#   'TNFSF10',
#   'RSAD2',
#   'SPON1',
#   'ZC3H12B',
#   'ENSG00000251600',
#   'ENSG00000232855',
#   'CSGALNACT1',
#   'UBE2E2',
#   'MT2A',
#   'IFIT2',
#   'CDHR3',
#   'PYHIN1',
#   'DYNC2H1',
#   'COL5A3',
#   'CD74',
#   'TMEM117',
#   'LINC00299',
#   'NEXN'],
#  'Donor10_MAIT_BAFF': ['IFIT3',
#   '7SK',
#   'IFIT2',
#   'MT2A',
#   'TRBC1',
#   'CTSB',
#   'ENSG00000249806',
#   'PRR5',
#   'BCL2',
#   'BIRC3',
#   'CMAHP',
#   'RSAD2',
#   'THEMIS',
#   'PPP2R2B',
#   'JAZF1',
#   'ISG15',
#   'IFI30',
#   'TSPAN5',
#   'CSGALNACT1',
#   'STX18-AS1'],
#  'Donor10_MAIT_C3a': ['7SK',
#   'TGFBR3',
#   'DPP4',
#   'ADAM19',
#   'TNFSF10',
#   'THEMIS',
#   'JAZF1',
#   'CD74',
#   'CEP112',
#   'ADAM23',
#   'SAMD3',
#   'CTSS',
#   'PALM2AKAP2',
#   'AGAP1',
#   'ENSG00000249806',
#   'LINC02384',
#   'LINC00299',
#   'C12orf40',
#   'ENSG00000226640',
#   'ISG15'],
#  'Donor10_MAIT_C5a': ['7SK',
#   'IL7R',
#   'LINC00299',
#   'CTSB',
#   'CMTM8',
#   'CMAHP',
#   'LINC02964',
#   'PDE4D',
#   'TRBC1',
#   'LTB',
#   'IL18RAP',
#   'IFIT2',
#   'ANK3',
#   'ENSG00000227240',
#   'LINC01814',
#   'SESN3',
#   'FAAH2',
#   'TSHZ2',
#   'KANK1',
#   'ENSG00000272369'],
#  'Donor10_MAIT_CD27L': ['7SK',
#   'ISG15',
#   'SLCO5A1',
#   'SAT1',
#   'TGFBR3',
#   'THEMIS',
#   'MT2A',
#   'JAZF1',
#   'LTB',
#   'SPON1',
#   'ENSG00000227240',
#   'CD74',
#   'DAB1',
#   'SESN3',
#   'LYN',
#   'CTSS',
#   'CFAP298-TCP10L',
#   'PTPRM',
#   'ZDHHC14',
#   'ARHGAP10'],
#  'Donor10_MAIT_CD30L': ['7SK',
#   'LAMP3',
#   'CAMK2D',
#   'ZC3H12B',
#   'AFF3',
#   'CTSC',
#   'CMTM8',
#   'CMSS1',
#   'SLC4A10',
#   'PPP2R2B',
#   'ENSG00000232855',
#   'SLC38A4-AS1',
#   'ST8SIA1',
#   'ADAM12',
#   'IL7R',
#   'ZDHHC14',
#   'SYTL2',
#   'IFIT3',
#   'WARS1',
#   'LINC01934'],
#  'Donor10_MAIT_CD40L': ['7SK',
#   'IFIT3',
#   'ANK3',
#   'PDE4B',
#   'IFIT2',
#   'RSAD2',
#   'THEMIS',
#   'FTH1',
#   'DLEU1',
#   'PALM2AKAP2',
#   'ENSG00000272369',
#   'ST8SIA1',
#   'ACSL1',
#   'MAST4',
#   'CMAHP',
#   'IL18RAP',
#   'ABCC4',
#   'CTSS',
#   'AUTS2',
#   'NCALD'],
#  'Donor10_MAIT_CT-1': ['7SK',
#   'ISG15',
#   'IL7R',
#   'MYBL1',
#   'CMAHP',
#   'SLCO5A1',
#   'PPP2R2B',
#   'TMEM117',
#   'TGFBR3',
#   'CTSB',
#   'IFIT3',
#   'ENSG00000249806',
#   'FRY',
#   'SLC4A10',
#   'PRKN',
#   'SLC39A8',
#   'IGSF9B',
#   'ZEB2',
#   'NELL2',
#   'TSHZ2'],
#  'Donor10_MAIT_Decorin': ['RUNX2',
#   'SLCO5A1',
#   'CMAHP',
#   'LYZ',
#   '7SK',
#   'LINC00299',
#   'LTB',
#   'PRR5',
#   'STX18-AS1',
#   'BCL2',
#   'BIRC3',
#   'SAMD4A',
#   'PDE4B',
#   'SAT1',
#   'MCF2L2',
#   'MTHFD1L',
#   'TGFBR3',
#   'IL7R',
#   'IL2RB',
#   'KANK1'],
#  'Donor10_MAIT_EGF': ['7SK',
#   'FRY',
#   'SLCO5A1',
#   'SLC38A4-AS1',
#   'CMAHP',
#   'LYZ',
#   'RUNX2',
#   'PRR5',
#   'UBE2E2',
#   'THEMIS',
#   'CCR6',
#   'FGL2',
#   'LAMP3',
#   'MCF2',
#   'KLRB1',
#   'MYBL1',
#   'TSHZ2',
#   'FHIT',
#   'CFAP298-TCP10L',
#   'IL7R'],
#  'Donor10_MAIT_EPO': ['SLCO5A1',
#   'IFIT3',
#   'TNFSF10',
#   'CD74',
#   'SAT1',
#   'PYHIN1',
#   'AUTS2',
#   'LAMP3',
#   'IFIT2',
#   'CSGALNACT1',
#   'NELL2',
#   'ENSG00000227240',
#   'TGFBR3',
#   'ISG15',
#   'ENSG00000227486',
#   '7SK',
#   'ENSG00000232855',
#   'SLC8A1',
#   'ADAM23',
#   'PKIA'],
#  'Donor10_MAIT_FGF-beta': ['SLCO5A1',
#   'FTH1',
#   'LAMP3',
#   'PLEKHG1',
#   'LINC01619',
#   'IL7R',
#   'CTSB',
#   'DAB1',
#   'LINC01814',
#   'IL2RB',
#   'BIRC3',
#   'FNDC3B',
#   'BCL2',
#   '7SK',
#   'MT2A',
#   'FRG1-DT',
#   'IFIT3',
#   'ZDHHC14',
#   'TSPAN18',
#   'THEMIS'],
#  'Donor10_MAIT_FLT3L': ['SLCO5A1',
#   'TRBC1',
#   'LAMP3',
#   'ABTB3',
#   'KANK1',
#   'MT2A',
#   'CRADD',
#   'LINC02964',
#   'SAT1',
#   'SAMD4A',
#   'LGALS3',
#   'CD74',
#   'IATPR',
#   'THEMIS',
#   'IL12RB2',
#   'FTH1',
#   'CMAHP',
#   'SLC4A10',
#   'ADAM19',
#   'LINC00298'],
#  'Donor10_MAIT_FasL': ['7SK',
#   'ABTB3',
#   'FAR2',
#   'ISG15',
#   'MT2A',
#   'MCTP2',
#   'ZC3H12B',
#   'CMAHP',
#   'UBE2E2',
#   'DAB1',
#   'TSPAN5',
#   'SLCO5A1',
#   'SPON1',
#   'PTPRM',
#   'CFAP298-TCP10L',
#   'RBM47',
#   'PRKN',
#   'BIRC3',
#   'MYBL1',
#   'STAP1'],
#  'Donor10_MAIT_G-CSF': ['IFIT3',
#   'SPON1',
#   'ISG15',
#   'TGFBR3',
#   'SAMD3',
#   'TNFSF10',
#   'CMAHP',
#   'LINC01619',
#   'RSAD2',
#   'ADAM23',
#   'MT2A',
#   'FRY',
#   'CSGALNACT1',
#   'IFIT2',
#   'TMEM117',
#   'KANK1',
#   'TOX',
#   '7SK',
#   'DYNC2H1',
#   'ZC3H12B'],
#  'Donor10_MAIT_GDNF': ['ISG15',
#   'SLCO5A1',
#   'TNFSF10',
#   'IFIT3',
#   'RSAD2',
#   'LYZ',
#   'GREM2',
#   'CMAHP',
#   'ANK3',
#   'PYHIN1',
#   'KANK1',
#   'MCF2L2',
#   'TGFBR3',
#   'PDE4B',
#   'BCL2',
#   'JAZF1',
#   'PLEKHG1',
#   'PLD1',
#   'PTPN13',
#   'TRPC1'],
#  'Donor10_MAIT_GITRL': ['IFIT3',
#   'ISG15',
#   'RSAD2',
#   'IFIT2',
#   'FAR2',
#   'TGFBR3',
#   'TNFSF10',
#   'MYBL1',
#   'PDE4D',
#   'LAMP3',
#   '7SK',
#   'SLCO5A1',
#   'LINC01619',
#   'JAZF1',
#   'CTSS',
#   'MT2A',
#   'DYNC2H1',
#   'CYTH3',
#   'PLCB1',
#   'AUTS2'],
#  ...}

# %%
donor_deg_dict = {k: v for k, v in deg_genes.items() if (k.startswith(donor) and k.endswith(f"_{cytokine}"))}

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/metrics_new_donor.csv", index_col=0)
# Out:
# /tmp/ipykernel_1159630/1534787288.py:1: DtypeWarning: Columns (1,148,149,150,154,175) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/metrics_new_donor.csv", index_col=0)

# %%
df_scaling = pd.DataFrame(df.groupby(["method", "num_cytokines_in_train"])["mean_deg_r_sq_per_cell_type"].mean())
df_scaling = df_scaling.reset_index()

# %%
df_scaling = df_scaling[df_scaling["num_cytokines_in_train"]>0.0]

# %%
#df_scaling["log2_num_cytokines_in_train"] = df_scaling["num_cytokines_in_train"].apply(np.log2)
#df_scaling["log2_ood_e_distance"] = df_scaling["ood_e_distance"].apply(np.log2)

# %%
#df_scaling.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/scaling_law.csv")

# %%
df_scaling2 = df_scaling.copy()

# %%
#df_scaling2 = df_scaling2[df_scaling2["log2_num_cytokines_in_train"]>3.0]

# %%
#df_scaling2["method"] = df_scaling2.apply(lambda x: x["method"]+"_red", axis=1)

# %%
#df_all = pd.concat((df_scaling, df_scaling2), axis=0)

# %%
#df_all.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/scaling_law_two_curves.csv")

# %%
df_scaling.to_csv("/lustre/groups/ml01/workspace/ot_perturbation/data/pbmc/results/allocation/scaling_law_deg.csv")

# %%
df_scaling
# Out:
#     method  num_cytokines_in_train  mean_deg_r_sq_per_cell_type
# 1       cf                     1.0                     0.727203
# 2       cf                     2.0                     0.738973
# 3       cf                     4.0                     0.756960
# 4       cf                     8.0                     0.754822
# 5       cf                    16.0                     0.754471
# 6       cf                    32.0                     0.767971
# 7       cf                    64.0                     0.776131
# 8       cf                    80.0                     0.779681
# 10  cl_emb                     1.0                     0.673728
# 11  cl_emb                     2.0                     0.673728
# 12  cl_emb                     4.0                     0.673728
# 13  cl_emb                     8.0                     0.673728
# 14  cl_emb                    16.0                     0.673728
# 15  cl_emb                    32.0                     0.673728
# 16  cl_emb                    64.0                     0.673728
# 17  cl_emb                    80.0                     0.673728
# 19      id                     1.0                     0.646947
# 20      id                     2.0                     0.646947
# 21      id                     4.0                     0.646947
# 22      id                     8.0                     0.646947
# 23      id                    16.0                     0.646947
# 24      id                    32.0                     0.646947
# 25      id                    64.0                     0.646947
# 26      id                    80.0                     0.646947
# 27      m1                     1.0                     0.594556
# 28      m1                     2.0                     0.598224
# 29      m1                     4.0                     0.603971
# 30      m1                     8.0                     0.607380
# 31      m1                    16.0                     0.608993
# 32      m1                    32.0                     0.611769
# 33      m1                    64.0                     0.612944
# 34      m1                    80.0                     0.613183
# 36      m2                     1.0                     0.630036
# 37      m2                     2.0                     0.630036
# 38      m2                     4.0                     0.630036
# 39      m2                     8.0                     0.630036
# 40      m2                    16.0                     0.630036
# 41      m2                    32.0                     0.630036
# 42      m2                    64.0                     0.630036
# 43      m2                    80.0                     0.630036

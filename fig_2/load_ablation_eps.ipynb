# %%
import pandas as pd
import os

# %%
file_dir = "/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_epsilon"

# %%
files = os.listdir("/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_epsilon")

# %%
h5ad_files = [el for el in files if ".h5ad" in el]

# %%
import json

# %%
with open("/lustre/groups/ml01/workspace/ot_perturbation/models/otfm/pbmc_new_donor_ablation_epsilon.json", "w") as f:
    json.dump(h5ad_files, f)

# %%
len(h5ad_files)
# Out:
# 810
